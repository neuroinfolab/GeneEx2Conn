# %% [markdown]
# ## Sim Demo

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from imports import *

# %%
# overall imports
import importlib
import data

# importlib.reload(data.data_utils)
# importlib.reload(data.data_load)
# importlib.reload(sim.sim_utils)
# importlib.reload(sim)
# importlib.reload(models)

import models
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run, open_pickled_results

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))
# Out:
# CPU Usage: 29.4%
# RAM Usage: 8.8%
# Available RAM: 1.3T
# Total RAM: 1.5T
# 52.4G

# %%
print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)
# Out:
# XGBoost version: 2.0.3
# cupy version: 13.1.0

# %%
GPUtil.getAvailable()
# if a number is seen a GPU is available
# Out:
# [0]

# %%
GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None:
    print('GPU found', DEVICE_ID)
    use_gpu = True
# Out:
# GPU found 0

# %%
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |

# %%
torch.cuda.is_available()

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
print(torch.cuda.memory_allocated())
print(torch.cuda.max_memory_allocated())
# Out:
# 0
# 0

# %% [markdown]
# #### Simulation tests <a id="sims"></a>

# %%
# Run simulation
single_sim_run(
              cv_type='spatial',
              random_seed=1,
              model_type='shared_transformer',
              feature_type=[{'transcriptome': None}, 
                           {'euclidean': None}],
              connectome_target='FC',
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              omit_subcortical=False,
              parcellation='S400',
              gene_list='0.2',
              hemisphere='left',
              search_method=('wandb', 'mse', 3),
              save_sim=False,
              track_wandb=True, 
              skip_cv=True
              )

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Clear CPU memory
import gc
gc.collect()
# Out:
# Number of components for 95% variance PCA: 105
# X shape: (214, 7380)
# X_pca shape: (214, 105)
# Y_sc shape: (214, 214)
# Y_sc_spectralL shape: (214, 222)
# Y_sc_spectralA shape: (214, 223)
# Y_fc shape: (214, 214)
# Coordinates shape: (214, 3)
# Y shape (214, 214)
# Network coverage: 100.0% of regions
# Network sizes: [53, 53, 53, 55]
# feature_name:  transcriptome
# processing_type:  None
# feature_name:  euclidean
# processing_type:  None
# X shape (214, 7383)
#
#  Test fold num: 1 X_train shape: (25760, 14766) Y_train shape: (25760,) X_test shape: (2756, 14766) Y_test shape: (2756,)
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/notebook/utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
#
# ERROR: Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: asratzan (alexander-ratzan-new-york-university). Use `wandb login --relogin` to force relogin
# 2
# 3
# 4
# BEST CONFIG {'input_dim': 14766, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0521, Val Loss: 0.0403
# Epoch 5/75, Train Pearson: 0.2219, Val Pearson: 0.3743
# Epoch 10/75, Train Loss: 0.0318, Val Loss: 0.0396
# Epoch 10/75, Train Pearson: 0.4241, Val Pearson: 0.4054
# Epoch 15/75, Train Loss: 0.0273, Val Loss: 0.0389
# Epoch 15/75, Train Pearson: 0.5289, Val Pearson: 0.3930
# Epoch 20/75, Train Loss: 0.0249, Val Loss: 0.0382
# Epoch 20/75, Train Pearson: 0.5848, Val Pearson: 0.4462
# Epoch 25/75, Train Loss: 0.0219, Val Loss: 0.0432
# Epoch 25/75, Train Pearson: 0.6499, Val Pearson: 0.4005
# Epoch 30/75, Train Loss: 0.0180, Val Loss: 0.0530
# Epoch 30/75, Train Pearson: 0.7262, Val Pearson: 0.3578
# Epoch 35/75, Train Loss: 0.0117, Val Loss: 0.0767
# Epoch 35/75, Train Pearson: 0.8352, Val Pearson: 0.3121
# Epoch 40/75, Train Loss: 0.0086, Val Loss: 0.0591
# Epoch 40/75, Train Pearson: 0.8829, Val Pearson: 0.3898
# Epoch 45/75, Train Loss: 0.0073, Val Loss: 0.0558
# Epoch 45/75, Train Pearson: 0.9031, Val Pearson: 0.4047
# Epoch 50/75, Train Loss: 0.0062, Val Loss: 0.0433
# Epoch 50/75, Train Pearson: 0.9178, Val Pearson: 0.4821
# Epoch 55/75, Train Loss: 0.0060, Val Loss: 0.0461
# Epoch 55/75, Train Pearson: 0.9205, Val Pearson: 0.4766
# Epoch 60/75, Train Loss: 0.0059, Val Loss: 0.0443
# Epoch 60/75, Train Pearson: 0.9230, Val Pearson: 0.5028
# Epoch 65/75, Train Loss: 0.0054, Val Loss: 0.0429
# Epoch 65/75, Train Pearson: 0.9306, Val Pearson: 0.5130
# Epoch 70/75, Train Loss: 0.0051, Val Loss: 0.0439
# Epoch 70/75, Train Pearson: 0.9345, Val Pearson: 0.4815
# Epoch 75/75, Train Loss: 0.0049, Val Loss: 0.0395
# Epoch 75/75, Train Pearson: 0.9371, Val Pearson: 0.5252
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.013374365551239742, 'mae': 0.07212589250023507, 'r2': 0.6460708025383033, 'pearson_corr': 0.8235790017597856, 'geodesic_distance': 12.205411143866064}
# TEST METRICS: {'mse': 0.039563382810292265, 'mae': 0.15174593799180602, 'r2': 0.0683036304898067, 'pearson_corr': 0.525062573508916, 'geodesic_distance': 7.242160231610135}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7383, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:89: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112656633162663, max=1.0…
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_142326-ka9fnjej</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ka9fnjej' target="_blank">shared_transformer_transcriptome+euclidean_FC_spatial_fold0_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ka9fnjej' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ka9fnjej</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▁▂▁▁▁▁▂▁▁▂▁▁▂▂▂▃▄▄▂▇█▄▄▃▄▃▂▂▃▂▂▂▂▂▂▂▂▁▁▁</td></tr><tr><td>test_pearson</td><td>▅▁▄▄▅▅▆▄▅▆▅▅▅▅▅▅▇▅▆▅▆▅▇▆▅▇▆▇▇▆▇▇█▇▇██▇██</td></tr><tr><td>train_mse_loss</td><td>█▅▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▁▂▂▃▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.03949</td></tr><tr><td>test_pearson</td><td>0.52521</td></tr><tr><td>train_mse_loss</td><td>0.00488</td></tr><tr><td>train_pearson</td><td>0.93707</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome+euclidean_FC_spatial_fold0_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ka9fnjej' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ka9fnjej</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_142326-ka9fnjej/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 22.1%
# RAM Usage: 10.6%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  5% |
#
#  Test fold num: 2 X_train shape: (25760, 14766) Y_train shape: (25760,) X_test shape: (2756, 14766) Y_test shape: (2756,)
# 1
# 3
# 4
# BEST CONFIG {'input_dim': 14766, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0501, Val Loss: 0.0532
# Epoch 5/75, Train Pearson: 0.3340, Val Pearson: 0.3511
# Epoch 10/75, Train Loss: 0.0252, Val Loss: 0.0606
# Epoch 10/75, Train Pearson: 0.5727, Val Pearson: 0.2251
# Epoch 15/75, Train Loss: 0.0197, Val Loss: 0.0639
# Epoch 15/75, Train Pearson: 0.6796, Val Pearson: 0.1676
# Epoch 20/75, Train Loss: 0.0165, Val Loss: 0.0519
# Epoch 20/75, Train Pearson: 0.7417, Val Pearson: 0.2974
# Epoch 25/75, Train Loss: 0.0133, Val Loss: 0.0480
# Epoch 25/75, Train Pearson: 0.7990, Val Pearson: 0.3848
# Epoch 30/75, Train Loss: 0.0103, Val Loss: 0.0473
# Epoch 30/75, Train Pearson: 0.8492, Val Pearson: 0.4241
# Epoch 35/75, Train Loss: 0.0082, Val Loss: 0.0465
# Epoch 35/75, Train Pearson: 0.8847, Val Pearson: 0.4223
# Epoch 40/75, Train Loss: 0.0068, Val Loss: 0.0441
# Epoch 40/75, Train Pearson: 0.9054, Val Pearson: 0.4609
# Epoch 45/75, Train Loss: 0.0060, Val Loss: 0.0426
# Epoch 45/75, Train Pearson: 0.9177, Val Pearson: 0.4968
# Epoch 50/75, Train Loss: 0.0056, Val Loss: 0.0432
# Epoch 50/75, Train Pearson: 0.9231, Val Pearson: 0.4928
# Epoch 55/75, Train Loss: 0.0053, Val Loss: 0.0435
# Epoch 55/75, Train Pearson: 0.9283, Val Pearson: 0.5004
# Epoch 60/75, Train Loss: 0.0049, Val Loss: 0.0454
# Epoch 60/75, Train Pearson: 0.9345, Val Pearson: 0.4629
# Epoch 65/75, Train Loss: 0.0048, Val Loss: 0.0444
# Epoch 65/75, Train Pearson: 0.9369, Val Pearson: 0.4895
# Epoch 70/75, Train Loss: 0.0044, Val Loss: 0.0439
# Epoch 70/75, Train Pearson: 0.9420, Val Pearson: 0.4930
# Epoch 75/75, Train Loss: 0.0043, Val Loss: 0.0455
# Epoch 75/75, Train Pearson: 0.9428, Val Pearson: 0.4741
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.006572996790349932, 'mae': 0.057001378330357365, 'r2': 0.8196121277482132, 'pearson_corr': 0.9182717336844807, 'geodesic_distance': 11.248545358001769}
# TEST METRICS: {'mse': 0.04553110808376859, 'mae': 0.17136434243909018, 'r2': 0.186348660118558, 'pearson_corr': 0.47259660769398215, 'geodesic_distance': 7.437243177467608}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7383, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_143627-09y03zgr</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/09y03zgr' target="_blank">shared_transformer_transcriptome+euclidean_FC_spatial_fold1_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/09y03zgr' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/09y03zgr</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▄▄▃▄▅██▇▆▇▂▃▂▁▃▂▃▂▃▂▂▂▁▁▁▁▂▂▂▂▂▃▂▂▂▁▁▁▁▂</td></tr><tr><td>test_pearson</td><td>▃▅▄▄▅▅▃▃▂▁▃▃▄▆▅▅▇▆▆▆▆▇▇▇▇▇██▇▇▇█▇▇▇▇██▇█</td></tr><tr><td>train_mse_loss</td><td>█▅▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▂▃▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.0455</td></tr><tr><td>test_pearson</td><td>0.47414</td></tr><tr><td>train_mse_loss</td><td>0.00433</td></tr><tr><td>train_pearson</td><td>0.94278</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome+euclidean_FC_spatial_fold1_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/09y03zgr' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/09y03zgr</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_143627-09y03zgr/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 46.1%
# RAM Usage: 12.0%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  9% |
#
#  Test fold num: 3 X_train shape: (25760, 14766) Y_train shape: (25760,) X_test shape: (2756, 14766) Y_test shape: (2756,)
# 1
# 2
# 4
# BEST CONFIG {'input_dim': 14766, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0449, Val Loss: 0.0454
# Epoch 5/75, Train Pearson: 0.2858, Val Pearson: 0.5910
# Epoch 10/75, Train Loss: 0.0249, Val Loss: 0.0500
# Epoch 10/75, Train Pearson: 0.5211, Val Pearson: 0.5391
# Epoch 15/75, Train Loss: 0.0198, Val Loss: 0.0400
# Epoch 15/75, Train Pearson: 0.6440, Val Pearson: 0.6875
# Epoch 20/75, Train Loss: 0.0158, Val Loss: 0.0368
# Epoch 20/75, Train Pearson: 0.7291, Val Pearson: 0.6990
# Epoch 25/75, Train Loss: 0.0121, Val Loss: 0.0356
# Epoch 25/75, Train Pearson: 0.8016, Val Pearson: 0.7138
# Epoch 30/75, Train Loss: 0.0093, Val Loss: 0.0314
# Epoch 30/75, Train Pearson: 0.8538, Val Pearson: 0.7419
# Epoch 35/75, Train Loss: 0.0073, Val Loss: 0.0285
# Epoch 35/75, Train Pearson: 0.8886, Val Pearson: 0.7719
# Epoch 40/75, Train Loss: 0.0061, Val Loss: 0.0307
# Epoch 40/75, Train Pearson: 0.9080, Val Pearson: 0.7619
# Epoch 45/75, Train Loss: 0.0060, Val Loss: 0.0311
# Epoch 45/75, Train Pearson: 0.9102, Val Pearson: 0.7690
# Epoch 50/75, Train Loss: 0.0052, Val Loss: 0.0360
# Epoch 50/75, Train Pearson: 0.9225, Val Pearson: 0.7588
# Epoch 55/75, Train Loss: 0.0049, Val Loss: 0.0365
# Epoch 55/75, Train Pearson: 0.9280, Val Pearson: 0.7208
# Epoch 60/75, Train Loss: 0.0048, Val Loss: 0.0366
# Epoch 60/75, Train Pearson: 0.9310, Val Pearson: 0.7426
# Epoch 65/75, Train Loss: 0.0045, Val Loss: 0.0403
# Epoch 65/75, Train Pearson: 0.9345, Val Pearson: 0.7172
# Epoch 70/75, Train Loss: 0.0043, Val Loss: 0.0369
# Epoch 70/75, Train Pearson: 0.9379, Val Pearson: 0.7324
# Epoch 75/75, Train Loss: 0.0044, Val Loss: 0.0378
# Epoch 75/75, Train Pearson: 0.9374, Val Pearson: 0.7199
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.023361682583690056, 'mae': 0.10625289566835773, 'r2': 0.3038298288222906, 'pearson_corr': 0.6192893217611466, 'geodesic_distance': 13.842661442878338}
# TEST METRICS: {'mse': 0.03753819770491162, 'mae': 0.1363541740271427, 'r2': 0.4608829702116364, 'pearson_corr': 0.7211544499039244, 'geodesic_distance': 7.521452704307786}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7383, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_144928-ww8ozx2v</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ww8ozx2v' target="_blank">shared_transformer_transcriptome+euclidean_FC_spatial_fold2_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ww8ozx2v' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ww8ozx2v</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>▇▆▇█▆▄▄▄▅▅▃▃▁▂▂▁▂▁▂▁▁▂▂▂▂▃▂▄▄▂▄▃▃▅▃▄▄▃▄▄</td></tr><tr><td>test_pearson</td><td>▂▃▂▂▃▁▁▁▂▃▆▅▆▅▆▇█▇▇██▇█████▇▇▇▇▇▇▆▇▇▇▇▇▇</td></tr><tr><td>train_mse_loss</td><td>█▆▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▁▂▂▃▄▅▅▆▆▇▇▇▇▇█████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.03776</td></tr><tr><td>test_pearson</td><td>0.71994</td></tr><tr><td>train_mse_loss</td><td>0.00435</td></tr><tr><td>train_pearson</td><td>0.93744</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome+euclidean_FC_spatial_fold2_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ww8ozx2v' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ww8ozx2v</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_144928-ww8ozx2v/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 40.1%
# RAM Usage: 11.2%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  9% |
#
#  Test fold num: 4 X_train shape: (25122, 14766) Y_train shape: (25122,) X_test shape: (2970, 14766) Y_test shape: (2970,)
# 1
# 2
# 3
# BEST CONFIG {'input_dim': 14766, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0555, Val Loss: 0.0850
# Epoch 5/75, Train Pearson: 0.3174, Val Pearson: -0.1106
# Epoch 10/75, Train Loss: 0.0323, Val Loss: 0.0481
# Epoch 10/75, Train Pearson: 0.5179, Val Pearson: 0.1946
# Epoch 15/75, Train Loss: 0.0198, Val Loss: 0.0325
# Epoch 15/75, Train Pearson: 0.7365, Val Pearson: 0.2840
# Epoch 20/75, Train Loss: 0.0128, Val Loss: 0.0361
# Epoch 20/75, Train Pearson: 0.8412, Val Pearson: 0.2703
# Epoch 25/75, Train Loss: 0.0100, Val Loss: 0.0409
# Epoch 25/75, Train Pearson: 0.8794, Val Pearson: 0.2490
# Epoch 30/75, Train Loss: 0.0084, Val Loss: 0.0516
# Epoch 30/75, Train Pearson: 0.9012, Val Pearson: 0.1754
# Epoch 35/75, Train Loss: 0.0074, Val Loss: 0.0447
# Epoch 35/75, Train Pearson: 0.9147, Val Pearson: 0.2371
# Epoch 40/75, Train Loss: 0.0065, Val Loss: 0.0495
# Epoch 40/75, Train Pearson: 0.9262, Val Pearson: 0.2271
# Epoch 45/75, Train Loss: 0.0061, Val Loss: 0.0423
# Epoch 45/75, Train Pearson: 0.9311, Val Pearson: 0.2524
# Epoch 50/75, Train Loss: 0.0055, Val Loss: 0.0431
# Epoch 50/75, Train Pearson: 0.9378, Val Pearson: 0.2523
# Epoch 55/75, Train Loss: 0.0054, Val Loss: 0.0407
# Epoch 55/75, Train Pearson: 0.9391, Val Pearson: 0.2718
# Epoch 60/75, Train Loss: 0.0051, Val Loss: 0.0419
# Epoch 60/75, Train Pearson: 0.9435, Val Pearson: 0.2365
# Epoch 65/75, Train Loss: 0.0049, Val Loss: 0.0374
# Epoch 65/75, Train Pearson: 0.9456, Val Pearson: 0.2504
# Epoch 70/75, Train Loss: 0.0047, Val Loss: 0.0375
# Epoch 70/75, Train Pearson: 0.9486, Val Pearson: 0.2600
# Epoch 75/75, Train Loss: 0.0046, Val Loss: 0.0387
# Epoch 75/75, Train Pearson: 0.9487, Val Pearson: 0.2468
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.02655620003485145, 'mae': 0.11666665907148485, 'r2': 0.3817482457667358, 'pearson_corr': 0.6883400350680564, 'geodesic_distance': 10.730221848408819}
# TEST METRICS: {'mse': 0.03916986295826067, 'mae': 0.13969973538017796, 'r2': -0.22422825723960993, 'pearson_corr': 0.23663421813274504, 'geodesic_distance': 11.693241558813266}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7383, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_150215-qz3z26zn</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/qz3z26zn' target="_blank">shared_transformer_transcriptome+euclidean_FC_spatial_fold3_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/qz3z26zn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/qz3z26zn</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▃▃▃▂▂▂▂▁▁▁▁▁▁▂▂▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▂</td></tr><tr><td>test_pearson</td><td>▁▄▅▆▆▇█▇▇▆▆▆▆▅▆▅▆▆▇▆▆▇▇▇▆▆▇▇▇▆▆▆▇▅▅▅▇▆▆▆</td></tr><tr><td>train_mse_loss</td><td>█▅▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▂▂▃▃▅▅▆▆▇▇▇▇▇▇▇▇███████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.03874</td></tr><tr><td>test_pearson</td><td>0.24685</td></tr><tr><td>train_mse_loss</td><td>0.00463</td></tr><tr><td>train_pearson</td><td>0.94866</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome+euclidean_FC_spatial_fold3_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/qz3z26zn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/qz3z26zn</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_150215-qz3z26zn/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 22.3%
# RAM Usage: 11.0%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  9% |
# 90099

# %%
# Run simulation
single_sim_run(
              cv_type='spatial',
              random_seed=1,
              model_type='shared_transformer',
              feature_type=[{'transcriptome': None}, 
                           {'euclidean': None}],
              connectome_target='SC',
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              omit_subcortical=False,
              parcellation='S400',
              gene_list='0.2',
              hemisphere='left',
              search_method=('wandb', 'mse', 3),
              save_sim=False,
              track_wandb=True, 
              skip_cv=True
              )

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Clear CPU memory
import gc
gc.collect()
# Out:
# Number of components for 95% variance PCA: 105
# X shape: (214, 7380)
# X_pca shape: (214, 105)
# Y_sc shape: (214, 214)
# Y_sc_spectralL shape: (214, 222)
# Y_sc_spectralA shape: (214, 223)
# Y_fc shape: (214, 214)
# Coordinates shape: (214, 3)
# Y shape (214, 214)
# Network coverage: 100.0% of regions
# Network sizes: [53, 53, 53, 55]
# feature_name:  transcriptome
# processing_type:  None
# feature_name:  euclidean
# processing_type:  None
# X shape (214, 7383)
#
#  Test fold num: 1 X_train shape: (25760, 14766) Y_train shape: (25760,) X_test shape: (2756, 14766) Y_test shape: (2756,)
# 2
# 3
# 4
# BEST CONFIG {'input_dim': 14766, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 2.2372, Val Loss: 3.5060
# Epoch 5/75, Train Pearson: 0.6445, Val Pearson: 0.4514
# Epoch 10/75, Train Loss: 1.7446, Val Loss: 3.4748
# Epoch 10/75, Train Pearson: 0.7292, Val Pearson: 0.4585
# Epoch 15/75, Train Loss: 1.4249, Val Loss: 4.1913
# Epoch 15/75, Train Pearson: 0.7854, Val Pearson: 0.4515
# Epoch 20/75, Train Loss: 1.2089, Val Loss: 3.6941
# Epoch 20/75, Train Pearson: 0.8234, Val Pearson: 0.5149
# Epoch 25/75, Train Loss: 1.0762, Val Loss: 4.2787
# Epoch 25/75, Train Pearson: 0.8452, Val Pearson: 0.5008
# Epoch 30/75, Train Loss: 0.9708, Val Loss: 3.8209
# Epoch 30/75, Train Pearson: 0.8625, Val Pearson: 0.5087
# Epoch 35/75, Train Loss: 0.8947, Val Loss: 3.4885
# Epoch 35/75, Train Pearson: 0.8745, Val Pearson: 0.5093
