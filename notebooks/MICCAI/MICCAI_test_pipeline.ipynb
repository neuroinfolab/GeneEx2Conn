# %% [markdown]
# ## MICCAI Test Pipeline

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from imports import *

# %%
# overall imports
import importlib
import data

# importlib.reload(data.data_utils)
# importlib.reload(data.data_load)
#importlib.reload(sim.sim_utils)
# importlib.reload(models)

import models
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run, open_pickled_results

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))
# Out:
# CPU Usage: 18.8%
# RAM Usage: 9.2%
# Available RAM: 342.4G
# Total RAM: 377.1G
# 52.4G

# %%
print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)
# Out:
# XGBoost version: 2.0.3
# cupy version: 13.1.0

# %%
GPUtil.getAvailable()
# if a number is seen a GPU is available
# Out:
# []

# %%
GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 3
#       1 GPUtil.getGPUs()
# ----> 3 DEVICE_ID_LIST = GPUtil.getFirstAvailable()
#       4 DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
#       5 if DEVICE_ID != None:
#
# File /ext3/miniconda3/lib/python3.11/site-packages/GPUtil/GPUtil.py:203, in getFirstAvailable(order, maxLoad, maxMemory, attempts, interval, verbose, includeNan, excludeID, excludeUUID)
#     201 # Check if an GPU was found, or if the attempts simply ran out. Throw error, if no GPU was found
#     202 if (not(available)):
# --> 203     raise RuntimeError('Could not find an available GPU after ' + str(attempts) + ' attempts with ' + str(interval) + ' seconds interval.')
#     205 # Return found GPU
#     206 return available
#
# RuntimeError: Could not find an available GPU after 1 attempts with 900 seconds interval.

# %%
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  2% |

# %%
torch.cuda.is_available()

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Start test pipeline <a id="sims"></a>

# %%
def run_simulation_set(model_types=['dynamic_mlp'],
                      cv_types=['spatial', 'random'],
                      parcellations=['S100', 'S400'],
                      connectome_targets=['FC', 'SC'],
                      feature_types=['transcriptome', 'euclidean'],
                      hemisphere='left',
                      random_seeds=[42, 123, 456]):
    """
    Run a set of simulations with different combinations of parameters.
    
    Args:
        model_types (list): List of model types to test
        cv_types (list): List of cross-validation types
        parcellations (list): List of parcellation schemes
        connectome_targets (list): List of connectome targets
        feature_types (list): List of feature types
        hemisphere (str): Brain hemisphere to use ('left', 'right', 'both')
        random_seeds (list): List of random seeds for multiple runs
    """
    
    for seed in random_seeds:
        for model in model_types:
            for cv in cv_types:
                for parc in parcellations:
                    # Set hemisphere based on parcellation
                    current_hemisphere = 'both' if parc == 'S100' else 'left'
                    
                    for target in connectome_targets:
                        for feat in feature_types:
                            # Configure feature type dict
                            feat_dict = [{'transcriptome': None}] if feat == 'transcriptome' else [{'euclidean': None}]
                            
                            print(f"Running simulation with: {model}, {cv}, {parc}, {target}, {feat}, seed={seed}")
                            
                            # Run single simulation
                            single_sim_run(
                                cv_type=cv,
                                random_seed=seed,
                                model_type=model,
                                feature_type=feat_dict,
                                connectome_target=target,
                                use_gpu=True,
                                use_shared_regions=False,
                                test_shared_regions=False,
                                omit_subcortical=False,
                                parcellation=parc,
                                gene_list='0.2',
                                hemisphere=current_hemisphere,
                                search_method=('wandb', 'mse', 10),
                                save_sim=False,
                                track_wandb=True,
                                skip_cv=False
                            )
                            
                            # Clear GPU memory
                            if torch.cuda.is_available():
                                torch.cuda.empty_cache()
                            # Clear CPU memory
                            gc.collect()

# Example usage:
run_simulation_set(
    model_types=['dynamic_mlp'],
    cv_types=['random', 'spatial'],
    parcellations=['S100', 'S400'],
    connectome_targets=['FC', 'SC'],
    feature_types=['transcriptome', 'euclidean'],
    hemisphere='both',
    random_seeds=[1, 2]
)
# Out:
# Number of components for 95% variance PCA: 34
# X shape: (114, 10760)
# X_pca shape: (114, 34)
# Y_sc shape: (114, 114)
# Y_sc_spectralL shape: (114, 113)
# Y_sc_spectralA shape: (114, 114)
# Y_fc shape: (114, 114)
# Coordinates shape: (114, 3)
# Y shape (114, 114)
# feature_name:  transcriptome
# processing_type:  PCA
# X shape (114, 34)
#
#  Test fold num: 1 X_train shape: (7140, 68) Y_train shape: (7140,) X_test shape: (812, 68) Y_test shape: (812,)
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/notebook/utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
#
# ERROR: Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: asratzan (alexander-ratzan-new-york-university). Use `wandb login --relogin` to force relogin
# 2
# 3
# 4
# BEST CONFIG {'input_dim': 68, 'learning_rate': 0.002, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'epochs': 300}
# Number of learnable parameters in bilinear SCM layer: 1157
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 10/300, Train Loss: 4.4262, Val Loss: 42.5225
# Epoch 20/300, Train Loss: 0.9355, Val Loss: 19.2290
# Epoch 30/300, Train Loss: 0.3779, Val Loss: 13.0412
# Epoch 40/300, Train Loss: 0.2018, Val Loss: 9.5064
# Epoch 50/300, Train Loss: 0.1175, Val Loss: 5.0608
# Epoch 60/300, Train Loss: 0.0744, Val Loss: 2.5153
# Epoch 70/300, Train Loss: 0.0488, Val Loss: 1.2343
# Epoch 80/300, Train Loss: 0.0372, Val Loss: 0.4865
# Epoch 90/300, Train Loss: 0.0337, Val Loss: 0.1684
# Epoch 100/300, Train Loss: 0.0322, Val Loss: 0.1008
# Epoch 110/300, Train Loss: 0.0321, Val Loss: 0.0870
# Epoch 120/300, Train Loss: 0.0336, Val Loss: 0.0865
# Epoch 130/300, Train Loss: 0.0342, Val Loss: 0.0857
# Epoch 140/300, Train Loss: 0.0338, Val Loss: 0.0929
# Epoch 150/300, Train Loss: 0.0336, Val Loss: 0.0857
# Epoch 160/300, Train Loss: 0.0309, Val Loss: 0.0885
# Epoch 170/300, Train Loss: 0.0308, Val Loss: 0.0873
# Epoch 180/300, Train Loss: 0.0308, Val Loss: 0.0816
# Epoch 190/300, Train Loss: 0.0309, Val Loss: 0.0863
# Epoch 200/300, Train Loss: 0.0313, Val Loss: 0.0823
# Epoch 210/300, Train Loss: 0.0308, Val Loss: 0.0861
# Epoch 220/300, Train Loss: 0.0319, Val Loss: 0.0806
# Epoch 230/300, Train Loss: 0.0312, Val Loss: 0.0866
# Epoch 240/300, Train Loss: 0.0307, Val Loss: 0.0820
# Epoch 250/300, Train Loss: 0.0310, Val Loss: 0.0829
# Epoch 260/300, Train Loss: 0.0314, Val Loss: 0.0805
# Epoch 270/300, Train Loss: 0.0307, Val Loss: 0.0848
# Epoch 280/300, Train Loss: 0.0309, Val Loss: 0.0855
# Epoch 290/300, Train Loss: 0.0314, Val Loss: 0.0875
# Epoch 300/300, Train Loss: 0.0307, Val Loss: 0.0869
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.012155321598125542, 'mae': 0.082667954867956, 'r2': 0.20141789483687567, 'pearson_corr': 0.5988605222812653, 'geodesic_distance': 8.27425938927038}
# TEST METRICS: {'mse': 0.06544985391299808, 'mae': 0.16109975865919848, 'r2': -4.154817594132062, 'pearson_corr': -0.09507631027725327, 'geodesic_distance': 9.39887435549387}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 34, 'learning_rate': 0.002, 'epochs': 300, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'device': 'cuda'}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250128_153948-ofrf7fpl</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ofrf7fpl' target="_blank">bilinear_SCM_transcriptome_PCA_FC_random_fold0_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ofrf7fpl' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ofrf7fpl</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▅▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_pearson</td><td>▅▆█▆▆▇▇█▇▇▆▆▅▄▃▂▁▂▃▂▃▃▃▂▂▃▂▂▂▃▄▂▂▂▂▃▂▁▂▂</td></tr><tr><td>train_mse_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▁▁▁▁▂▂▂▃▄▅▆▆▆▇▇▇▇▇▇▇▆▆▇▆███████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.08686</td></tr><tr><td>test_pearson</td><td>-0.09641</td></tr><tr><td>train_mse_loss</td><td>0.0307</td></tr><tr><td>train_pearson</td><td>0.59562</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_SCM_transcriptome_PCA_FC_random_fold0_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ofrf7fpl' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/ofrf7fpl</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250128_153948-ofrf7fpl/logs</code>
# Final evaluation metrics logged successfully.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# CPU Usage: 22.5%
# RAM Usage: 13.2%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  2% |
#
#  Test fold num: 2 X_train shape: (7140, 68) Y_train shape: (7140,) X_test shape: (812, 68) Y_test shape: (812,)
# 1
# 3
# 4
# BEST CONFIG {'input_dim': 68, 'learning_rate': 0.002, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'epochs': 300}
# Number of learnable parameters in bilinear SCM layer: 1157
# Epoch 10/300, Train Loss: 5.0176, Val Loss: 17.0164
# Epoch 20/300, Train Loss: 0.9705, Val Loss: 8.1960
# Epoch 30/300, Train Loss: 0.3530, Val Loss: 3.1932
# Epoch 40/300, Train Loss: 0.1622, Val Loss: 1.6462
# Epoch 50/300, Train Loss: 0.0862, Val Loss: 0.7575
# Epoch 60/300, Train Loss: 0.0507, Val Loss: 0.3054
# Epoch 70/300, Train Loss: 0.0364, Val Loss: 0.1347
# Epoch 80/300, Train Loss: 0.0326, Val Loss: 0.0728
# Epoch 90/300, Train Loss: 0.0319, Val Loss: 0.0609
# Epoch 100/300, Train Loss: 0.0322, Val Loss: 0.0563
# Epoch 110/300, Train Loss: 0.0326, Val Loss: 0.0599
# Epoch 120/300, Train Loss: 0.0321, Val Loss: 0.0564
# Epoch 130/300, Train Loss: 0.0327, Val Loss: 0.0584
# Epoch 140/300, Train Loss: 0.0345, Val Loss: 0.0633
# Epoch 150/300, Train Loss: 0.0341, Val Loss: 0.0619
# Epoch 160/300, Train Loss: 0.0309, Val Loss: 0.0651
# Epoch 170/300, Train Loss: 0.0305, Val Loss: 0.0622
# Epoch 180/300, Train Loss: 0.0303, Val Loss: 0.0577
# Epoch 190/300, Train Loss: 0.0302, Val Loss: 0.0599
# Epoch 200/300, Train Loss: 0.0302, Val Loss: 0.0581
# Epoch 210/300, Train Loss: 0.0303, Val Loss: 0.0594
# Epoch 220/300, Train Loss: 0.0304, Val Loss: 0.0575
# Epoch 230/300, Train Loss: 0.0312, Val Loss: 0.0604
# Epoch 240/300, Train Loss: 0.0301, Val Loss: 0.0623
# Epoch 250/300, Train Loss: 0.0302, Val Loss: 0.0583
# Epoch 260/300, Train Loss: 0.0303, Val Loss: 0.0603
# Epoch 270/300, Train Loss: 0.0300, Val Loss: 0.0650
# Epoch 280/300, Train Loss: 0.0305, Val Loss: 0.0598
# Epoch 290/300, Train Loss: 0.0306, Val Loss: 0.0601
# Epoch 300/300, Train Loss: 0.0301, Val Loss: 0.0670
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.011948876229065994, 'mae': 0.08065177798548875, 'r2': 0.1214258142861736, 'pearson_corr': 0.5462266877774333, 'geodesic_distance': 9.277401859558662}
# TEST METRICS: {'mse': 0.042251299336523496, 'mae': 0.13347028802586478, 'r2': -1.5904106721408655, 'pearson_corr': 0.08726431627110985, 'geodesic_distance': 8.477030457569308}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 34, 'learning_rate': 0.002, 'epochs': 300, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'device': 'cuda'}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250128_154015-kwsacab5</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/kwsacab5' target="_blank">bilinear_SCM_transcriptome_PCA_FC_random_fold1_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/kwsacab5' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/kwsacab5</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▇▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_pearson</td><td>▂▁▂▄▃▄▄▄▄▅▆▆▆▅▇▆▆▅▅█▅▆▆▇█▇▆▇▆▆▅▇▆█▇▆▆▇▇▆</td></tr><tr><td>train_mse_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▁▂▂▂▃▄▆▆▆▇▇▇▇▇▇▆▆▆▆▆███████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.06704</td></tr><tr><td>test_pearson</td><td>0.10052</td></tr><tr><td>train_mse_loss</td><td>0.03014</td></tr><tr><td>train_pearson</td><td>0.54826</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_SCM_transcriptome_PCA_FC_random_fold1_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/kwsacab5' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/kwsacab5</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250128_154015-kwsacab5/logs</code>
# Final evaluation metrics logged successfully.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# CPU Usage: 22.4%
# RAM Usage: 13.2%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  2% |
#
#  Test fold num: 3 X_train shape: (7310, 68) Y_train shape: (7310,) X_test shape: (756, 68) Y_test shape: (756,)
# 1
# 2
# 4
# BEST CONFIG {'input_dim': 68, 'learning_rate': 0.002, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'epochs': 300}
# Number of learnable parameters in bilinear SCM layer: 1157
# Epoch 10/300, Train Loss: 3.6121, Val Loss: 32.5082
# Epoch 20/300, Train Loss: 0.6578, Val Loss: 13.5514
# Epoch 30/300, Train Loss: 0.2561, Val Loss: 10.7525
# Epoch 40/300, Train Loss: 0.1325, Val Loss: 5.8547
# Epoch 50/300, Train Loss: 0.0757, Val Loss: 2.1724
# Epoch 60/300, Train Loss: 0.0473, Val Loss: 0.9958
# Epoch 70/300, Train Loss: 0.0349, Val Loss: 0.2736
# Epoch 80/300, Train Loss: 0.0314, Val Loss: 0.0885
# Epoch 90/300, Train Loss: 0.0310, Val Loss: 0.0595
# Epoch 100/300, Train Loss: 0.0310, Val Loss: 0.0500
# Epoch 110/300, Train Loss: 0.0312, Val Loss: 0.0534
# Epoch 120/300, Train Loss: 0.0313, Val Loss: 0.0496
# Epoch 130/300, Train Loss: 0.0318, Val Loss: 0.0500
# Epoch 140/300, Train Loss: 0.0303, Val Loss: 0.0507
# Epoch 150/300, Train Loss: 0.0303, Val Loss: 0.0528
# Epoch 160/300, Train Loss: 0.0301, Val Loss: 0.0517
# Epoch 170/300, Train Loss: 0.0302, Val Loss: 0.0525
# Epoch 180/300, Train Loss: 0.0302, Val Loss: 0.0502
# Epoch 190/300, Train Loss: 0.0302, Val Loss: 0.0497
# Epoch 200/300, Train Loss: 0.0302, Val Loss: 0.0552
# Epoch 210/300, Train Loss: 0.0302, Val Loss: 0.0527
# Epoch 220/300, Train Loss: 0.0302, Val Loss: 0.0500
# Epoch 230/300, Train Loss: 0.0302, Val Loss: 0.0500
# Epoch 240/300, Train Loss: 0.0301, Val Loss: 0.0524
# Epoch 250/300, Train Loss: 0.0301, Val Loss: 0.0531
# Epoch 260/300, Train Loss: 0.0302, Val Loss: 0.0532
# Epoch 270/300, Train Loss: 0.0301, Val Loss: 0.0522
# Epoch 280/300, Train Loss: 0.0302, Val Loss: 0.0513
# Epoch 290/300, Train Loss: 0.0302, Val Loss: 0.0536
# Epoch 300/300, Train Loss: 0.0301, Val Loss: 0.0542
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.012350193514602526, 'mae': 0.08321147964270578, 'r2': 0.14158518456086067, 'pearson_corr': 0.5586852525176206, 'geodesic_distance': 8.909637284892732}
# TEST METRICS: {'mse': 0.03406793690637429, 'mae': 0.13242890993163117, 'r2': -1.6172679178698441, 'pearson_corr': -0.07185845807875421, 'geodesic_distance': 6.544870697196004}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 34, 'learning_rate': 0.002, 'epochs': 300, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'device': 'cuda'}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250128_154042-xokhpr7e</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/xokhpr7e' target="_blank">bilinear_SCM_transcriptome_PCA_FC_random_fold2_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/xokhpr7e' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/xokhpr7e</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▆▅▅▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_pearson</td><td>▄▇▅▅█▆▅▅▃▃▅▄▃▆▃▃▄▁▄▂▄▃▂▂▃▂▄▄▅▃▃▄▃▃▄▂▃▂▃▂</td></tr><tr><td>train_mse_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▁▁▁▁▂▃▃▄▅▅▆▆▇▇█████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.05415</td></tr><tr><td>test_pearson</td><td>-0.08811</td></tr><tr><td>train_mse_loss</td><td>0.03014</td></tr><tr><td>train_pearson</td><td>0.55992</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_SCM_transcriptome_PCA_FC_random_fold2_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/xokhpr7e' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/xokhpr7e</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250128_154042-xokhpr7e/logs</code>
# Final evaluation metrics logged successfully.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# CPU Usage: 20.7%
# RAM Usage: 13.2%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  2% |
#
#  Test fold num: 4 X_train shape: (7310, 68) Y_train shape: (7310,) X_test shape: (756, 68) Y_test shape: (756,)
# 1
# 2
# 3
# BEST CONFIG {'input_dim': 68, 'learning_rate': 0.002, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'epochs': 300}
# Number of learnable parameters in bilinear SCM layer: 1157
# Epoch 10/300, Train Loss: 3.0856, Val Loss: 104.5614
# Epoch 20/300, Train Loss: 0.6822, Val Loss: 66.2856
# Epoch 30/300, Train Loss: 0.3017, Val Loss: 41.3202
# Epoch 40/300, Train Loss: 0.1735, Val Loss: 26.9498
# Epoch 50/300, Train Loss: 0.1124, Val Loss: 17.3498
# Epoch 60/300, Train Loss: 0.0759, Val Loss: 14.5155
# Epoch 70/300, Train Loss: 0.0526, Val Loss: 8.4808
# Epoch 80/300, Train Loss: 0.0390, Val Loss: 4.9752
# Epoch 90/300, Train Loss: 0.0325, Val Loss: 2.3068
# Epoch 100/300, Train Loss: 0.0305, Val Loss: 1.5449
# Epoch 110/300, Train Loss: 0.0299, Val Loss: 0.9109
# Epoch 120/300, Train Loss: 0.0299, Val Loss: 0.9336
# Epoch 130/300, Train Loss: 0.0304, Val Loss: 0.8886
# Epoch 140/300, Train Loss: 0.0310, Val Loss: 0.7398
# Epoch 150/300, Train Loss: 0.0347, Val Loss: 0.8612
# Epoch 160/300, Train Loss: 0.1828, Val Loss: 0.8662
# Epoch 170/300, Train Loss: 0.0319, Val Loss: 0.8486
# Epoch 180/300, Train Loss: 0.0292, Val Loss: 0.8898
# Epoch 190/300, Train Loss: 0.0289, Val Loss: 0.9480
# Epoch 200/300, Train Loss: 0.0289, Val Loss: 1.0584
# Epoch 210/300, Train Loss: 0.0289, Val Loss: 1.0835
# Epoch 220/300, Train Loss: 0.0289, Val Loss: 0.9402
# Epoch 230/300, Train Loss: 0.0289, Val Loss: 0.8732
# Epoch 240/300, Train Loss: 0.0289, Val Loss: 0.8229
# Epoch 250/300, Train Loss: 0.0289, Val Loss: 0.8011
# Epoch 260/300, Train Loss: 0.0289, Val Loss: 0.8984
# Epoch 270/300, Train Loss: 0.0289, Val Loss: 0.8804
# Epoch 280/300, Train Loss: 0.0289, Val Loss: 1.1106
# Epoch 290/300, Train Loss: 0.0289, Val Loss: 0.7563
# Epoch 300/300, Train Loss: 0.0289, Val Loss: 0.9279
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.01078211902104352, 'mae': 0.07739964041657073, 'r2': 0.26876842312445826, 'pearson_corr': 0.6493537677563043, 'geodesic_distance': 9.794517931558708}
# TEST METRICS: {'mse': 0.9162065262394034, 'mae': 0.3472686348059025, 'r2': -68.65168683668286, 'pearson_corr': 0.028799643638573593, 'geodesic_distance': 8.984701477554427}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 34, 'learning_rate': 0.002, 'epochs': 300, 'batch_size': 324, 'regularization': 'l2', 'lambda_reg': 0.1, 'device': 'cuda'}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250128_154109-nvuniixx</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/nvuniixx' target="_blank">bilinear_SCM_transcriptome_PCA_FC_random_fold3_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/nvuniixx' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/nvuniixx</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▅▅▃▄▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_pearson</td><td>▅▄▂▂▁▁▂▃▁▁▃▂▄▅▅▆▆▆▅▇▆▆▇█▇▇▆▆▅▆▆██▇▇▆▇█▇▇</td></tr><tr><td>train_mse_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▂▁▁▁▁▃▄▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▆▃▂▇██████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.9279</td></tr><tr><td>test_pearson</td><td>0.03456</td></tr><tr><td>train_mse_loss</td><td>0.02894</td></tr><tr><td>train_pearson</td><td>0.64933</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_SCM_transcriptome_PCA_FC_random_fold3_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/nvuniixx' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/nvuniixx</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250128_154109-nvuniixx/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 20.5%
# RAM Usage: 13.2%
# Available RAM: 1.3T
# Total RAM: 1.5T
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  2% |
# 36624

# %%
def run_simulation_set(model_types=['dynamic_mlp'],
                      cv_types=['spatial', 'random'],
                      parcellations=['S100', 'S400'],
                      connectome_targets=['FC', 'SC'],
                      feature_types=['transcriptome', 'euclidean'],
                      hemisphere='left',
                      random_seeds=[42, 123, 456]):
    """
    Run a set of simulations with different combinations of parameters.
    
    Args:
        model_types (list): List of model types to test
        cv_types (list): List of cross-validation types
        parcellations (list): List of parcellation schemes
        connectome_targets (list): List of connectome targets
        feature_types (list): List of feature types
        hemisphere (str): Brain hemisphere to use ('left', 'right', 'both')
        random_seeds (list): List of random seeds for multiple runs
    """
    
    for seed in random_seeds:
        for model in model_types:
            for cv in cv_types:
                for parc in parcellations:
                    # Set hemisphere based on parcellation
                    current_hemisphere = 'both' if parc == 'S100' else 'left'
                    
                    for target in connectome_targets:
                        for feat in feature_types:
                            # Configure feature type dict
                            feat_dict = [{'transcriptome': None}] if feat == 'transcriptome' else [{'euclidean': None}]
                            
                            print(f"Running simulation with: {model}, {cv}, {parc}, {target}, {feat}, seed={seed}")
                            
                            # Run single simulation
                            single_sim_run(
                                cv_type=cv,
                                random_seed=seed,
                                model_type=model,
                                feature_type=feat_dict,
                                connectome_target=target,
                                use_gpu=True,
                                use_shared_regions=False,
                                test_shared_regions=False,
                                omit_subcortical=False,
                                parcellation=parc,
                                gene_list='0.2',
                                hemisphere=current_hemisphere,
                                search_method=('wandb', 'mse', 10),
                                save_sim=False,
                                track_wandb=True,
                                skip_cv=False
                            )
                            
                            # Clear GPU memory
                            if torch.cuda.is_available():
                                torch.cuda.empty_cache()
                            # Clear CPU memory
                            gc.collect()

# Example usage:
run_simulation_set(
    model_types=['bilinear_lowrank', 'shared_mlp_encoder', 'shared_linear_encoder'],
    cv_types=['random', 'spatial'],
    parcellations=['S100', 'S400'],
    connectome_targets=['FC', 'SC'],
    feature_types=['transcriptome'],
    hemisphere='both',
    random_seeds=[1, 2]
)

# %%
def run_simulation_set(model_types=['dynamic_mlp'],
                      cv_types=['spatial', 'random'],
                      parcellations=['S100', 'S400'],
                      connectome_targets=['FC', 'SC'],
                      feature_types=['transcriptome', 'euclidean'],
                      hemisphere='left',
                      random_seeds=[42, 123, 456]):
    """
    Run a set of simulations with different combinations of parameters.
    
    Args:
        model_types (list): List of model types to test
        cv_types (list): List of cross-validation types
        parcellations (list): List of parcellation schemes
        connectome_targets (list): List of connectome targets
        feature_types (list): List of feature types
        hemisphere (str): Brain hemisphere to use ('left', 'right', 'both')
        random_seeds (list): List of random seeds for multiple runs
    """
    
    for seed in random_seeds:
        for model in model_types:
            for cv in cv_types:
                for parc in parcellations:
                    # Set hemisphere based on parcellation
                    current_hemisphere = 'both' if parc == 'S100' else 'left'
                    
                    for target in connectome_targets:
                        for feat in feature_types:
                            # Configure feature type dict
                            feat_dict = [{'transcriptome': None}] if feat == 'transcriptome' else [{'euclidean': None}]
                            
                            print(f"Running simulation with: {model}, {cv}, {parc}, {target}, {feat}, seed={seed}")
                            
                            # Run single simulation
                            single_sim_run(
                                cv_type=cv,
                                random_seed=seed,
                                model_type=model,
                                feature_type=feat_dict,
                                connectome_target=target,
                                use_gpu=True,
                                use_shared_regions=False,
                                test_shared_regions=False,
                                omit_subcortical=False,
                                parcellation=parc,
                                gene_list='0.2',
                                hemisphere=current_hemisphere,
                                search_method=('wandb', 'mse', 10),
                                save_sim=False,
                                track_wandb=True,
                                skip_cv=False
                            )
                            
                            # Clear GPU memory
                            if torch.cuda.is_available():
                                torch.cuda.empty_cache()
                            # Clear CPU memory
                            gc.collect()

# Example usage:
run_simulation_set(
    model_types=['shared_transformer'],
    cv_types=['random', 'spatial'],
    parcellations=['S100', 'S400'],
    connectome_targets=['FC', 'SC'],
    feature_types=['transcriptome'],
    hemisphere='both',
    random_seeds=[1, 2]
)
