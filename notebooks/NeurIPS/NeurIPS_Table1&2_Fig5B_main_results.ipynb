# %% [markdown]
# # NeurIPS Main Results — Random and Spatial Split
#
# **Purpose:** Scrapes final NeurIPS results for random and spatial split evaluations from Weights & Biases. This notebook contains all computed performance metrics.
#
# **Associated Tables:** Table 1, Table 2
# **Associated Figures:** Fig. 5B
#
# **Author:** Alexander Ratzan
# **Project:** Predicting Functional Brain Connectivity with Context-Aware Deep Neural Networks (NeurIPS 2025)

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from env.imports import *
# Out:
# /ext3/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 2025-11-20 13:05:07.301750: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-20 13:05:08.258311: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-20 13:05:09.045010: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-20 13:05:09.046366: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-20 13:05:11.130401: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/utils/useful.py:10: PendingDeprecationWarning: Importing from numpy.matlib is deprecated since 1.19.0. The matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   import numpy.matlib as npm
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/plotting/colormaps.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   autumn = cm.get_cmap('autumn', 256)
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/plotting/colormaps.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   winter = cm.get_cmap('winter_r', 256)

# %%
import importlib
import data

import models
import sim.sim
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run
from sim.wandb_scrape import *
# Out:
# Resorting genes by reference genome order

# %% [markdown]
# ## Wandb API Query <a id="sims"></a>

# %% [markdown]
# Search and plot Random

# %%
from collections import defaultdict

# Define model groups and their valid feature types
models = ['cge', 'gaussian_kernel', 'exponential_decay',
          'bilinear_CM', 'pls_bilineardecoder', 'bilinear_lowrank',
          'dynamic_mlp', 'shared_transformer', 'shared_transformer_cls']

# Dictionary mapping models to their required feature types
model_feature_types = {
    'cge': ['transcriptome_PCA'],
    'gaussian_kernel': ['euclidean'],
    'exponential_decay': ['euclidean'],
    'bilinear_CM': ['transcriptome', 'transcriptome_PCA'],
    'pls_bilineardecoder': ['transcriptome'],
    'bilinear_lowrank': ['transcriptome'],
    'dynamic_mlp': ['transcriptome', 'transcriptome+euclidean'],
    'shared_transformer': ['transcriptome'],
    'shared_transformer_cls': ['transcriptome']
}

# Time ranges for true models
time_ranges_true = {
    'default': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
    'model_specific': {
        'cge': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'gaussian_kernel': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'exponential_decay': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'bilinear_CM': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'pls_bilineardecoder': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        # Reran for validation
        'bilinear_lowrank': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': days_ago_from_date('2025-10-13')},
        'dynamic_mlp': {'within_last': days_ago_from_date('2025-10-08'), 'before_last': days_ago_from_date('2025-10-17')},
        'shared_transformer': {'within_last': days_ago_from_date('2025-10-11'), 'before_last': days_ago_from_date('2025-10-16')},
        'shared_transformer_cls': {'within_last': days_ago_from_date('2025-10-11'), 'before_last': days_ago_from_date('2025-10-16')}
    }
}

# Time ranges for null models
time_ranges_spin = {
    'default': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
    'model_specific': {
        'cge': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'gaussian_kernel': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'exponential_decay': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'bilinear_CM': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'pls_bilineardecoder': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        # Reran for validation
        'bilinear_lowrank': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': 0},
        'dynamic_mlp': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'shared_transformer': {'within_last': days_ago_from_date('2025-10-13'), 'before_last': 0},
        'shared_transformer_cls': {'within_last': days_ago_from_date('2025-10-13'), 'before_last': 0},
    }
}

cv_type = 'random'
null_model = 'none'

# Store summary DataFrames
summary_dict_random = {}
process_model_feature_combinations(cv_type, null_model, models, model_feature_types, summary_dict_random, time_ranges=time_ranges_true)

cv_type = 'random'
null_model = 'spin'

# Store summary DataFrames
summary_dict_random_spin = {}
process_model_feature_combinations(cv_type, null_model, models, model_feature_types, summary_dict_random_spin, time_ranges=time_ranges_spin)
# Out:
# Checking which model/feature type combinations return 40 runs for null_model=none:
#
# 🔍 Fetching runs for: model=cge, cv_type=random, null_model=none, feature_type=transcriptome_PCA
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# wandb: WARNING A graphql request initiated by the public wandb API timed out (timeout=19 sec). Create a new API with an integer timeout larger than 19, e.g., `api = wandb.Api(timeout=29)` to increase the graphql timeout.
# ! cge with transcriptome_PCA: Unexpected error: HTTPSConnectionPool(host='api.wandb.ai', port=443): Read timed out. (read timeout=19)
# 🔍 Fetching runs for: model=gaussian_kernel, cv_type=random, null_model=none, feature_type=euclidean
# ✓ gaussian_kernel with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=exponential_decay, cv_type=random, null_model=none, feature_type=euclidean
# ✓ exponential_decay with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ bilinear_CM: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=random, null_model=none, feature_type=transcriptome_PCA
# ✓ bilinear_CM_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=pls_bilineardecoder, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ pls_bilineardecoder with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_lowrank, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ bilinear_lowrank with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ dynamic_mlp: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=random, null_model=none, feature_type=transcriptome+euclidean
# ✓ dynamic_mlp_coords: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ shared_transformer with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer_cls, cv_type=random, null_model=none, feature_type=transcriptome
# ✓ shared_transformer_cls with transcriptome: Successfully found 40 runs
# Checking which model/feature type combinations return 40 runs for null_model=spin:
#
# 🔍 Fetching runs for: model=cge, cv_type=random, null_model=spin, feature_type=transcriptome_PCA
# ✓ cge with transcriptome_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=gaussian_kernel, cv_type=random, null_model=spin, feature_type=euclidean
# ✓ gaussian_kernel with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=exponential_decay, cv_type=random, null_model=spin, feature_type=euclidean
# ✓ exponential_decay with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ bilinear_CM: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=random, null_model=spin, feature_type=transcriptome_PCA
# ✓ bilinear_CM_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=pls_bilineardecoder, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ pls_bilineardecoder with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_lowrank, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ bilinear_lowrank with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ dynamic_mlp: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=random, null_model=spin, feature_type=transcriptome+euclidean
# ✓ dynamic_mlp_coords: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ shared_transformer with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer_cls, cv_type=random, null_model=spin, feature_type=transcriptome
# ✓ shared_transformer_cls with transcriptome: Successfully found 40 runs

# %%
summary_dict_random
# Out:
# {'cge':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                22.901140            0.198661
#  std                  0.665635            0.011159
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.235094                    0.249401
#  std                           0.032808                    0.022346
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.242524                        0.204553
#  std                        0.020347                        0.028832
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.245641                           0.261587
#  std                       0.021493                           0.022129
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.304388                           0.234153  ...
#  std                       0.017291                           0.022364  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.118352  0.157778        0.225796 -3.734953           0.254366
#  std     0.030384  0.011202        0.034404  0.444194           0.049308
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.252571         0.157173           0.009918           0.309535
#  std       0.042314         0.029703           0.103985           0.053448
#
#        test_weak_r
#  mean     0.070548
#  std      0.029190
#
#  [2 rows x 66 columns],
#  'gaussian_kernel':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                25.242848            0.165182
#  std                  0.723968            0.013119
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.254945                    0.273449
#  std                           0.040033                    0.020734
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.275170                        0.261498
#  std                        0.016154                        0.020146
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.301303                           0.271686
#  std                       0.027503                           0.019025
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.282150                           0.235664  ...
#  std                       0.013864                           0.021748  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.037701  0.030754        0.302969  0.081503           0.388405
#  std     0.023868  0.002482        0.023110  0.021559           0.040552
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.394565         0.274422           0.073560           0.323635
#  std       0.037750         0.040506           0.073356           0.049035
#
#        test_weak_r
#  mean     0.140361
#  std      0.014665
#
#  [2 rows x 66 columns],
#  'exponential_decay':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                24.280642            0.240199
#  std                  0.592051            0.014062
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.270781                    0.307985
#  std                           0.037431                    0.021107
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.308927                        0.293727
#  std                        0.019530                        0.025867
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.338305                           0.312857
#  std                       0.028733                           0.020684
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.339144                           0.273472  ...
#  std                       0.017778                           0.026999  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.070054  0.029589        0.346384  0.116986           0.428095
#  std     0.031983  0.002670        0.027742  0.021635           0.045452
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.411112         0.274422           0.112940           0.338260
#  std       0.037968         0.040506           0.090884           0.044773
#
#        test_weak_r
#  mean     0.194947
#  std      0.024016
#
#  [2 rows x 66 columns],
#  'bilinear_CM':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                 7.355913            0.980035
#  std                  2.287597            0.019884
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.980812                    0.982333
#  std                           0.017889                    0.016265
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.982236                        0.984113
#  std                        0.015935                        0.014343
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.982393                           0.982850
#  std                       0.016865                           0.015771
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.984282                           0.981133  ...
#  std                       0.014210                           0.016945  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.592061  0.029999         0.61742  0.093072           0.687322
#  std     0.091204  0.012024         0.09527  0.396373           0.075791
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.629498         0.612392           0.081611           0.223129
#  std       0.118085         0.079290           0.118872           0.103166
#
#        test_weak_r
#  mean     0.527832
#  std      0.089203
#
#  [2 rows x 66 columns],
#  'bilinear_CM_PCA':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                26.377205            0.563593
#  std                  0.384894            0.011718
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.579745                    0.634353
#  std                           0.026438                    0.020769
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.556948                        0.664618
#  std                        0.022317                        0.021660
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.640950                           0.659887
#  std                       0.021164                           0.018891
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.628567                           0.574442  ...
#  std                       0.019537                           0.018277  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.429059  0.025475        0.506183  0.239215           0.552589
#  std     0.039413  0.003394        0.037472  0.076884           0.046726
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.566888         0.474875           0.018753           0.306351
#  std       0.047674         0.037534           0.116674           0.078082
#
#        test_weak_r
#  mean      0.37354
#  std       0.03380
#
#  [2 rows x 66 columns],
#  'pls_bilineardecoder':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                17.432876            0.886570
#  std                  4.120862            0.096135
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.886349                    0.899823
#  std                           0.090353                    0.078007
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.885023                        0.911064
#  std                        0.092489                        0.069515
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.900891                           0.903689
#  std                       0.081725                           0.069087
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.903492                           0.890248  ...
#  std                       0.078294                           0.090124  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.678275  0.016133        0.720171  0.517065           0.749213
#  std     0.088845  0.003585        0.078622  0.102897           0.077203
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.753851         0.686221           0.057583           0.369813
#  std       0.078118         0.074922           0.125284           0.096321
#
#        test_weak_r
#  mean     0.620565
#  std      0.080997
#
#  [2 rows x 66 columns],
#  'bilinear_lowrank':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                16.915113            0.939050
#  std                  2.267172            0.012426
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.936733                    0.946349
#  std                           0.013040                    0.011025
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.939081                        0.954872
#  std                        0.011261                        0.008940
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.949504                           0.945708
#  std                       0.009721                           0.009454
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.953853                           0.940611  ...
#  std                       0.009029                           0.012197  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.741195  0.013548        0.772488  0.593582           0.803490
#  std     0.034716  0.001323        0.028608  0.044427           0.033089
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.798412         0.740753           0.086357           0.399282
#  std       0.024596         0.039621           0.120549           0.066351
#
#        test_weak_r
#  mean     0.682127
#  std      0.039725
#
#  [2 rows x 66 columns],
#  'dynamic_mlp':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                 12.36835            0.992567
#  std                   0.81247            0.002003
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.990470                    0.991978
#  std                           0.002547                    0.001964
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.991032                        0.993382
#  std                        0.002315                        0.001692
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                       0.99209                           0.991949
#  std                        0.00207                           0.001983
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.993507                           0.991058  ...
#  std                       0.001763                           0.002295  ...
#
#        test_mse  test_pearson_r   test_r2  test_right_hemi_r  test_short_r  \
#  mean  0.013739        0.781012  0.587260           0.809219      0.816432
#  std   0.001442        0.029019  0.054125           0.040047      0.027190
#
#        test_spearman_r  test_strong_neg_r  test_strong_pos_r  test_weak_r  \
#  mean         0.739778           0.094833           0.478894     0.668754
#  std          0.036113           0.124431           0.075599     0.035903
#
#        test_intra_network_Cerebellum_r
#  mean                         0.523591
#  std                          0.516493
#
#  [2 rows x 66 columns],
#  'dynamic_mlp_coords':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                11.829611            0.995566
#  std                  0.721022            0.000580
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.995313                    0.995626
#  std                           0.000653                    0.000681
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.995416                        0.996058
#  std                        0.000643                        0.000628
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.995671                           0.995499
#  std                       0.000577                           0.000656
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.996164                           0.995462  ...
#  std                       0.000635                           0.000665  ...
#
#        test_mid_r  test_mse  test_pearson_r   test_r2  test_right_hemi_r  \
#  mean    0.799261  0.010829        0.826084  0.674274           0.846332
#  std     0.031838  0.001316        0.027481  0.049735           0.033576
#
#        test_short_r  test_spearman_r  test_strong_neg_r  test_strong_pos_r  \
#  mean      0.846717         0.791561           0.156605           0.532150
#  std       0.026042         0.035505           0.128223           0.071645
#
#        test_weak_r
#  mean     0.729118
#  std      0.035044
#
#  [2 rows x 66 columns],
#  'shared_transformer':       train_geodesic_distance  train_inter_hemi_r  train_left_hemi_r  \
#  mean                13.030056            0.991344           0.989918
#  std                  0.985319            0.003780           0.004836
#
#        train_long_r  train_mae  train_mid_r  train_mse  train_pearson_r  \
#  mean      0.988395   0.020978     0.989537   0.000845         0.990374
#  std       0.006022   0.008822     0.005006   0.000699         0.004481
#
#        train_r2  train_right_hemi_r  ...  test_intra_network_Cont_r  \
#  mean  0.974938            0.991573  ...                   0.789681
#  std   0.020467            0.003898  ...                   0.105317
#
#        test_intra_network_Default_r  test_intra_network_DorsAttn_r  \
#  mean                      0.795958                       0.820842
#  std                       0.056182                       0.137526
#
#        test_intra_network_Limbic_r  test_intra_network_SalVentAttn_r  \
#  mean                     0.843172                          0.818371
#  std                      0.125691                          0.142961
#
#        test_intra_network_SomMot_r  test_intra_network_Subcortical_r  \
#  mean                     0.841598                          0.664231
#  std                      0.073208                          0.205030
#
#        test_intra_network_Vis_r  test_strong_neg_r  \
#  mean                  0.871569           0.139253
#  std                   0.054295           0.125750
#
#        test_intra_network_Cerebellum_r
#  mean                         0.742987
#  std                          0.336046
#
#  [2 rows x 66 columns],
#  'shared_transformer_cls':       train_geodesic_distance  train_inter_hemi_r  \
#  mean                 12.36421            0.992844
#  std                   0.92078            0.002900
#
#        train_inter_network_Cerebellum_r  train_inter_network_Cont_r  \
#  mean                          0.992460                    0.993239
#  std                           0.003358                    0.003026
#
#        train_inter_network_Default_r  train_inter_network_DorsAttn_r  \
#  mean                       0.992678                        0.994064
#  std                        0.003344                        0.002472
#
#        train_inter_network_Limbic_r  train_inter_network_SalVentAttn_r  \
#  mean                      0.993528                           0.993209
#  std                       0.002465                           0.002757
#
#        train_inter_network_SomMot_r  train_inter_network_Subcortical_r  ...  \
#  mean                      0.993968                           0.992721  ...
#  std                       0.002548                           0.003225  ...
#
#        test_mse  test_pearson_r   test_r2  test_right_hemi_r  test_short_r  \
#  mean  0.009784        0.844356  0.706686           0.862564      0.861841
#  std   0.001284        0.021676  0.039602           0.026105      0.020014
#
#        test_spearman_r  test_strong_neg_r  test_strong_pos_r  test_weak_r  \
#  mean         0.810337           0.250164           0.549877     0.750359
#  std          0.031087           0.125553           0.059151     0.033442
#
#        test_intra_network_Cerebellum_r
#  mean                         0.684340
#  std                          0.506503
#
#  [2 rows x 66 columns]}

# %%
plot_true_vs_null_model_barchart_w_legend(
    summary_true_dict=summary_dict_random,                # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_random_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    xlim=(0.1, 0.9),
    overlay_style='alpha'                         

)

# %%
# PLot with standard error bars
plot_true_vs_null_model_barchart(
    summary_true_dict=summary_dict_random,                # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_random_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    xlim=(0.1, 0.9),
    overlay_style='alpha',                          # or 'alpha'
    display_metric=True
)
# Out:
# {'Non-Linear': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253),
#  'Feature Based': (0.595839, 0.848717, 0.243329)}

# %%
plot_final_subsetted_barchart(
    summary_true_dict=summary_dict_random,        # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_random_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    ylim=(0.2, .85),
    overlay_style='alpha',                          # or 'alpha'
    #display_metric=True,
    title="Random CV Test Performance on UKBB",
    horizontal=True, 
    model_groups = {
        'Deep Learning': {
            'dynamic_mlp': 'MLP',
            'dynamic_mlp_coords': 'MLP w/ coords',
            'shared_transformer': 'SMT',
            'shared_transformer_cls': 'SMT w/ [CLS]'
        },
        'Bilinear': {
            'bilinear_CM': 'Bilinear CM',
            'bilinear_CM_PCA': 'Bilinear CM (PCA)',
            'pls_bilineardecoder': 'Bilinear CM (PLS)',
            'bilinear_lowrank': 'Bilinear Lowrank'
        },
        'Rules-Based': {
            'cge': 'Corr. Gene Exp.',
            'gaussian_kernel': 'Gaussian Kernel',
            'exponential_decay': 'Exponential Decay'
        }
    }
)
# Out:
# {'Deep Learning': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253),
#  'Rules-Based': (0.595839, 0.848717, 0.243329)}

# %% [markdown]
# Search and plot spatial

# %%
# Define model groups and their valid feature types
models = ['cge', 'gaussian_kernel', 'exponential_decay',
          'bilinear_CM', 'pls_bilineardecoder', 'bilinear_lowrank',
          'dynamic_mlp', 'shared_transformer', 'shared_transformer_cls']

# Dictionary mapping models to their required feature types
model_feature_types = {
    'cge': ['transcriptome_PCA'],
    'gaussian_kernel': ['euclidean'],
    'exponential_decay': ['euclidean'],
    'bilinear_CM': ['transcriptome', 'transcriptome_PCA'],
    'pls_bilineardecoder': ['transcriptome'],
    'bilinear_lowrank': ['transcriptome'],
    'dynamic_mlp': ['transcriptome', 'transcriptome+euclidean'],
    'shared_transformer': ['transcriptome'],
    'shared_transformer_cls': ['transcriptome']
}

model_groups = {
    'rules based': ['cge', 'gaussian_kernel', 'exponential_decay'],
    'bilinear': ['bilinear_CM', 'bilinear_CM_PCA', 'pls_bilineardecoder', 'bilinear_lowrank'],
    'deep learning': ['dynamic_mlp', 'dynamic_mlp_coords', 'shared_transformer', 'shared_transformer_cls']
}


# Time ranges for true models
time_ranges_true = {
    'default': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
    'model_specific': {
        'cge': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'gaussian_kernel': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'exponential_decay': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        # Reran for validation
        'bilinear_CM': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': days_ago_from_date('2025-09-01')},
        'pls_bilineardecoder': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': days_ago_from_date('2025-09-01')},
        'bilinear_lowrank': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': days_ago_from_date('2025-10-13')},
        'dynamic_mlp': {'within_last': days_ago_from_date('2025-10-08'), 'before_last': days_ago_from_date('2025-10-17')},
        'shared_transformer': {'within_last': days_ago_from_date('2025-10-11'), 'before_last': days_ago_from_date('2025-10-16')},
        'shared_transformer_cls': {'within_last': days_ago_from_date('2025-10-11'), 'before_last': days_ago_from_date('2025-10-16')}
    }
}

# Time ranges for null models
time_ranges_spin = {
    'default': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
    'model_specific': {
        'cge': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'gaussian_kernel': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'exponential_decay': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'bilinear_CM': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'pls_bilineardecoder': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        # Reran for validation
        'bilinear_lowrank': {'within_last': days_ago_from_date('2025-07-10'), 'before_last': 0},
        'dynamic_mlp': {'within_last': days_ago_from_date('2025-06-15'), 'before_last': 0},
        'shared_transformer': {'within_last': days_ago_from_date('2025-10-13'), 'before_last': 0},
        'shared_transformer_cls': {'within_last': days_ago_from_date('2025-10-13'), 'before_last': 0},
    }
}

cv_type = 'spatial'
null_model = 'none'

# Store summary DataFrames
summary_dict_spatial = {}
process_model_feature_combinations(cv_type, null_model, models, model_feature_types, summary_dict_spatial, time_ranges=time_ranges_true)


cv_type = 'spatial'
null_model = 'spin'

# Store summary DataFrames
summary_dict_spatial_spin = {}
process_model_feature_combinations(cv_type, null_model, models, model_feature_types, summary_dict_spatial_spin, time_ranges=time_ranges_spin)
# Out:
# Checking which model/feature type combinations return 40 runs for null_model=none:
#
# 🔍 Fetching runs for: model=cge, cv_type=spatial, null_model=none, feature_type=transcriptome_PCA
# ✓ cge with transcriptome_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=gaussian_kernel, cv_type=spatial, null_model=none, feature_type=euclidean
# ✓ gaussian_kernel with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=exponential_decay, cv_type=spatial, null_model=none, feature_type=euclidean
# ✓ exponential_decay with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ bilinear_CM: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=spatial, null_model=none, feature_type=transcriptome_PCA
# ✓ bilinear_CM_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=pls_bilineardecoder, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ pls_bilineardecoder with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_lowrank, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ bilinear_lowrank with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ dynamic_mlp: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=spatial, null_model=none, feature_type=transcriptome+euclidean
# ✓ dynamic_mlp_coords: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ shared_transformer with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer_cls, cv_type=spatial, null_model=none, feature_type=transcriptome
# ✓ shared_transformer_cls with transcriptome: Successfully found 40 runs
# Checking which model/feature type combinations return 40 runs for null_model=spin:
#
# 🔍 Fetching runs for: model=cge, cv_type=spatial, null_model=spin, feature_type=transcriptome_PCA
# ✓ cge with transcriptome_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=gaussian_kernel, cv_type=spatial, null_model=spin, feature_type=euclidean
# ✓ gaussian_kernel with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=exponential_decay, cv_type=spatial, null_model=spin, feature_type=euclidean
# ✓ exponential_decay with euclidean: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ bilinear_CM: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_CM, cv_type=spatial, null_model=spin, feature_type=transcriptome_PCA
# ✓ bilinear_CM_PCA: Successfully found 40 runs
# 🔍 Fetching runs for: model=pls_bilineardecoder, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ pls_bilineardecoder with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=bilinear_lowrank, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ bilinear_lowrank with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ dynamic_mlp: Successfully found 40 runs
# 🔍 Fetching runs for: model=dynamic_mlp, cv_type=spatial, null_model=spin, feature_type=transcriptome+euclidean
# ✓ dynamic_mlp_coords: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ shared_transformer with transcriptome: Successfully found 40 runs
# 🔍 Fetching runs for: model=shared_transformer_cls, cv_type=spatial, null_model=spin, feature_type=transcriptome
# ✓ shared_transformer_cls with transcriptome: Successfully found 40 runs

# %%
plot_true_vs_null_model_barchart(
    summary_true_dict=summary_dict_spatial,                # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_spatial_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    xlim=(0.0, 1),
    overlay_style='alpha',                          # or 'alpha'
    display_metric=False
)
# Out:
# {'Non-Linear': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253),
#  'Feature Based': (0.595839, 0.848717, 0.243329)}

# %%
plot_true_vs_null_model_barchart(
    summary_true_dict=summary_dict_spatial,                # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_spatial_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    xlim=(0.0, 1),
    overlay_style='alpha',                          # or 'alpha'
    display_metric=True
)
# Out:
# {'Non-Linear': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253),
#  'Feature Based': (0.595839, 0.848717, 0.243329)}

# %%
plot_final_subsetted_barchart(
    summary_true_dict=summary_dict_spatial,        # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_spatial_spin,           # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    ylim=(0.25, .85),
    overlay_style='alpha',                          # or 'alpha'
    #display_metric=False,
    title="Spatial CV UKBB Performance",
    horizontal=True
)
# Out:
# {'Non-Linear': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253)}

# %%
plot_final_subsetted_barchart(
    summary_true_dict=summary_dict_spatial,        # cv_type='spatial', null_model='none'
    summary_null_dict=summary_dict_spatial_spin,   # cv_type='spatial', null_model='spin'
    metric="test_pearson_r",
    ylim=(0.2, .85),
    overlay_style='alpha',                          # or 'alpha'
    #display_metric=True,
    title="Spatial CV Test Performance on UKBB",
    horizontal=True, 
    model_groups = {
        'Deep Learning': {
            'dynamic_mlp': 'MLP',
            'dynamic_mlp_coords': 'MLP w/ coords',
            'shared_transformer': 'SMT',
            'shared_transformer_cls': 'SMT w/ [CLS]'
        },
        'Bilinear': {
            'bilinear_CM': 'Bilinear CM',
            'bilinear_CM_PCA': 'Bilinear CM (PCA)',
            'pls_bilineardecoder': 'Bilinear CM (PLS)',
            'bilinear_lowrank': 'Bilinear Lowrank'
        },
        'Rules-Based': {
            'cge': 'Corr. Gene Exp.',
            'gaussian_kernel': 'Gaussian Kernel',
            'exponential_decay': 'Exponential Decay'
        }
    }
)
# Out:
# {'Deep Learning': (0.239346, 0.300855, 0.540844),
#  'Bilinear': (0.120092, 0.600104, 0.54253),
#  'Rules-Based': (0.595839, 0.848717, 0.243329)}

# %% [markdown]
# Build tables with all relevant metrics

# %%
def create_test_metric_dataframes(summary_dict):
    # Initialize empty lists for global and subnetwork metrics
    global_metrics = []
    subnetwork_metrics = []
    
    # Define global metric columns
    global_cols = ['pearson_r', 'r2', 'short_r', 'mid_r', 'long_r',
                  'strong_pos_r', 'strong_neg_r', 'weak_r',
                  'left_hemi_r', 'right_hemi_r', 'inter_hemi_r',
                  'mse', 'geodesic_distance']
                  
    # Define subnetworks
    networks = ['Vis', 'SomMot', 'DorsAttn', 'SalVentAttn', 'Limbic', 
                'Cont', 'Default', 'Subcortical', 'Cerebellum']
    
    # Process each model
    model_order = ['shared_transformer_cls', 'dynamic_mlp_coords', 'shared_transformer', 'dynamic_mlp']
    remaining_models = [m for m in reversed(summary_dict.keys()) if m not in model_order]
    ordered_models = model_order + remaining_models
    
    for model in ordered_models:
        if model not in summary_dict:
            continue
            
        df = summary_dict[model]
        
        # Global metrics
        global_row = {}
        for col in global_cols:
            mean = df.loc['mean', f'test_{col}']
            std = df.loc['std', f'test_{col}']
            global_row[col] = f"{mean:.3f} ± {std:.3f}"
        global_metrics.append({'Model': model, **global_row})
        
        # Subnetwork metrics  
        subnetwork_row = {'Model': model}
        for network in networks:
            # Intra-network correlation
            intra_mean = df.loc['mean', f'test_intra_network_{network}_r']
            intra_std = df.loc['std', f'test_intra_network_{network}_r']
            subnetwork_row[f'{network} Intra'] = f"{intra_mean:.3f} ± {intra_std:.3f}"
            
            # Inter-network correlation
            inter_mean = df.loc['mean', f'test_inter_network_{network}_r'] 
            inter_std = df.loc['std', f'test_inter_network_{network}_r']
            subnetwork_row[f'{network} Inter'] = f"{inter_mean:.3f} ± {inter_std:.3f}"
            
        subnetwork_metrics.append(subnetwork_row)
    
    # Create dataframes
    global_df = pd.DataFrame(global_metrics).set_index('Model')
    subnetwork_df = pd.DataFrame(subnetwork_metrics).set_index('Model')
    
    return global_df, subnetwork_df

# %%
# Create the dataframes for random
global_metrics_df_random, subnetwork_metrics_df_random = create_test_metric_dataframes(summary_dict_random)

print("\nRANDOM TEST METRICS:")
print("\nGlobal Test Metrics:")
display(global_metrics_df_random)
print("\nSubnetwork Test Metrics:") 
display(subnetwork_metrics_df_random)

# Create the dataframes for random
global_metrics_df_random_spin, subnetwork_metrics_df_random_spin = create_test_metric_dataframes(summary_dict_random_spin)

print("\nRandom Test Spin Metrics:")
print("\nGlobal Test  Spin Metrics:")
display(global_metrics_df_random_spin)
# Out:
# RANDOM TEST METRICS:
#
# Global Test Metrics:
#                             pearson_r              r2        short_r  \
# Model
# shared_transformer_cls  0.844 ± 0.022   0.707 ± 0.040  0.862 ± 0.020
# dynamic_mlp_coords      0.826 ± 0.027   0.674 ± 0.050  0.847 ± 0.026
# shared_transformer      0.794 ± 0.029   0.610 ± 0.057  0.825 ± 0.026
# dynamic_mlp             0.781 ± 0.029   0.587 ± 0.054  0.816 ± 0.027
# bilinear_lowrank        0.772 ± 0.029   0.594 ± 0.044  0.798 ± 0.025
# pls_bilineardecoder     0.720 ± 0.079   0.517 ± 0.103  0.754 ± 0.078
# bilinear_CM_PCA         0.506 ± 0.037   0.239 ± 0.077  0.567 ± 0.048
# bilinear_CM             0.617 ± 0.095   0.093 ± 0.396  0.629 ± 0.118
# exponential_decay       0.346 ± 0.028   0.117 ± 0.022  0.411 ± 0.038
# gaussian_kernel         0.303 ± 0.023   0.082 ± 0.022  0.395 ± 0.038
# cge                     0.226 ± 0.034  -3.735 ± 0.444  0.253 ± 0.042
#
#                                 mid_r         long_r   strong_pos_r  \
# Model
# shared_transformer_cls  0.820 ± 0.027  0.783 ± 0.057  0.550 ± 0.059
# dynamic_mlp_coords      0.799 ± 0.032  0.752 ± 0.064  0.532 ± 0.072
# shared_transformer      0.763 ± 0.032  0.691 ± 0.072  0.483 ± 0.069
# dynamic_mlp             0.748 ± 0.033  0.668 ± 0.060  0.479 ± 0.076
# bilinear_lowrank        0.741 ± 0.035  0.695 ± 0.060  0.399 ± 0.066
# pls_bilineardecoder     0.678 ± 0.089  0.626 ± 0.109  0.370 ± 0.096
# bilinear_CM_PCA         0.429 ± 0.039  0.347 ± 0.069  0.306 ± 0.078
# bilinear_CM             0.592 ± 0.091  0.552 ± 0.089  0.223 ± 0.103
# exponential_decay       0.070 ± 0.032  0.095 ± 0.069  0.338 ± 0.045
# gaussian_kernel         0.038 ± 0.024  0.065 ± 0.047  0.324 ± 0.049
# cge                     0.118 ± 0.030  0.185 ± 0.076  0.310 ± 0.053
#
#                          strong_neg_r         weak_r    left_hemi_r  \
# Model
# shared_transformer_cls  0.250 ± 0.126  0.750 ± 0.033  0.829 ± 0.034
# dynamic_mlp_coords      0.157 ± 0.128  0.729 ± 0.035  0.816 ± 0.036
# shared_transformer      0.139 ± 0.126  0.687 ± 0.033  0.781 ± 0.040
# dynamic_mlp             0.095 ± 0.124  0.669 ± 0.036  0.785 ± 0.038
# bilinear_lowrank        0.086 ± 0.121  0.682 ± 0.040  0.754 ± 0.046
# pls_bilineardecoder     0.058 ± 0.125  0.621 ± 0.081  0.703 ± 0.089
# bilinear_CM_PCA         0.019 ± 0.117  0.374 ± 0.034  0.490 ± 0.052
# bilinear_CM             0.082 ± 0.119  0.528 ± 0.089  0.652 ± 0.084
# exponential_decay       0.113 ± 0.091  0.195 ± 0.024  0.399 ± 0.048
# gaussian_kernel         0.074 ± 0.073  0.140 ± 0.015  0.368 ± 0.042
# cge                     0.010 ± 0.104  0.071 ± 0.029  0.248 ± 0.048
#
#                          right_hemi_r   inter_hemi_r            mse  \
# Model
# shared_transformer_cls  0.863 ± 0.026  0.842 ± 0.024  0.010 ± 0.001
# dynamic_mlp_coords      0.846 ± 0.034  0.821 ± 0.031  0.011 ± 0.001
# shared_transformer      0.831 ± 0.032  0.786 ± 0.032  0.013 ± 0.001
# dynamic_mlp             0.809 ± 0.040  0.766 ± 0.035  0.014 ± 0.001
# bilinear_lowrank        0.803 ± 0.033  0.771 ± 0.031  0.014 ± 0.001
# pls_bilineardecoder     0.749 ± 0.077  0.718 ± 0.078  0.016 ± 0.004
# bilinear_CM_PCA         0.553 ± 0.047  0.498 ± 0.042  0.025 ± 0.003
# bilinear_CM             0.687 ± 0.076  0.583 ± 0.113  0.030 ± 0.012
# exponential_decay       0.428 ± 0.045  0.242 ± 0.044  0.030 ± 0.003
# gaussian_kernel         0.388 ± 0.041  0.170 ± 0.034  0.031 ± 0.002
# cge                     0.254 ± 0.049  0.200 ± 0.036  0.158 ± 0.011
#
#                        geodesic_distance
# Model
# shared_transformer_cls     9.803 ± 0.928
# dynamic_mlp_coords         9.591 ± 0.783
# shared_transformer        10.194 ± 0.982
# dynamic_mlp               10.249 ± 1.074
# bilinear_lowrank          11.183 ± 1.103
# pls_bilineardecoder       11.956 ± 1.929
# bilinear_CM_PCA           15.302 ± 0.639
# bilinear_CM               16.070 ± 1.388
# exponential_decay         15.667 ± 0.711
# gaussian_kernel           18.336 ± 1.726
# cge                       15.120 ± 0.807
# Subnetwork Test Metrics:
#                             Vis Intra      Vis Inter   SomMot Intra  \
# Model
# shared_transformer_cls  0.886 ± 0.059  0.872 ± 0.024  0.876 ± 0.061
# dynamic_mlp_coords      0.880 ± 0.054  0.866 ± 0.024  0.870 ± 0.055
# shared_transformer      0.872 ± 0.054  0.843 ± 0.023  0.842 ± 0.073
# dynamic_mlp             0.858 ± 0.067  0.834 ± 0.027  0.836 ± 0.064
# bilinear_lowrank        0.838 ± 0.065  0.818 ± 0.027  0.821 ± 0.061
# pls_bilineardecoder     0.794 ± 0.085  0.770 ± 0.072  0.774 ± 0.100
# bilinear_CM_PCA         0.603 ± 0.125  0.566 ± 0.055  0.570 ± 0.129
# bilinear_CM             0.727 ± 0.115  0.682 ± 0.088  0.658 ± 0.136
# exponential_decay       0.497 ± 0.156  0.332 ± 0.092  0.332 ± 0.144
# gaussian_kernel         0.452 ± 0.156  0.272 ± 0.072  0.265 ± 0.143
# cge                     0.373 ± 0.152  0.298 ± 0.078  0.359 ± 0.119
#
#                          SomMot Inter DorsAttn Intra DorsAttn Inter  \
# Model
# shared_transformer_cls  0.875 ± 0.029  0.861 ± 0.076  0.876 ± 0.028
# dynamic_mlp_coords      0.866 ± 0.029  0.843 ± 0.114  0.866 ± 0.030
# shared_transformer      0.845 ± 0.032  0.821 ± 0.138  0.845 ± 0.035
# dynamic_mlp             0.839 ± 0.032  0.808 ± 0.144  0.840 ± 0.040
# bilinear_lowrank        0.827 ± 0.031  0.803 ± 0.137  0.830 ± 0.039
# pls_bilineardecoder     0.782 ± 0.074  0.767 ± 0.153  0.789 ± 0.064
# bilinear_CM_PCA         0.573 ± 0.069  0.598 ± 0.224  0.598 ± 0.070
# bilinear_CM             0.684 ± 0.103  0.653 ± 0.201  0.690 ± 0.100
# exponential_decay       0.356 ± 0.057  0.089 ± 0.226  0.313 ± 0.073
# gaussian_kernel         0.297 ± 0.043  0.123 ± 0.220  0.275 ± 0.070
# cge                     0.311 ± 0.058  0.207 ± 0.236  0.248 ± 0.078
#
#                        SalVentAttn Intra SalVentAttn Inter   Limbic Intra  \
# Model
# shared_transformer_cls     0.853 ± 0.093     0.867 ± 0.028  0.856 ± 0.144
# dynamic_mlp_coords         0.854 ± 0.084     0.860 ± 0.031  0.845 ± 0.145
# shared_transformer         0.818 ± 0.143     0.833 ± 0.039  0.843 ± 0.126
# dynamic_mlp                0.815 ± 0.167     0.829 ± 0.039  0.822 ± 0.172
# bilinear_lowrank           0.788 ± 0.136     0.812 ± 0.045  0.803 ± 0.156
# pls_bilineardecoder        0.742 ± 0.198     0.771 ± 0.083  0.781 ± 0.218
# bilinear_CM_PCA            0.559 ± 0.174     0.586 ± 0.060  0.635 ± 0.255
# bilinear_CM                0.647 ± 0.214     0.667 ± 0.105  0.712 ± 0.231
# exponential_decay          0.299 ± 0.261     0.340 ± 0.061  0.200 ± 0.390
# gaussian_kernel            0.286 ± 0.243     0.308 ± 0.062  0.199 ± 0.372
# cge                        0.156 ± 0.216     0.242 ± 0.061  0.160 ± 0.397
#
#                          Limbic Inter     Cont Intra     Cont Inter  \
# Model
# shared_transformer_cls  0.867 ± 0.031  0.838 ± 0.102  0.853 ± 0.040
# dynamic_mlp_coords      0.858 ± 0.035  0.825 ± 0.106  0.847 ± 0.040
# shared_transformer      0.833 ± 0.040  0.790 ± 0.105  0.813 ± 0.043
# dynamic_mlp             0.826 ± 0.047  0.783 ± 0.104  0.808 ± 0.043
# bilinear_lowrank        0.816 ± 0.040  0.766 ± 0.148  0.799 ± 0.049
# pls_bilineardecoder     0.779 ± 0.066  0.721 ± 0.163  0.751 ± 0.077
# bilinear_CM_PCA         0.590 ± 0.082  0.497 ± 0.239  0.538 ± 0.085
# bilinear_CM             0.679 ± 0.090  0.658 ± 0.145  0.663 ± 0.097
# exponential_decay       0.349 ± 0.080  0.217 ± 0.224  0.322 ± 0.074
# gaussian_kernel         0.318 ± 0.084  0.179 ± 0.210  0.284 ± 0.070
# cge                     0.245 ± 0.066  0.190 ± 0.168  0.230 ± 0.059
#
#                         Default Intra  Default Inter Subcortical Intra  \
# Model
# shared_transformer_cls  0.809 ± 0.081  0.843 ± 0.034     0.789 ± 0.112
# dynamic_mlp_coords      0.824 ± 0.060  0.840 ± 0.029     0.774 ± 0.121
# shared_transformer      0.796 ± 0.056  0.812 ± 0.029     0.664 ± 0.205
# dynamic_mlp             0.782 ± 0.073  0.804 ± 0.033     0.654 ± 0.259
# bilinear_lowrank        0.773 ± 0.066  0.793 ± 0.033     0.680 ± 0.199
# pls_bilineardecoder     0.723 ± 0.083  0.740 ± 0.082     0.619 ± 0.195
# bilinear_CM_PCA         0.433 ± 0.126  0.508 ± 0.064     0.399 ± 0.225
# bilinear_CM             0.620 ± 0.151  0.639 ± 0.093     0.472 ± 0.304
# exponential_decay       0.298 ± 0.160  0.281 ± 0.043     0.235 ± 0.325
# gaussian_kernel         0.272 ± 0.157  0.251 ± 0.042     0.188 ± 0.293
# cge                     0.224 ± 0.119  0.224 ± 0.058     0.284 ± 0.249
#
#                        Subcortical Inter Cerebellum Intra Cerebellum Inter
# Model
# shared_transformer_cls     0.855 ± 0.028    0.684 ± 0.507    0.853 ± 0.035
# dynamic_mlp_coords         0.843 ± 0.029    0.603 ± 0.527    0.840 ± 0.043
# shared_transformer         0.808 ± 0.033    0.743 ± 0.336    0.808 ± 0.042
# dynamic_mlp                0.799 ± 0.038    0.524 ± 0.516    0.791 ± 0.058
# bilinear_lowrank           0.795 ± 0.034    0.543 ± 0.691    0.789 ± 0.051
# pls_bilineardecoder        0.744 ± 0.076    0.829 ± 0.367    0.735 ± 0.089
# bilinear_CM_PCA            0.510 ± 0.056    0.038 ± 0.852    0.495 ± 0.086
# bilinear_CM                0.648 ± 0.087    0.109 ± 0.726    0.646 ± 0.096
# exponential_decay          0.294 ± 0.064    0.195 ± 0.807    0.276 ± 0.068
# gaussian_kernel            0.250 ± 0.063    0.246 ± 0.804    0.243 ± 0.081
# cge                        0.250 ± 0.060    0.326 ± 0.823    0.260 ± 0.085
# Random Test Spin Metrics:
#
# Global Test  Spin Metrics:
#                             pearson_r              r2        short_r  \
# Model
# shared_transformer_cls  0.732 ± 0.050   0.502 ± 0.089  0.759 ± 0.051
# dynamic_mlp_coords      0.483 ± 0.088   0.132 ± 0.139  0.498 ± 0.093
# shared_transformer      0.343 ± 0.086  -0.115 ± 0.149  0.344 ± 0.089
# dynamic_mlp             0.286 ± 0.086  -0.260 ± 0.158  0.299 ± 0.084
# bilinear_lowrank        0.415 ± 0.072   0.141 ± 0.071  0.420 ± 0.069
# pls_bilineardecoder     0.330 ± 0.081   0.075 ± 0.086  0.334 ± 0.092
# bilinear_CM_PCA         0.315 ± 0.063   0.087 ± 0.053  0.337 ± 0.070
# bilinear_CM             0.205 ± 0.083  -1.480 ± 0.997  0.222 ± 0.082
# exponential_decay       0.346 ± 0.027   0.117 ± 0.021  0.411 ± 0.038
# gaussian_kernel         0.303 ± 0.023   0.081 ± 0.022  0.394 ± 0.037
# cge                     0.173 ± 0.037  -3.907 ± 0.434  0.212 ± 0.042
#
#                                 mid_r         long_r   strong_pos_r  \
# Model
# shared_transformer_cls  0.687 ± 0.057  0.666 ± 0.079  0.460 ± 0.075
# dynamic_mlp_coords      0.410 ± 0.090  0.370 ± 0.125  0.318 ± 0.060
# shared_transformer      0.288 ± 0.085  0.280 ± 0.113  0.174 ± 0.071
# dynamic_mlp             0.234 ± 0.084  0.223 ± 0.114  0.153 ± 0.073
# bilinear_lowrank        0.347 ± 0.079  0.346 ± 0.103  0.218 ± 0.077
# pls_bilineardecoder     0.258 ± 0.084  0.267 ± 0.096  0.188 ± 0.085
# bilinear_CM_PCA         0.217 ± 0.068  0.240 ± 0.071  0.273 ± 0.074
# bilinear_CM             0.160 ± 0.077  0.153 ± 0.104  0.101 ± 0.076
# exponential_decay       0.071 ± 0.032  0.094 ± 0.059  0.338 ± 0.043
# gaussian_kernel         0.039 ± 0.023  0.062 ± 0.045  0.323 ± 0.047
# cge                     0.080 ± 0.032  0.116 ± 0.081  0.222 ± 0.056
#
#                           strong_neg_r         weak_r    left_hemi_r  \
# Model
# shared_transformer_cls   0.164 ± 0.126  0.608 ± 0.060  0.705 ± 0.074
# dynamic_mlp_coords       0.057 ± 0.135  0.356 ± 0.086  0.460 ± 0.102
# shared_transformer       0.048 ± 0.131  0.252 ± 0.071  0.341 ± 0.100
# dynamic_mlp              0.019 ± 0.139  0.207 ± 0.071  0.276 ± 0.098
# bilinear_lowrank         0.028 ± 0.120  0.306 ± 0.069  0.403 ± 0.079
# pls_bilineardecoder     -0.005 ± 0.120  0.239 ± 0.066  0.325 ± 0.082
# bilinear_CM_PCA          0.011 ± 0.108  0.202 ± 0.046  0.306 ± 0.081
# bilinear_CM              0.004 ± 0.133  0.142 ± 0.069  0.199 ± 0.095
# exponential_decay        0.114 ± 0.092  0.195 ± 0.025  0.398 ± 0.049
# gaussian_kernel          0.074 ± 0.073  0.140 ± 0.016  0.367 ± 0.041
# cge                      0.005 ± 0.127  0.043 ± 0.032  0.182 ± 0.042
#
#                          right_hemi_r   inter_hemi_r            mse  \
# Model
# shared_transformer_cls  0.757 ± 0.058  0.731 ± 0.054  0.017 ± 0.003
# dynamic_mlp_coords      0.501 ± 0.096  0.482 ± 0.087  0.029 ± 0.006
# shared_transformer      0.355 ± 0.096  0.340 ± 0.087  0.038 ± 0.006
# dynamic_mlp             0.303 ± 0.100  0.284 ± 0.087  0.042 ± 0.006
# bilinear_lowrank        0.427 ± 0.088  0.416 ± 0.073  0.029 ± 0.003
# pls_bilineardecoder     0.338 ± 0.102  0.329 ± 0.086  0.031 ± 0.004
# bilinear_CM_PCA         0.329 ± 0.077  0.314 ± 0.061  0.031 ± 0.003
# bilinear_CM             0.236 ± 0.093  0.191 ± 0.083  0.083 ± 0.031
# exponential_decay       0.428 ± 0.047  0.244 ± 0.044  0.030 ± 0.003
# gaussian_kernel         0.388 ± 0.042  0.171 ± 0.035  0.031 ± 0.002
# cge                     0.194 ± 0.059  0.157 ± 0.040  0.164 ± 0.011
#
#                        geodesic_distance
# Model
# shared_transformer_cls    11.611 ± 0.985
# dynamic_mlp_coords        14.022 ± 0.812
# shared_transformer        15.223 ± 1.430
# dynamic_mlp               15.847 ± 1.692
# bilinear_lowrank          16.032 ± 1.392
# pls_bilineardecoder       19.310 ± 3.827
# bilinear_CM_PCA           18.765 ± 1.107
# bilinear_CM               18.212 ± 0.972
# exponential_decay         15.622 ± 0.835
# gaussian_kernel           17.856 ± 1.579
# cge                       15.137 ± 0.890

# %%
# Create the dataframes for spatial
global_metrics_df_spatial, subnetwork_metrics_df_spatial = create_test_metric_dataframes(summary_dict_spatial)

print("SPATIAL TEST METRICS")
print("\nGlobal Test Metrics:")
display(global_metrics_df_spatial)
print("\nSubnetwork Test Metrics:") 
display(subnetwork_metrics_df_spatial)


# Create the dataframes for random
global_metrics_df_spatial_spin, subnetwork_metrics_df_spatial_spin = create_test_metric_dataframes(summary_dict_spatial_spin)

print("\nSpatial Test Spin Metrics:")
print("\nGlobal Test  Spin Metrics:")
display(global_metrics_df_spatial_spin)
# Out:
# SPATIAL TEST METRICS
#
# Global Test Metrics:
#                             pearson_r              r2        short_r  \
# Model
# shared_transformer_cls  0.699 ± 0.019   0.403 ± 0.049  0.700 ± 0.021
# dynamic_mlp_coords      0.735 ± 0.021   0.486 ± 0.046  0.736 ± 0.023
# shared_transformer      0.719 ± 0.021   0.468 ± 0.042  0.722 ± 0.023
# dynamic_mlp             0.721 ± 0.020   0.442 ± 0.051  0.727 ± 0.022
# bilinear_lowrank        0.660 ± 0.021   0.409 ± 0.035  0.670 ± 0.023
# pls_bilineardecoder     0.579 ± 0.027   0.297 ± 0.042  0.595 ± 0.028
# bilinear_CM_PCA         0.423 ± 0.024  -1.281 ± 0.600  0.421 ± 0.026
# bilinear_CM             0.443 ± 0.039  -0.945 ± 0.428  0.432 ± 0.042
# exponential_decay       0.441 ± 0.009   0.153 ± 0.014  0.445 ± 0.009
# gaussian_kernel         0.408 ± 0.008   0.075 ± 0.022  0.431 ± 0.009
# cge                     0.305 ± 0.013  -3.830 ± 0.308  0.301 ± 0.013
#
#                                 mid_r          long_r   strong_pos_r  \
# Model
# shared_transformer_cls  0.616 ± 0.021   0.530 ± 0.040  0.409 ± 0.020
# dynamic_mlp_coords      0.663 ± 0.022   0.579 ± 0.035  0.461 ± 0.019
# shared_transformer      0.646 ± 0.022   0.492 ± 0.043  0.405 ± 0.017
# dynamic_mlp             0.643 ± 0.022   0.498 ± 0.042  0.430 ± 0.018
# bilinear_lowrank        0.566 ± 0.024   0.400 ± 0.045  0.346 ± 0.016
# pls_bilineardecoder     0.458 ± 0.033   0.381 ± 0.039  0.324 ± 0.016
# bilinear_CM_PCA         0.294 ± 0.021   0.198 ± 0.037  0.217 ± 0.019
# bilinear_CM             0.428 ± 0.030   0.247 ± 0.032  0.145 ± 0.031
# exponential_decay       0.080 ± 0.013  -0.006 ± 0.020  0.356 ± 0.014
# gaussian_kernel         0.045 ± 0.007   0.007 ± 0.012  0.349 ± 0.014
# cge                     0.141 ± 0.018   0.067 ± 0.040  0.301 ± 0.012
#
#                           strong_neg_r         weak_r    left_hemi_r  \
# Model
# shared_transformer_cls   0.075 ± 0.032  0.540 ± 0.020  0.676 ± 0.025
# dynamic_mlp_coords       0.074 ± 0.029  0.583 ± 0.023  0.711 ± 0.022
# shared_transformer       0.103 ± 0.030  0.575 ± 0.022  0.694 ± 0.024
# dynamic_mlp              0.081 ± 0.030  0.567 ± 0.023  0.703 ± 0.021
# bilinear_lowrank         0.028 ± 0.027  0.524 ± 0.023  0.630 ± 0.024
# pls_bilineardecoder      0.003 ± 0.026  0.441 ± 0.028  0.565 ± 0.033
# bilinear_CM_PCA         -0.020 ± 0.018  0.284 ± 0.018  0.421 ± 0.026
# bilinear_CM              0.011 ± 0.024  0.361 ± 0.032  0.381 ± 0.042
# exponential_decay        0.074 ± 0.021  0.236 ± 0.006  0.489 ± 0.016
# gaussian_kernel          0.094 ± 0.012  0.199 ± 0.004  0.467 ± 0.015
# cge                     -0.023 ± 0.022  0.116 ± 0.014  0.355 ± 0.022
#
#                          right_hemi_r   inter_hemi_r            mse  \
# Model
# shared_transformer_cls  0.711 ± 0.028  0.617 ± 0.032  0.025 ± 0.002
# dynamic_mlp_coords      0.734 ± 0.025  0.656 ± 0.025  0.021 ± 0.002
# shared_transformer      0.716 ± 0.029  0.631 ± 0.026  0.022 ± 0.002
# dynamic_mlp             0.729 ± 0.022  0.624 ± 0.027  0.023 ± 0.002
# bilinear_lowrank        0.647 ± 0.028  0.573 ± 0.026  0.025 ± 0.001
# pls_bilineardecoder     0.561 ± 0.036  0.521 ± 0.030  0.029 ± 0.002
# bilinear_CM_PCA         0.439 ± 0.031  0.386 ± 0.029  0.080 ± 0.017
# bilinear_CM             0.407 ± 0.042  0.272 ± 0.037  0.076 ± 0.012
# exponential_decay       0.497 ± 0.020  0.366 ± 0.021  0.036 ± 0.001
# gaussian_kernel         0.466 ± 0.018  0.291 ± 0.016  0.039 ± 0.001
# cge                     0.383 ± 0.025  0.311 ± 0.019  0.191 ± 0.007
#
#                        geodesic_distance
# Model
# shared_transformer_cls    11.055 ± 0.302
# dynamic_mlp_coords        10.328 ± 0.328
# shared_transformer        10.881 ± 0.265
# dynamic_mlp               10.506 ± 0.300
# bilinear_lowrank          12.909 ± 0.345
# pls_bilineardecoder       14.466 ± 0.646
# bilinear_CM_PCA           16.299 ± 0.337
# bilinear_CM               16.763 ± 0.364
# exponential_decay         14.015 ± 0.207
# gaussian_kernel           14.352 ± 0.292
# cge                       13.474 ± 0.374
# Subnetwork Test Metrics:
#                             Vis Intra      Vis Inter   SomMot Intra  \
# Model
# shared_transformer_cls  0.698 ± 0.025  0.700 ± 0.018  0.740 ± 0.017
# dynamic_mlp_coords      0.757 ± 0.022  0.757 ± 0.018  0.778 ± 0.017
# shared_transformer      0.754 ± 0.020  0.750 ± 0.016  0.755 ± 0.019
# dynamic_mlp             0.750 ± 0.020  0.750 ± 0.018  0.753 ± 0.021
# bilinear_lowrank        0.645 ± 0.029  0.675 ± 0.019  0.651 ± 0.039
# pls_bilineardecoder     0.572 ± 0.033  0.590 ± 0.027  0.570 ± 0.046
# bilinear_CM_PCA         0.416 ± 0.043  0.443 ± 0.025  0.453 ± 0.028
# bilinear_CM             0.414 ± 0.055  0.464 ± 0.046  0.540 ± 0.044
# exponential_decay       0.422 ± 0.048  0.384 ± 0.014  0.455 ± 0.023
# gaussian_kernel         0.393 ± 0.046  0.350 ± 0.011  0.441 ± 0.036
# cge                     0.313 ± 0.033  0.273 ± 0.016  0.302 ± 0.037
#
#                          SomMot Inter DorsAttn Intra DorsAttn Inter  \
# Model
# shared_transformer_cls  0.705 ± 0.018  0.676 ± 0.035  0.679 ± 0.021
# dynamic_mlp_coords      0.754 ± 0.018  0.734 ± 0.049  0.728 ± 0.024
# shared_transformer      0.737 ± 0.018  0.731 ± 0.044  0.716 ± 0.024
# dynamic_mlp             0.739 ± 0.019  0.724 ± 0.052  0.715 ± 0.024
# bilinear_lowrank        0.678 ± 0.018  0.656 ± 0.035  0.657 ± 0.023
# pls_bilineardecoder     0.588 ± 0.030  0.611 ± 0.029  0.566 ± 0.032
# bilinear_CM_PCA         0.449 ± 0.024  0.413 ± 0.051  0.431 ± 0.027
# bilinear_CM             0.476 ± 0.040  0.495 ± 0.048  0.471 ± 0.042
# exponential_decay       0.423 ± 0.013  0.351 ± 0.048  0.396 ± 0.013
# gaussian_kernel         0.380 ± 0.010  0.420 ± 0.025  0.381 ± 0.011
# cge                     0.239 ± 0.021  0.392 ± 0.034  0.285 ± 0.016
#
#                        SalVentAttn Intra SalVentAttn Inter   Limbic Intra  \
# Model
# shared_transformer_cls     0.692 ± 0.028     0.672 ± 0.024  0.711 ± 0.036
# dynamic_mlp_coords         0.719 ± 0.031     0.715 ± 0.027  0.714 ± 0.043
# shared_transformer         0.709 ± 0.030     0.702 ± 0.025  0.689 ± 0.053
# dynamic_mlp                0.700 ± 0.030     0.706 ± 0.025  0.703 ± 0.052
# bilinear_lowrank           0.633 ± 0.033     0.643 ± 0.028  0.660 ± 0.048
# pls_bilineardecoder        0.514 ± 0.055     0.558 ± 0.035  0.556 ± 0.062
# bilinear_CM_PCA            0.411 ± 0.045     0.429 ± 0.025  0.476 ± 0.047
# bilinear_CM                0.446 ± 0.054     0.436 ± 0.045  0.502 ± 0.062
# exponential_decay          0.472 ± 0.032     0.419 ± 0.014  0.442 ± 0.057
# gaussian_kernel            0.442 ± 0.033     0.379 ± 0.012  0.474 ± 0.037
# cge                        0.283 ± 0.028     0.205 ± 0.026  0.255 ± 0.045
#
#                          Limbic Inter     Cont Intra     Cont Inter  \
# Model
# shared_transformer_cls  0.667 ± 0.025  0.627 ± 0.032  0.655 ± 0.023
# dynamic_mlp_coords      0.716 ± 0.027  0.669 ± 0.031  0.698 ± 0.025
# shared_transformer      0.693 ± 0.026  0.663 ± 0.033  0.687 ± 0.025
# dynamic_mlp             0.711 ± 0.025  0.655 ± 0.031  0.690 ± 0.024
# bilinear_lowrank        0.639 ± 0.027  0.601 ± 0.036  0.631 ± 0.025
# pls_bilineardecoder     0.561 ± 0.032  0.538 ± 0.043  0.548 ± 0.034
# bilinear_CM_PCA         0.421 ± 0.028  0.469 ± 0.029  0.429 ± 0.024
# bilinear_CM             0.456 ± 0.043  0.390 ± 0.053  0.407 ± 0.048
# exponential_decay       0.375 ± 0.014  0.458 ± 0.026  0.404 ± 0.013
# gaussian_kernel         0.323 ± 0.012  0.434 ± 0.028  0.379 ± 0.012
# cge                     0.280 ± 0.014  0.308 ± 0.031  0.273 ± 0.016
#
#                         Default Intra  Default Inter Subcortical Intra  \
# Model
# shared_transformer_cls  0.662 ± 0.023  0.672 ± 0.021     0.693 ± 0.033
# dynamic_mlp_coords      0.713 ± 0.026  0.716 ± 0.025     0.664 ± 0.054
# shared_transformer      0.689 ± 0.024  0.702 ± 0.024     0.691 ± 0.041
# dynamic_mlp             0.701 ± 0.024  0.705 ± 0.023     0.673 ± 0.051
# bilinear_lowrank        0.648 ± 0.024  0.645 ± 0.024     0.633 ± 0.043
# pls_bilineardecoder     0.538 ± 0.034  0.552 ± 0.033     0.566 ± 0.043
# bilinear_CM_PCA         0.398 ± 0.027  0.417 ± 0.025     0.386 ± 0.049
# bilinear_CM             0.435 ± 0.047  0.427 ± 0.046     0.482 ± 0.049
# exponential_decay       0.447 ± 0.017  0.398 ± 0.013     0.377 ± 0.031
# gaussian_kernel         0.421 ± 0.014  0.365 ± 0.011     0.272 ± 0.022
# cge                     0.316 ± 0.022  0.236 ± 0.019     0.164 ± 0.029
#
#                        Subcortical Inter Cerebellum Intra Cerebellum Inter
# Model
# shared_transformer_cls     0.671 ± 0.023    0.588 ± 0.046    0.681 ± 0.025
# dynamic_mlp_coords         0.724 ± 0.025    0.539 ± 0.061    0.745 ± 0.018
# shared_transformer         0.701 ± 0.025    0.513 ± 0.073    0.729 ± 0.017
# dynamic_mlp                0.711 ± 0.024    0.480 ± 0.070    0.730 ± 0.016
# bilinear_lowrank           0.660 ± 0.026    0.482 ± 0.066    0.646 ± 0.023
# pls_bilineardecoder        0.557 ± 0.032    0.473 ± 0.060    0.552 ± 0.034
# bilinear_CM_PCA            0.407 ± 0.029    0.364 ± 0.044    0.439 ± 0.028
# bilinear_CM                0.445 ± 0.048    0.167 ± 0.088    0.407 ± 0.046
# exponential_decay          0.386 ± 0.014    0.330 ± 0.047    0.303 ± 0.031
# gaussian_kernel            0.327 ± 0.012    0.464 ± 0.056    0.243 ± 0.027
# cge                        0.217 ± 0.018    0.032 ± 0.056    0.221 ± 0.031
# Spatial Test Spin Metrics:
#
# Global Test  Spin Metrics:
#                             pearson_r              r2        short_r  \
# Model
# shared_transformer_cls  0.488 ± 0.021   0.006 ± 0.062  0.479 ± 0.022
# dynamic_mlp_coords      0.421 ± 0.015   0.034 ± 0.032  0.403 ± 0.015
# shared_transformer      0.301 ± 0.019  -0.135 ± 0.034  0.290 ± 0.019
# dynamic_mlp             0.261 ± 0.019  -0.258 ± 0.048  0.253 ± 0.018
# bilinear_lowrank        0.336 ± 0.021   0.052 ± 0.025  0.327 ± 0.021
# pls_bilineardecoder     0.259 ± 0.019  -0.011 ± 0.023  0.251 ± 0.020
# bilinear_CM_PCA         0.249 ± 0.021  -1.167 ± 0.588  0.233 ± 0.021
# bilinear_CM             0.152 ± 0.020  -2.315 ± 0.537  0.145 ± 0.020
# exponential_decay       0.437 ± 0.009   0.147 ± 0.014  0.442 ± 0.009
# gaussian_kernel         0.405 ± 0.008   0.069 ± 0.022  0.428 ± 0.009
# cge                     0.234 ± 0.011  -3.696 ± 0.271  0.227 ± 0.010
#
#                                 mid_r          long_r   strong_pos_r  \
# Model
# shared_transformer_cls  0.359 ± 0.025   0.387 ± 0.019  0.286 ± 0.018
# dynamic_mlp_coords      0.279 ± 0.016   0.209 ± 0.023  0.256 ± 0.015
# shared_transformer      0.206 ± 0.018   0.147 ± 0.019  0.128 ± 0.014
# dynamic_mlp             0.171 ± 0.017   0.103 ± 0.012  0.106 ± 0.012
# bilinear_lowrank        0.216 ± 0.020   0.170 ± 0.020  0.161 ± 0.013
# pls_bilineardecoder     0.142 ± 0.020   0.125 ± 0.013  0.139 ± 0.014
# bilinear_CM_PCA         0.128 ± 0.017   0.102 ± 0.021  0.153 ± 0.015
# bilinear_CM             0.099 ± 0.015   0.070 ± 0.010  0.052 ± 0.014
# exponential_decay       0.078 ± 0.012  -0.008 ± 0.023  0.355 ± 0.014
# gaussian_kernel         0.045 ± 0.007  -0.005 ± 0.014  0.349 ± 0.014
# cge                     0.081 ± 0.012  -0.004 ± 0.020  0.189 ± 0.012
#
#                           strong_neg_r         weak_r    left_hemi_r  \
# Model
# shared_transformer_cls   0.040 ± 0.027  0.322 ± 0.018  0.518 ± 0.027
# dynamic_mlp_coords       0.041 ± 0.020  0.247 ± 0.012  0.427 ± 0.022
# shared_transformer      -0.013 ± 0.020  0.190 ± 0.015  0.284 ± 0.025
# dynamic_mlp              0.034 ± 0.016  0.160 ± 0.014  0.274 ± 0.026
# bilinear_lowrank         0.022 ± 0.019  0.209 ± 0.018  0.332 ± 0.024
# pls_bilineardecoder      0.025 ± 0.018  0.147 ± 0.015  0.277 ± 0.028
# bilinear_CM_PCA          0.022 ± 0.020  0.136 ± 0.013  0.235 ± 0.029
# bilinear_CM              0.006 ± 0.018  0.098 ± 0.013  0.143 ± 0.022
# exponential_decay        0.078 ± 0.021  0.234 ± 0.006  0.484 ± 0.017
# gaussian_kernel          0.092 ± 0.013  0.197 ± 0.004  0.462 ± 0.016
# cge                      0.035 ± 0.021  0.083 ± 0.010  0.250 ± 0.024
#
#                          right_hemi_r   inter_hemi_r            mse  \
# Model
# shared_transformer_cls  0.556 ± 0.028  0.476 ± 0.036  0.041 ± 0.002
# dynamic_mlp_coords      0.427 ± 0.041  0.410 ± 0.020  0.041 ± 0.002
# shared_transformer      0.278 ± 0.034  0.245 ± 0.020  0.048 ± 0.002
# dynamic_mlp             0.268 ± 0.025  0.202 ± 0.019  0.053 ± 0.002
# bilinear_lowrank        0.306 ± 0.035  0.276 ± 0.022  0.041 ± 0.002
# pls_bilineardecoder     0.251 ± 0.033  0.222 ± 0.023  0.044 ± 0.002
# bilinear_CM_PCA         0.269 ± 0.032  0.230 ± 0.023  0.072 ± 0.013
# bilinear_CM             0.125 ± 0.037  0.087 ± 0.017  0.119 ± 0.011
# exponential_decay       0.507 ± 0.023  0.361 ± 0.021  0.037 ± 0.001
# gaussian_kernel         0.478 ± 0.023  0.288 ± 0.016  0.039 ± 0.001
# cge                     0.282 ± 0.028  0.231 ± 0.018  0.188 ± 0.006
#
#                        geodesic_distance
# Model
# shared_transformer_cls    12.603 ± 0.230
# dynamic_mlp_coords        14.099 ± 0.240
# shared_transformer        15.172 ± 0.260
# dynamic_mlp               15.225 ± 0.257
# bilinear_lowrank          16.566 ± 0.334
# pls_bilineardecoder       20.212 ± 0.664
# bilinear_CM_PCA           19.427 ± 0.317
# bilinear_CM               18.781 ± 0.305
# exponential_decay         14.097 ± 0.228
# gaussian_kernel           14.403 ± 0.290
# cge                       13.721 ± 0.349

# %%
# Extract metrics for shared_transformer and bilinear_lowrank
smt_metrics = subnetwork_metrics_df_spatial.loc['shared_transformer']
blr_metrics = subnetwork_metrics_df_spatial.loc['bilinear_lowrank']

# Calculate gains for each subnetwork
networks = ['Vis', 'SomMot', 'DorsAttn', 'SalVentAttn', 'Limbic', 'Cont', 'Default', 'Subcortical', 'Cerebellum']
gains = {'Intra': [], 'Inter': []}

for network in networks:
    # Extract values from string format "mean ± std"
    smt_intra = float(smt_metrics[f'{network} Intra'].split('±')[0])
    blr_intra = float(blr_metrics[f'{network} Intra'].split('±')[0])
    smt_inter = float(smt_metrics[f'{network} Inter'].split('±')[0])
    blr_inter = float(blr_metrics[f'{network} Inter'].split('±')[0])
    
    # Calculate gains
    gains['Intra'].append(smt_intra - blr_intra)
    gains['Inter'].append(smt_inter - blr_inter)

# Plot the per-subnetwork gains
plt.figure(figsize=(12, 6))
x = np.arange(len(networks))
width = 0.35

plt.bar(x - width/2, gains['Intra'], width, label='Intra-network gain')
plt.bar(x + width/2, gains['Inter'], width, label='Inter-network gain')

# Calculate and plot mean gains per subnetwork
subnetwork_mean_gains = []
for i in range(len(networks)):
    subnetwork_mean = (gains['Intra'][i] + gains['Inter'][i]) / 2
    subnetwork_mean_gains.append(subnetwork_mean)
    
# Add mean gain points
plt.plot(x, subnetwork_mean_gains, 'ko', markersize=6, label='Mean gain')

plt.xlabel('Subnetworks')
plt.ylabel('SMT > Bilinear Gain (Pearson-r)')
plt.title('Test Performance Gain of SMT vs Bilinear Low-Rank by Subnetwork (Spatial Split)')
plt.xticks(x, networks, rotation=45)
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
from data.data_load import *

# Load necessary labeled data
X, valid_genes = load_transcriptome(parcellation='S456', gene_list='0.2', hemisphere='both', omit_subcortical=False, sort_genes='expression', impute_strategy='mirror_interpolate', return_valid_genes=True)
labels, network_labels = load_network_labels(parcellation='S456', hemisphere='both', omit_subcortical=False)
valid_indices = ~np.isnan(X).all(axis=1)
X_valid = X[valid_indices]
labels = [labels[i] for i in range(len(labels)) if valid_indices[i]]
network_labels = network_labels[valid_indices]
unique_networks = np.unique(network_labels)

# Create color mapping for networks
colors = plt.cm.rainbow(np.linspace(0.0, 1, len(unique_networks)+1))
network_colors = dict(zip(unique_networks, colors))

def plot_network_gains_colored(subnetwork_metrics_df_spatial, network_colors, use_preloaded_gains=False):
    # Manual color mapping based on image with lighter colors
    network_colors = {
        'Cont': '#B77DFF',      # Lighter purple
        'Default': '#6BB5FF',   # Lighter blue  
        'DorsAttn': '#66E6E8',  # Lighter turquoise
        'Limbic': '#BFFFBF',    # Lighter green
        'SalVentAttn': '#D6CF8D', # Lighter khaki
        'SomMot': '#FFC4A8',    # Lighter salmon
        'Vis': '#FF6666',       # Lighter red
        'Cerebellum': '#B366B3', # Lighter dark purple
        'Subcortical': '#8B58B5' # Lighter indigo
    }

    # Define preloaded gains
    mean_gains = {
        'Vis': 0.088,
        'SomMot': 0.081, 
        'DorsAttn': 0.063,
        'SalVentAttn': 0.061,
        'Limbic': 0.044,
        'Cont': 0.054,
        'Default': 0.047,
        'Subcortical': 0.036,
        'Cerebellum': 0.058
    }

    intra_network_gains = {
        'Vis': 0.11,
        'SomMot': 0.11,
        'DorsAttn': 0.071,
        'SalVentAttn': 0.069,
        'Limbic': 0.035,
        'Cont': 0.057,
        'Default': 0.040,
        'Subcortical': 0.032,
        'Cerebellum': 0.035
    }

    inter_network_gains = {
        'Vis': 0.069,
        'SomMot': 0.056,
        'DorsAttn': 0.055,
        'SalVentAttn': 0.054,
        'Limbic': 0.054,
        'Cont': 0.051,
        'Default': 0.055,
        'Subcortical': 0.041,
        'Cerebellum': 0.082
    }

    networks = ['Vis', 'SomMot', 'DorsAttn', 'SalVentAttn', 'Limbic', 'Cont', 'Default', 'Subcortical', 'Cerebellum']
    gains = {'Intra': [], 'Inter': []}

    if use_preloaded_gains:
        # Use preloaded gains from the dictionaries
        gains['Intra'] = [intra_network_gains[network] for network in networks]
        gains['Inter'] = [inter_network_gains[network] for network in networks]
    else:
        # Extract metrics for shared_transformer and bilinear_lowrank
        smt_metrics = subnetwork_metrics_df_spatial.loc['shared_transformer']
        blr_metrics = subnetwork_metrics_df_spatial.loc['bilinear_lowrank']

        for network in networks:
            # Extract values from string format "mean ± std"
            smt_intra = float(smt_metrics[f'{network} Intra'].split('±')[0])
            blr_intra = float(blr_metrics[f'{network} Intra'].split('±')[0])
            smt_inter = float(smt_metrics[f'{network} Inter'].split('±')[0])
            blr_inter = float(blr_metrics[f'{network} Inter'].split('±')[0])
            
            # Calculate gains
            gains['Intra'].append(smt_intra - blr_intra)
            gains['Inter'].append(smt_inter - blr_inter)

    # Plot the per-subnetwork gains
    plt.figure(figsize=(11, 6), dpi=300)  # Increased DPI to 300
    x = np.arange(len(networks))
    width = 0.35

    # Plot bars with network colors and black outline
    for i, network in enumerate(networks):
        plt.bar(x[i] - width/2, gains['Intra'][i], width, color=network_colors[network], 
                alpha=0.7, edgecolor='black', linewidth=0.5)
        plt.bar(x[i] + width/2, gains['Inter'][i], width, color=network_colors[network], 
                alpha=0.4, edgecolor='black', linewidth=0.5)

    # Calculate and plot mean gains per subnetwork
    subnetwork_mean_gains = []
    for i in range(len(networks)):
        subnetwork_mean = (gains['Intra'][i] + gains['Inter'][i]) / 2
        subnetwork_mean_gains.append(subnetwork_mean)
        
    # Add mean gain points
    plt.plot(x, subnetwork_mean_gains, 'ko', markersize=5, label='Mean gain')

    plt.xlabel('Subnetworks')
    plt.ylabel('Pearson-r Gain')
    plt.title('Spatial Split Performance Gain of SMT > Bilinear Low-rank')
    plt.xticks(x, networks, rotation=45)
    
    # Set y-axis ticks at 0.02 intervals and remove leading zeros
    plt.gca().yaxis.set_major_locator(plt.MultipleLocator(0.02))
    plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x:.2f}'.lstrip('0')))
    
    # Create custom legend
    from matplotlib.patches import Patch
    legend_elements = [
        Patch(facecolor='gray', alpha=0.7, label='Intra-network gain', edgecolor='black', linewidth=0.5),
        Patch(facecolor='gray', alpha=0.4, label='Inter-network gain', edgecolor='black', linewidth=0.5),
        plt.Line2D([0], [0], marker='o', color='k', label='Mean gain', 
                  markerfacecolor='k', markersize=6, linestyle='None')
    ]
    plt.legend(handles=legend_elements)
    
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# Call the function
plot_network_gains_colored(subnetwork_metrics_df_spatial, network_colors, use_preloaded_gains=True)
# Out:
# Resorting genes by expression level

# %%
from data.data_load import *

def plot_network_gains_transposed(subnetwork_metrics_df_spatial, network_colors, use_preloaded_gains=False):
    # Lighter, consistent color map
    network_colors = {
        'Cont': '#B77DFF',      # Lighter purple
        'Default': '#6BB5FF',   # Lighter blue  
        'DorsAttn': '#66E6E8',  # Lighter turquoise
        'Limbic': '#BFFFBF',    # Lighter green
        'SalVentAttn': '#D6CF8D', # Lighter khaki
        'SomMot': '#FFC4A8',    # Lighter salmon
        'Vis': '#FF6666',       # Lighter red
        'Cerebellum': '#B366B3', # Lighter dark purple
        'Subcortical': '#8B58B5' # Lighter indigo
    }
    intra_network_gains = {
        'Vis': 0.11,
        'SomMot': 0.11,
        'DorsAttn': 0.071,
        'SalVentAttn': 0.069,
        'Limbic': 0.035,
        'Cont': 0.057,
        'Default': 0.040,
        'Subcortical': 0.032,
        'Cerebellum': 0.035
    }
    inter_network_gains = {
        'Vis': 0.069,
        'SomMot': 0.056,
        'DorsAttn': 0.055,
        'SalVentAttn': 0.054,
        'Limbic': 0.054,
        'Cont': 0.051,
        'Default': 0.055,
        'Subcortical': 0.041,
        'Cerebellum': 0.082
    }
    # REVERSE ORDER
    networks = ['Cerebellum', 'Subcortical', 'Default', 'Cont', 'Limbic', 'SalVentAttn', 'DorsAttn', 'SomMot', 'Vis']
    gains = {'Intra': [], 'Inter': []}
    if use_preloaded_gains:
        gains['Intra'] = [intra_network_gains[n] for n in networks]
        gains['Inter'] = [inter_network_gains[n] for n in networks]
    else:
        smt_metrics = subnetwork_metrics_df_spatial.loc['shared_transformer']
        blr_metrics = subnetwork_metrics_df_spatial.loc['bilinear_lowrank']
        for network in networks:
            smt_intra = float(smt_metrics[f'{network} Intra'].split('±')[0])
            blr_intra = float(blr_metrics[f'{network} Intra'].split('±')[0])
            smt_inter = float(smt_metrics[f'{network} Inter'].split('±')[0])
            blr_inter = float(blr_metrics[f'{network} Inter'].split('±')[0])
            gains['Intra'].append(smt_intra - blr_intra)
            gains['Inter'].append(smt_inter - blr_inter)

    fig, ax = plt.subplots(figsize=(4, 5.5), dpi=150)
    y = np.arange(len(networks))
    height = 0.43  # Slightly increased bar height

    # SWAP the bar order so INTRA is on top
    bars_intra = ax.barh(
        y + height/2,
        gains['Intra'],
        height=height,
        color=[network_colors[n] for n in networks],
        alpha=0.7,
        edgecolor='black',
        linewidth=0.6,

        label='Intra gain'
    )
    bars_inter = ax.barh(
        y - height/2,
        gains['Inter'],
        height=height,
        color=[network_colors[n] for n in networks],
        alpha=0.4,
        edgecolor='black',
        linewidth=0.6,

        label='Inter gain'
    )

    # Mean gain points - SMALLER, should be above both bars for visibility
    subnetwork_mean_gains = [(gains['Intra'][i] + gains['Inter'][i]) / 2 for i in range(len(networks))]
    ax.plot(
        subnetwork_mean_gains, y, 
        'ko', 
        markersize=4,  # was 3
        zorder=5
    )

    # y-ticks = subnetworks (no label), x-ticks = Pearson gain
    # MOVE y-ticks and y-tick labels from left (ax) to right (ax2)
    ax.set_yticks([])  # Remove y-ticks entirely from left
    ax.set_yticklabels([])  # Remove y-tick labels from left
    ax.set_xlabel('Pearson-r Gain', fontsize=14)  # was 13
    ax.set_ylabel('')
    ax.set_xticks([0.05, 0.10])
    ax.set_xlim(0.03, 0.12)
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'{x:.2f}'.lstrip('0')))
    ax.tick_params(axis='y', labelsize=13, left=False, right=False, length=0)  # was 12
    ax.tick_params(axis='x', labelsize=13)  # was 12

    # Add right-hand side y-axis with ticks/labels
    ax2 = ax.twinx()
    ax2.set_yticks(y)
    ax2.set_yticklabels(networks, fontsize=13)  # was 12
    ax2.tick_params(axis='y', labelsize=13, left=False, right=True)  # was 12
    ax2.set_ylim(ax.get_ylim())  # Sync limits

    # Custom smaller legend in the style of ref code (patches and dot; smaller, compact, edgecolor black)
    legend_elements = [
        Patch(facecolor='gray', alpha=0.7, label='Intra gain', edgecolor='black', linewidth=0.5),
        Patch(facecolor='gray', alpha=0.4, label='Inter gain', edgecolor='black', linewidth=0.5),
        plt.Line2D([0], [0], marker='o', color='k', label='Mean gain', markerfacecolor='k', markersize=6, linestyle='None')  # was 5
    ]
    ax.legend(
        handles=legend_elements,
        loc='center right',
        frameon=True,
        edgecolor='black',
        fontsize=11,  # was 10
        handlelength=1.0,  # was 0.9
        borderpad=0.7,
        labelspacing=0.39  # was 0.35
    )

    # Grid style as in ref code (plt.grid(True, alpha=0.3))
    ax.grid(True, alpha=0.3)
    ax.set_ylim(-0.7, len(networks)-0.3)
    ax2.set_ylim(ax.get_ylim())
    plt.tight_layout()
    plt.show()

# %%
# Call: compact transposed version
plot_network_gains_transposed(subnetwork_metrics_df_spatial, None, use_preloaded_gains=True)

# %% [markdown]
# Manually plot gain above null for replication datasets

# %%
# Data
datasets = ["MPI-183", "MPI-391", "MPI-729", "HCP", "UKBB"]
smt_values = [0.25, 0.3, 0.26, 0.38, 0.42]
smt_cls_values = [0.03, 0.07, 0.08, 0.20, 0.21]

# --- SMT Plot ---
plt.figure(figsize=(4, 5))
plt.plot(datasets, smt_values, marker='o', color='skyblue')

# Define font sizes
ytick_fontsize = 19
xtick_fontsize = 19
ylabel_fontsize = 23
title_fontsize = 25

plt.ylim(0.1, 0.5)                                 # y-axis from 0.1 to 0.5
plt.yticks(np.arange(0.1, 0.51, 0.2), fontsize=ytick_fontsize)  # show y-ticks every 0.2 with consistent font
plt.xticks(rotation=90, fontsize=xtick_fontsize)    # rotate x-axis labels with consistent font

plt.ylabel("Gain over null (r)", fontsize=ylabel_fontsize)
plt.title("SMT", fontsize=title_fontsize)

plt.grid(axis='y', linestyle='--', linewidth=0.5)   # only horizontal lines
plt.grid(axis='x', visible=False)                   # remove vertical gridlines

# Add light horizontal lines every 0.1
for y in np.arange(0.1, 0.51, 0.1):
    plt.axhline(y, color='lightgray', linestyle='-', linewidth=0.5, zorder=0)

plt.tight_layout()
plt.show()

# --- SMT w/ CLS Plot ---
plt.figure(figsize=(4, 5))
plt.plot(datasets, smt_cls_values, marker='o', color='blue')
plt.ylim(0.0, 0.3)                                 # y-axis from 0.0 to 0.3
plt.xticks(rotation=90, fontsize=xtick_fontsize)    # consistent font size and rotation
plt.yticks(np.arange(0.0, 0.31, 0.1), fontsize=ytick_fontsize)  # consistent y-tick font size
plt.ylabel("Gain over null (r)", fontsize=ylabel_fontsize)       # consistent ylabel font
plt.title("SMT w/ [CLS]", fontsize=title_fontsize)                 # consistent title font
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.grid(axis='x', visible=False)

# Add light horizontal lines every 0.1
for y in np.arange(0.0, 0.31, 0.1):
    plt.axhline(y, color='lightgray', linestyle='-', linewidth=0.5, zorder=0)

plt.tight_layout()
plt.show()
