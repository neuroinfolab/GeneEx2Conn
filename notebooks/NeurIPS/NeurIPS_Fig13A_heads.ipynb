# %% [markdown]
# ## NeurIPS attention heads visualization
#
# **Purpose:** Visualization of attention heads for SMT models trained on full dataset
#
# **Associated Figures:** Fig. 13
#
# **Author:** Alexander Ratzan
# **Project:** Predicting Functional Brain Connectivity with Context-Aware Deep Neural Networks (NeurIPS 2025)

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from env.imports import *
# Out:
# /ext3/miniconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 2025-05-29 18:23:44.018751: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-29 18:23:45.515148: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-29 18:23:47.659152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/utils/useful.py:10: PendingDeprecationWarning: Importing from numpy.matlib is deprecated since 1.19.0. The matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   import numpy.matlib as npm
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/plotting/colormaps.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   autumn = cm.get_cmap('autumn', 256)
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/enigmatoolbox-2.0.3-py3.11.egg/enigmatoolbox/plotting/colormaps.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   winter = cm.get_cmap('winter_r', 256)

# %%
import importlib
import data

import models
import sim.sim
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run

importlib.reload(sim.sim)
importlib.reload(sim.sim_run)
# Out:
# absolute_root_path /scratch/asr655/neuroinformatics/GeneEx2Conn
# absolute_root_path /scratch/asr655/neuroinformatics/GeneEx2Conn
# <module 'sim.sim_run' from '/scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim_run.py'>

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))
# Out:
# CPU Usage: 4.5%
# RAM Usage: 4.4%
# Available RAM: 962.7G
# Total RAM: 1007.0G
# 52.4G

# %%
print(os.environ.get("CUDA_VISIBLE_DEVICES"))

# Check available GPUs
print(f"Available GPUs: {torch.cuda.device_count()}")

for i in range(torch.cuda.device_count()):
    print(f"GPU {i}: {torch.cuda.get_device_name(i)} - Memory Allocated: {torch.cuda.memory_allocated(i)/1024**3:.2f} GB")
# Out:
# None
# Available GPUs: 1
# GPU 0: NVIDIA A100-SXM4-80GB - Memory Allocated: 0.00 GB

# %%
print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)

GPUtil.getAvailable()

# if a number is seen a GPU is available
GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True

    GPUtil.showUtilization()
# Out:
# XGBoost version: 2.0.3
# cupy version: 13.1.0
# GPU found 0
# | ID | GPU | MEM |
# ------------------
# |  0 | 11% |  1% |

# %%
torch.cuda.is_available()

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %% [markdown]
# ### Attention heads analysis

# %%
from models.base_models import ModelBuild, BaseModel
from models.bilinear import BilinearLowRank, BilinearCM
from models.pls import PLSTwoStepModel, PLS_MLPDecoderModel, PLS_BilinearDecoderModel
from models.dynamic_mlp import DynamicMLP
from models.shared_encoder_models import SharedMLPEncoderModel, SharedLinearEncoderModel
from models.transformer_models import SharedSelfAttentionModel, SharedSelfAttentionCLSModel, CrossAttentionModel

from data.data_load import load_transcriptome, load_connectome, load_coords, load_network_labels
from data.data_viz import plot_connectome, plot_transcriptome
from data.data_utils import expand_X_symmetric, expand_Y_symmetric

from data.data_utils import RegionPairDataset
from torch.utils.data import Subset

# %% [markdown]
# ### Load UKBB data and models

# %%
# Load data
print("Loading data...")
X_UKBB = load_transcriptome(parcellation='S400', hemisphere='both', omit_subcortical=False, sort_genes='refgenome', impute_strategy='mirror_interpolate')
Y_UKBB = load_connectome(parcellation='S400', hemisphere='both', omit_subcortical=False)
coords_UKBB = load_coords(parcellation='S400', hemisphere='both', omit_subcortical=False)
labels_UKBB, network_labels_UKBB = load_network_labels(parcellation='S400', hemisphere='both', omit_subcortical=False)

# Find rows that are not all NaN - necessary for gene expression data with unsampled regions
valid_indices_UKBB = ~np.isnan(X_UKBB).all(axis=1)

# Create index map so we know true indices of valid data
valid_indices_values_UKBB = np.where(valid_indices_UKBB)[0]
valid2true_mapping_UKBB = dict(enumerate(valid_indices_values_UKBB))

# Subset all data using valid indices
X_UKBB_valid = X_UKBB[valid_indices_UKBB]
Y_UKBB_valid = Y_UKBB[valid_indices_UKBB][:, valid_indices_UKBB]
coords_UKBB_valid = coords_UKBB[valid_indices_UKBB]
labels_UKBB = [labels_UKBB[i] for i in range(len(labels_UKBB)) if valid_indices_UKBB[i]]
network_labels_UKBB = network_labels_UKBB[valid_indices_UKBB]

print(f"X_UKBB_valid shape: {X_UKBB_valid.shape}")

# Create full region pair dataset
print("Creating RegionPairDataset...")
dataset_UKBB = RegionPairDataset(
    X=X_UKBB_valid,
    Y=Y_UKBB_valid,
    coords=coords_UKBB_valid,
    valid2true_mapping=valid2true_mapping_UKBB
)

batch_size = 512
# Create dataloader with all pairs
dataloader_UKBB = DataLoader(
    dataset_UKBB,
    batch_size=batch_size,
    shuffle=False,
    num_workers=4,
    pin_memory=True  # Speed up data transfer to GPU
)

# Set up regular self-attention model with same hyperparameters
smt_UKBB_model = SharedSelfAttentionModel(
    input_dim=14760,
    token_encoder_dim=60, 
    d_model=128,
    nhead=4,
    num_layers=4,
    use_alibi=True,
    dropout_rate=0.2,
    transformer_dropout=0.2,
    aug_prob=0.0,
    binarize=False
)

# Load saved weights
smt_UKBB_model.load_state_dict(torch.load("/scratch/asr655/neuroinformatics/GeneEx2Conn/models/saved_models/UKBB_base.pt"))
smt_UKBB_model.eval()
smt_UKBB_model.to("cuda")

# Set up CLS model with the same hyperparameters used for training
smt_cls_UKBB_model = SharedSelfAttentionCLSModel(
    input_dim=14760,   # should be 2 * num_genes
    token_encoder_dim=60,
    d_model=128,
    encoder_output_dim=10,
    nhead=4,
    num_layers=4,
    cls_init='spatial_learned',
    use_alibi=True,
    dropout_rate=0.2,
    transformer_dropout=0.2,
    aug_prob=0.0,
    binarize=False
)

# Load saved CLS weights
smt_cls_UKBB_model.load_state_dict(torch.load("/scratch/asr655/neuroinformatics/GeneEx2Conn/models/saved_models/UKBB_cls.pt"))
smt_cls_UKBB_model.eval()
smt_cls_UKBB_model.to("cuda")
# Out:
# Loading data...
# X_UKBB_valid shape: (455, 7380)
# Creating RegionPairDataset...
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Number of learnable parameters in SMT model: 1399947
# Number of learnable parameters in SMT w/ CLS model: 1405579
# SharedSelfAttentionCLSModel(
#   (encoder): OptimizedModule(
#     (_orig_mod): SelfAttentionCLSEncoder(
#       (input_projection): Linear(in_features=60, out_features=128, bias=True)
#       (coord_to_cls): Linear(in_features=3, out_features=128, bias=True)
#       (layers): ModuleList(
#         (0-3): 4 x FastSelfAttentionBlock(
#           (qkv_proj): Linear(in_features=128, out_features=384, bias=True)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (attn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (ffn): Sequential(
#             (0): Linear(in_features=128, out_features=512, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=512, out_features=128, bias=True)
#             (3): Dropout(p=0.2, inplace=False)
#           )
#           (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (output_projection): Linear(in_features=128, out_features=10, bias=True)
#     )
#   )
#   (deep_layers): Sequential(
#     (0): Linear(in_features=2480, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (output_layer): Linear(in_features=128, out_features=1, bias=True)
#   (criterion): MSELoss()
# )

# %%
# Load data
print("Loading data...")
X_iPA391 = load_transcriptome(parcellation='iPA_391', hemisphere='both', omit_subcortical=False, sort_genes='refgenome', impute_strategy='mirror_interpolate')
Y_iPA391 = load_connectome(parcellation='iPA_391', hemisphere='both', omit_subcortical=False)
coords_iPA391 = load_coords(parcellation='iPA_391', hemisphere='both', omit_subcortical=False)
labels_iPA391, network_labels_iPA391 = load_network_labels(parcellation='iPA_391', hemisphere='both', omit_subcortical=False)

# Find rows that are not all NaN - necessary for gene expression data with unsampled regions
valid_indices_iPA391 = ~np.isnan(X_iPA391).all(axis=1)

# Create index map so we know true indices of valid data
valid_indices_values_iPA391 = np.where(valid_indices_iPA391)[0]
valid2true_mapping_iPA391 = dict(enumerate(valid_indices_values_iPA391))

# Subset all data using valid indices
X_iPA391_valid = X_iPA391[valid_indices_iPA391]
Y_iPA391_valid = Y_iPA391[valid_indices_iPA391][:, valid_indices_iPA391]
coords_iPA391_valid = coords_iPA391[valid_indices_iPA391]
labels_iPA391 = [labels_iPA391[i] for i in range(len(labels_iPA391)) if valid_indices_iPA391[i]]
network_labels_iPA391 = network_labels_iPA391[valid_indices_iPA391]

print(f"X_iPA391_valid shape: {X_iPA391_valid.shape}")

# Create full region pair dataset
print("Creating RegionPairDataset...")
dataset_iPA391 = RegionPairDataset(
    X=X_iPA391_valid,
    Y=Y_iPA391_valid,
    coords=coords_iPA391_valid,
    valid2true_mapping=valid2true_mapping_iPA391
)

batch_size = 512
# Create dataloader with all pairs
dataloader_iPA391 = DataLoader(
    dataset_iPA391,
    batch_size=batch_size,
    shuffle=False,
    num_workers=4,
    pin_memory=True  # Speed up data transfer to GPU
)

# Set up regular self-attention model with same hyperparameters
smt_iPA391_model = SharedSelfAttentionModel(
    input_dim=14760,
    token_encoder_dim=60, 
    d_model=128,
    nhead=4,
    num_layers=4,
    use_alibi=True,
    dropout_rate=0.2,
    transformer_dropout=0.2,
    aug_prob=0.0,
    binarize=False
)

# Load saved weights
smt_iPA391_model.load_state_dict(torch.load("/scratch/asr655/neuroinformatics/GeneEx2Conn/models/saved_models/iPA391_base.pt"))
smt_iPA391_model.eval()
smt_iPA391_model.to("cuda")

# Set up CLS model with the same hyperparameters used for training
smt_cls_iPA391_model = SharedSelfAttentionCLSModel(
    input_dim=14760,   # should be 2 * num_genes
    token_encoder_dim=60,
    d_model=128,
    encoder_output_dim=10,
    nhead=4,
    num_layers=4,
    cls_init='spatial_learned',
    use_alibi=True,
    dropout_rate=0.2,
    transformer_dropout=0.2,
    aug_prob=0.0,
    binarize=False
)

# Load saved CLS weights
smt_cls_iPA391_model.load_state_dict(torch.load("/scratch/asr655/neuroinformatics/GeneEx2Conn/models/saved_models/iPA391_cls.pt"))
smt_cls_iPA391_model.eval()
smt_cls_iPA391_model.to("cuda")
# Out:
# Loading data...
# X_iPA391_valid shape: (345, 7380)
# Creating RegionPairDataset...
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Number of learnable parameters in SMT model: 1399947
# Number of learnable parameters in SMT w/ CLS model: 1405579
# SharedSelfAttentionCLSModel(
#   (encoder): OptimizedModule(
#     (_orig_mod): SelfAttentionCLSEncoder(
#       (input_projection): Linear(in_features=60, out_features=128, bias=True)
#       (coord_to_cls): Linear(in_features=3, out_features=128, bias=True)
#       (layers): ModuleList(
#         (0-3): 4 x FastSelfAttentionBlock(
#           (qkv_proj): Linear(in_features=128, out_features=384, bias=True)
#           (attn_dropout): Dropout(p=0.2, inplace=False)
#           (attn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (ffn): Sequential(
#             (0): Linear(in_features=128, out_features=512, bias=True)
#             (1): ReLU()
#             (2): Linear(in_features=512, out_features=128, bias=True)
#             (3): Dropout(p=0.2, inplace=False)
#           )
#           (ffn_norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (output_projection): Linear(in_features=128, out_features=10, bias=True)
#     )
#   )
#   (deep_layers): Sequential(
#     (0): Linear(in_features=2480, out_features=256, bias=True)
#     (1): ReLU()
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): ReLU()
#     (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (output_layer): Linear(in_features=128, out_features=1, bias=True)
#   (criterion): MSELoss()
# )

# %% [markdown]
# ### Evaluate attention heads

# %% [markdown]
# Map gene tokens to corresponding genes

# %%
# Get valid genes from load_transcriptome
X, valid_genes = load_transcriptome(parcellation='S400', gene_list='0.2', dataset='AHBA', run_PCA=False, omit_subcortical=False, hemisphere='both', impute_strategy='mirror_interpolate', sort_genes='refgenome', return_valid_genes=True, null_model='none', random_seed=42)

# Get reference genome info for valid genes
refgenome = pd.read_csv('./data/enigma/gene_lists/human_refgenome_ordered.csv')
valid_refgenome = refgenome[refgenome['gene_id'].isin(valid_genes)]

# Create gene groups/tokens
token_chunk_size = 60
num_tokens = len(valid_refgenome) // token_chunk_size
gene_tokens = []

for i in range(num_tokens):
    start_idx = i * token_chunk_size
    end_idx = start_idx + token_chunk_size
    token_genes = valid_refgenome.iloc[start_idx:end_idx]
    
    # Get unique chromosome for this token
    chrom = token_genes['chromosome'].iloc[0]
    
    token = {
        'token_id': i,
        'genes': token_genes['gene_id'].tolist(),
        'chromosome': chrom
    }
    gene_tokens.append(token)

# Handle remaining genes if any
remaining_genes = len(valid_refgenome) % token_chunk_size
if remaining_genes > 0:
    start_idx = num_tokens * token_chunk_size
    token_genes = valid_refgenome.iloc[start_idx:]
    token = {
        'token_id': num_tokens,
        'genes': token_genes['gene_id'].tolist(), 
        'chromosome': token_genes['chromosome'].iloc[0]
    }
    gene_tokens.append(token)

# Get chromosome switch points
chrom_switches = []
for i in range(1, len(gene_tokens)):
    if gene_tokens[i]['chromosome'] != gene_tokens[i-1]['chromosome']:
        chrom_switches.append(i)

gene_tokens
# Out:
# valid genes ['LOC729737', 'LINC01128', 'SAMD11', 'PERM1', 'HES4', 'ISG15', 'AGRN', 'TNFRSF4', 'B3GALT6', 'ACAP3', 'PUSL1', 'DVL1', 'MXRA8', 'CCNL2', 'ANKRD65', 'FNDC10', 'CDK11A', 'GABRD', 'RER1', 'PEX10', 'PLCH2', 'HES5', 'TNFRSF14', 'ARHGEF16', 'TPRG1L', 'AJAP1', 'TNFRSF25', 'PLEKHG5', 'NOL9', 'PHF13', 'CAMTA1', 'PER3', 'ERRFI1', 'SLC45A1', 'ENO1', 'SLC2A5', 'SPSB1', 'TMEM201', 'PIK3CD', 'CLSTN1', 'CTNNBIP1', 'UBE4B', 'PGD', 'TARDBP', 'MASP2', 'SRM', 'FBXO2', 'FBXO44', 'DRAXIN', 'CLCN6', 'NPPA', 'NPPB', 'VPS13D', 'DHRS3', 'LRRC38', 'PDPN', 'PRDM2', 'KAZN', 'EFHD2', 'AGMAT', 'PLEKHM2', 'SLC25A34', 'UQCRHL', 'SRARP', 'SZRD1', 'CROCCP2', 'SDHB', 'RCC2', 'ARHGEF10L', 'IGSF21', 'ALDH4A1', 'IFFO2', 'MRTO4', 'AKR7L', 'AKR7A3', 'AKR7A2', 'CAPZB', 'UBXN10', 'CAMK2N1', 'FAM43B', 'PINK1', 'KIF17', 'SH2D5', 'NBPF3', 'ALPL', 'RAP1GAP', 'CDC42', 'WNT4', 'ZBTB40', 'C1QA', 'C1QC', 'C1QB', 'EPHB2', 'LUZP1', 'ZNF436', 'ZNF436-AS1', 'TCEA3', 'ASAP3', 'HMGCL', 'IFNLR1', 'STPG1', 'NIPAL3', 'RCAN3', 'SYF2', 'RSRP1', 'TMEM50A', 'MACO1', 'MAN1C1', 'SELENON', 'MTFR1L', 'AUNIP', 'STMN1', 'PAFAH2', 'EXTL1', 'PDIK1L', 'SH3BGRL3', 'CD52', 'ARID1A', 'GPATCH3', 'NUDC', 'KDF1', 'TRNP1', 'SLC9A1', 'MAP3K6', 'WASF2', 'IFI6', 'STX12', 'PPP1R8', 'THEMIS2', 'RPA2', 'XKR8', 'EYA3', 'YTHDF2', 'EPB41', 'MECR', 'LAPTM5', 'SDC3', 'NKAIN1', 'ZCCHC17', 'FABP3', 'PEF1', 'COL16A1', 'SPOCD1', 'TXLNA', 'TMEM234', 'MTMR9LP', 'FAM167B', 'HDAC1', 'BSDC1', 'ZBTB8A', 'ZBTB8OS', 'RBBP4', 'KIAA1522', 'S100PBP', 'FNDC5', 'HPCA', 'TMEM54', 'RNF19B', 'AK2', 'ZNF362', 'SMIM12', 'DLGAP3', 'ZMYM4', 'PSMB2', 'C1orf216', 'AGO4', 'AGO1', 'AGO3', 'TEKT2', 'COL8A2', 'LSM10', 'GRIK3', 'LINC01137', 'DNALI1', 'EPHA10', 'MANEAL', 'POU3F1', 'AKIRIN1', 'MACF1', 'PPIEL', 'HEYL', 'HPCAL4', 'PPIE', 'BMP8B', 'TRIT1', 'ZMPSTE24', 'SMAP2', 'ZFP69', 'ZNF684', 'RIMS3', 'NFYC', 'CITED4', 'GUCA2B', 'RIMKLA', 'ZMYND12', 'PPIH', 'YBX1', 'C1orf50', 'EBNA1BP2', 'MED8', 'SZT2', 'HYI', 'PTPRF', 'ST3GAL3', 'B4GALT2', 'CCDC24', 'ERI3', 'RNF220', 'TMEM53', 'KIF2C', 'ZSWIM5', 'MMACHC', 'PRDX1', 'GPBP1L1', 'TSPAN1', 'UQCRH', 'MKNK1', 'ATPAF1', 'CYP4X1', 'CYP4Z1', 'CMPK1', 'SPATA6', 'AGBL4', 'BEND5', 'ELAVL4', 'CDKN2C', 'RNF11', 'TTC39A', 'OSBPL9', 'NRDC', 'RAB3B', 'ZFYVE9', 'GPX7', 'SHISAL2A', 'ZYG11B', 'ECHDC2', 'SCP2', 'C1orf123', 'LRP8', 'GLIS1', 'YIPF1', 'LRRC42', 'MRPL37', 'SSBP3', 'DHCR24', 'TMEM61', 'PLPP3', 'PRKAA2', 'OMA1', 'MYSM1', 'JUN', 'FGGY', 'CYP2J2', 'NFIA', 'PATJ', 'KANK4', 'DOCK7', 'ITGB3BP', 'EFCAB7', 'PGM1', 'CACHD1', 'RAVER2', 'JAK1', 'AK4', 'LEPROT', 'LEPR', 'PDE4B', 'SGIP1', 'TCTEX1D1', 'SLC35D1', 'IL12RB2', 'GNG12', 'DIRAS3', 'WLS', 'LRRC7', 'PIN1P1', 'SRSF11', 'CTH', 'PTGER3', 'ZRANB2', 'NEGR1', 'ERICH3', 'CRYZ', 'TYW3', 'LHX8', 'SLC44A5', 'ST6GALNAC3', 'ST6GALNAC5', 'AK5', 'ZZZ3', 'USP33', 'MIGA1', 'NEXN', 'DNAJB4', 'IFI44', 'ADGRL2', 'SPATA1', 'SSX2IP', 'SYDE2', 'DDAH1', 'COL24A1', 'ODF2L', 'SH3GLB1', 'HS2ST1', 'LINC01140', 'LMO4', 'PKN2', 'GBP3', 'GBP2', 'GBP4', 'LOC729930', 'LRRC8B', 'LRRC8C', 'CDC7', 'EPHX4', 'KIAA1107', 'GLMN', 'EVI5', 'MTF2', 'DR1', 'FNBP1L', 'BCAR3', 'GCLM', 'ARHGAP29', 'F3', 'SLC44A3', 'CNN3', 'DPYD', 'SNX7', 'PLPPR5', 'PLPPR4', 'PALMD', 'AGL', 'RTCA', 'CDC14A', 'GPR88', 'EXTL2', 'DPH5', 'S1PR1', 'OLFM3', 'COL11A1', 'RNPC3', 'PRMT6', 'NTNG1', 'VAV3', 'FAM102B', 'PRPF38B', 'STXBP3', 'GPSM2', 'CLCC1', 'WDR47', 'CELSR2', 'MYBPHL', 'SORT1', 'ATXN7L2', 'AMIGO1', 'GPR61', 'GSTM2', 'GSTM1', 'GSTM5', 'GSTM3', 'AHCYL1', 'ALX3', 'SLC6A17', 'KCNC4', 'RBM15', 'KCNA2', 'KCNA3', 'CD53', 'DENND2D', 'OVGP1', 'C1orf162', 'TMIGD3', 'KCND3', 'LINC01750', 'WNT2B', 'ST7L', 'RHOC', 'PPM1J', 'MAGI3', 'SYT6', 'BCAS2', 'DENND2C', 'NRAS', 'SIKE1', 'TSPAN2', 'VANGL1', 'IGSF3', 'TTF2', 'GDAP2', 'LINC00622', 'ZNF697', 'PHGDH', 'PPIAL4A', 'EMBP1', 'NUDT17', 'RBM8A', 'LIX1L', 'ANKRD34A', 'POLR3GL', 'PRKAB2', 'CHD1L', 'PDIA3P1', 'PPIAL4G', 'MTMR11', 'PLEKHO1', 'ANP32E', 'C1orf54', 'ECM1', 'MCL1', 'ENSA', 'CTSK', 'SETDB1', 'MLLT11', 'TNFAIP8L2', 'PSMD4', 'RFX5', 'SELENBP1', 'SNX27', 'CELF3', 'RIIAD ...
# [{'token_id': 0,
#   'genes': ['LOC729737',
#    'LINC01128',
#    'SAMD11',
#    'PERM1',
#    'HES4',
#    'ISG15',
#    'AGRN',
#    'TNFRSF4',
#    'B3GALT6',
#    'ACAP3',
#    'PUSL1',
#    'DVL1',
#    'MXRA8',
#    'CCNL2',
#    'ANKRD65',
#    'FNDC10',
#    'CDK11A',
#    'GABRD',
#    'RER1',
#    'PEX10',
#    'PLCH2',
#    'HES5',
#    'TNFRSF14',
#    'ARHGEF16',
#    'TPRG1L',
#    'AJAP1',
#    'CHD5',
#    'TNFRSF25',
#    'PLEKHG5',
#    'NOL9',
#    'PHF13',
#    'CAMTA1',
#    'PER3',
#    'ERRFI1',
#    'SLC45A1',
#    'ENO1',
#    'SLC2A5',
#    'SPSB1',
#    'TMEM201',
#    'PIK3CD',
#    'CLSTN1',
#    'CTNNBIP1',
#    'UBE4B',
#    'PGD',
#    'TARDBP',
#    'MASP2',
#    'SRM',
#    'FBXO2',
#    'FBXO44',
#    'DRAXIN',
#    'CLCN6',
#    'NPPA',
#    'NPPB',
#    'VPS13D',
#    'DHRS3',
#    'LRRC38',
#    'PDPN',
#    'PRDM2',
#    'KAZN',
#    'EFHD2'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 1,
#   'genes': ['AGMAT',
#    'PLEKHM2',
#    'SLC25A34',
#    'UQCRHL',
#    'SRARP',
#    'SZRD1',
#    'CROCCP2',
#    'SDHB',
#    'RCC2',
#    'ARHGEF10L',
#    'IGSF21',
#    'ALDH4A1',
#    'IFFO2',
#    'MRTO4',
#    'AKR7L',
#    'AKR7A3',
#    'AKR7A2',
#    'CAPZB',
#    'UBXN10',
#    'CAMK2N1',
#    'FAM43B',
#    'PINK1',
#    'KIF17',
#    'SH2D5',
#    'NBPF3',
#    'ALPL',
#    'RAP1GAP',
#    'CDC42',
#    'WNT4',
#    'ZBTB40',
#    'C1QA',
#    'C1QC',
#    'C1QB',
#    'EPHB2',
#    'LUZP1',
#    'ZNF436',
#    'ZNF436-AS1',
#    'TCEA3',
#    'ASAP3',
#    'HMGCL',
#    'IFNLR1',
#    'STPG1',
#    'NIPAL3',
#    'RCAN3',
#    'SYF2',
#    'RSRP1',
#    'TMEM50A',
#    'MACO1',
#    'MAN1C1',
#    'SELENON',
#    'MTFR1L',
#    'AUNIP',
#    'STMN1',
#    'PAFAH2',
#    'EXTL1',
#    'PDIK1L',
#    'SH3BGRL3',
#    'CD52',
#    'CIT',
#    'ARID1A'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 2,
#   'genes': ['GPATCH3',
#    'NUDC',
#    'KDF1',
#    'TRNP1',
#    'SLC9A1',
#    'MAP3K6',
#    'WASF2',
#    'IFI6',
#    'STX12',
#    'PPP1R8',
#    'THEMIS2',
#    'RPA2',
#    'XKR8',
#    'EYA3',
#    'YTHDF2',
#    'EPB41',
#    'MECR',
#    'LAPTM5',
#    'SDC3',
#    'NKAIN1',
#    'ZCCHC17',
#    'FABP3',
#    'PEF1',
#    'COL16A1',
#    'SPOCD1',
#    'TXLNA',
#    'TMEM234',
#    'MTMR9LP',
#    'FAM167B',
#    'HDAC1',
#    'BSDC1',
#    'ZBTB8A',
#    'ZBTB8OS',
#    'RBBP4',
#    'KIAA1522',
#    'S100PBP',
#    'FNDC5',
#    'HPCA',
#    'TMEM54',
#    'RNF19B',
#    'AK2',
#    'ZNF362',
#    'SMIM12',
#    'DLGAP3',
#    'ZMYM4',
#    'PSMB2',
#    'C1orf216',
#    'AGO4',
#    'AGO1',
#    'AGO3',
#    'TEKT2',
#    'COL8A2',
#    'LSM10',
#    'GRIK3',
#    'LINC01137',
#    'DNALI1',
#    'EPHA10',
#    'MANEAL',
#    'POU3F1',
#    'AKIRIN1'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 3,
#   'genes': ['MACF1',
#    'PPIEL',
#    'HEYL',
#    'HPCAL4',
#    'PPIE',
#    'BMP8B',
#    'TRIT1',
#    'CAP1',
#    'ZMPSTE24',
#    'SMAP2',
#    'ZFP69',
#    'ZNF684',
#    'RIMS3',
#    'NFYC',
#    'CITED4',
#    'GUCA2B',
#    'RIMKLA',
#    'ZMYND12',
#    'PPIH',
#    'YBX1',
#    'C1orf50',
#    'EBNA1BP2',
#    'MED8',
#    'SZT2',
#    'HYI',
#    'PTPRF',
#    'ST3GAL3',
#    'B4GALT2',
#    'CCDC24',
#    'ERI3',
#    'RNF220',
#    'TMEM53',
#    'KIF2C',
#    'ZSWIM5',
#    'MMACHC',
#    'PRDX1',
#    'GPBP1L1',
#    'TSPAN1',
#    'UQCRH',
#    'MKNK1',
#    'ATPAF1',
#    'CYP4X1',
#    'CYP4Z1',
#    'CMPK1',
#    'SPATA6',
#    'AGBL4',
#    'BEND5',
#    'ELAVL4',
#    'CDKN2C',
#    'RNF11',
#    'TTC39A',
#    'OSBPL9',
#    'NRDC',
#    'RAB3B',
#    'ZFYVE9',
#    'GPX7',
#    'SHISAL2A',
#    'ZYG11B',
#    'ECHDC2',
#    'SCP2'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 4,
#   'genes': ['C1orf123',
#    'LRP8',
#    'GLIS1',
#    'YIPF1',
#    'LRRC42',
#    'MRPL37',
#    'SSBP3',
#    'DHCR24',
#    'TMEM61',
#    'PLPP3',
#    'PRKAA2',
#    'OMA1',
#    'MYSM1',
#    'JUN',
#    'FGGY',
#    'HK1',
#    'CYP2J2',
#    'NFIA',
#    'PATJ',
#    'KANK4',
#    'DOCK7',
#    'ITGB3BP',
#    'EFCAB7',
#    'PGM1',
#    'CACHD1',
#    'RAVER2',
#    'JAK1',
#    'AK4',
#    'LEPR',
#    'LEPROT',
#    'LEPR',
#    'PDE4B',
#    'SGIP1',
#    'TCTEX1D1',
#    'SLC35D1',
#    'IL12RB2',
#    'GNG12',
#    'DIRAS3',
#    'WLS',
#    'LRRC7',
#    'PIN1P1',
#    'SRSF11',
#    'CTH',
#    'PTGER3',
#    'ZRANB2',
#    'NEGR1',
#    'ERICH3',
#    'CRYZ',
#    'TYW3',
#    'LHX8',
#    'SLC44A5',
#    'ST6GALNAC3',
#    'ST6GALNAC5',
#    'AK5',
#    'ZZZ3',
#    'USP33',
#    'MIGA1',
#    'NEXN',
#    'DNAJB4',
#    'IFI44'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 5,
#   'genes': ['ADGRL2',
#    'SPATA1',
#    'SSX2IP',
#    'SYDE2',
#    'DDAH1',
#    'COL24A1',
#    'ODF2L',
#    'SH3GLB1',
#    'HS2ST1',
#    'LINC01140',
#    'LMO4',
#    'PKN2',
#    'GBP3',
#    'GBP2',
#    'GBP4',
#    'LOC729930',
#    'LRRC8B',
#    'LRRC8C',
#    'CDC7',
#    'EPHX4',
#    'KIAA1107',
#    'GLMN',
#    'FAP',
#    'EVI5',
#    'MTF2',
#    'DR1',
#    'FNBP1L',
#    'BCAR3',
#    'GCLM',
#    'ARHGAP29',
#    'F3',
#    'SLC44A3',
#    'CNN3',
#    'DPYD',
#    'SNX7',
#    'PLPPR5',
#    'PLPPR4',
#    'PALMD',
#    'AGL',
#    'RTCA',
#    'CDC14A',
#    'GPR88',
#    'EXTL2',
#    'DPH5',
#    'S1PR1',
#    'OLFM3',
#    'COL11A1',
#    'RNPC3',
#    'PRMT6',
#    'NTNG1',
#    'NDUFA4',
#    'VAV3',
#    'FAM102B',
#    'PRPF38B',
#    'STXBP3',
#    'GPSM2',
#    'CLCC1',
#    'WDR47',
#    'CELSR2',
#    'MYBPHL'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 6,
#   'genes': ['SORT1',
#    'ATXN7L2',
#    'AMIGO1',
#    'GPR61',
#    'GSTM2',
#    'GSTM1',
#    'GSTM5',
#    'GSTM3',
#    'AHCYL1',
#    'ALX3',
#    'SLC6A17',
#    'KCNC4',
#    'RBM15',
#    'KCNA2',
#    'KCNA3',
#    'CD53',
#    'DENND2D',
#    'OVGP1',
#    'C1orf162',
#    'TMIGD3',
#    'KCND3',
#    'LINC01750',
#    'WNT2B',
#    'ST7L',
#    'RHOC',
#    'PPM1J',
#    'MAGI3',
#    'SYT6',
#    'BCAS2',
#    'DENND2C',
#    'NRAS',
#    'SIKE1',
#    'TSPAN2',
#    'VANGL1',
#    'ATP1A1',
#    'IGSF3',
#    'TTF2',
#    'GDAP2',
#    'LINC00622',
#    'ZNF697',
#    'PHGDH',
#    'PPIAL4A',
#    'EMBP1',
#    'NUDT17',
#    'RBM8A',
#    'LIX1L',
#    'ANKRD34A',
#    'POLR3GL',
#    'PRKAB2',
#    'CHD1L',
#    'PDIA3P1',
#    'PPIAL4G',
#    'MTMR11',
#    'PLEKHO1',
#    'ANP32E',
#    'C1orf54',
#    'ECM1',
#    'MCL1',
#    'ENSA',
#    'CTSK'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 7,
#   'genes': ['SETDB1',
#    'MLLT11',
#    'TNFAIP8L2',
#    'PSMD4',
#    'RFX5',
#    'SELENBP1',
#    'SNX27',
#    'CELF3',
#    'RIIAD1',
#    'TDRKH',
#    'S100A10',
#    'TCHH',
#    'LCE3C',
#    'LOR',
#    'S100A6',
#    'S100A16',
#    'S100A13',
#    'SLC27A3',
#    'DENND4B',
#    'RAB13',
#    'RPS27',
#    'TPM3',
#    'C1orf43',
#    'HAX1',
#    'ATP8B2',
#    'IL6R',
#    'KCNN3',
#    'PMVK',
#    'PBXIP1',
#    'SHC1',
#    'CKS1B',
#    'FLAD1',
#    'ZBTB7B',
#    'ADAM15',
#    'EFNA1',
#    'SLC50A1',
#    'THBS3',
#    'MTX1',
#    'GBA',
#    'SCAMP3',
#    'HCN3',
#    'FDPS',
#    'ASH1L',
#    'ASH1L-AS1',
#    'GON4L',
#    'SYT12',
#    'RIT1',
#    'LAMTOR2',
#    'LMNA',
#    'SEMA4A',
#    'C1orf61',
#    'NAXE',
#    'GPATCH4',
#    'HAPLN2',
#    'BCAN',
#    'ARHGEF11',
#    'KIRREL1',
#    'MNDA',
#    'IFI16',
#    'AIM2'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 8,
#   'genes': ['CADM3',
#    'ACKR1',
#    'DUSP23',
#    'TAGLN2',
#    'KCNJ9',
#    'IGSF8',
#    'ATP1A4',
#    'ATP1A1',
#    'CASQ1',
#    'PEA15',
#    'PEX19',
#    'COPA',
#    'VANGL2',
#    'CD84',
#    'TSTD1',
#    'KLHDC9',
#    'UFC1',
#    'USP16',
#    'NDUFS2',
#    'TOMM40L',
#    'PCP4L1',
#    'FCGR2A',
#    'FCGR3A',
#    'RPL31P11',
#    'FCRLB',
#    'DUSP12',
#    'ATF6',
#    'OLFML2B',
#    'NOS1AP',
#    'C1orf226',
#    'UHMK1',
#    'DDR2',
#    'RGS4',
#    'RGS5',
#    'MGST3',
#    'ALDH9A1',
#    'FAM78B',
#    'TADA1',
#    'ILDR2',
#    'CREG1',
#    'RCSD1',
#    'MPZL1',
#    'DCAF6',
#    'MPC2',
#    'GPR161',
#    'TBX19',
#    'ATP1B1',
#    'CCDC181',
#    'SLC19A2',
#    'KIFAP3',
#    'PRRX1',
#    'FMO2',
#    'FMO2',
#    'METTL13',
#    'DNM3',
#    'PIGC',
#    'SUCO',
#    'PRDX6',
#    'ANKRD45',
#    'KLHL20'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 9,
#   'genes': ['RABGAP1L',
#    'GPR52',
#    'CACYBP',
#    'ASTN1',
#    'BRINP2',
#    'RASAL2',
#    'RALGPS2',
#    'SOAT1',
#    'TOR1AIP2',
#    'TOR1AIP1',
#    'QSOX1',
#    'XPR1',
#    'KIAA1614',
#    'MR1',
#    'IER5',
#    'CACNA1E',
#    'RNASEL',
#    'RGS8',
#    'NPL',
#    'DHX9',
#    'NMNAT2',
#    'ARPC5',
#    'COLGALT2',
#    'C1orf21',
#    'EDEM3',
#    'IVNS1ABP',
#    'TPR',
#    'PTGS2',
#    'PLA2G4A',
#    'BRINP3',
#    'RGS18',
#    'RGS2',
#    'GLRX2',
#    'B3GALT2',
#    'KCNT2',
#    'DENND1B',
#    'PTPRC',
#    'DDX59',
#    'KIF21B',
#    'TMEM9',
#    'IGFN1',
#    'TNNT2',
#    'PHLDA3',
#    'NAV1',
#    'SHISA4',
#    'TIMM17A',
#    'LGR6',
#    'PPP1R12B',
#    'SYT2',
#    'RABIF',
#    'ADIPOR1',
#    'CYB5R1',
#    'TMEM183A',
#    'PPFIA4',
#    'ADORA1',
#    'CHI3L1',
#    'ATP2B4',
#    'ATP2B2',
#    'LINC00260',
#    'ZBED6'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 10,
#   'genes': ['GOLT1A',
#    'PLEKHA6',
#    'MDM4',
#    'LRRN2',
#    'TMEM81',
#    'TMCC2',
#    'KLHDC8A',
#    'MFSD4A',
#    'RAB29',
#    'RAB7B',
#    'SRGAP2',
#    'RASSF5',
#    'DYRK3',
#    'PFKFB2',
#    'YOD1',
#    'MIR29B2CHG',
#    'CAMK1G',
#    'LAMB3',
#    'G0S2',
#    'HSD11B1',
#    'TRAF3IP3',
#    'C1orf74',
#    'SERTAD4-AS1',
#    'SERTAD4',
#    'HHAT',
#    'KCNH1',
#    'RCOR3',
#    'TRAF5',
#    'LINC00467',
#    'SLC30A1',
#    'LPGAT1',
#    'PPP2R5A',
#    'NENF',
#    'BATF3',
#    'FLVCR1-AS1',
#    'FLVCR1',
#    'VASH2',
#    'RPS6KC1',
#    'SMYD2',
#    'PTPN14',
#    'CENPF',
#    'KCNK2',
#    'KCTD3',
#    'ESRRG',
#    'LYPLAL1',
#    'SLC30A10',
#    'IARS2',
#    'RAB3GAP2',
#    'MARK1',
#    'C1orf115',
#    'TAF1A',
#    'BROX',
#    'DISP1',
#    'SUSD4',
#    'CAPN2',
#    'TP53BP2',
#    'FBXO28',
#    'WDR26',
#    'CNIH3',
#    'DNAH14'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 11,
#   'genes': ['SRP9',
#    'EPHX1',
#    'LIN9',
#    'STUM',
#    'CDC42BPA',
#    'SNAP47',
#    'JMJD4',
#    'GUK1',
#    'GJC2',
#    'OBSCN',
#    'TRIM17',
#    'RNF187',
#    'DUSP5P1',
#    'RAB4A',
#    'ACTA1',
#    'LINC01736',
#    'PGBD5',
#    'COG2',
#    'AGT',
#    'FAM89A',
#    'EGLN1',
#    'SIPA1L2',
#    'PCNX2',
#    'MAP3K21',
#    'KCNK1',
#    'SLC35F3',
#    'COA6',
#    'TARBP1',
#    'RBM34',
#    'TBCE',
#    'B3GALNT2',
#    'GNG4',
#    'LYST',
#    'GPR137B',
#    'ERO1B',
#    'EDARADD',
#    'LGALS8',
#    'HEATR1',
#    'ACTN2',
#    'RYR2',
#    'LOC100130331',
#    'CHRM3',
#    'FMN2',
#    'GREM2',
#    'RGS7',
#    'FH',
#    'OPN3',
#    'CHML',
#    'ZBTB18',
#    'COX20',
#    'HNRNPU',
#    'EFCAB2',
#    'KIF26B',
#    'TFB2M',
#    'CNST',
#    'ZNF670',
#    'ZNF124',
#    'NLRP3',
#    'TRIM58',
#    'OR2L13'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 12,
#   'genes': ['OR2L8',
#    'OR2AK2',
#    'OR2L3',
#    'OR14I1',
#    'LYPD8',
#    'SH3BP5L',
#    'ZNF672',
#    'ZNF692',
#    'FAM110C',
#    'ACP1',
#    'ALKAL2',
#    'TMEM18',
#    'SNTG2',
#    'PXDN',
#    'EIPR1',
#    'ADI1',
#    'SOX11',
#    'LINC01105',
#    'RSAD2',
#    'RNF144A',
#    'ID2',
#    'MBOAT2',
#    'ASAP2',
#    'ITGB1BP1',
#    'YWHAQ',
#    'CYS1',
#    'HPCAL1',
#    'KCNF1',
#    'FLJ33534',
#    'ROCK2',
#    'NTSR2',
#    'LPIN1',
#    'TRIB2',
#    'FAM84A',
#    'NBAS',
#    'DDX1',
#    'VSNL1',
#    'SMC6',
#    'KCNS3',
#    'PAN2',
#    'WDR35',
#    'LAPTM4A',
#    'KLHL29',
#    'ATAD2B',
#    'FKBP1B',
#    'FAM228B',
#    'TP53I3',
#    'PTRHD1',
#    'ADCY3',
#    'EFR3B',
#    'POMC',
#    'DNMT3A',
#    'KIF3C',
#    'GAREM2',
#    'HADHB',
#    'DRC1',
#    'KCNK3',
#    'DPYSL5',
#    'OST4',
#    'KHK'],
#   'chromosome': 'NC_000001.11'},
#  {'token_id': 13,
#   'genes': ['CGREF1',
#    'ABHD1',
#    'SLC5A6',
#    'SLC30A3',
#    'DNAJC5G',
#    'GTF3C2',
#    'SNX17',
#    'KRTCAP3',
#    'FNDC4',
#    'CCDC121',
#    'SLC4A1AP',
#    'MRPL33',
#    'RBKS',
#    'BABAM2',
#    'FOSL2',
#    'PLB1',
#    'PPP1CB',
#    'TRMT61B',
#    'CLIP4',
#    'ALK',
#    'YPEL5',
#    'LBH',
#    'GALNT14',
#    'EHD3',
#    'YIPF4',
#    'FAM98A',
#    'CRIM1',
#    'FEZ2',
#    'VIT',
#    'STRN',
#    'PRKD3',
#    'QPCT',
#    'CDC42EP3',
#    'RMDN2',
#    'CYP1B1',
#    'CYP1B1-AS1',
#    'GALM',
#    'TMEM178A',
#    'SLC8A1',
#    'PKDCC',
#    'EML4',
#    'KCNG3',
#    'MTA3',
#    'ZFP36L2',
#    'BRF2',
#    'PLEKHH2',
#    'LRPPRC',
#    'PPM1B',
#    'CAMKMT',
#    'SIX3',
#    'PRKCE',
#    'EPAS1',
#    'ATP6V1E2',
#    'RHOQ',
#    'PIGF',
#    'SOCS5',
#    'EPCAM',
#    'KCNK12',
#    'FOXN2',
#    'PPP1R21'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 14,
#   'genes': ['STON1',
#    'NRXN1',
#    'GPR75',
#    'ACYP2',
#    'EML6',
#    'RTN4',
#    'MTIF2',
#    'EFEMP1',
#    'CCDC85A',
#    'FANCL',
#    'BCL11A',
#    'KIAA1841',
#    'TMEM17',
#    'WDPCP',
#    'MDH1',
#    'UGP2',
#    'VPS54',
#    'PELI1',
#    'GRP',
#    'AFTPH',
#    'SLC1A4',
#    'CEP68',
#    'SPRED2',
#    'MEIS1',
#    'C1D',
#    'PPP3R1',
#    'CNRIP1',
#    'ARHGAP25',
#    'ANTXR1',
#    'AAK1',
#    'ANXA4',
#    'SNRNP27',
#    'MXD1',
#    'FAM136A',
#    'ADD2',
#    'NAGK',
#    'CYP26B1',
#    'SPR',
#    'EMX1',
#    'RAB11FIP5',
#    'PRADC1',
#    'FBXO41',
#    'EGR4',
#    'ALMS1P1',
#    'TPRKB',
#    'STAMBP',
#    'BOLA3-AS1',
#    'MTHFD2',
#    'DCTN1',
#    'WDR54',
#    'PCGF1',
#    'TLX2',
#    'AUP1',
#    'HTRA2',
#    'LOXL3',
#    'DOK1',
#    'SEMA4F',
#    'HK2',
#    'POLE4',
#    'MRPL19'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 15,
#   'genes': ['LRRTM4',
#    'CTNNA2',
#    'LRRTM1',
#    'SUCLG1',
#    'TRABD2A',
#    'TMSB10',
#    'KCMF1',
#    'TCF7L1',
#    'ELMOD3',
#    'CAPG',
#    'GGCX',
#    'VAMP8',
#    'RNF181',
#    'ST3GAL5',
#    'MRPL35',
#    'RMND5A',
#    'CD8B',
#    'CYTOR',
#    'ANKRD36BP2',
#    'ANKRD20A8P',
#    'TEKT4',
#    'KCNIP3',
#    'DUSP2',
#    'TMEM127',
#    'NEURL3',
#    'ARID5A',
#    'LMAN2L',
#    'CNNM4',
#    'SEMA4C',
#    'ACTR1B',
#    'INPP4A',
#    'UNC50',
#    'MGAT4A',
#    'MRPL30',
#    'REV1',
#    'LONRF2',
#    'CHST10',
#    'PDCL3',
#    'TBC1D8',
#    'CREG2',
#    'MFSD9',
#    'TMEM182',
#    'LINC01102',
#    'POU3F3',
#    'TGFBRAP1',
#    'FHL2',
#    'NCK2',
#    'C2orf40',
#    'UXS1',
#    'RGPD3',
#    'ST6GAL2',
#    'SULT1C4',
#    'GCC2',
#    'LIMS1',
#    'RANBP2',
#    'SEPT10',
#    'SOWAHC',
#    'MALL',
#    'NPHP1',
#    'LINC01106'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 16,
#   'genes': ['MIR4435-2HG',
#    'ANAPC1',
#    'MERTK',
#    'TMEM87B',
#    'FBLN7',
#    'ZC3H8',
#    'TTL',
#    'POLR1B',
#    'SLC20A1',
#    'IL1B',
#    'PAX8',
#    'PAX8-AS1',
#    'SLC35F5',
#    'DPP10',
#    'DPP10-AS1',
#    'MARCO',
#    'C1QL2',
#    'DBI',
#    'PTPN4',
#    'EPB41L5',
#    'TMEM185B',
#    'RALB',
#    'INHBB',
#    'NIFK',
#    'CNTNAP5',
#    'IWS1',
#    'LIMS2',
#    'WDR33',
#    'UGGT1',
#    'HS6ST1',
#    'FAR2P1',
#    'MZT2B',
#    'CCDC115',
#    'IMP4',
#    'FAR2P2',
#    'AMER3',
#    'ARHGEF4',
#    'MZT2A',
#    'LYPD1',
#    'NCKAP5',
#    'MGAT5',
#    'TMEM163',
#    'RAB3GAP1',
#    'ZRANB3',
#    'R3HDM1',
#    'MCM6',
#    'CXCR4',
#    'HNMT',
#    'SPOPL',
#    'NXPH2',
#    'LRP1B',
#    'KYNU',
#    'GTDC1',
#    'ACVR2A',
#    'EPC2',
#    'KIF5C',
#    'LYPD6',
#    'MMADHC',
#    'NMI',
#    'NEB'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 17,
#   'genes': ['ARL5A',
#    'CACNB4',
#    'STAM2',
#    'PRPF40A',
#    'GALNT13',
#    'RPRM',
#    'KCNJ3',
#    'NR4A2',
#    'GPD2',
#    'ACVR1C',
#    'ACVR1',
#    'UPP2',
#    'CCDC148',
#    'DAPL1',
#    'TANC1',
#    'PLA2R1',
#    'RBMS1',
#    'TANK',
#    'TBR1',
#    'FAP',
#    'IFIH1',
#    'KCNH7',
#    'FIGN',
#    'GRB14',
#    'COBLL1',
#    'SLC38A11',
#    'SCN3A',
#    'SCN2A',
#    'CSRNP3',
#    'LOC100506124',
#    'TTC21B',
#    'SCN1A',
#    'SCN9A',
#    'SCN7A',
#    'STK39',
#    'CERS6',
#    'NOSTRIN',
#    'DHRS9',
#    'FASTKD1',
#    'SP5',
#    'TLK1',
#    'METTL8',
#    'DCAF17',
#    'CYBRD1',
#    'SLC25A12',
#    'DLX1',
#    'RAPGEF4',
#    'MAP3K20',
#    'SP3',
#    'GPR155',
#    'CHN1',
#    'ATP5MC3',
#    'HOXD1',
#    'MTX2',
#    'LINC01116',
#    'HNRNPA3',
#    'NFE2L2',
#    'HEBP1',
#    'PDE11A',
#    'OSBPL6'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 18,
#   'genes': ['PJVK',
#    'FKBP7',
#    'TTN',
#    'ZNF385B',
#    'NEUROD1',
#    'PDE1A',
#    'DNAJC10',
#    'NCKAP1',
#    'ZC3H15',
#    'FAM171B',
#    'GULP1',
#    'COL5A2',
#    'WDR75',
#    'SLC40A1',
#    'OSGEPL1',
#    'HIBCH',
#    'NAB1',
#    'GLS',
#    'STAT1',
#    'STAT4',
#    'MYO1B',
#    'NABP1',
#    'TMEFF2',
#    'SLC39A10',
#    'STK17B',
#    'HECW2',
#    'GTF3C3',
#    'PGAP1',
#    'ARSB',
#    'RFTN2',
#    'PLCL1',
#    'SATB2',
#    'C2orf69',
#    'TYW5',
#    'SPATS2L',
#    'CLK1',
#    'PPIL3',
#    'NIF3L1',
#    'FAM126B',
#    'NDUFB3',
#    'CFLAR',
#    'CASP10',
#    'TRAK2',
#    'C2CD6',
#    'TMEM237',
#    'ALS2',
#    'FZD7',
#    'NOP58',
#    'FAM117B',
#    'ICA1L',
#    'NBEAL1',
#    'CYP20A1',
#    'RAPH1',
#    'PARD3B',
#    'NRP2',
#    'NDUFS1',
#    'EEF1B2',
#    'ADAM23',
#    'KLF7',
#    'METTL21A'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 19,
#   'genes': ['CCNYL1',
#    'PLEKHM3',
#    'CRYGD',
#    'C2orf80',
#    'IDH1-AS1',
#    'CFD',
#    'KANSL1L',
#    'ACADL',
#    'LANCL1',
#    'SPAG16',
#    'VWC2L',
#    'BARD1',
#    'FN1',
#    'MREG',
#    'PECR',
#    'TMEM169',
#    'LINC01963',
#    'RPL37A',
#    'IGFBP2',
#    'IGFBP5',
#    'TNS1',
#    'ARPC2',
#    'PNKD',
#    'TMBIM1',
#    'CTDSP1',
#    'USP37',
#    'PLCD4',
#    'TTLL4',
#    'WNT6',
#    'WNT10A',
#    'CRYBA2',
#    'CFAP65',
#    'RETREG2',
#    'ABCB6',
#    'ATG9A',
#    'ANKZF1',
#    'TUBA4A',
#    'TUBA4B',
#    'DNAJB2',
#    'RESP18',
#    'DNPEP',
#    'SPEG',
#    'ASIC4',
#    'SLC4A3',
#    'EPHA4',
#    'SGPP2',
#    'MOGAT1',
#    'ACSL3',
#    'KCNE4',
#    'SCG2',
#    'CUL3',
#    'NYAP2',
#    'IRS1',
#    'SPHKAP',
#    'PID1',
#    'TRIP12',
#    'SLC16A14',
#    'SP110',
#    'CAB39',
#    'PSMD1'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 20,
#   'genes': ['DIS3L2',
#    'ECEL1',
#    'PRSS56',
#    'EIF4E2',
#    'GIGYF2',
#    'NGEF',
#    'INPP5D',
#    'ATG16L1',
#    'DGKD',
#    'ARL4C',
#    'SH3BP4',
#    'AGAP1',
#    'IQCA1',
#    'ACKR3',
#    'LRRFIP1',
#    'RAMP1',
#    'ERFE',
#    'HES6',
#    'PER2',
#    'HDAC4',
#    'NDUFA10',
#    'COPS9',
#    'AGT',
#    'PASK',
#    'STK25',
#    'PDCD1',
#    'LOC285097',
#    'CHL1',
#    'CNTN6',
#    'CNTN4',
#    'LRRN1',
#    'SUMF1',
#    'ITPR1',
#    'BHLHE40',
#    'EDEM1',
#    'GRM7',
#    'LMCD1',
#    'OXTR',
#    'SRGAP3',
#    'CPNE9',
#    'OGG1',
#    'CAMK1',
#    'ARPC4',
#    'RPUSD3',
#    'CIDEC',
#    'CRELD1',
#    'PRRT3',
#    'EMC3',
#    'BRK1',
#    'TATDN2',
#    'GHRLOS',
#    'ATP2B2',
#    'HRH1',
#    'ATG7',
#    'TAMM41',
#    'SYN2',
#    'TIMP4',
#    'PPARG',
#    'TSEN2',
#    'MKRN2'],
#   'chromosome': 'NC_000002.12'},
#  {'token_id': 21,
#   'genes': ['CAND2',
#    'RPL32',
#    'IQSEC1',
#    'FBLN2',
#    'WNT7A',
#    'TPRXL',
#    'CHCHD4',
#    'LSM3',
#    'SLC6A6',
#    'GRIP2',
#    'CCDC174',
#    'FGD5',
#    'RBSN',
#    'CAPN7',
#    'METTL6',
#    'HACL1',
#    'GALNT15',
#    'DPH3',
#    'OXNAD1',
#    'RFTN1',
#    'SATB1',
#    'KAT2B',
#    'ZNF385D',
#    'UBE2E2',
#    'RPL15',
#    'NR1D2',
#    'THRB',
#    'RARB',
#    'NGLY1',
#    'LRRC3B',
#    'NEK10',
#    'AZI2',
#    'ZCWPW2',
#    'RBMS3',
#    'STT3B',
#    'OSBPL10',
#    'GPD1L',
#    'CMTM8',
#    'CMTM7',
#    'CMTM6',
#    'TRIM71',
#    'CRTAP',
#    'SUSD5',
#    'FBXL2',
#    'UBP1',
#    'ARPP21',
#    'TRANK1',
#    'LRRFIP2',
#    'VILL',
#    'DLEC1',
#    'ACVR2B',
#    'EXOG',
#    'CX3CR1',
#    'MYRIP',
#    'EIF1B',
#    'ZNF620',
#    'CTNNB1',
#    'CCK',
#    'VIPR1',
#    'ZBTB47'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 22,
#   'genes': ['HIGD1A',
#    'ANO10',
#    'ZNF35',
#    'ZNF502',
#    'TMEM42',
#    'ZDHHC3',
#    'TMEM158',
#    'LARS2',
#    'LZTFL1',
#    'FYCO1',
#    'CCR1',
#    'CCR5',
#    'LRRC2',
#    'ALS2CL',
#    'TMIE',
#    'PTH1R',
#    'CCDC12',
#    'KIF9-AS1',
#    'KIF9',
#    'KLHL18',
#    'SMARCC1',
#    'SPINK8',
#    'CCDC51',
#    'SHISA5',
#    'COL7A1',
#    'UQCRC1',
#    'CELSR3',
#    'NCKIPSD',
#    'IP6K2',
#    'PRKAR2A',
#    'P4HTM',
#    'WDR6',
#    'USP19',
#    'KLHDC8B',
#    'USP4',
#    'RHOA',
#    'TCTA',
#    'AMT',
#    'NICN1',
#    'BSN',
#    'APEH',
#    'RNF123',
#    'GMPPB',
#    'TRAIP',
#    'CAMKV',
#    'MST1R',
#    'MON1A',
#    'RBM6',
#    'RBM5',
#    'SEMA3B-AS1',
#    'IFRD2',
#    'HYAL3',
#    'TUSC2',
#    'ZMYND10',
#    'CACNA2D2',
#    'C3orf18',
#    'DOCK3',
#    'MANF',
#    'PARP3',
#    'RPL29'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 23,
#   'genes': ['POC1A',
#    'ALAS1',
#    'TWF2',
#    'PPM1M',
#    'BAP1',
#    'NISCH',
#    'NT5DC2',
#    'PRKCD',
#    'DCP1A',
#    'CHDH',
#    'IL17RB',
#    'CACNA2D3',
#    'ERC2',
#    'CAST',
#    'ERC2-IT1',
#    'CCDC66',
#    'ARHGEF3',
#    'IL17RD',
#    'APPL1',
#    'DNAH12',
#    'DENND6A',
#    'SLMAP',
#    'ABHD6',
#    'PDHB',
#    'KCTD6',
#    'ACOX2',
#    'FAM107A',
#    'C3orf14',
#    'FEZF2',
#    'CADPS',
#    'SYNPR',
#    'THOC7',
#    'ATXN7',
#    'PSMD6',
#    'PRICKLE2',
#    'ADAMTS9',
#    'MAGI1',
#    'SLC25A26',
#    'SUCLG2',
#    'FAM19A1',
#    'UBA3',
#    'MITF',
#    'FOXP1',
#    'GPR27',
#    'RYBP',
#    'GXYLT2',
#    'PDZRN3',
#    'CNTN3',
#    'FAM86DP',
#    'ZNF717',
#    'ROBO1',
#    'GBE1',
#    'CHMP2B',
#    'HTR1F',
#    'ZNF654',
#    'C3orf38',
#    'EPHA3',
#    'ARL13B',
#    'STX19',
#    'DHFR2'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 24,
#   'genes': ['EPHA6',
#    'CRYBG3',
#    'RIOX2',
#    'ST3GAL6-AS1',
#    'ST3GAL6',
#    'DCBLD2',
#    'CMSS1',
#    'FILIP1L',
#    'NIT2',
#    'LNP1',
#    'SENP7',
#    'TRMT10C',
#    'PCNP',
#    'RPS18',
#    'ZBTB11',
#    'PDCL3P4',
#    'CEP97',
#    'NXPE3',
#    'NFKBIZ',
#    'ALCAM',
#    'DUBR',
#    'BBX',
#    'IFT57',
#    'MYH15',
#    'DZIP3',
#    'NECTIN3',
#    'PHLDB2',
#    'TAGLN3',
#    'CD200',
#    'CCDC80',
#    'CFAP44',
#    'SPICE1',
#    'SIDT1',
#    'ATP6V1A',
#    'GRAMD1C',
#    'ZDHHC23',
#    'CCDC191',
#    'QTRT2',
#    'ZBTB20',
#    'GAP43',
#    'LSAMP',
#    'TMEM39A',
#    'POGLUT1',
#    'COX17',
#    'GSK3B',
#    'FSTL1',
#    'STXBP5L',
#    'FBXO40',
#    'HCLS1',
#    'GOLGB1',
#    'SLC15A2',
#    'CCDC58',
#    'FAM162A',
#    'DTX3L',
#    'PARP14',
#    'HSPBAP1',
#    'DIRC2',
#    'SEMA5B',
#    'PDIA5',
#    'HACD2'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 25,
#   'genes': ['MYLK',
#    'CCDC14',
#    'KALRN',
#    'UMPS',
#    'SLC12A8',
#    'ZNF148',
#    'SNX4',
#    'OSBPL11',
#    'ALDH1L1',
#    'ZXDC',
#    'TXNRD3',
#    'CHCHD6',
#    'PLXNA1',
#    'ABTB1',
#    'MGLL',
#    'KBTBD12',
#    'LOC90246',
#    'RAB11B',
#    'HMCES',
#    'IFT122',
#    'PLXND1',
#    'TMCC1',
#    'TRH',
#    'FAM86HP',
#    'ASTE1',
#    'NEK11',
#    'CPNE4',
#    'TMEM108',
#    'TF',
#    'RAB6B',
#    'SLCO2A1',
#    'RYK',
#    'CEP63',
#    'STAG1',
#    'NCK1',
#    'DBR1',
#    'ARMC8',
#    'MRAS',
#    'CEP70',
#    'PIK3CB',
#    'FOXL2',
#    'MRPS22',
#    'COPB2',
#    'RBP1',
#    'NMNAT3',
#    'CLSTN2',
#    'SLC25A36',
#    'PXYLP1',
#    'ZBTB38',
#    'RASA2',
#    'RNF7',
#    'ATP1B3',
#    'TFDP2',
#    'TRPC1',
#    'PCOLCE2',
#    'PAQR9',
#    'U2SURP',
#    'C3orf58',
#    'PLOD2',
#    'PLSCR4'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 26,
#   'genes': ['ZIC4',
#    'ZIC1',
#    'HLTF',
#    'WWTR1',
#    'RNF13',
#    'PFN2',
#    'SERP1',
#    'EIF2A',
#    'ERICH6-AS1',
#    'SIAH2',
#    'P2RY13',
#    'P2RY12',
#    'MBNL1',
#    'P2RY1',
#    'RAP2B',
#    'GPR149',
#    'PLCH1',
#    'TIPARP',
#    'LINC00886',
#    'PTX3',
#    'RSRC1',
#    'MLF1',
#    'GFM1',
#    'LXN',
#    'RARRES1',
#    'MFSD1',
#    'IQCJ',
#    'C3orf80',
#    'PPM1L',
#    'B3GALNT1',
#    'SPTSSB',
#    'SLITRK3',
#    'BCHE',
#    'ZBBX',
#    'SERPINI2',
#    'WDR49',
#    'SERPINI1',
#    'EGFEM1P',
#    'MECOM',
#    'MYNN',
#    'LRRC34',
#    'SEC62',
#    'PHC3',
#    'PRKCI',
#    'SLC7A14',
#    'EIF5A2',
#    'TNIK',
#    'FNDC3B',
#    'NCEH1',
#    'NLGN1',
#    'KCNMB2',
#    'PIK3CA',
#    'GNB4',
#    'ACTL6A',
#    'MRPL47',
#    'USP13',
#    'PEX5L',
#    'TTC14',
#    'CCDC39',
#    'DNAJC19'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 27,
#   'genes': ['SOX2',
#    'MCF2L2',
#    'B3GNT5',
#    'KLHL24',
#    'YEATS2',
#    'MAP6D1',
#    'PARL',
#    'ABCC5',
#    'EIF2B5',
#    'AP2M1',
#    'ALG3',
#    'CAMK2N2',
#    'PSMD2',
#    'FAM131A',
#    'POLR2H',
#    'CHRD',
#    'EPHB3',
#    'MAGEF1',
#    'C3orf70',
#    'MAP3K13',
#    'IGF2BP2',
#    'ETV5',
#    'DGKG',
#    'CRYGS',
#    'DNAJB11',
#    'AHSG',
#    'KNG1',
#    'EIF4A2',
#    'ST6GAL1',
#    'RPL39L',
#    'RTP1',
#    'MASP1',
#    'SST',
#    'LPP',
#    'IL1RAP',
#    'OSTN',
#    'CCDC50',
#    'FGF12',
#    'MB21D2',
#    'HES1',
#    'ATP13A3',
#    'TMEM44',
#    'FAM43A',
#    'TNK2',
#    'TFRC',
#    'RNF168',
#    'PAK2',
#    'NCBP2',
#    'MELTF',
#    'BDH1',
#    'RUBCN',
#    'FYTTD1',
#    'LMLN',
#    'ANKRD18DP',
#    'ZNF718',
#    'ZNF141',
#    'ZNF141',
#    'PDE6B',
#    'ATP5ME',
#    'MYL5'],
#   'chromosome': 'NC_000003.12'},
#  {'token_id': 28,
#   'genes': ['SLC49A3',
#    'CPLX1',
#    'RNF212',
#    'SPON2',
#    'CTBP1',
#    'SLBP',
#    'FGFR3',
#    'NSD2',
#    'NELFA',
#    'NAT8L',
#    'HAUS3',
#    'MXD4',
#    'ZFYVE28',
#    'ADD1',
#    'NOP14',
#    'MSANTD1',
#    'RGS12',
#    'DOK7',
#    'LRPAP1',
#    'ADRA2C',
#    'FAM86EP',
#    'NSG1',
#    'STX18',
#    'MSX1',
#    'CYTL1',
#    'CRMP1',
#    'JAKMIP1',
#    'WFS1',
#    'MRFAP1',
#    'LINC02482',
#    'TBC1D14',
#    'CCDC96',
#    'TADA2B',
#    'SORCS2',
#    'ABLIM2',
#    'ACOX3',
#    'DEFB131A',
#    'WDR1',
#    'HS3ST1',
#    'CPEB2',
#    'CD38',
#    'TAPT1',
#    'LDB2',
#    'QDPR',
#    'DCAF16',
#    'CAPG',
#    'SLIT2',
#    'ADGRA3',
#    'PPARGC1A',
#    'LGI2',
#    'ANAPC4',
#    'SEL1L3',
#    'TBC1D19',
#    'STIM2',
#    'PCDH7',
#    'ARAP2',
#    'NWD2',
#    'RELL1',
#    'TBC1D1',
#    'PTTG2'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 29,
#   'genes': ['FAM114A1',
#    'KLHL5',
#    'WDR19',
#    'RFC1',
#    'RPL9',
#    'LIAS',
#    'SMIM14',
#    'UBE2K',
#    'PDS5A',
#    'N4BP2',
#    'APBB2',
#    'UCHL1',
#    'ATP8A1',
#    'KCTD8',
#    'GNPDA2',
#    'GABRG1',
#    'GABRA2',
#    'GABRA4',
#    'GABRB1',
#    'ATP10D',
#    'SLAIN2',
#    'SLC10A4',
#    'FRYL',
#    'DCUN1D4',
#    'SPATA18',
#    'RASL11B',
#    'FIP1L1',
#    'LNX1',
#    'PDGFRA',
#    'SRD5A3',
#    'CLOCK',
#    'NMU',
#    'CEP135',
#    'AASDH',
#    'ARL9',
#    'HOPX',
#    'SPINK2',
#    'REST',
#    'ADGRL3',
#    'EPHA5',
#    'CENPC',
#    'YTHDC1',
#    'GRSF1',
#    'MOB1B',
#    'SLC4A4',
#    'DBP',
#    'NPFFR2',
#    'ALB',
#    'CXCL3',
#    'CXCL2',
#    'MTHFD2L',
#    'AR',
#    'BTC',
#    'PARM1',
#    'RCHY1',
#    'USO1',
#    'NAAA',
#    'ART3',
#    'NUP54',
#    'FAM47E'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 30,
#   'genes': ['FAM47E',
#    'STBD1',
#    'SHROOM3',
#    'SOWAHB',
#    'CCNI',
#    'CCNG2',
#    'CNOT6L',
#    'ANXA3',
#    'LINC01094',
#    'BMP2K',
#    'ANTXR2',
#    'PRDM8',
#    'RASGEF1B',
#    'TMEM150C',
#    'SEC31A',
#    'THAP9',
#    'COPS4',
#    'HELQ',
#    'MRPS18C',
#    'GPAT3',
#    'CDS1',
#    'WDFY3-AS2',
#    'MAPK10',
#    'AFF1',
#    'KLHL8',
#    'HSD17B11',
#    'NUDT10',
#    'SPARCL1',
#    'SPP1',
#    'PKD2',
#    'ABCG2',
#    'PPM1K',
#    'HERC6',
#    'HERC5',
#    'HERC3',
#    'FAM13A',
#    'TIGD2',
#    'SNCA',
#    'CCSER1',
#    'GRID2',
#    'PDLIM5',
#    'BMPR1B',
#    'TSPAN5',
#    'METAP1',
#    'MAP1A',
#    'ADH5',
#    'TRMT10A',
#    'MTTP',
#    'LAMTOR3',
#    'DDIT4L',
#    'EMCN',
#    'PPP3CA',
#    'FLJ20021',
#    'SLC39A8',
#    'NFKB1',
#    'CISD2',
#    'BDH2',
#    'CXXC4',
#    'TET2',
#    'PPA2'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 31,
#   'genes': ['INTS12',
#    'NPNT',
#    'PAPSS1',
#    'HADH',
#    'LEF1',
#    'ETNPPL',
#    'MCUB',
#    'CASP6',
#    'GAR1',
#    'TIFA',
#    'ALPK1',
#    'ZGRF1',
#    'LARP7',
#    'CAMK2D',
#    'ARSJ',
#    'UGT8',
#    'NDST3',
#    'SNHG8',
#    'SEC24D',
#    'SYNPO2',
#    'USP53',
#    'C4orf3',
#    'PDE5A',
#    'PRDM5',
#    'QRFPR',
#    'ANXA5',
#    'PP12613',
#    'EXOSC9',
#    'BBS7',
#    'TRPC3',
#    'FGF2',
#    'NUDT6',
#    'SPRY1',
#    'ANKRD50',
#    'INTU',
#    'HSPA4L',
#    'MFSD8',
#    'PGRMC2',
#    'JADE1',
#    'SCLT1',
#    'C4orf33',
#    'PCDH10',
#    'SLC7A11',
#    'MGARP',
#    'SMC2',
#    'SETD7',
#    'MGST2',
#    'MAML3',
#    'SCOC',
#    'CLGN',
#    'ELMOD2',
#    'RNF150',
#    'IL15',
#    'INPP4B',
#    'USP38',
#    'FREM3',
#    'HHIP-AS1',
#    'ABCE1',
#    'SMAD1',
#    'ZNF827'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 32,
#   'genes': ['EDNRA',
#    'TMEM184C',
#    'ARHGAP10',
#    'NR3C2',
#    'DCLK2',
#    'RPS3A',
#    'SH3D19',
#    'GATB',
#    'FBXW7',
#    'TRIM2',
#    'RNF175',
#    'SFRP2',
#    'MAP9',
#    'GUCY1A1',
#    'CTSO',
#    'PDGFC',
#    'GLRB',
#    'TMEM144',
#    'RXFP1',
#    'FNIP2',
#    'RAPGEF2',
#    'FSTL5',
#    'NPY1R',
#    'NPY5R',
#    'TRIM61',
#    'KLHL2',
#    'MSMO1',
#    'CPE',
#    'TLL1',
#    'SPOCK3',
#    'DDX60L',
#    'PALLD',
#    'SH3RF1',
#    'NEK1',
#    'CLCN3',
#    'MFAP3L',
#    'LOC441052',
#    'HMGB2',
#    'SCRG1',
#    'CEP44',
#    'HPGD',
#    'GLRA3',
#    'GPM6A',
#    'WDR17',
#    'ASB5',
#    'SPCS3',
#    'VEGFC',
#    'AGA',
#    'TENM3',
#    'DCTD',
#    'RWDD4',
#    'STOX2',
#    'ENPP6',
#    'CASP3',
#    'SLC25A4',
#    'CFAP97',
#    'SNX25',
#    'ANKRD37',
#    'C4orf47',
#    'CCDC110'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 33,
#   'genes': ['PDLIM3',
#    'SORBS2',
#    'TLR3',
#    'FAM149A',
#    'CYP4V2',
#    'KLKB1',
#    'FAT1',
#    'SDHA',
#    'PDCD6',
#    'AHRR',
#    'EXOC3-AS1',
#    'CEP72',
#    'NKD2',
#    'LPCAT1',
#    'ICE1',
#    'MED10',
#    'UBE2QL1',
#    'NSUN2',
#    'SRD5A1',
#    'ADCY2',
#    'C5orf49',
#    'SEMA5A',
#    'SNHG18',
#    'CCT5',
#    'ROPN1L',
#    'ANKRD33B',
#    'DAP',
#    'CTNND2',
#    'DNAH5',
#    'TRIO',
#    'FAM105A',
#    'ANKH',
#    'ZNF622',
#    'RETREG1',
#    'BASP1-AS1',
#    'BASP1',
#    'LINC02217',
#    'CDH18',
#    'CDH12',
#    'CDH10',
#    'CDH9',
#    'CDH6',
#    'PDZD2',
#    'GOLPH3',
#    'MTMR12',
#    'SUB1',
#    'NPR3',
#    'TARS',
#    'C1QTNF3',
#    'RAI14',
#    'TTC23L',
#    'NADK2',
#    'RANBP3L',
#    'NIPBL',
#    'WDR70',
#    'LIFR',
#    'LIFR-AS1',
#    'RICTOR',
#    'FYB1',
#    'DAB2'],
#   'chromosome': 'NC_000004.12'},
#  {'token_id': 34,
#   'genes': ['PTGER4',
#    'PRKAA1',
#    'RPL37',
#    'CARD6',
#    'PLCXD3',
#    'OXCT1',
#    'GHR',
#    'CCDC152',
#    'ZNF131',
#    'NIM1K',
#    'HMGCS1',
#    'CCL28',
#    'PAIP1',
#    'MRPS30-DT',
#    'MRPS30',
#    'HCN1',
#    'EMB',
#    'PARP8',
#    'ITGA1',
#    'ARL15',
#    'HSPB3',
#    'CCNO',
#    'PLPP1',
#    'IL6ST',
#    'MAP3K1',
#    'PLK2',
#    'RAB3C',
#    'PART1',
#    'ELOVL7',
#    'ERCC8',
#    'NDUFAF2',
#    'ZSWIM6',
#    'KIF2A',
#    'DIMT1',
#    'HTR1A',
#    'SREK1IP1',
#    'CENPK',
#    'SGTB',
#    'NLN',
#    'ERBIN',
#    'MAST4',
#    'PIK3R1',
#    'CCNB1',
#    'GTF2H2B',
#    'MCCC2',
#    'CARTPT',
#    'MAP1B',
#    'FOXD1',
#    'BTF3',
#    'ANKRA2',
#    'ARHGEF28',
#    'ENC1',
#    'CCL28',
#    'HEXB',
#    'GCNT4',
#    'HMGCR',
#    'SV2C',
#    'S100Z',
#    'CRHBP',
#    'AGGF1'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 35,
#   'genes': ['TBCA',
#    'AP3B1',
#    'LHFPL2',
#    'ARSB',
#    'DMGDH',
#    'BHMT2',
#    'HOMER1',
#    'CMYA5',
#    'THBS4',
#    'LOC644936',
#    'CRSP8P',
#    'FAM151B',
#    'RASGRF2',
#    'CKMT2',
#    'SSBP2',
#    'XRCC4',
#    'VCAN',
#    'EDIL3',
#    'CCNH',
#    'MEF2C',
#    'CETN3',
#    'MBLAC2',
#    'POLR3G',
#    'ADGRV1',
#    'NR2F1-AS1',
#    'NR2F1',
#    'KIAA0825',
#    'SLF1',
#    'MCTP1',
#    'GPR150',
#    'GLRX',
#    'ELL2',
#    'CAST',
#    'PCSK1',
#    'ERAP2',
#    'LIX1',
#    'RGMB',
#    'CHD1',
#    'ST8SIA4',
#    'PPIP5K2',
#    'C5orf30',
#    'NUDT12',
#    'EFNA5',
#    'CAMK4',
#    'STARD4',
#    'NREP',
#    'EPB41L4A',
#    'SRP19',
#    'DCP2',
#    'KCNN2',
#    'TRIM36',
#    'PGGT1B',
#    'CCDC112',
#    'TMED7',
#    'CDO1',
#    'AP3S1',
#    'DTWD2',
#    'DBP',
#    'PRR16',
#    'SRFBP1'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 36,
#   'genes': ['SNCAIP',
#    'SNX2',
#    'SNX24',
#    'PPIC',
#    'CEP120',
#    'ZNF608',
#    'GRAMD2B',
#    'ALDH7A1',
#    'MEGF10',
#    'CTXN3',
#    'ISOC1',
#    'ADAMTS19',
#    'CHSY3',
#    'HINT1',
#    'LYRM7',
#    'CDC42SE2',
#    'RAPGEF6',
#    'ACSL6',
#    'P4HA2',
#    'PDLIM4',
#    'SLC22A5',
#    'C5orf56',
#    'RAD50',
#    'SOWAHA',
#    'LEAP2',
#    'AFF4',
#    'ZCCHC10',
#    'HSPA4',
#    'FSTL4',
#    'SKP1',
#    'UBE2B',
#    'CDKN2AIPNL',
#    'SAR1B',
#    'DDX46',
#    'C5orf24',
#    'PCBD2',
#    'CXCL14',
#    'TGFBI',
#    'SMAD5',
#    'SMIM32',
#    'KLHL3',
#    'FAM13B',
#    'NME5',
#    'BRD8',
#    'FAM53C',
#    'REEP2',
#    'EGR1',
#    'ETF1',
#    'CTNNA1',
#    'LRRTM2',
#    'SIL1',
#    'PAIP2',
#    'DNAJC18',
#    'UBE2D2',
#    'NRG2',
#    'IGIP',
#    'CYSTM1',
#    'SLC4A9',
#    'SRA1',
#    'APBB3'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 37,
#   'genes': ['SLC35A4',
#    'DND1',
#    'ZMAT2',
#    'CNR1',
#    'CNR1',
#    'PCDHA11',
#    'PCDHAC2',
#    'PCDHB2',
#    'ME1',
#    'PCDHB9',
#    'PCDHB10',
#    'PCDHB11',
#    'ME2',
#    'PCDHB12',
#    'PCDHB14',
#    'PCDHB18P',
#    'PCDHGA3',
#    'PCDHGB4',
#    'PCDHGC3',
#    'PCDHGC5',
#    'DIAPH1',
#    'RELL2',
#    'ARAP3',
#    'PCDH12',
#    'SPRY4',
#    'FGF1',
#    'ARHGAP26',
#    'NR3C1',
#    'KCTD16',
#    'PRELID2',
#    'TCERG1',
#    'PPP2R2B',
#    'DPYSL3',
#    'JAKMIP2',
#    'HTR4',
#    'ADRB2',
#    'AFAP1L1',
#    'GRPEL2',
#    'PPARGC1B',
#    'HMGXB3',
#    'CSF1R',
#    'SLC6A7',
#    'CAMK2A',
#    'TCOF1',
#    'CD74',
#    'RPS14',
#    'NDST1',
#    'MYOZ3',
#    'RBM22',
#    'DCTN4',
#    'SMIM3',
#    'GPX3',
#    'TNIP1',
#    'ANXA6',
#    'SLC36A1',
#    'SPARC',
#    'ATOX1',
#    'G3BP1',
#    'GRIA1',
#    'MFAP3'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 38,
#   'genes': ['GALNT10',
#    'SAP30L',
#    'LARP1',
#    'GEMIN5',
#    'MRPL22',
#    'HAVCR2',
#    'FNDC9',
#    'THG1L',
#    'LSM11',
#    'CLINT1',
#    'ADRA1B',
#    'FABP6',
#    'SLU7',
#    'PTTG1',
#    'GABRB2',
#    'GABRA1',
#    'GABRG2',
#    'MAT2B',
#    'TENM2',
#    'WWC1',
#    'SLIT3',
#    'SPDL1',
#    'LCP2',
#    'RANBP17',
#    'FGF18',
#    'FBXW11',
#    'STK10',
#    'UBTD2',
#    'NEURL1B',
#    'ATP6V0E1',
#    'CREBRF',
#    'STC2',
#    'LINC01485',
#    'CPEB4',
#    'NSG2',
#    'HRH2',
#    'CPLX2',
#    'LOC100996385',
#    'KIAA1191',
#    'ARL10',
#    'NOP16',
#    'RNF44',
#    'GPRIN1',
#    'SNCB',
#    'EIF4E1B',
#    'UNC5A',
#    'UIMC1',
#    'ZNF346',
#    'RAB24',
#    'PRELID1',
#    'RGS14',
#    'F12',
#    'GRK6',
#    'PRR7',
#    'PDLIM7',
#    'DOK3',
#    'FAM153A',
#    'LOC728554',
#    'RMND5B',
#    'NHP2'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 39,
#   'genes': ['COL23A1',
#    'CLK4',
#    'CANX',
#    'MAML1',
#    'LTC4S',
#    'MGAT4B',
#    'MRNIP',
#    'TBC1D9B',
#    'RASGEF1C',
#    'GFPT2',
#    'SCGB3A1',
#    'FLT4',
#    'MGAT1',
#    'BTNL9',
#    'TRIM7',
#    'TRIM41',
#    'TRIM52',
#    'FOXQ1',
#    'FOXF2',
#    'FOXC1',
#    'SERPINB1',
#    'SERPINB9',
#    'SERPINB6',
#    'LINC01011',
#    'BPHL',
#    'TUBB2A',
#    'TUBB2B',
#    'SLC22A23',
#    'ECI2',
#    'LYRM4',
#    'NRN1',
#    'LY86-AS1',
#    'LY86',
#    'RREB1',
#    'SSR1',
#    'DSP',
#    'SNRNP48',
#    'C6orf52',
#    'TMEM14C',
#    'SMIM13',
#    'TMEM170B',
#    'ADTRP',
#    'HIVEP1',
#    'EDN1',
#    'GFOD1',
#    'SIRT5',
#    'MCUR1',
#    'RNF182',
#    'CD83',
#    'JARID2',
#    'DTNBP1',
#    'MYLIP',
#    'GMPR',
#    'ATXN1',
#    'RBM24',
#    'CAP2',
#    'NHLRC1',
#    'TPMT',
#    'KDM1B',
#    'ID4'],
#   'chromosome': 'NC_000005.10'},
#  {'token_id': 40,
#   'genes': ['MBOAT1',
#    'E2F3',
#    'SOX4',
#    'CASC15',
#    'MRS2',
#    'GPLD1',
#    'KIAA0319',
#    'TDP2',
#    'ACOT13',
#    'C6orf62',
#    'GMNN',
#    'RIPOR2',
#    'CMAHP',
#    'SCGN',
#    'BTN3A2',
#    'BTN2A2',
#    'BTN3A1',
#    'BTN3A3',
#    'BTF3',
#    'BTN2A1',
#    'ZNF322',
#    'PRSS16',
#    'ZNF184',
#    'ZNF165',
#    'ZSCAN9',
#    'ZSCAN26',
#    'ZSCAN31',
#    'COX11',
#    'TRIM27',
#    'GABBR1',
#    'HCG4',
#    'HLA-G',
#    'HLA-H',
#    'PPP1R11',
#    'TRIM26',
#    'GNL1',
#    'ABCF1',
#    'C6orf136',
#    'TUBB',
#    'FLOT1',
#    'PSORS1C1',
#    'HLA-C',
#    'MICA',
#    'MICB',
#    'ATP6V1G2',
#    'TNF',
#    'LTB',
#    'LST1',
#    'AIF1',
#    'BAG6',
#    'APOM',
#    'C6orf47',
#    'LY6G5B',
#    'DDAH2',
#    'HSPA1L',
#    'NELFE',
#    'STK19',
#    'RNF5',
#    'NOTCH4',
#    'HCG23'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 41,
#   'genes': ['HLA-DRA',
#    'HLA-DRB1',
#    'TAP1',
#    'LOC100294145',
#    'HLA-DMB',
#    'HLA-DMA',
#    'BRD2',
#    'HLA-DOA',
#    'HLA-DPA1',
#    'HLA-DPB1',
#    'HLA-DPB2',
#    'COL11A2',
#    'SLC39A7',
#    'RPS18',
#    'BAK1',
#    'UQCC2',
#    'LEMD2',
#    'GRM4',
#    'HMGA1',
#    'SMIM29',
#    'RPS10',
#    'PACSIN1',
#    'SPDEF',
#    'C6orf106',
#    'ANKS1A',
#    'PPARD',
#    'FKBP5',
#    'SRPK1',
#    'SLC26A8',
#    'MAPK13',
#    'BRPF3',
#    'CPNE5',
#    'MTCH1',
#    'PIM1',
#    'RNF8',
#    'CCDC167',
#    'MDGA1',
#    'ZFAND3',
#    'BTBD9',
#    'GLO1',
#    'MOCS1',
#    'LRFN2',
#    'OARD1',
#    'TREM2',
#    'TFEB',
#    'TOMM6',
#    'USP49',
#    'BYSL',
#    'GUCA1B',
#    'TRERF1',
#    'UBR2',
#    'PRPH2',
#    'ATP6V0CP3',
#    'TBCC',
#    'BICRAL',
#    'MEA1',
#    'KLHDC3',
#    'CRIP3',
#    'DLK2',
#    'LRRC73'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 42,
#   'genes': ['RSPH9',
#    'MRPS18A',
#    'VEGFA',
#    'SLC29A1',
#    'NFKBIE',
#    'TCTE1',
#    'AARS2',
#    'RUNX2',
#    'CLIC5',
#    'ENPP4',
#    'ENPP5',
#    'RCAN2',
#    'SLC25A27',
#    'TDRD6',
#    'PLA2G7',
#    'ADGRF5',
#    'TNFRSF21',
#    'PTCHD4',
#    'MCM3',
#    'PAQR8',
#    'TRAM2',
#    'TRAM2-AS1',
#    'TMEM14A',
#    'GSTA4',
#    'FBXO9',
#    'ELOVL5',
#    'LRRC1',
#    'MLIP',
#    'COL21A1',
#    'BEND6',
#    'BAG2',
#    'RAB23',
#    'GUSBP4',
#    'LINC00680',
#    'KHDRBS2',
#    'PTP4A1',
#    'PHF3',
#    'ADGRB3',
#    'COL19A1',
#    'B3GAT2',
#    'RIMS1',
#    'KCNQ5',
#    'KHDC1L',
#    'KHDC1',
#    'COL12A1',
#    'FILIP1',
#    'SENP6',
#    'IRAK1BP1',
#    'LCA5',
#    'SH3BGRL2',
#    'ELOVL4',
#    'TPBG',
#    'UBE3D',
#    'PGM3',
#    'ME1',
#    'PRSS35',
#    'CYB5R4',
#    'MRAP2',
#    'CEP162',
#    'NT5E'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 43,
#   'genes': ['SYNCRIP',
#    'SNHG5',
#    'HTR1E',
#    'ZNF292',
#    'SMIM8',
#    'LAT',
#    'AKIRIN2',
#    'CNR1',
#    'PM20D2',
#    'SRSF12',
#    'UBE2J1',
#    'RRAGD',
#    'ANKRD6',
#    'CASP8AP2',
#    'BACH2',
#    'FUT9',
#    'UFL1',
#    'NDUFAF4',
#    'POU3F2',
#    'FBXL4',
#    'FAXC',
#    'COQ3',
#    'PNISR',
#    'USP45',
#    'MCHR2',
#    'ASCC3',
#    'GRIK2',
#    'HACE1',
#    'LIN28B',
#    'POPDC3',
#    'PREP',
#    'ATG5',
#    'CD24',
#    'SOBP',
#    'NR2E1',
#    'SNX3',
#    'ARMC2',
#    'PPIL6',
#    'MICAL1',
#    'GPR6',
#    'WASF1',
#    'CDC40',
#    'METTL24',
#    'CDK19',
#    'AMD1',
#    'GTF3C6',
#    'RPF2',
#    'GSTM2P1',
#    'MFSD4B',
#    'REV3L',
#    'TRAF3IP2',
#    'FYN',
#    'TUBE1',
#    'FAM229B',
#    'LAMA4',
#    'MARCKS',
#    'HDAC2',
#    'HS3ST5',
#    'FRK',
#    'NT5DC1'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 44,
#   'genes': ['COL10A1',
#    'TSPYL4',
#    'TSPYL1',
#    'CALHM6',
#    'RWDD1',
#    'FAM162B',
#    'DCBLD1',
#    'GOPC',
#    'NUS1',
#    'SLC35F1',
#    'CEP85L',
#    'ASF1A',
#    'FAM184A',
#    'MAN1A1',
#    'GJA1',
#    'SERINC1',
#    'PKIB',
#    'FABP7',
#    'CLVS2',
#    'NKAIN2',
#    'RNF217',
#    'TPD52L1',
#    'HDDC2',
#    'HEY2',
#    'TRMT11',
#    'CENPW',
#    'RSPO3',
#    'THEMIS',
#    'PTPRK',
#    'LAMA2',
#    'ARHGAP18',
#    'TMEM200A',
#    'AKAP7',
#    'CTGF',
#    'MOXD1',
#    'STX7',
#    'EYA4',
#    'SLC2A12',
#    'SGK1',
#    'MYB',
#    'AHI1',
#    'PDE7B',
#    'MAP7',
#    'MAP3K5',
#    'PERP',
#    'ARFGEF3',
#    'HEBP2',
#    'NHSL1',
#    'CCDC28A',
#    'REPS1',
#    'ABRACL',
#    'HECA',
#    'TXLNB',
#    'CITED2',
#    'ADGRG6',
#    'HIVEP2',
#    'FUCA2',
#    'PHACTR2',
#    'PLAGL1',
#    'UTRN'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 45,
#   'genes': ['FBXO30',
#    'GRM1',
#    'RAB32',
#    'STXBP5',
#    'SAMD5',
#    'SASH1',
#    'UST',
#    'TAB2',
#    'GINM1',
#    'PCMT1',
#    'RAET1E-AS1',
#    'PPP1R14C',
#    'MTHFD1L',
#    'AKAP12',
#    'ZBTB2',
#    'RMND1',
#    'ARMT1',
#    'SYNE1',
#    'MYCT1',
#    'VIP',
#    'RGS17',
#    'OPRM1',
#    'IPCEF1',
#    'CNKSR3',
#    'TIAM2',
#    'TFB1M',
#    'ARID1B',
#    'ZDHHC14',
#    'SERAC1',
#    'GTF2H5',
#    'EZR',
#    'RSPH3',
#    'ACAT2',
#    'TCP1',
#    'MRPL18',
#    'PNLDC1',
#    'PACRG',
#    'QKI',
#    'C6orf118',
#    'PDE10A',
#    'LINC00473',
#    'MPC1',
#    'RPS6KA2',
#    'RNASET2',
#    'DACT2',
#    'SMOC2',
#    'C6orf120',
#    'PSMB1',
#    'PRKAR1B',
#    'DNAAF5',
#    'SUN1',
#    'ADAP1',
#    'C7orf50',
#    'GPER1',
#    'ZFAND2A',
#    'MAFK',
#    'PSMG3',
#    'PSMG3-AS1',
#    'MAD1L1',
#    'SNX8'],
#   'chromosome': 'NC_000006.12'},
#  {'token_id': 46,
#   'genes': ['CHST12',
#    'LFNG',
#    'IQCE',
#    'AMZ1',
#    'GNA12',
#    'SDK1',
#    'RADIL',
#    'WIPI2',
#    'SLC29A4',
#    'FBXL18',
#    'PMS2',
#    'RAC1',
#    'DAGLB',
#    'ZDHHC4',
#    'ZNF12',
#    'C1GALT1',
#    'MIOS',
#    'GLCCI1',
#    'ICA1',
#    'NXPH1',
#    'NDUFA4',
#    'THSD7A',
#    'VWDE',
#    'SCIN',
#    'ARL4A',
#    'ETV1',
#    'DGKB',
#    'SOSTDC1',
#    'TSPAN13',
#    'PRPS1',
#    'HDAC9',
#    'TWIST1',
#    'TMEM196',
#    'ITGB8',
#    'RAPGEF5',
#    'GPNMB',
#    'MALSU1',
#    'IGF2BP3',
#    'RPS2P32',
#    'NPY',
#    'MPP6',
#    'GSDME',
#    'OSBPL3',
#    'CYCS',
#    'SNX10',
#    'SKAP2',
#    'HIBADH',
#    'JAZF1',
#    'TRIL',
#    'CPVL',
#    'DPY19L2P3',
#    'WIPF3',
#    'FKBP14',
#    'PLEKHA8',
#    'DKFZP586I1420',
#    'GGCT',
#    'AQP1',
#    'ADCYAP1R1',
#    'NEUROD6',
#    'PPP1R17'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 47,
#   'genes': ['DPY19L1P1',
#    'ZNRF2P1',
#    'KBTBD2',
#    'RP9P',
#    'RP9',
#    'BBS9',
#    'BMPER',
#    'DPY19L1',
#    'DPY19L2P1',
#    'EEPD1',
#    'STARD3NL',
#    'AMPH',
#    'VPS41',
#    'POU6F2',
#    'CDK13',
#    'SUGCT',
#    'INHBA',
#    'GLI3',
#    'HECW1',
#    'STK17A',
#    'COA1',
#    'BLVRA',
#    'URGCP',
#    'RASA4CP',
#    'DBNL',
#    'AEBP1',
#    'CAMK2B',
#    'NUDCD3',
#    'OGDH',
#    'ZMIZ2',
#    'PPIA',
#    'PURB',
#    'CCM2',
#    'RAMP3',
#    'ADCY1',
#    'TNS3',
#    'UPP1',
#    'VWC2',
#    'DDC',
#    'GRB10',
#    'VSTM2A',
#    'EGFR',
#    'NUPR2',
#    'ZNF727',
#    'ZNF736',
#    'ZNF107',
#    'ZNF273',
#    'INTS4P1',
#    'ZNF92',
#    'VKORC1L1',
#    'ASL',
#    'TPST1',
#    'GS1-124K5.4',
#    'RABGEF1',
#    'STAG3L4',
#    'AUTS2',
#    'GALNT17',
#    'CALN1',
#    'NSUN5',
#    'FZD9'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 48,
#   'genes': ['MLXIPL',
#    'VPS37D',
#    'STX1A',
#    'CLDN4',
#    'LIMK1',
#    'EIF4H',
#    'LAT2',
#    'RFC2',
#    'CLIP2',
#    'GTF2IRD1',
#    'GTF2IRD2',
#    'GTF2IRD2',
#    'NCF1C',
#    'RHBDD2',
#    'TMEM120A',
#    'MDH2',
#    'SRRM3',
#    'HSPB1',
#    'YWHAG',
#    'SSC4D',
#    'FDPSP2',
#    'CCDC146',
#    'FGL2',
#    'GSAP',
#    'PTPN12',
#    'APTR',
#    'TMEM60',
#    'PHTF2',
#    'MAGI2-AS3',
#    'SEMA3C',
#    'HGF',
#    'PCLO',
#    'SEMA3E',
#    'SEMA3A',
#    'SEMA3D',
#    'GRM3',
#    'TP53TG1',
#    'RUNDC3B',
#    'SLC25A40',
#    'ADAM22',
#    'TEX47',
#    'DPY19L2P4',
#    'STEAP1',
#    'STEAP2',
#    'CFAP69',
#    'CDK14',
#    'FZD1',
#    'CYP51A1',
#    'KRIT1',
#    'ANKIB1',
#    'PEX1',
#    'SAMD9',
#    'COL1A2',
#    'PEG10',
#    'PPP1R9A',
#    'PON3',
#    'PON2',
#    'DYNC1I1',
#    'SLC25A13',
#    'SEM1'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 49,
#   'genes': ['TAC1',
#    'CCZ1P-OR7E38P',
#    'LMTK2',
#    'NPTX2',
#    'TMEM130',
#    'TRRAP',
#    'LOC101927550',
#    'ZNF789',
#    'ZNF394',
#    'ZNF655',
#    'AZGP1',
#    'MCM7',
#    'TAF6',
#    'MBLAC1',
#    'PILRA',
#    'MEPCE',
#    'ACTL6B',
#    'GNB2',
#    'GIGYF1',
#    'POP7',
#    'TRIP6',
#    'ACHE',
#    'AP1S1',
#    'VGF',
#    'FIS1',
#    'IFT22',
#    'COL26A1',
#    'CUX1',
#    'ORAI2',
#    'LRRC17',
#    'ARMC10',
#    'NAPEPLD',
#    'DPY19L2P2',
#    'PMPCB',
#    'DNAJC2',
#    'PSMC2',
#    'RELN',
#    'LHFPL3',
#    'KMT2E',
#    'ATXN7L1',
#    'NAMPT',
#    'CCDC71L',
#    'PRKAR2B',
#    'COG5',
#    'GPR22',
#    'DUS4L',
#    'SLC26A4-AS1',
#    'SLC26A4',
#    'DLD',
#    'LAMB1',
#    'NRCAM',
#    'DNAJB9',
#    'LRRN3',
#    'DOCK4',
#    'LSMEM1',
#    'TMEM168',
#    'GPR85',
#    'SMIM30',
#    'FOXP2',
#    'TFEC'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 50,
#   'genes': ['TES',
#    'CAV2',
#    'MET',
#    'CTTNBP2',
#    'ING3',
#    'FAM3C',
#    'PTPRZ1',
#    'AASS',
#    'CADPS2',
#    'CAPS2',
#    'IQUB',
#    'TMEM229A',
#    'GRM8',
#    'SND1-IT1',
#    'LRRC4',
#    'PRRT4',
#    'IMPDH1',
#    'CCDC136',
#    'ATP6V1F',
#    'IRF5',
#    'TPI1P2',
#    'LOC407835',
#    'TSPAN33',
#    'SMO',
#    'TMEM209',
#    'MEST',
#    'LINC-PINT',
#    'MKLN1',
#    'PLXNA4',
#    'EXOC4',
#    'SLC35B4',
#    'CALD1',
#    'CNOT4',
#    'NUP205',
#    'STMP1',
#    'CHRM2',
#    'PTN',
#    'CREB3L2',
#    'TRIM24',
#    'ATP6V0A4',
#    'KIAA1549',
#    'ZC3HAV1',
#    'CLEC2L',
#    'KDM7A',
#    'JHDM1D-AS1',
#    'MKRN1',
#    'DENND2A',
#    'BRAF',
#    'MRPS33',
#    'TMEM178B',
#    'TAS2R5',
#    'PRSS1',
#    'PRSS1',
#    'PRSS2',
#    'EPHB6',
#    'GSTK1',
#    'FAM131B',
#    'ZYX',
#    'TPK1',
#    'CNTNAP2'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 51,
#   'genes': ['ZNF786',
#    'ZNF398',
#    'KRBA1',
#    'ATP6V0E2',
#    'ACTR3C',
#    'LRRC61',
#    'REPIN1',
#    'LOC728743',
#    'GIMAP2',
#    'TMEM176B',
#    'TMEM176A',
#    'CDK5',
#    'AGAP3',
#    'ABCF2',
#    'SMARCD3',
#    'NUB1',
#    'WDR86',
#    'RHEB',
#    'PRKAG2',
#    'PRKAG2-AS1',
#    'GALNTL5',
#    'GALNT11',
#    'KMT2C',
#    'FABP5P3',
#    'ACTR3B',
#    'DPP6',
#    'PAXIP1',
#    'HTR5A',
#    'C7orf13',
#    'LMBR1',
#    'ESYT2',
#    'VIPR2',
#    'FBXO25',
#    'ERICH1',
#    'ARHGEF10',
#    'KBTBD11',
#    'MYOM2',
#    'AGPAT5',
#    'LINC00965',
#    'FAM86B3P',
#    'PRAG1',
#    'PPP1R3B',
#    'TNKS',
#    'LINC00599',
#    'MSRA',
#    'PINX1',
#    'XKR6',
#    'FAM167A-AS1',
#    'FDFT1',
#    'TRMT9B',
#    'DLC1',
#    'TUSC3',
#    'MICU3',
#    'ZDHHC2',
#    'ASAH1',
#    'PSD3',
#    'CSGALNACT1',
#    'LPL',
#    'LZTS1',
#    'GFRA2'],
#   'chromosome': 'NC_000007.14'},
#  {'token_id': 52,
#   'genes': ['NPM2',
#    'FGF17',
#    'DMTN',
#    'NUDT18',
#    'HR',
#    'LGI3',
#    'PHYHIP',
#    'POLR3D',
#    'SLC39A14',
#    'PPP3CC',
#    'SORBS3',
#    'BIN3',
#    'EGR3',
#    'PEBP4',
#    'RHOBTB2',
#    'TNFRSF10B',
#    'LOR',
#    'ENTPD4',
#    'SLC25A37',
#    'NKX3-1',
#    'ADAM28',
#    'NEFM',
#    'NEFL',
#    'GNRH1',
#    'KCTD9',
#    'PPP2R2A',
#    'DPYSL2',
#    'TRIM35',
#    'PTK2B',
#    'CHRNA2',
#    'EPHX2',
#    'CLU',
#    'CCDC25',
#    'SCARA5',
#    'ELP3',
#    'PNOC',
#    'ZNF395',
#    'FBXO16',
#    'FZD3',
#    'INTS9',
#    'LEPROTL1',
#    'DCTN6',
#    'UBXN8',
#    'NRG1',
#    'TTI2',
#    'UNC5D',
#    'LOC728024',
#    'PLPBP',
#    'ADGRA2',
#    'BRF2',
#    'EIF4EBP1',
#    'ASH2L',
#    'STAR',
#    'DDHD2',
#    'PLPP5',
#    'NSD3',
#    'FGFR1',
#    'TACC1',
#    'TCIM',
#    'ZMAT4'],
#   'chromosome': 'NC_000008.11'},
#  {'token_id': 53,
#   'genes': ['SFRP1',
#    'NKX6-3',
#    'ANK1',
#    'AP3M2',
#    'PLAT',
#    'IKBKB',
#    'SLC20A2',
#    'SMIM19',
#    'ASNSP1',
#    'SPIDR',
#    'SNTG1',
#    'RB1CC1',
#    'OPRK1',
#    'ATP6V1H',
#    'RGS20',
#    'LYPLA1',
#    'MRPL15',
#    'XKR4',
#    'TGS1',
#    'LYN',
#    'RPS20',
#    'CHCHD7',
#    'SDR16C5',
#    'PENK',
#    'SDCBP',
#    'NSMAF',
#    'TOX',
#    'CA8',
#    'CHD7',
#    'CLVS1',
#    'ASPH',
#    'NKAIN3',
#    'TTPA',
#    'MIR124-2HG',
#    'BHLHE22',
#    'CYP7B1',
#    'MTFR1',
#    'CRH',
#    'RRS1',
#    'C8orf46',
#    'MYBL1',
#    'C8orf44',
#    'PPP1R42',
#    'COPS5',
#    'PREX2',
#    'C8orf34',
#    'SULF1',
#    'LACTB2',
#    'XKR9',
#    'EYA1',
#    'KCNB2',
#    'RDH10',
#    'STAU2',
#    'UBE2W',
#    'ELOC',
#    'TMEM70',
#    'LY96',
#    'CRISPLD1',
#    'ZFHX4-AS1',
#    'ZFHX4'],
#   'chromosome': 'NC_000008.11'},
#  {'token_id': 54,
#   'genes': ['PKIA',
#    'ZC2HC1A',
#    'STMN2',
#    'HEY1',
#    'TPD52',
#    'ZBTB10',
#    'PAG1',
#    'FABP5',
#    'PMP2',
#    'IMPA1',
#    'E2F5',
#    'CA13',
#    'CA2',
#    'WWP1',
#    'RMDN1',
#    'CPNE3',
#    'MMP16',
#    'RIPK2',
#    'CALB1',
#    'NECAB1',
#    'PIP4P2',
#    'OTUD6B-AS1',
#    'OTUD6B',
# ...
#    'DAPK3',
#    'EEF2',
#    'ZBTB7A',
#    'MAP2K2',
#    'CREB3L3',
#    'ANKRD24',
#    'SHD',
#    'FSD1',
#    'MPND',
#    'SH3GL1',
#    'CHAF1A',
#    'UBXN6',
#    'PLIN5',
#    'SEMA6B',
#    'TNFAIP8L1',
#    'MYDGF',
#    'MIR7-3HG',
#    'TICAM1',
#    'PLIN3',
#    'ZNRF4',
#    'TINCR'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 106,
#   'genes': ['HSD11B1L',
#    'RPL36',
#    'LONP1',
#    'RFX2',
#    'MLLT1',
#    'KHSRP',
#    'SLC25A41',
#    'SLC25A23',
#    'DENND1C',
#    'C3',
#    'GPR108',
#    'VAV1',
#    'ZNF557',
#    'INSR',
#    'ARHGEF18',
#    'ZNF358',
#    'MCOLN1',
#    'CLEC4G',
#    'CLEC4M',
#    'TGFBR3L',
#    'CTXN1',
#    'TIMM44',
#    'ELAVL1',
#    'CERS4',
#    'KANK3',
#    'RAB11B',
#    'MYO1F',
#    'OR7E24',
#    'ZNF562',
#    'ZNF812P',
#    'FBXL12',
#    'UBL5',
#    'PIN1',
#    'OLFM2',
#    'COL5A3',
#    'C19orf66',
#    'S1PR2',
#    'MRPL4',
#    'ICAM5',
#    'FDX1L',
#    'ICAM3',
#    'CDC37',
#    'PDE4A',
#    'KEAP1',
#    'ATG4D',
#    'KRI1',
#    'CDKN2D',
#    'SLC44A2',
#    'LDLR',
#    'FH',
#    'RAB3D',
#    'TMEM205',
#    'PLPPR2',
#    'ELAVL3',
#    'ZNF653',
#    'ECSIT',
#    'CNN1',
#    'ELOF1',
#    'ZNF844',
#    'ZNF136'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 107,
#   'genes': ['ZNF44',
#    'ZNF443',
#    'WDR83',
#    'DHPS',
#    'FBXW9',
#    'HOOK2',
#    'HK2',
#    'RNASEH2A',
#    'RTBDN',
#    'FARSA',
#    'CALR',
#    'RAD23A',
#    'NFIX',
#    'IER2',
#    'CACNA1A',
#    'CCDC130',
#    'ZSWIM4',
#    'NANOS3',
#    'C19orf57',
#    'DDX39A',
#    'DNAJB1',
#    'ZNF333',
#    'AKAP8',
#    'WIZ',
#    'RASAL3',
#    'RAB8A',
#    'FAM32A',
#    'AP1M1',
#    'KLF2',
#    'TMEM38A',
#    'NWD1',
#    'SIN3B',
#    'CPAMD8',
#    'HAUS8',
#    'OCEL1',
#    'BABAM1',
#    'ABHD8',
#    'MRPL34',
#    'DDA1',
#    'UNC13A',
#    'CCDC124',
#    'KCNN1',
#    'MAST3',
#    'IFI30',
#    'MPV17L2',
#    'IQCN',
#    'LSM4',
#    'GRP',
#    'ISYNA1',
#    'ELL',
#    'KXD1',
#    'UBA52',
#    'CRLF1',
#    'TMEM59L',
#    'COMP',
#    'CERS1',
#    'CERS1',
#    'HOMER3',
#    'SUGP2',
#    'RFXANK'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 108,
#   'genes': ['NR2C2AP',
#    'NCAN',
#    'HAPLN4',
#    'GATAD2A',
#    'YJEFN3',
#    'PBX4',
#    'GMIP',
#    'ZNF714',
#    'ZNF493',
#    'ZNF429',
#    'IPO5P1',
#    'ZNF681',
#    'ZNF254',
#    'UQCRFS1',
#    'POP4',
#    'PLEKHF1',
#    'C19orf12',
#    'CCNE1',
#    'URI1',
#    'TSHZ3',
#    'DPY19L3',
#    'ANKRD27',
#    'CEP89',
#    'RHPN2',
#    'GPATCH1',
#    'CEBPA',
#    'PEPD',
#    'CHST8',
#    'KCTD15',
#    'GPI',
#    'PDCD2L',
#    'WTIP',
#    'ZNF599',
#    'SCN1B',
#    'LGI4',
#    'FXYD1',
#    'FXYD7',
#    'USF2',
#    'DMKN',
#    'ATP4A',
#    'IGFLR1',
#    'PSENEN',
#    'HSPB6',
#    'ARHGAP33',
#    'NPHS1',
#    'KIRREL2',
#    'HCST',
#    'TYROBP',
#    'SDHAF1',
#    'SYNE4',
#    'POLR2I',
#    'TBCB',
#    'CAPNS1',
#    'COX7A1',
#    'ZNF565',
#    'ZNF146',
#    'ZFP14',
#    'LOC644189',
#    'ZNF566',
#    'ZNF567'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 109,
#   'genes': ['ZNF790',
#    'HKR1',
#    'ZNF569',
#    'ZNF570',
#    'ZNF540',
#    'ZNF781',
#    'SIPA1L3',
#    'DPF1',
#    'SPINT2',
#    'GGN',
#    'FAM98C',
#    'RYR1',
#    'ACTN4',
#    'CAPN12',
#    'ECH1',
#    'HNRNPL',
#    'RINL',
#    'CCER2',
#    'FBXO27',
#    'GMFG',
#    'SAMD4B',
#    'DLL3',
#    'EID2B',
#    'FBL',
#    'FCGBP',
#    'MAP3K10',
#    'TTC9B',
#    'PLD3',
#    'SPTBN4',
#    'LTBP4',
#    'NUMBL',
#    'ITPKC',
#    'HNRNPUL1',
#    'TMEM91',
#    'BCKDHA',
#    'DMAC2',
#    'PCAT19',
#    'RPS19',
#    'ATP1A3',
#    'POU2F2',
#    'DEDD2',
#    'GSK3A',
#    'PAFAH1B3',
#    'TMEM145',
#    'MEGF8',
#    'CNFN',
#    'LIPE',
#    'PHLDB3',
#    'ZNF575',
#    'PINLYP',
#    'ZNF576',
#    'ZNF576',
#    'CADM4',
#    'KCNN4',
#    'LYPD5',
#    'ZNF222',
#    'ZNF284',
#    'ZNF224',
#    'ZNF226',
#    'ZNF112'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 110,
#   'genes': ['ZNF229',
#    'PVR',
#    'CEACAM19',
#    'BCL3',
#    'NECTIN2',
#    'TOMM40',
#    'APOE',
#    'APOC1',
#    'CLPTM1',
#    'GEMIN7',
#    'PPP1R37',
#    'TRAPPC6A',
#    'KLC2',
#    'ERCC2',
#    'FOSB',
#    'RTN2',
#    'PPM1N',
#    'VASP',
#    'GPR4',
#    'EML2',
#    'FBXO46',
#    'MYPOP',
#    'NOS2',
#    'NOVA2',
#    'CCDC8',
#    'PNMA8A',
#    'PNMA8B',
#    'PPP5D1',
#    'CALM3',
#    'GNG8',
#    'DACT3',
#    'FKRP',
#    'AP2S1',
#    'NPAS1',
#    'TMEM160',
#    'SAE1',
#    'BBC3',
#    'CCDC9',
#    'MEIS3',
#    'SLC8A2',
#    'NAPA',
#    'ZNF541',
#    'EHD2',
#    'NOP53',
#    'SELENOW',
#    'ZSWIM9',
#    'EMP3',
#    'KCNJ14',
#    'SPHK2',
#    'DBP',
#    'CA11',
#    'RASIP1',
#    'PLEKHA4',
#    'DHDH',
#    'FTL',
#    'RUVBL2',
#    'LIN7B',
#    'HRC',
#    'TRPM4',
#    'SLC17A7'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 111,
#   'genes': ['PIH1D1',
#    'FCGRT',
#    'RCN3',
#    'SRA1',
#    'IRF3',
#    'ADM5',
#    'CPT1C',
#    'AKT1S1',
#    'SIGLEC11',
#    'KCNC3',
#    'NR1H2',
#    'FAM71E1',
#    'LRRC4B',
#    'SYT3',
#    'SHANK1',
#    'CLEC11A',
#    'KLK5',
#    'KLK6',
#    'KLK7',
#    'KLK10',
#    'CD33',
#    'IGLON5',
#    'VSIG10L',
#    'ETFB',
#    'ZNF175',
#    'SPACA6',
#    'FPR1',
#    'ZNF577',
#    'ZNF350',
#    'ZNF615',
#    'ZNF480',
#    'ZNF610',
#    'ZNF880',
#    'ZNF83',
#    'ZNF611',
#    'ZNF816',
#    'ZNF677',
#    'ZNF845',
#    'ZNF765',
#    'TPM3P9',
#    'MYADM',
#    'PRKCG',
#    'CACNG7',
#    'CACNG8',
#    'CACNG6',
#    'VSTM1',
#    'TFPT',
#    'MBOAT7',
#    'TSEN34',
#    'TTYH1',
#    'LILRB4',
#    'PPP1R12C',
#    'TNNT1',
#    'TNNI3',
#    'SYT5',
#    'PTPRH',
#    'TMEM86B',
#    'BRSK1',
#    'TMEM238',
#    'UBE2S'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 112,
#   'genes': ['SHISA7',
#    'SSC5D',
#    'FIZ1',
#    'ZNF787',
#    'ZNF444',
#    'GAL',
#    'ZSCAN5A',
#    'ZNF542P',
#    'ZNF667',
#    'ZIM2',
#    'PEG3',
#    'TRAPPC2B',
#    'ZNF772',
#    'ZNF586',
#    'ZNF418',
#    'ZSCAN18',
#    'ZNF329',
#    'ZNF8',
#    'LOC105372480',
#    'A1BG',
#    'A1BG-AS1',
#    'ZNF584',
#    'ZNF324',
#    'SLC27A5',
#    'ZBTB45',
#    'CHMP2A',
#    'UBE2M',
#    'CENPBD1P1',
#    'C20orf96',
#    'ZCCHC3',
#    'SOX12',
#    'TRIB3',
#    'SRXN1',
#    'FAM110A',
#    'RSPO4',
#    'TMEM74B',
#    'SNPH',
#    'FKBP1A',
#    'NSFL1C',
#    'SIRPA',
#    'PDYN',
#    'SNRPB',
#    'PTPRA',
#    'FASTKD5',
#    'LZTS3',
#    'DDRGK1',
#    'SLC4A11',
#    'HSPA12B',
#    'C20orf27',
#    'ADRA1D',
#    'PRNP',
#    'RASSF2',
#    'TMEM230',
#    'PCNA',
#    'CDS2',
#    'LOC643406',
#    'GPCPD1',
#    'FERMT1',
#    'TMX4',
#    'PLCB1'],
#   'chromosome': 'NC_000019.10'},
#  {'token_id': 113,
#   'genes': ['PLCB4',
#    'LAMP5',
#    'PAK5',
#    'SNAP25',
#    'MKKS',
#    'SLX4IP',
#    'JAG1',
#    'BTBD3',
#    'TASP1',
#    'ISM1',
#    'ESF1',
#    'NDUFAF5',
#    'MACROD2',
#    'FLRT3',
#    'BFSP1',
#    'DSTN',
#    'SNX5',
#    'OVOL2',
#    'KAT14',
#    'ZNF133',
#    'LINC00652',
#    'SLC24A3',
#    'NAA20',
#    'CFAP61',
#    'INSM1',
#    'RALGAPA2',
#    'KIZ',
#    'THBD',
#    'GZF1',
#    'SYNDIG1',
#    'APMAP',
#    'ENTPD6',
#    'ABHD12',
#    'NINL',
#    'LOC101926935',
#    'NCOR1P1',
#    'MYLK2',
#    'PDRG1',
#    'PLAGL2',
#    'KIF3B',
#    'NOL4L',
#    'COMMD7',
#    'MAPRE1',
#    'SNTA1',
#    'NECAB3',
#    'E2F1',
#    'PXMP4',
#    'CHMP4B',
#    'RALY',
#    'EIF2S2',
#    'AHCY',
#    'MAP1LC3A',
#    'GSS',
#    'MYH7B',
#    'ERGIC3',
#    'FER1L4',
#    'SPAG4',
#    'CPNE1',
#    'ROMO1',
#    'PHF20'],
#   'chromosome': 'NC_000020.11'},
#  {'token_id': 114,
#   'genes': ['EPB41L1',
#    'NDRG3',
#    'DSN1',
#    'MROH8',
#    'RPN2',
#    'NNAT',
#    'VSTM2L',
#    'PPP1R16B',
#    'DHX35',
#    'MAFB',
#    'EMILIN3',
#    'CHD6',
#    'PTPRT',
#    'SRSF6',
#    'IFT52',
#    'TOX2',
#    'GDAP1L1',
#    'FITM2',
#    'TTPAL',
#    'SERINC3',
#    'PKIG',
#    'LINC01260',
#    'RIMS4',
#    'YWHAB',
#    'PABPC1L',
#    'TOMM34',
#    'STK4',
#    'KCNS1',
#    'MATN4',
#    'WFDC2',
#    'TNNC2',
#    'SNX21',
#    'ACOT8',
#    'CTSA',
#    'PLTP',
#    'SLC12A5',
#    'CDH22',
#    'ELMO2',
#    'ZNF334',
#    'SLC2A10',
#    'EYA2',
#    'ZMYND8',
#    'NCOA3',
#    'SULF2',
#    'STAU1',
#    'ZFAS1',
#    'KCNB1',
#    'PTGIS',
#    'B4GALT5',
#    'SPATA2',
#    'PARD6B',
#    'ADNP',
#    'KCNG1',
#    'ATP9A',
#    'ZFP64',
#    'TSHZ2',
#    'ZNF217',
#    'BCAS1',
#    'CBLN4',
#    'FAM210B'],
#   'chromosome': 'NC_000020.11'},
#  {'token_id': 115,
#   'genes': ['BMP7',
#    'PMEPA1',
#    'STAG1',
#    'RAB22A',
#    'VAPB',
#    'GNAS',
#    'CTSZ',
#    'PRELID3B',
#    'ZNF831',
#    'EDN3',
#    'PHACTR3',
#    'SYCP2',
#    'FAM217B',
#    'PPP1R3D',
#    'CDH4',
#    'HRH3',
#    'OSBPL2',
#    'CABLES2',
#    'SLCO4A1',
#    'NTSR1',
#    'COL9A3',
#    'TCFL5',
#    'DIDO1',
#    'HAR1A',
#    'NKAIN4',
#    'CHRNA4',
#    'KCNQ2',
#    'PPDPF',
#    'STMN3',
#    'RTEL1',
#    'SLC2A4RG',
#    'DNAJC5',
#    'TCEA2',
#    'MYT1',
#    'TPTE',
#    'ANKRD20A11P',
#    'NRIP1',
#    'MIR99AHG',
#    'CXADR',
#    'BTG3',
#    'CHODL',
#    'NCAM2',
#    'LINC00158',
#    'LINC00515',
#    'MRPL39',
#    'JAM2',
#    'ATP5PF',
#    'GABPA',
#    'ADAMTS5',
#    'RWDD2B',
#    'USP16',
#    'GRIK1',
#    'TIAM1',
#    'HUNK',
#    'MIS18A',
#    'SYNJ1',
#    'PAXBP1-AS1',
#    'PAXBP1',
#    'IFNAR2',
#    'DNAJC28'],
#   'chromosome': 'NC_000020.11'},
#  {'token_id': 116,
#   'genes': ['GART',
#    'CRYZL1',
#    'MRPS6',
#    'RCAN1',
#    'CHAF1B',
#    'SIM2',
#    'HLCS',
#    'PIGP',
#    'DSCR9',
#    'KCNJ6',
#    'ERG',
#    'ETS2',
#    'PSMG1',
#    'BRWD1',
#    'HMGN1',
#    'CHD5',
#    'SH3BGR',
#    'B3GALT5-AS1',
#    'PCP4',
#    'CHD2',
#    'BACE2',
#    'MX1',
#    'C2CD2',
#    'ZBTB21',
#    'UMODL1-AS1',
#    'ABCG1',
#    'CLIP4',
#    'RSPH1',
#    'PDE9A',
#    'WDR4',
#    'PKNOX1',
#    'PDXK',
#    'CSTB',
#    'AGPAT3',
#    'C21orf33',
#    'AIRE',
#    'PFKL',
#    'C21orf2',
#    'TRPM2',
#    'SUMO3',
#    'PTTG1IP',
#    'ITGB2',
#    'LINC01547',
#    'SLC19A1',
#    'PCBP3',
#    'COL6A1',
#    'FTCD',
#    'SPATC1L',
#    'LSS',
#    'MCM3AP-AS1',
#    'YBEY',
#    'PCNT',
#    'DIP2A',
#    'PRMT2',
#    'TPTEP1',
#    'IL17RA',
#    'LINC01664',
#    'CECR2',
#    'SLC25A18',
#    'ATP6V1E1'],
#   'chromosome': 'NC_000021.9'},
#  {'token_id': 117,
#   'genes': ['BID',
#    'MICAL3',
#    'USP18',
#    'DGCR5',
#    'SLC25A1',
#    'CLTCL1',
#    'C22orf39',
#    'CLDN5',
#    'GNB1L',
#    'RTL10',
#    'TANGO2',
#    'DGCR8',
#    'RTN4R',
#    'ZNF74',
#    'TMEM191A',
#    'PI4KA',
#    'LINC01637',
#    'AIFM3',
#    'THAP7',
#    'P2RX6',
#    'SLC7A4',
#    'P2RX6P',
#    'BCRP2',
#    'HIC2',
#    'SDF2L1',
#    'PPIL2',
#    'YPEL1',
#    'MAPK1',
#    'BMS1P20',
#    'RSPH14',
#    'GNAZ',
#    'RAB36',
#    'BCR',
#    'BCR',
#    'IGLL1',
#    'MIF',
#    'SUSD2',
#    'SPECC1L',
#    'SNRPD3',
#    'SGSM1',
#    'IGLL3P',
#    'GRK3',
#    'SEZ6L',
#    'ASPHD2',
#    'SRRD',
#    'TFIP11',
#    'TPST2',
#    'CRYBB1',
#    'MIAT',
#    'PITPNB',
#    'CHEK2',
#    'CDS1',
#    'KREMEN1',
#    'EMID1',
#    'EWSR1',
#    'RASL10A',
#    'RFPL1',
#    'RFPL1S',
#    'NEFH',
#    'THOC5'],
#   'chromosome': 'NC_000022.11'},
#  {'token_id': 118,
#   'genes': ['NF2',
#    'UQCR10',
#    'MTMR3',
#    'CASTOR1',
#    'KIAA1656',
#    'SEC14L2',
#    'MTFP1',
#    'DUSP18',
#    'OSBP2',
#    'MORC2-AS1',
#    'INPP5J',
#    'LIMK2',
#    'PATZ1',
#    'SFI1',
#    'DEPDC5',
#    'YWHAH',
#    'RFPL2',
#    'RFPL3',
#    'RTCB',
#    'SYN3',
#    'TIMP3',
#    'LARGE1',
#    'RASD2',
#    'RBFOX2',
#    'APOL2',
#    'TXN2',
#    'FOXRED2',
#    'CACNG2',
#    'IFT27',
#    'PVALB',
#    'MPST',
#    'CYTH4',
#    'ELFN2',
#    'LOC100506271',
#    'MFNG',
#    'SH3BP1',
#    'PDXP',
#    'LGALS1',
#    'MICALL1',
#    'C22orf23',
#    'PICK1',
#    'SLC16A8',
#    'BAIAP2L2',
#    'TMEM184B',
#    'KCNJ4',
#    'JOSD1',
#    'DNAL4',
#    'NPTXR',
#    'CBX6',
#    'CBX7',
#    'RPL3',
#    'SYNGR1',
#    'MIEF1',
#    'ATF4',
#    'RPS19BP1',
#    'CACNA1I',
#    'CACNA1I',
#    'SGSM3',
#    'MCHR1',
#    'SLC25A17'],
#   'chromosome': 'NC_000022.11'},
#  {'token_id': 119,
#   'genes': ['L3MBTL2',
#    'CHADL',
#    'RANGAP1',
#    'ZC3H7B',
#    'ACO2',
#    'POLR3H',
#    'CSDC2',
#    'PMM1',
#    'XRCC6',
#    'MEI1',
#    'SREBF2',
#    'SHISA8',
#    'TNFRSF13C',
#    'NAGA',
#    'NDUFA6-AS1',
#    'LINC01315',
#    'RRP7A',
#    'SERHL2',
#    'RRP7BP',
#    'CYB5R3',
#    'PACSIN2',
#    'TTLL1',
#    'TTLL12',
#    'MPPED1',
#    'PNPLA3',
#    'SAMM50',
#    'PARVB',
#    'SHISAL1',
#    'RTL6',
#    'PRR5',
#    'FAM118A',
#    'ATXN10',
#    'WNT7B',
#    'MIRLET7BHG',
#    'PPARA',
#    'TTC38',
#    'GRAMD4',
#    'CERK',
#    'PIM3',
#    'MLC1',
#    'PANX2',
#    'SELENOO',
#    'TUBGCP6',
#    'MAPK12',
#    'MAPK11',
#    'PPP6R2',
#    'SBF1',
#    'TYMP',
#    'SYCE3',
#    'MAPK8IP2',
#    'SHANK3',
#    'PLCXD1',
#    'PPP2R3B',
#    'IL3RA',
#    'DHRSX',
#    'ZBED1',
#    'CD99',
#    'GYG2',
#    'NLGN4X',
#    'PUDP'],
#   'chromosome': 'NC_000022.11'},
#  {'token_id': 120,
#   'genes': ['STS',
#    'VCX',
#    'PNPLA4',
#    'VCX2',
#    'ANOS1',
#    'TBL1X',
#    'GPR143',
#    'SHROOM2',
#    'ARHGAP6',
#    'MSL3',
#    'FRMPD4',
#    'PRPS2',
#    'TMSB4X',
#    'RAB9A',
#    'OFD1',
#    'GPM6B',
#    'GLRA2',
#    'MOSPD2',
#    'PIR',
#    'CA5B',
#    'AP1S2',
#    'CTPS2',
#    'TXLNG',
#    'RBBP7',
#    'REPS2',
#    'CDKL5',
#    'PPEF1',
#    'PHKA2',
#    'SH3KBP1',
#    'BCLAF3',
#    'EIF1AX',
#    'RPS6KA3',
#    'CNKSR2',
#    'SMPX',
#    'PTCHD1',
#    'PRDX4',
#    'APOO',
#    'EIF2S3',
#    'ZFX',
#    'PDK3',
#    'DCAF8L2',
#    'NR0B1',
#    'GK',
#    'TAB3',
#    'DMD',
#    'TMEM47',
#    'LANCL3',
#    'XK',
#    'CYBB',
#    'DYNLT3',
#    'SYTL5',
#    'SRPX',
#    'RPGR',
#    'BCOR',
#    'CXorf38',
#    'MED14',
#    'USP9X',
#    'DDX3X',
#    'CASK',
#    'GPR34'],
#   'chromosome': 'NC_000023.11'},
#  {'token_id': 121,
#   'genes': ['MAOA',
#    'MAOB',
#    'EFHC2',
#    'KRBOX4',
#    'SLC9A7',
#    'RGN',
#    'USP11',
#    'SYN1',
#    'TIMP1',
#    'CFP',
#    'ELK1',
#    'ZNF630',
#    'WDR13',
#    'SUV39H1',
#    'TIMM17B',
#    'SLC35A2',
#    'PIM2',
#    'CCDC120',
#    'PRAF2',
#    'WDR45',
#    'GPKOW',
#    'SYP',
#    'PPP1R3F',
#    'CLCN5',
#    'NUDT10',
#    'NUDT11',
#    'CENPVL3',
#    'GSPT2',
#    'MAGED1',
#    'TSPYL2',
#    'IQSEC2',
#    'SMC1A',
#    'RIBC1',
#    'HSD17B10',
#    'PHF8',
#    'FAM120C',
#    'TSR2',
#    'TRO',
#    'MAGEH1',
#    'RRAGB',
#    'KLF8',
#    'NBDY',
#    'ZXDA',
#    'AMER1',
#    'MSN',
#    'VSIG4',
#    'AR',
#    'OPHN1',
#    'YIPF6',
#    'EFNB1',
#    'PJA1',
#    'EDA',
#    'OTUD6A',
#    'GDPD2',
#    'SNX12',
#    'GJB1',
#    'ZMYM3',
#    'NONO',
#    'OGT',
#    'GCNA'],
#   'chromosome': 'NC_000023.11'},
#  {'token_id': 122,
#   'genes': ['LOC100129291',
#    'RTL5',
#    'RPS4X',
#    'HDAC8',
#    'PHKA1',
#    'NAP1L2',
#    'CHIC1',
#    'SLC16A2',
#    'RLIM',
#    'NEXMIF',
#    'ABCB7',
#    'ATRX',
#    'PGK1',
#    'TAF9B',
#    'ITM2A',
#    'BRWD3',
#    'SH3BGRL',
#    'POU3F4',
#    'RPS6KA6',
#    'ZNF711',
#    'DACH2',
#    'PABPC5',
#    'PCDH11X',
#    'NAP1L3',
#    'FAM133A',
#    'DIAPH2',
#    'PCDH19',
#    'TSPAN6',
#    'SYTL4',
#    'CSTF2',
#    'TRMT2B',
#    'TMEM35A',
#    'DRP2',
#    'ARMCX4',
#    'ARMCX1',
#    'ARMCX3',
#    'ARMCX2',
#    'ZMAT1',
#    'BEX5',
#    'TMSB15A',
#    'BEX1',
#    'BEX2',
#    'BEX2',
#    'BEX1',
#    'TMSB15B',
#    'TMSB15B',
#    'ZCCHC18',
#    'IL1RAPL2',
#    'MUM1L1',
#    'CXorf57',
#    'RNF128',
#    'TBC1D8B',
#    'MORC4',
#    'PRPS1',
#    'TSC22D3',
#    'MID2',
#    'KCNE5',
#    'ACSL4',
#    'TMEM164',
#    'AMMECR1'],
#   'chromosome': 'NC_000023.11'},
#  {'token_id': 123,
#   'genes': ['CHRDL1',
#    'PAK3',
#    'ALG13',
#    'TRPC5',
#    'HTR2C',
#    'IL13RA2',
#    'LRCH2',
#    'PLS3',
#    'KLHL13',
#    'WDR44',
#    'DOCK11',
#    'IL13RA1',
#    'ZCCHC12',
#    'LONRF3',
#    'PGRMC1',
#    'SLC25A5',
#    'CXorf56',
#    'UBE2A',
#    'SOWAHD',
#    'RNF113A',
#    'NKAPP1',
#    'TMEM255A',
#    'CUL4B',
#    'MCTS1',
#    'GLUD2',
#    'GRIA3',
#    'THOC2',
#    'TENM1',
#    'SMARCA1',
#    'APLN',
#    'RAB33A',
#    'ENOX2',
#    'ARHGAP36',
#    'IGSF1',
#    'STK26',
#    'RAP2C-AS1',
#    'MBNL3',
#    'HS6ST2',
#    'GPC4',
#    'CCDC160',
#    'MOSPD1',
#    'SMIM10',
#    'RTL8C',
#    'RTL8A',
#    'SMIM10L2B',
#    'ZNF449',
#    'SMIM10L2A',
#    'INTS6L',
#    'SLC9A6',
#    'FHL1',
#    'MAP7D3',
#    'ARHGEF6',
#    'ZIC3',
#    'FGF13',
#    'MCF2',
#    'ATP11C',
#    'SOX3',
#    'SLITRK4',
#    'SLITRK2',
#    'AFF2'],
#   'chromosome': 'NC_000023.11'},
#  {'token_id': 124,
#   'genes': ['IDS',
#    'MAMLD1',
#    'MTM1',
#    'CD99L2',
#    'PRRG3',
#    'GABRE',
#    'GABRA3',
#    'CETN2',
#    'NSDHL',
#    'PNMA5',
#    'PNMA3',
#    'PNMA6A',
#    'PNMA6E',
#    'HAUS7',
#    'ATP2B3',
#    'CCNQ',
#    'LOC105373383',
#    'PNCK',
#    'SLC6A8',
#    'PLXNB3',
#    'IDH3G',
#    'SSR4',
#    'ARHGAP4',
#    'NAA10',
#    'DNASE1L1',
#    'ATP6AP1',
#    'PLXNA3',
#    'LAGE3',
#    'MPP1',
#    'CMC4',
#    'VBP1',
#    'TMLHE',
#    'SPRY3',
#    'PCDH11Y',
#    'TBL1Y',
#    'TXLNGY',
#    'EIF1AY',
#    'MTTP',
#    'LOC100233156',
#    'LOC389834',
#    'LOC389831',
#    'PRSS1',
#    'PRSS3P2',
#    'C8orf31',
#    'CARS',
#    'UBE2Q2L',
#    'C16orf45',
#    'NPIPA8',
#    'CORO7',
#    'GSTT1',
#    'FAM189A1',
#    'CHRNA7',
#    'NDUFA6-AS1',
#    'GBA',
#    'NDUFA6-AS1',
#    'TAS2R45',
#    'NDUFA6-AS1',
#    'NDUFA6-AS1',
#    'NDUFA6-AS1',
#    'FAM189A1'],
#   'chromosome': 'NC_000023.11'},
#  {'token_id': 125,
#   'genes': ['CHRNA7',
#    'NDUFA6-AS1',
#    'NDUFA6-AS1',
#    'DLG4',
#    'TMEM159',
#    'LINC00599',
#    'DUSP23',
#    'UBL7-AS1',
#    'C19orf57',
#    'CNR1',
#    'CNR1',
#    'ME1',
#    'ME2',
#    'UBE2Q2L',
#    'CHD2',
#    'CXorf56'],
#   'chromosome': 'NW_011332701.1'}]

# %% [markdown]
# Head plotting helpers

# %%
# Global font size parameter
FONTSIZE = 24

def plot_all_attention_heads(attn_weights, chrom_switches):
    '''
    Plot individual attention weights for each head plus average in a single row
    '''
    num_heads = attn_weights.shape[0]

    # Create a figure with num_heads + 1 subplots in a single row (extra one for average)
    fig, axes = plt.subplots(1, num_heads + 1, figsize=(25, 6))
    
    # Plot individual heads
    for head in range(num_heads):
        vmin, vmax = attn_weights[head].min(), attn_weights[head].max()
        im = axes[head].imshow(attn_weights[head], cmap="viridis", vmin=vmin, vmax=vmax)
        axes[head].set_title(f"Head {head+1}", fontsize=FONTSIZE+2)
        if head == 0:  # Only add labels for first plot
            axes[head].set_xlabel("Key", fontsize=FONTSIZE)
            axes[head].set_ylabel("Query", fontsize=FONTSIZE)
        # Add chromosome switch points as ticks
        axes[head].set_xticks(chrom_switches)
        axes[head].set_yticks(chrom_switches)
        axes[head].tick_params(axis='both', which='major', labelsize=FONTSIZE-10)
        axes[head].tick_params(axis='x', rotation=90)
    
    # Plot average head
    avg_head = attn_weights.mean(axis=0)
    vmin, vmax = avg_head.min(), avg_head.max()
    im = axes[-1].imshow(avg_head, cmap="viridis", vmin=vmin, vmax=vmax)
    axes[-1].set_title("Average", fontsize=FONTSIZE+2)
    axes[-1].set_xticks(chrom_switches)
    axes[-1].set_yticks(chrom_switches)
    axes[-1].tick_params(axis='both', which='major', labelsize=FONTSIZE-8)
    axes[-1].tick_params(axis='x', rotation=90)
    
    plt.tight_layout()
    plt.show()

    # Plot colorbar separately
    # fig_cbar = plt.figure(figsize=(2, 6))
    # cbar = plt.colorbar(im, cax=plt.gca(), label=f"[{vmin:.2f}, {vmax:.2f}]")
    # cbar.ax.tick_params(labelsize=FONTSIZE-4)
    # cbar.set_label(f"[{vmin:.2f}, {vmax:.2f}]", fontsize=FONTSIZE)
    # plt.show()

def plot_average_head(avg_attn, chrom_switches):
    '''
    Plot average attention weights across all heads
    '''
    # Average across all heads
    avg_head = avg_attn.mean(axis=0)
    
    plt.figure(figsize=(8, 7))
    vmin, vmax = avg_head.min(), avg_head.max()
    im = plt.imshow(avg_head, cmap="viridis", vmin=vmin, vmax=vmax)
    cbar = plt.colorbar(im, label=f"[{vmin:.2f}, {vmax:.2f}]", shrink=0.3)
    cbar.ax.tick_params(labelsize=FONTSIZE)
    cbar.set_label(f"[{vmin:.2f}, {vmax:.2f}]", fontsize=FONTSIZE)
    plt.title("Average Attention Across All Heads", fontsize=FONTSIZE+2)
    plt.xlabel("Key", fontsize=FONTSIZE)
    plt.ylabel("Query", fontsize=FONTSIZE)
    plt.xticks(chrom_switches, fontsize=FONTSIZE-6, rotation=90)
    plt.yticks(chrom_switches, fontsize=FONTSIZE-6)
    plt.show()

chrom_switches = chrom_switches[:-1]

def plot_all_attention_heads_true_ticks(attn_weights, chrom_switches):
    '''
    Plot individual attention weights for each head plus average in a single row
    '''
    num_heads = attn_weights.shape[0]
    max_idx = attn_weights.shape[1]
    tick_indices = list(range(0, max_idx, 5))

    # Create a figure with num_heads + 1 subplots in a single row (extra one for average)
    fig, axes = plt.subplots(1, num_heads + 1, figsize=(25, 6))
    
    # Plot individual heads
    for head in range(num_heads):
        vmin, vmax = attn_weights[head].min(), attn_weights[head].max()
        im = axes[head].imshow(attn_weights[head], cmap="viridis", vmin=vmin, vmax=vmax)
        axes[head].set_title(f"Head {head+1}", fontsize=FONTSIZE+2)
        axes[head].set_xlabel("Key", fontsize=FONTSIZE)
        axes[head].set_ylabel("Query", fontsize=FONTSIZE)
        # Add indices as ticks with smaller font
        axes[head].set_xticks(tick_indices)
        axes[head].set_yticks(tick_indices)
        axes[head].tick_params(axis='both', which='major', labelsize=6)
        cbar = fig.colorbar(im, ax=axes[head], label=f"[{vmin:.2f}, {vmax:.2f}]", shrink=0.3)
        cbar.ax.tick_params(labelsize=FONTSIZE-8)
        cbar.set_label(f"[{vmin:.2f}, {vmax:.2f}]", fontsize=FONTSIZE)
    
    # Plot average head
    avg_head = attn_weights.mean(axis=0)
    vmin, vmax = avg_head.min(), avg_head.max()
    im = axes[-1].imshow(avg_head, cmap="viridis", vmin=vmin, vmax=vmax)
    axes[-1].set_title("Average", fontsize=FONTSIZE+2)
    axes[-1].set_xlabel("Key", fontsize=FONTSIZE)
    axes[-1].set_ylabel("Query", fontsize=FONTSIZE)
    axes[-1].set_xticks(tick_indices)
    axes[-1].set_yticks(tick_indices)
    axes[-1].tick_params(axis='both', which='major', labelsize=6)
    cbar = fig.colorbar(im, ax=axes[-1], label=f"[{vmin:.2f}, {vmax:.2f}]", shrink=0.3)
    cbar.ax.tick_params(labelsize=FONTSIZE-8)
    cbar.set_label(f"[{vmin:.2f}, {vmax:.2f}]", fontsize=FONTSIZE)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Compute attention weights

# %%
# # UKBB
# predictions_ukbb_base, targets_ukbb_base = smt_base_model.predict(subset_loader, collect_attn=True, save_attn_path='attn_base_SMT_full_training.npy')
# predictions_ukbb_cls, targets_ukbb_cls = smt_cls_model.predict(subset_loader, collect_attn=True, save_attn_path='attn_cls_SMT_full_training.npy')

# # iPA391
# predictions_ipa_base, targets_ipa_base = smt_base_model.predict(dataloader_iPA391, collect_attn=True, save_attn_path='attn_base_SMT_full_training_ipa.npy')
# predictions_ipa_cls, targets_ipa_cls = smt_cls_model.predict(dataloader_iPA391, collect_attn=True, save_attn_path='attn_cls_SMT_full_training_ipa.npy')

# %%
# Load if already computed
avg_base_smt_attn_ukbb = np.load('./notebooks/NeurIPS/attn_heads/attn_base_SMT_full_training.npy')
avg_smt_cls_attn_ukbb = np.load('./notebooks/NeurIPS/attn_heads/attn_cls_SMT_full_training.npy')
avg_base_smt_attn_ipa = np.load('./notebooks/NeurIPS/attn_heads/attn_base_SMT_full_training_ipa.npy')
avg_smt_cls_attn_ipa = np.load('./notebooks/NeurIPS/attn_heads/attn_cls_SMT_full_training_ipa.npy')

# %% [markdown]
# No CLS eval

# %%
# Plot attention weights for UKBB model
print("UKBB Model Attention:")
plot_all_attention_heads(avg_base_smt_attn_ukbb, chrom_switches)

# Plot attention weights for IPA391 model
print("\nIPA391 Model Attention:") 
plot_all_attention_heads(avg_base_smt_attn_ipa, chrom_switches)
# Out:
# UKBB Model Attention:
# IPA391 Model Attention:

# %%
# Plot attention weights for UKBB model with indices
print("UKBB Model Attention with Indices:")
plot_all_attention_heads_true_ticks(avg_base_smt_attn_ukbb, chrom_switches)

# Plot attention weights for IPA391 model with indices
print("\nIPA391 Model Attention with Indices:")
plot_all_attention_heads_true_ticks(avg_base_smt_attn_ipa, chrom_switches)
# Out:
# UKBB Model Attention with Indices:
# IPA391 Model Attention with Indices:

# %%
# Plot average attention heads separately
print("UKBB Base Model Average Attention:")
plot_average_head(avg_base_smt_attn_ukbb, chrom_switches)

print("\niPA391 Base Model Average Attention:")
plot_average_head(avg_base_smt_attn_ipa, chrom_switches)
# Out:
# UKBB Base Model Average Attention:
# iPA391 Base Model Average Attention:

# %% [markdown]
# CLS evaluation

# %%
# Plot attention weights for UKBB CLS model
print("UKBB CLS Model Attention:")
plot_all_attention_heads(avg_smt_cls_attn_ukbb, chrom_switches)

# Plot attention weights for IPA391 CLS model
print("\nIPA391 CLS Model Attention:") 
plot_all_attention_heads(avg_smt_cls_attn_ipa, chrom_switches)
# Out:
# UKBB CLS Model Attention:
# IPA391 CLS Model Attention:

# %%
def plot_attention_and_genes(attention_weights, chrom_switches, token_idx, is_cls_model=False, gene_tokens=gene_tokens):
    """
    Plot average attention head and print genes for specified token index
    
    Args:
        attention_weights: attention weight matrix
        chrom_switches: chromosome boundary indices
        token_idx: token index to analyze
        is_cls_model: whether attention is from CLS model
        gene_tokens: dictionary mapping token indices to gene information
    """
    # Plot average attention head
    print("Average Attention Head:")
    plot_average_head(attention_weights, chrom_switches)
    
    # Adjust token index for CLS model
    print_idx = token_idx - 1 if is_cls_model else token_idx
    
    print(f"\nGenes in token {print_idx}:")
    print(gene_tokens[print_idx]['genes'])
    print("\nChromosome:", gene_tokens[print_idx]['chromosome'])
    print(' '.join(gene_tokens[print_idx]['genes']))

# Example usage:
# For base model
plot_attention_and_genes(avg_base_smt_attn_ukbb, chrom_switches, 106, is_cls_model=False)

# For CLS model  
plot_attention_and_genes(avg_smt_cls_attn_ukbb, chrom_switches, 54, is_cls_model=True)

print("Note: Gene lists for any token can be manually passed into https://biit.cs.ut.ee/gprofiler/gost for quick functional profiling")
# Out:
# Average Attention Head:
# Genes in token 106:
# ['HSD11B1L', 'RPL36', 'LONP1', 'RFX2', 'MLLT1', 'KHSRP', 'SLC25A41', 'SLC25A23', 'DENND1C', 'C3', 'GPR108', 'VAV1', 'ZNF557', 'INSR', 'ARHGEF18', 'ZNF358', 'MCOLN1', 'CLEC4G', 'CLEC4M', 'TGFBR3L', 'CTXN1', 'TIMM44', 'ELAVL1', 'CERS4', 'KANK3', 'RAB11B', 'MYO1F', 'OR7E24', 'ZNF562', 'ZNF812P', 'FBXL12', 'UBL5', 'PIN1', 'OLFM2', 'COL5A3', 'C19orf66', 'S1PR2', 'MRPL4', 'ICAM5', 'FDX1L', 'ICAM3', 'CDC37', 'PDE4A', 'KEAP1', 'ATG4D', 'KRI1', 'CDKN2D', 'SLC44A2', 'LDLR', 'FH', 'RAB3D', 'TMEM205', 'PLPPR2', 'ELAVL3', 'ZNF653', 'ECSIT', 'CNN1', 'ELOF1', 'ZNF844', 'ZNF136']
#
# Chromosome: NC_000019.10
# HSD11B1L RPL36 LONP1 RFX2 MLLT1 KHSRP SLC25A41 SLC25A23 DENND1C C3 GPR108 VAV1 ZNF557 INSR ARHGEF18 ZNF358 MCOLN1 CLEC4G CLEC4M TGFBR3L CTXN1 TIMM44 ELAVL1 CERS4 KANK3 RAB11B MYO1F OR7E24 ZNF562 ZNF812P FBXL12 UBL5 PIN1 OLFM2 COL5A3 C19orf66 S1PR2 MRPL4 ICAM5 FDX1L ICAM3 CDC37 PDE4A KEAP1 ATG4D KRI1 CDKN2D SLC44A2 LDLR FH RAB3D TMEM205 PLPPR2 ELAVL3 ZNF653 ECSIT CNN1 ELOF1 ZNF844 ZNF136
# Average Attention Head:
# Genes in token 53:
# ['SFRP1', 'NKX6-3', 'ANK1', 'AP3M2', 'PLAT', 'IKBKB', 'SLC20A2', 'SMIM19', 'ASNSP1', 'SPIDR', 'SNTG1', 'RB1CC1', 'OPRK1', 'ATP6V1H', 'RGS20', 'LYPLA1', 'MRPL15', 'XKR4', 'TGS1', 'LYN', 'RPS20', 'CHCHD7', 'SDR16C5', 'PENK', 'SDCBP', 'NSMAF', 'TOX', 'CA8', 'CHD7', 'CLVS1', 'ASPH', 'NKAIN3', 'TTPA', 'MIR124-2HG', 'BHLHE22', 'CYP7B1', 'MTFR1', 'CRH', 'RRS1', 'C8orf46', 'MYBL1', 'C8orf44', 'PPP1R42', 'COPS5', 'PREX2', 'C8orf34', 'SULF1', 'LACTB2', 'XKR9', 'EYA1', 'KCNB2', 'RDH10', 'STAU2', 'UBE2W', 'ELOC', 'TMEM70', 'LY96', 'CRISPLD1', 'ZFHX4-AS1', 'ZFHX4']
#
# Chromosome: NC_000008.11
# SFRP1 NKX6-3 ANK1 AP3M2 PLAT IKBKB SLC20A2 SMIM19 ASNSP1 SPIDR SNTG1 RB1CC1 OPRK1 ATP6V1H RGS20 LYPLA1 MRPL15 XKR4 TGS1 LYN RPS20 CHCHD7 SDR16C5 PENK SDCBP NSMAF TOX CA8 CHD7 CLVS1 ASPH NKAIN3 TTPA MIR124-2HG BHLHE22 CYP7B1 MTFR1 CRH RRS1 C8orf46 MYBL1 C8orf44 PPP1R42 COPS5 PREX2 C8orf34 SULF1 LACTB2 XKR9 EYA1 KCNB2 RDH10 STAU2 UBE2W ELOC TMEM70 LY96 CRISPLD1 ZFHX4-AS1 ZFHX4
# Note: Gene lists for any token can be manually passed into https://biit.cs.ut.ee/gprofiler/gost for quick functional profiling
