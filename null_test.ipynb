# %% [markdown]
# ## Sim Demo

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from imports import *

# %%
# overall imports
import importlib
import data

# importlib.reload(sim.sim)
# importlib.reload(sim.sim_utils)
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run, open_pickled_results

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))
# Out:
# CPU Usage: 1.6%
# RAM Usage: 8.5%
# Available RAM: 460.2G
# Total RAM: 503.0G
# 52.4G

# %%
print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)
# Out:
# XGBoost version: 2.0.3
# cupy version: 13.1.0

# %%
GPUtil.getAvailable()
# if a number is seen a GPU is available
# Out:
# [0]

# %%
GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True
# Out:
# GPU found 0

# %%
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  9% |

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# #### Null sim test <a id="sims"></a>

# %%
# Run simulation
single_sim_run(
              cv_type='random',
              random_seed=42,
              model_type='bilinear_lowrank', 
              feature_type=[{'transcriptome': None}],
              connectome_target='FC',
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              omit_subcortical=False,
              parcellation='S100',
              gene_list='0.2',
              search_method=('wandb', 'mse', 10),
              save_sim=False,
              track_wandb=True
              )

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Clear CPU memory
import gc
gc.collect()
# Out:
# Number of components for PCA: 34
# X shape: (114, 11053)
# X_pca shape: (114, 34)
# Y_sc shape: (114, 114)
# Y_sc_spectralL shape: (114, 113)
# Y_sc_spectralA shape: (114, 114)
# Y_fc shape: (114, 114)
# Coordinates shape: (114, 3)
# Y shape (114, 114)
# feature_name:  transcriptome
# processing_type:  None
# X shape (114, 11053)
#
#  Test fold num: 1 X_train shape: (7140, 22106) Y_train shape: (7140,) X_test shape: (812, 22106) Y_test shape: (812,)
# SEARCH METHOD ('wandb', 'mse', 10)
# 2
# 3
# 4
# Create sweep with ID: agwcbk14
# Sweep URL: https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14
# wandb: Agent Starting Run: 1rsnrw9g with config:
# wandb: 	activation: none
# wandb: 	batch_size: 128
# wandb: 	epochs: 100
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 0.01
# wandb: 	learning_rate: 0.003
# wandb: 	reduced_dim: 12
# wandb: 	regularization: l1
# wandb: 	shared_weights: True
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-1rsnrw9g.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_133858-1rsnrw9g</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/1rsnrw9g' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/1rsnrw9g' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/1rsnrw9g</a>
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 132636
# Epoch 10/100, Train Loss: 60.3286, Val Loss: 52.7283
# Epoch 20/100, Train Loss: 31.7591, Val Loss: 29.0461
# Epoch 30/100, Train Loss: 19.9416, Val Loss: 18.6245
# Epoch 40/100, Train Loss: 14.3887, Val Loss: 13.5771
# Epoch 50/100, Train Loss: 11.4182, Val Loss: 10.8526
# Epoch 60/100, Train Loss: 9.6697, Val Loss: 9.2528
# Epoch 70/100, Train Loss: 8.5671, Val Loss: 8.2514
# Epoch 80/100, Train Loss: 7.8352, Val Loss: 7.5930
# Epoch 90/100, Train Loss: 7.3295, Val Loss: 7.1428
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Epoch 100/100, Train Loss: 6.9699, Val Loss: 6.8254
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 132636
# Epoch 10/100, Train Loss: 30.8793, Val Loss: 55.7309
# Epoch 20/100, Train Loss: 24.5305, Val Loss: 47.0514
# Epoch 30/100, Train Loss: 19.5027, Val Loss: 38.4599
# Epoch 40/100, Train Loss: 15.9516, Val Loss: 31.5400
# Epoch 50/100, Train Loss: 13.4877, Val Loss: 26.1397
# Epoch 60/100, Train Loss: 11.7620, Val Loss: 21.9389
# Epoch 70/100, Train Loss: 10.5180, Val Loss: 18.6584
# Epoch 80/100, Train Loss: 9.5925, Val Loss: 16.0902
# Epoch 90/100, Train Loss: 8.8870, Val Loss: 14.0715
# Epoch 100/100, Train Loss: 8.3393, Val Loss: 12.4773
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 132636
# Epoch 10/100, Train Loss: 26.8833, Val Loss: 11.9337
# Epoch 20/100, Train Loss: 22.7420, Val Loss: 10.7995
# Epoch 30/100, Train Loss: 18.8098, Val Loss: 9.7007
# Epoch 40/100, Train Loss: 15.5936, Val Loss: 8.8433
# Epoch 50/100, Train Loss: 13.1464, Val Loss: 8.2097
# Epoch 60/100, Train Loss: 11.3386, Val Loss: 7.7437
# Epoch 70/100, Train Loss: 10.0186, Val Loss: 7.4022
# Epoch 80/100, Train Loss: 9.0575, Val Loss: 7.1501
# Epoch 90/100, Train Loss: 8.3557, Val Loss: 6.9613
# Epoch 100/100, Train Loss: 7.8399, Val Loss: 6.8170
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>fold0_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▆▁▄▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr><tr><td>fold0_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>█▅▁▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>fold1_train_loss</td><td>█▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▁█▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>fold1_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>█▁▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇█████</td></tr><tr><td>fold2_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>▁█▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>fold2_val_loss</td><td>███▇▇▆▆▆▆▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>█▁▅▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅██████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>99</td></tr><tr><td>fold0_train_loss</td><td>6.96994</td></tr><tr><td>fold0_train_pearson</td><td>0.28966</td></tr><tr><td>fold0_val_loss</td><td>6.82542</td></tr><tr><td>fold0_val_pearson</td><td>0.17171</td></tr><tr><td>fold1_epoch</td><td>99</td></tr><tr><td>fold1_train_loss</td><td>8.3393</td></tr><tr><td>fold1_train_pearson</td><td>0.16381</td></tr><tr><td>fold1_val_loss</td><td>12.47726</td></tr><tr><td>fold1_val_pearson</td><td>0.20269</td></tr><tr><td>fold2_epoch</td><td>99</td></tr><tr><td>fold2_train_loss</td><td>7.83988</td></tr><tr><td>fold2_train_pearson</td><td>0.18329</td></tr><tr><td>fold2_val_loss</td><td>6.817</td></tr><tr><td>fold2_val_pearson</td><td>0.12931</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>7.71637</td></tr><tr><td>mean_train_pearson</td><td>0.21225</td></tr><tr><td>mean_val_loss</td><td>8.70656</td></tr><tr><td>mean_val_pearson</td><td>0.16791</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/1rsnrw9g' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/1rsnrw9g</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_133858-1rsnrw9g/logs</code>
# wandb: Agent Starting Run: 5f0txnqh with config:
# wandb: 	activation: none
# wandb: 	batch_size: 512
# wandb: 	epochs: 150
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 1
# wandb: 	learning_rate: 0.01
# wandb: 	reduced_dim: 3
# wandb: 	regularization: l2
# wandb: 	shared_weights: True
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-5f0txnqh.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_133929-5f0txnqh</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/5f0txnqh' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/5f0txnqh' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/5f0txnqh</a>
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 33159
# Epoch 10/150, Train Loss: 4100.4671, Val Loss: 4388.7068
# Epoch 20/150, Train Loss: 41.9804, Val Loss: 9.2696
# Epoch 30/150, Train Loss: 17.6610, Val Loss: 3.2639
# Epoch 40/150, Train Loss: 10.5434, Val Loss: 2.4497
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=90, family=2, type=1, proto=0, laddr=('127.0.0.1', 35774), raddr=('127.0.0.1', 37389)>
#   return tuple(tensor[index] for tensor in self.tensors)
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=112, family=2, type=1, proto=0, laddr=('127.0.0.1', 49950), raddr=('127.0.0.1', 33995)>
#   return tuple(tensor[index] for tensor in self.tensors)
# Epoch 50/150, Train Loss: 7.5162, Val Loss: 2.4426
# Epoch 60/150, Train Loss: 6.0487, Val Loss: 2.6021
# Epoch 70/150, Train Loss: 5.2564, Val Loss: 2.7487
# Epoch 80/150, Train Loss: 4.7681, Val Loss: 2.8292
# Epoch 90/150, Train Loss: 4.4205, Val Loss: 2.8422
# Epoch 100/150, Train Loss: 4.1426, Val Loss: 2.8052
# Epoch 110/150, Train Loss: 3.9040, Val Loss: 2.7371
# Epoch 120/150, Train Loss: 3.6910, Val Loss: 2.6527
# Epoch 130/150, Train Loss: 3.4972, Val Loss: 2.5615
# Epoch 140/150, Train Loss: 3.3190, Val Loss: 2.4689
# Epoch 150/150, Train Loss: 3.1543, Val Loss: 2.3782
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 33159
# Epoch 10/150, Train Loss: 5294.6313, Val Loss: 4663.5100
# Epoch 20/150, Train Loss: 135.4334, Val Loss: 27.7403
# Epoch 30/150, Train Loss: 105.5935, Val Loss: 15.9230
# Epoch 40/150, Train Loss: 85.0900, Val Loss: 11.8479
# Epoch 50/150, Train Loss: 68.7046, Val Loss: 9.4324
# Epoch 60/150, Train Loss: 55.5953, Val Loss: 7.7777
# Epoch 70/150, Train Loss: 45.1801, Val Loss: 6.5673
# Epoch 80/150, Train Loss: 36.9362, Val Loss: 5.6511
# Epoch 90/150, Train Loss: 30.4112, Val Loss: 4.9429
# Epoch 100/150, Train Loss: 25.2329, Val Loss: 4.3865
# Epoch 110/150, Train Loss: 21.1051, Val Loss: 3.9438
# Epoch 120/150, Train Loss: 17.7962, Val Loss: 3.5874
# Epoch 130/150, Train Loss: 15.1276, Val Loss: 3.2972
# Epoch 140/150, Train Loss: 12.9613, Val Loss: 3.0586
# Epoch 150/150, Train Loss: 11.1913, Val Loss: 2.8606
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 33159
# Epoch 10/150, Train Loss: 5004.8967, Val Loss: 5717.9883
# Epoch 20/150, Train Loss: 32.1609, Val Loss: 25.6092
# Epoch 30/150, Train Loss: 14.0918, Val Loss: 14.2342
# Epoch 40/150, Train Loss: 8.9935, Val Loss: 10.8301
# Epoch 50/150, Train Loss: 6.7725, Val Loss: 9.3739
# Epoch 60/150, Train Loss: 5.6285, Val Loss: 8.6733
# Epoch 70/150, Train Loss: 4.9735, Val Loss: 8.3246
# Epoch 80/150, Train Loss: 4.5711, Val Loss: 8.1573
# Epoch 90/150, Train Loss: 4.3115, Val Loss: 8.0873
# Epoch 100/150, Train Loss: 4.1375, Val Loss: 8.0677
# Epoch 110/150, Train Loss: 4.0168, Val Loss: 8.0699
# Epoch 120/150, Train Loss: 3.9296, Val Loss: 8.0760
# Epoch 130/150, Train Loss: 3.8635, Val Loss: 8.0748
# Epoch 140/150, Train Loss: 3.8103, Val Loss: 8.0598
# Epoch 150/150, Train Loss: 3.7648, Val Loss: 8.0280
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇█</td></tr><tr><td>fold0_train_loss</td><td>▅█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▆█▁▁▁▁▂▃▃▄▅▅▅▆▆▆▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>fold0_val_loss</td><td>▃█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>█▁▁▂▃▅▅▆▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>fold1_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▁▁██▇▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▄▄</td></tr><tr><td>fold1_val_loss</td><td>█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>▁▇▅▆▇███████████▇▇▇▇▇▇▇▇▇▇▇▇████████████</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>fold2_train_loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>▁▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████████████████</td></tr><tr><td>fold2_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>█▁██████▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅█████████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>149</td></tr><tr><td>fold0_train_loss</td><td>3.15428</td></tr><tr><td>fold0_train_pearson</td><td>0.43943</td></tr><tr><td>fold0_val_loss</td><td>2.37821</td></tr><tr><td>fold0_val_pearson</td><td>0.51806</td></tr><tr><td>fold1_epoch</td><td>149</td></tr><tr><td>fold1_train_loss</td><td>11.19129</td></tr><tr><td>fold1_train_pearson</td><td>0.24684</td></tr><tr><td>fold1_val_loss</td><td>2.8606</td></tr><tr><td>fold1_val_pearson</td><td>0.17718</td></tr><tr><td>fold2_epoch</td><td>149</td></tr><tr><td>fold2_train_loss</td><td>3.76485</td></tr><tr><td>fold2_train_pearson</td><td>0.15444</td></tr><tr><td>fold2_val_loss</td><td>8.02801</td></tr><tr><td>fold2_val_pearson</td><td>0.14041</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>6.03681</td></tr><tr><td>mean_train_pearson</td><td>0.28023</td></tr><tr><td>mean_val_loss</td><td>4.42227</td></tr><tr><td>mean_val_pearson</td><td>0.27855</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/5f0txnqh' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/5f0txnqh</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_133929-5f0txnqh/logs</code>
# wandb: Agent Starting Run: fa8gs5ur with config:
# wandb: 	activation: none
# wandb: 	batch_size: 512
# wandb: 	epochs: 150
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 1
# wandb: 	learning_rate: 0.01
# wandb: 	reduced_dim: 5
# wandb: 	regularization: l1
# wandb: 	shared_weights: True
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-fa8gs5ur.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_133955-fa8gs5ur</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/fa8gs5ur' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/fa8gs5ur' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/fa8gs5ur</a>
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 55265
# Epoch 10/150, Train Loss: 5155.1091, Val Loss: 849.2207
# Epoch 20/150, Train Loss: 280.2633, Val Loss: 279.1535
# Epoch 30/150, Train Loss: 262.9549, Val Loss: 265.2742
# Epoch 40/150, Train Loss: 260.0563, Val Loss: 262.3885
# Epoch 50/150, Train Loss: 258.0257, Val Loss: 260.2519
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=114, family=2, type=1, proto=0, laddr=('127.0.0.1', 33250), raddr=('127.0.0.1', 35185)>
#   return tuple(tensor[index] for tensor in self.tensors)
# Epoch 60/150, Train Loss: 256.0903, Val Loss: 258.1850
# Epoch 70/150, Train Loss: 254.0930, Val Loss: 256.0483
# Epoch 80/150, Train Loss: 251.9930, Val Loss: 253.8065
# Epoch 90/150, Train Loss: 249.7792, Val Loss: 251.4511
# Epoch 100/150, Train Loss: 247.4524, Val Loss: 248.9856
# Epoch 110/150, Train Loss: 245.0139, Val Loss: 246.4121
# Epoch 120/150, Train Loss: 242.4640, Val Loss: 243.7320
# Epoch 130/150, Train Loss: 239.8061, Val Loss: 240.9496
# Epoch 140/150, Train Loss: 237.0423, Val Loss: 238.0675
# Epoch 150/150, Train Loss: 234.1749, Val Loss: 235.0883
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 55265
# Epoch 10/150, Train Loss: 8347.8322, Val Loss: 3851.3162
# Epoch 20/150, Train Loss: 771.6326, Val Loss: 411.2101
# Epoch 30/150, Train Loss: 624.3478, Val Loss: 386.1428
# Epoch 40/150, Train Loss: 520.9371, Val Loss: 362.3181
# Epoch 50/150, Train Loss: 452.4579, Val Loss: 345.7168
# Epoch 60/150, Train Loss: 406.7678, Val Loss: 333.7269
# Epoch 70/150, Train Loss: 375.6408, Val Loss: 324.8095
# Epoch 80/150, Train Loss: 353.8447, Val Loss: 317.9299
# Epoch 90/150, Train Loss: 338.1225, Val Loss: 312.4276
# Epoch 100/150, Train Loss: 326.4147, Val Loss: 307.8586
# Epoch 110/150, Train Loss: 317.4118, Val Loss: 303.9293
# Epoch 120/150, Train Loss: 310.2581, Val Loss: 300.4384
# Epoch 130/150, Train Loss: 304.3904, Val Loss: 297.2511
# Epoch 140/150, Train Loss: 299.4281, Val Loss: 294.2737
# Epoch 150/150, Train Loss: 295.1066, Val Loss: 291.4365
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 55265
# Epoch 10/150, Train Loss: 4602.2689, Val Loss: 1468.5128
# Epoch 20/150, Train Loss: 317.7775, Val Loss: 319.0430
# Epoch 30/150, Train Loss: 305.5439, Val Loss: 303.0872
# Epoch 40/150, Train Loss: 302.6293, Val Loss: 299.7243
# Epoch 50/150, Train Loss: 299.9630, Val Loss: 297.2777
# Epoch 60/150, Train Loss: 297.1728, Val Loss: 294.8353
# Epoch 70/150, Train Loss: 294.2205, Val Loss: 292.2498
# Epoch 80/150, Train Loss: 291.1100, Val Loss: 289.4971
# Epoch 90/150, Train Loss: 287.8521, Val Loss: 286.5777
# Epoch 100/150, Train Loss: 284.4573, Val Loss: 283.4956
# Epoch 110/150, Train Loss: 280.9338, Val Loss: 280.2558
# Epoch 120/150, Train Loss: 277.2873, Val Loss: 276.8645
# Epoch 130/150, Train Loss: 273.5225, Val Loss: 273.3235
# Epoch 140/150, Train Loss: 269.6434, Val Loss: 269.6375
# Epoch 150/150, Train Loss: 265.6509, Val Loss: 265.8105
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>fold0_train_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▃▇▂▁▂▆▇▇▇▇▇▇▇▇▇▇▇▇██████████████████████</td></tr><tr><td>fold0_val_loss</td><td>█▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>█▄▄▂▁▄▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇█</td></tr><tr><td>fold1_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▇█▁▄▆▆▆▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>fold1_val_loss</td><td>▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>▁▆▇██▅▆██████████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▁▁▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>fold2_train_loss</td><td>█▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>▇▁██▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>fold2_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>█▃▁▂▄▂▁▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅██████████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>149</td></tr><tr><td>fold0_train_loss</td><td>234.17494</td></tr><tr><td>fold0_train_pearson</td><td>0.21473</td></tr><tr><td>fold0_val_loss</td><td>235.08826</td></tr><tr><td>fold0_val_pearson</td><td>0.17924</td></tr><tr><td>fold1_epoch</td><td>149</td></tr><tr><td>fold1_train_loss</td><td>295.10657</td></tr><tr><td>fold1_train_pearson</td><td>0.30199</td></tr><tr><td>fold1_val_loss</td><td>291.43646</td></tr><tr><td>fold1_val_pearson</td><td>0.28027</td></tr><tr><td>fold2_epoch</td><td>149</td></tr><tr><td>fold2_train_loss</td><td>265.65087</td></tr><tr><td>fold2_train_pearson</td><td>0.12351</td></tr><tr><td>fold2_val_loss</td><td>265.81049</td></tr><tr><td>fold2_val_pearson</td><td>0.06748</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>264.97746</td></tr><tr><td>mean_train_pearson</td><td>0.21341</td></tr><tr><td>mean_val_loss</td><td>264.11174</td></tr><tr><td>mean_val_pearson</td><td>0.17566</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/fa8gs5ur' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/fa8gs5ur</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_133955-fa8gs5ur/logs</code>
# wandb: Agent Starting Run: 3ys4047d with config:
# wandb: 	activation: none
# wandb: 	batch_size: 256
# wandb: 	epochs: 150
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 1
# wandb: 	learning_rate: 0.01
# wandb: 	reduced_dim: 7
# wandb: 	regularization: l1
# wandb: 	shared_weights: False
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-3ys4047d.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_134020-3ys4047d</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/3ys4047d' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/3ys4047d' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/3ys4047d</a>
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 25777.5941, Val Loss: 37736.5449
# Epoch 20/150, Train Loss: 3624.9992, Val Loss: 4425.0588
# Epoch 30/150, Train Loss: 6407.2820, Val Loss: 15381.5476
# Epoch 40/150, Train Loss: 7060.4427, Val Loss: 20076.1182
# Epoch 50/150, Train Loss: 6072.2403, Val Loss: 8192.7146
# Epoch 60/150, Train Loss: 14697.0696, Val Loss: 2811.4781
# Epoch 70/150, Train Loss: 1329.7431, Val Loss: 965.2439
# Epoch 80/150, Train Loss: 1080.3039, Val Loss: 1111.7325
# Epoch 90/150, Train Loss: 1032.0031, Val Loss: 1084.4365
# Epoch 100/150, Train Loss: 1002.2509, Val Loss: 1085.1552
# Epoch 110/150, Train Loss: 974.0246, Val Loss: 1080.7368
# Epoch 120/150, Train Loss: 944.9123, Val Loss: 1065.7954
# Epoch 130/150, Train Loss: 913.7387, Val Loss: 1036.3245
# Epoch 140/150, Train Loss: 880.9081, Val Loss: 992.6398
# Epoch 150/150, Train Loss: 848.9714, Val Loss: 942.5921
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 5972.5152, Val Loss: 3923.6780
# Epoch 20/150, Train Loss: 1423.4758, Val Loss: 1354.0090
# Epoch 30/150, Train Loss: 1209.4399, Val Loss: 1180.9762
# Epoch 40/150, Train Loss: 1099.5191, Val Loss: 1048.5477
# Epoch 50/150, Train Loss: 1026.8034, Val Loss: 965.9220
# Epoch 60/150, Train Loss: 977.7751, Val Loss: 920.6304
# Epoch 70/150, Train Loss: 940.4462, Val Loss: 893.6033
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=91, family=2, type=1, proto=0, laddr=('127.0.0.1', 52524), raddr=('127.0.0.1', 46067)>
#   return tuple(tensor[index] for tensor in self.tensors)
# Epoch 80/150, Train Loss: 909.4900, Val Loss: 873.8003
# Epoch 90/150, Train Loss: 882.6669, Val Loss: 856.6125
# Epoch 100/150, Train Loss: 858.7358, Val Loss: 840.2818
# Epoch 110/150, Train Loss: 836.9026, Val Loss: 824.1811
# Epoch 120/150, Train Loss: 816.5880, Val Loss: 808.1073
# Epoch 130/150, Train Loss: 797.3998, Val Loss: 792.0220
# Epoch 140/150, Train Loss: 779.0437, Val Loss: 775.9182
# Epoch 150/150, Train Loss: 761.2849, Val Loss: 759.7795
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 1811.4336, Val Loss: 1852.6948
# Epoch 20/150, Train Loss: 1239.7361, Val Loss: 1188.0021
# Epoch 30/150, Train Loss: 1056.5972, Val Loss: 1153.3605
# Epoch 40/150, Train Loss: 966.4173, Val Loss: 1020.9870
# Epoch 50/150, Train Loss: 919.4849, Val Loss: 950.3008
# Epoch 60/150, Train Loss: 888.2561, Val Loss: 909.5435
# Epoch 70/150, Train Loss: 864.6740, Val Loss: 881.3516
# Epoch 80/150, Train Loss: 845.3285, Val Loss: 858.8363
# Epoch 90/150, Train Loss: 828.5158, Val Loss: 839.2646
# Epoch 100/150, Train Loss: 813.2722, Val Loss: 821.5230
# Epoch 110/150, Train Loss: 799.0160, Val Loss: 805.1189
# Epoch 120/150, Train Loss: 785.3721, Val Loss: 789.8482
# Epoch 130/150, Train Loss: 772.0541, Val Loss: 775.7497
# Epoch 140/150, Train Loss: 758.6066, Val Loss: 762.9311
# Epoch 150/150, Train Loss: 744.3389, Val Loss: 750.1737
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>fold0_train_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▄▄▃▄▃▄▄▄▄▄▃▂▂▁▁▁▃█▆▆▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄▄</td></tr><tr><td>fold0_val_loss</td><td>▂█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>▂█▄▄▂▃▃▄▄▄▄▄▃▁▁▅██▂▆▂▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇█████</td></tr><tr><td>fold1_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▁▁▁▂▂▆▆▇▇▇▇█████████████████████▇▇▇▇▇▇▇▇</td></tr><tr><td>fold1_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>▁▁▃▆▇▇▇▇▇████████████████████▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▁▁▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>fold2_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>▁▃▄▄▄▅▆▆▆▇▇▇█████████████████▇▇▇▇▇▇▇▇▆▆▅</td></tr><tr><td>fold2_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>██▇▅▆▄▄▄▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅█████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>149</td></tr><tr><td>fold0_train_loss</td><td>848.97138</td></tr><tr><td>fold0_train_pearson</td><td>0.00868</td></tr><tr><td>fold0_val_loss</td><td>942.59206</td></tr><tr><td>fold0_val_pearson</td><td>-0.0273</td></tr><tr><td>fold1_epoch</td><td>149</td></tr><tr><td>fold1_train_loss</td><td>761.28494</td></tr><tr><td>fold1_train_pearson</td><td>0.01877</td></tr><tr><td>fold1_val_loss</td><td>759.77954</td></tr><tr><td>fold1_val_pearson</td><td>-0.18951</td></tr><tr><td>fold2_epoch</td><td>149</td></tr><tr><td>fold2_train_loss</td><td>744.33888</td></tr><tr><td>fold2_train_pearson</td><td>0.02766</td></tr><tr><td>fold2_val_loss</td><td>750.17367</td></tr><tr><td>fold2_val_pearson</td><td>0.00947</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>784.86507</td></tr><tr><td>mean_train_pearson</td><td>0.01837</td></tr><tr><td>mean_val_loss</td><td>817.51509</td></tr><tr><td>mean_val_pearson</td><td>-0.06911</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/3ys4047d' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/3ys4047d</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_134020-3ys4047d/logs</code>
# wandb: Agent Starting Run: i6cfe1u4 with config:
# wandb: 	activation: none
# wandb: 	batch_size: 256
# wandb: 	epochs: 150
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 1
# wandb: 	learning_rate: 0.003
# wandb: 	reduced_dim: 9
# wandb: 	regularization: l2
# wandb: 	shared_weights: False
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-i6cfe1u4.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_134051-i6cfe1u4</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/i6cfe1u4' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/agwcbk14</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/i6cfe1u4' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/i6cfe1u4</a>
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 198954
# Epoch 10/150, Train Loss: 117.8471, Val Loss: 126.0338
# Epoch 20/150, Train Loss: 62.6716, Val Loss: 64.0291
# Epoch 30/150, Train Loss: 39.0703, Val Loss: 39.4724
# Epoch 40/150, Train Loss: 25.1285, Val Loss: 25.6885
# Epoch 50/150, Train Loss: 17.1407, Val Loss: 17.9662
# Epoch 60/150, Train Loss: 12.5357, Val Loss: 13.5530
# Epoch 70/150, Train Loss: 9.8107, Val Loss: 10.9331
# Epoch 80/150, Train Loss: 8.1266, Val Loss: 9.2843
# Epoch 90/150, Train Loss: 7.0233, Val Loss: 8.1667
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=112, family=2, type=1, proto=0, laddr=('127.0.0.1', 38696), raddr=('127.0.0.1', 39213)>
#   return tuple(tensor[index] for tensor in self.tensors)
# Epoch 100/150, Train Loss: 6.2517, Val Loss: 7.3494
# Epoch 110/150, Train Loss: 5.6780, Val Loss: 6.7128
# Epoch 120/150, Train Loss: 5.2298, Val Loss: 6.1944
# Epoch 130/150, Train Loss: 4.8669, Val Loss: 5.7600
# Epoch 140/150, Train Loss: 4.5657, Val Loss: 5.3898
# Epoch 150/150, Train Loss: 4.3114, Val Loss: 5.0706
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 198954
# Epoch 10/150, Train Loss: 204.8041, Val Loss: 289.2417
# Epoch 20/150, Train Loss: 141.0559, Val Loss: 336.3568
# Epoch 30/150, Train Loss: 44.3690, Val Loss: 122.6988
# Epoch 40/150, Train Loss: 30.7233, Val Loss: 39.2445
# Epoch 50/150, Train Loss: 153.3508, Val Loss: 105.9629
# Epoch 60/150, Train Loss: 896.1451, Val Loss: 120.3880
# Epoch 70/150, Train Loss: 11.8652, Val Loss: 6.6221
# Epoch 80/150, Train Loss: 8.6241, Val Loss: 4.0915
# Epoch 90/150, Train Loss: 6.3751, Val Loss: 3.5296
# Epoch 100/150, Train Loss: 5.0574, Val Loss: 3.3157
# Epoch 110/150, Train Loss: 4.2835, Val Loss: 3.2962
# Epoch 120/150, Train Loss: 3.8339, Val Loss: 3.3327
# Epoch 130/150, Train Loss: 3.5449, Val Loss: 3.3637
# Epoch 140/150, Train Loss: 3.3418, Val Loss: 3.3786
# Epoch 150/150, Train Loss: 3.1904, Val Loss: 3.3784
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 198954
# Epoch 10/150, Train Loss: 847.8502, Val Loss: 997.4317
# Epoch 20/150, Train Loss: 84.5106, Val Loss: 137.7633
# Epoch 30/150, Train Loss: 111.5261, Val Loss: 48.5459
# Epoch 40/150, Train Loss: 220.5718, Val Loss: 92.2220
# Epoch 50/150, Train Loss: 402.8816, Val Loss: 183.5779
# Epoch 60/150, Train Loss: 3757.2170, Val Loss: 1095.9853
# Epoch 70/150, Train Loss: 43.3370, Val Loss: 31.6559
# Epoch 80/150, Train Loss: 28.6752, Val Loss: 20.8042
# Epoch 90/150, Train Loss: 21.1041, Val Loss: 15.5715
# Epoch 100/150, Train Loss: 16.2680, Val Loss: 12.2431
# Epoch 110/150, Train Loss: 12.9267, Val Loss: 9.9594
# Epoch 120/150, Train Loss: 10.5233, Val Loss: 8.3264
# Epoch 130/150, Train Loss: 8.7513, Val Loss: 7.1250
# Epoch 140/150, Train Loss: 7.4227, Val Loss: 6.2222
# Epoch 150/150, Train Loss: 6.4142, Val Loss: 5.5324
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>fold0_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▂▁▂▂▂▂▂▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇████████</td></tr><tr><td>fold0_val_loss</td><td>█▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>█▄▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>fold1_train_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▇▆▆▅▅▄▃▃▃▃▂▆▂▁█▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆</td></tr><tr><td>fold1_val_loss</td><td>▂█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>▆▁▇██▅▅▅▄▄▄▆██▆▅▆▅▅▅▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇█</td></tr><tr><td>fold2_train_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>▁█▇▇▇▇▆▆▆▆▆▅▄▄▃▃▃▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃▃</td></tr><tr><td>fold2_val_loss</td><td>█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>▅▁██▇▄▅▅▅▃▃▃▃▃▄▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅█████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>149</td></tr><tr><td>fold0_train_loss</td><td>4.31138</td></tr><tr><td>fold0_train_pearson</td><td>0.05458</td></tr><tr><td>fold0_val_loss</td><td>5.07061</td></tr><tr><td>fold0_val_pearson</td><td>-0.09857</td></tr><tr><td>fold1_epoch</td><td>149</td></tr><tr><td>fold1_train_loss</td><td>3.19041</td></tr><tr><td>fold1_train_pearson</td><td>0.1346</td></tr><tr><td>fold1_val_loss</td><td>3.37842</td></tr><tr><td>fold1_val_pearson</td><td>0.05289</td></tr><tr><td>fold2_epoch</td><td>149</td></tr><tr><td>fold2_train_loss</td><td>6.41417</td></tr><tr><td>fold2_train_pearson</td><td>0.02942</td></tr><tr><td>fold2_val_loss</td><td>5.5324</td></tr><tr><td>fold2_val_pearson</td><td>0.24189</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>4.63865</td></tr><tr><td>mean_train_pearson</td><td>0.07287</td></tr><tr><td>mean_val_loss</td><td>4.66048</td></tr><tr><td>mean_val_pearson</td><td>0.0654</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold0_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/i6cfe1u4' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/i6cfe1u4</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_134051-i6cfe1u4/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: sgbv9u6z with config:
# wandb: 	activation: none
# wandb: 	batch_size: 128
# wandb: 	epochs: 100
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 0.01
# wandb: 	learning_rate: 0.01
# wandb: 	reduced_dim: 11
# wandb: 	regularization: l1
# wandb: 	shared_weights: False
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-agwcbk14/config-sgbv9u6z.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_134131-sgbv9u6z</code>
# ...
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold3_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/av0mjx6f' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/av0mjx6f</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_135842-av0mjx6f/logs</code>
# wandb: Agent Starting Run: wu4asj5h with config:
# wandb: 	activation: none
# wandb: 	batch_size: 128
# wandb: 	epochs: 150
# wandb: 	input_dim: 22106
# wandb: 	lambda_reg: 10
# wandb: 	learning_rate: 0.01
# wandb: 	reduced_dim: 7
# wandb: 	regularization: l1
# wandb: 	shared_weights: False
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_setup.py:258: ResourceWarning: unclosed file <_io.TextIOWrapper name='/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/sweep-0fb52q4m/config-wu4asj5h.yaml' mode='r' encoding='utf-8'>
#   self._sweep_config = config_util.dict_from_config_file(
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_135912-wu4asj5h</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/wu4asj5h' target="_blank">bilinear_lowrank_transcriptome_FC_random_fold3_innerCV</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/0fb52q4m' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/0fb52q4m</a>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View sweep at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/0fb52q4m' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/sweeps/0fb52q4m</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/wu4asj5h' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/wu4asj5h</a>
# Processing inner fold 0
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 14032.1078, Val Loss: 16469.4495
# Epoch 20/150, Train Loss: 11108.0180, Val Loss: 17544.3802
# Epoch 30/150, Train Loss: 6359.0336, Val Loss: 6359.8572
# Epoch 40/150, Train Loss: 5118.0676, Val Loss: 5114.5733
# Epoch 50/150, Train Loss: 4051.3913, Val Loss: 4041.3820
# Epoch 60/150, Train Loss: 3055.2149, Val Loss: 2977.9801
# Epoch 70/150, Train Loss: 2084.2573, Val Loss: 2046.3284
# Epoch 80/150, Train Loss: 1277.1537, Val Loss: 1240.6016
# Epoch 90/150, Train Loss: 673.2241, Val Loss: 647.5296
# Epoch 100/150, Train Loss: 283.9360, Val Loss: 269.3275
# Epoch 110/150, Train Loss: 87.6380, Val Loss: 81.4899
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The variance of predictions or target is close to zero. This can cause instability in Pearson correlationcoefficient, leading to wrong results. Consider re-scaling the input if possible or computing using alarger dtype (currently using torch.float32).
#   warnings.warn(*args, **kwargs)  # noqa: B028
# Epoch 120/150, Train Loss: 17.7956, Val Loss: 16.1622
# Epoch 130/150, Train Loss: 3.4164, Val Loss: 3.2098
# Epoch 140/150, Train Loss: 2.2636, Val Loss: 2.2331
# Epoch 150/150, Train Loss: 2.4896, Val Loss: 2.4791
# Processing inner fold 1
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 4063.9373, Val Loss: 4000.5836
# Epoch 20/150, Train Loss: 2395.8927, Val Loss: 2317.5316
# Epoch 30/150, Train Loss: 1027.9394, Val Loss: 973.9718
# Epoch 40/150, Train Loss: 291.3529, Val Loss: 269.0846
# Epoch 50/150, Train Loss: 49.8179, Val Loss: 44.7268
# Epoch 60/150, Train Loss: 6.5171, Val Loss: 5.9815
# Epoch 70/150, Train Loss: 3.1004, Val Loss: 3.0909
# Epoch 80/150, Train Loss: 3.5030, Val Loss: 3.5222
# Epoch 90/150, Train Loss: 4.0059, Val Loss: 4.0256
# Epoch 100/150, Train Loss: 4.5719, Val Loss: 4.6077
# Epoch 110/150, Train Loss: 5.2130, Val Loss: 5.2520
# Epoch 120/150, Train Loss: 5.9712, Val Loss: 6.0028
# Epoch 130/150, Train Loss: 6.8519, Val Loss: 6.9004
# Epoch 140/150, Train Loss: 7.8581, Val Loss: 7.9138
# Epoch 150/150, Train Loss: 8.9806, Val Loss: 9.0352
# Processing inner fold 2
# Number of learnable parameters in bilinear low rank model: 154742
# Epoch 10/150, Train Loss: 7234.3389, Val Loss: 7094.2290
# Epoch 20/150, Train Loss: 5506.0402, Val Loss: 5392.3403
# Epoch 30/150, Train Loss: 3806.9322, Val Loss: 3703.1638
# Epoch 40/150, Train Loss: 2325.6164, Val Loss: 2239.8927
# Epoch 50/150, Train Loss: 1211.8938, Val Loss: 1155.7153
# Epoch 60/150, Train Loss: 525.9515, Val Loss: 498.7120
# Epoch 70/150, Train Loss: 180.7387, Val Loss: 169.5236
# Epoch 80/150, Train Loss: 44.8194, Val Loss: 41.3115
# Epoch 90/150, Train Loss: 9.1182, Val Loss: 8.4825
# Epoch 100/150, Train Loss: 4.4191, Val Loss: 4.4157
# Epoch 110/150, Train Loss: 4.5972, Val Loss: 4.6375
# Epoch 120/150, Train Loss: 5.2472, Val Loss: 5.2943
# Epoch 130/150, Train Loss: 6.0175, Val Loss: 6.0873
# Epoch 140/150, Train Loss: 6.9160, Val Loss: 6.9778
# Epoch 150/150, Train Loss: 7.9815, Val Loss: 8.0533
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>fold0_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_train_pearson</td><td>▁▂▂▃▄▂▂▂▂▂▃▃▄▄▅▆▆▆▆▆▆▆▆▆▇▇▇▇██████████▇▁</td></tr><tr><td>fold0_val_loss</td><td>█▇▇▇▆▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold0_val_pearson</td><td>▃▄▃▂▁▃▃▃▃▁▁▁▁▁▁▁▁▁▁▂▂▃▃▃▄▄▄▄▄▄▄▅▅▆▇████▂</td></tr><tr><td>fold1_epoch</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>fold1_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_train_pearson</td><td>▇█▇▇▆▅▅▅▄▃▃▂▂▁▁▁▁▁▆▇█▇▇█▇██▇█▇▇▇▇▇▇▇▇▇▆▆</td></tr><tr><td>fold1_val_loss</td><td>█▇▇▇▆▅▄▄▄▃▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold1_val_pearson</td><td>█▆▆▅▅▅▄▄▃▂▂▂▂▂▂▇▇▄▆▆▇▆▇█▇▇▆▅▅▅▃▁▅▅▆▂▄▃▂▃</td></tr><tr><td>fold2_epoch</td><td>▁▁▁▁▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>fold2_train_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_train_pearson</td><td>█▃▃▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▂▂▂▃▃▁▁▅▄▅▅▄▅▄▅▄▄▄</td></tr><tr><td>fold2_val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>fold2_val_pearson</td><td>▁▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▁▁▂█▅▄▅▄▅▄▅▅▄▄</td></tr><tr><td>inner_fold</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▅▅▅▅▅▅▅▅▅▅▅▅▅██████████████</td></tr><tr><td>mean_train_loss</td><td>▁</td></tr><tr><td>mean_train_pearson</td><td>▁</td></tr><tr><td>mean_val_loss</td><td>▁</td></tr><tr><td>mean_val_pearson</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>fold0_epoch</td><td>149</td></tr><tr><td>fold0_train_loss</td><td>2.48963</td></tr><tr><td>fold0_train_pearson</td><td>-0.06477</td></tr><tr><td>fold0_val_loss</td><td>2.47909</td></tr><tr><td>fold0_val_pearson</td><td>-0.11052</td></tr><tr><td>fold1_epoch</td><td>149</td></tr><tr><td>fold1_train_loss</td><td>8.98061</td></tr><tr><td>fold1_train_pearson</td><td>-0.02766</td></tr><tr><td>fold1_val_loss</td><td>9.03521</td></tr><tr><td>fold1_val_pearson</td><td>-0.37508</td></tr><tr><td>fold2_epoch</td><td>149</td></tr><tr><td>fold2_train_loss</td><td>7.98145</td></tr><tr><td>fold2_train_pearson</td><td>-0.08738</td></tr><tr><td>fold2_val_loss</td><td>8.05335</td></tr><tr><td>fold2_val_pearson</td><td>-0.06342</td></tr><tr><td>inner_fold</td><td>2</td></tr><tr><td>mean_train_loss</td><td>6.4839</td></tr><tr><td>mean_train_pearson</td><td>-0.05994</td></tr><tr><td>mean_val_loss</td><td>6.52255</td></tr><tr><td>mean_val_pearson</td><td>-0.18301</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_FC_random_fold3_innerCV</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/wu4asj5h' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/wu4asj5h</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_135912-wu4asj5h/logs</code>
# wandb: Sorting runs by +summary_metrics.mean_val_loss
# Number of learnable parameters in bilinear low rank model: 44212
# Epoch 10/150, Train Loss: 4.6372, Val Loss: 1.0075
# Epoch 20/150, Train Loss: 1.1455, Val Loss: 0.3348
# Epoch 30/150, Train Loss: 0.4985, Val Loss: 0.2169
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/torch/utils/data/dataset.py:211: ResourceWarning: unclosed <socket.socket fd=114, family=2, type=1, proto=0, laddr=('127.0.0.1', 38732), raddr=('127.0.0.1', 45355)>
#   return tuple(tensor[index] for tensor in self.tensors)
# Epoch 40/150, Train Loss: 0.3002, Val Loss: 0.1782
# Epoch 50/150, Train Loss: 0.2212, Val Loss: 0.1611
# Epoch 60/150, Train Loss: 0.1842, Val Loss: 0.1520
# Epoch 70/150, Train Loss: 0.1649, Val Loss: 0.1466
# Epoch 80/150, Train Loss: 0.1541, Val Loss: 0.1431
# Epoch 90/150, Train Loss: 0.1475, Val Loss: 0.1407
# Epoch 100/150, Train Loss: 0.1434, Val Loss: 0.1389
# Epoch 110/150, Train Loss: 0.1407, Val Loss: 0.1375
# Epoch 120/150, Train Loss: 0.1388, Val Loss: 0.1365
# Epoch 130/150, Train Loss: 0.1375, Val Loss: 0.1357
# Epoch 140/150, Train Loss: 0.1365, Val Loss: 0.1352
# Epoch 150/150, Train Loss: 0.1358, Val Loss: 0.1350
# TRAIN METRICS: {'mse': 0.025345144051943068, 'mae': 0.1160980921941164, 'r2': 0.24482055240052802, 'pearson_corr': 0.5477442240971516, 'geodesic_distance': 11.175423334490164}
# TEST METRICS: {'mse': 0.024372973745734272, 'mae': 0.11748944595559832, 'r2': 0.18594947495707992, 'pearson_corr': 0.5690802764536124, 'geodesic_distance': 5.366114037430464}
# BEST VAL SCORE 0.17362148438890776
# BEST MODEL PARAMS {'input_dim': 11053, 'reduced_dim': 4, 'activation': 'identity', 'learning_rate': 0.003, 'epochs': 150, 'batch_size': 256, 'regularization': 'l2', 'lambda_reg': 0.1, 'shared_weights': True, 'device': 'cuda'}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
#
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250110_140019-p1mosy3a</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/p1mosy3a' target="_blank">bilinear_lowrank_transcriptome_predFC_random_fold3_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/p1mosy3a' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/p1mosy3a</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>test_pearson</td><td>▁▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>train_mse_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0.17362</td></tr><tr><td>test_mse_loss</td><td>0.13501</td></tr><tr><td>test_pearson</td><td>0.54542</td></tr><tr><td>train_mse_loss</td><td>0.13582</td></tr><tr><td>train_pearson</td><td>0.52014</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bilinear_lowrank_transcriptome_predFC_random_fold3_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/p1mosy3a' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/p1mosy3a</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250110_140019-p1mosy3a/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 1.6%
# RAM Usage: 9.5%
# Available RAM: 455.0G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 11% |
# WARNING: /state/partition1/job-55745164/ipykernel_174234/3104647973.py:24: ResourceWarning: unclosed <socket.socket fd=104, family=2, type=1, proto=0, laddr=('127.0.0.1', 49544), raddr=('127.0.0.1', 41635)>
#   gc.collect()
# 53456
