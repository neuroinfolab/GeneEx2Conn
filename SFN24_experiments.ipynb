# %% [markdown]
# ## SFN 24 Experiments

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from imports import *

# %%
from models import *
from data import * 
from env import *
from harmonize import *
from metrics import * 
from sim import *
from sim import multi_sim_run
from sim import plot

# %%
# overall imports
import importlib
import data

# data load
importlib.reload(data.data_load)
from data.data_load import load_transcriptome, load_connectome
importlib.reload(data.data_load)

# data utils
from data.data_utils import (
    reconstruct_connectome,
    reconstruct_upper_triangle,
    make_symmetric,
    expand_X_symmetric,
    expand_Y_symmetric,
    expand_X_symmetric_shared,
    expand_X_Y_symmetric_conn_only,
    expand_shared_matrices,
    expand_X_symmetric_w_conn, 
    process_cv_splits, 
    process_cv_splits_conn_only_model, 
    expanded_inner_folds_combined_plus_indices
)

import data.data_utils
importlib.reload(data.data_utils)

# cross-validation classes
import data.cv_split
from data.cv_split import RandomCVSplit, SchaeferCVSplit, CommunityCVSplit, SubnetworkCVSplit
importlib.reload(data.cv_split)

# prebuilt model classes
import models.prebuilt_models
from models.prebuilt_models import ModelBuild
importlib.reload(models.prebuilt_models)

# metric classes
import metrics.distance_FC
import metrics.eval
from metrics.eval import ModelEvaluator
from metrics.eval import pearson_numpy, mse_numpy, r2_numpy, pearson_cupy, mse_cupy, r2_cupy
importlib.reload(metrics.eval)

# sim class
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
import sim.multi_sim_run
from sim.sim import Simulation
from sim.multi_sim_run import multi_sim_run, single_sim_run, open_pickled_results, combine_results
importlib.reload(sim.sim)
importlib.reload(sim.sim_utils)
importlib.reload(sim.multi_sim_run)

import sim.plot
from sim.plot import (
    plot_predictions, 
    barplot_model_performance,
    boxplot_model_performance,
    plot_predictions_with_metrics,
    plot_best_params_table, plot_best_parameters_table_colored, 
    violin_plot_model_performance, 
    plot_transcriptome_performance_bar, plot_connectome_performance_bar, 
    plot_combined_performance_bar
)

importlib.reload(sim.plot)
# Out:
# <module 'sim.plot' from '/scratch/asr655/neuroinformatics/GeneEx2Conn/sim/plot.py'>

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))

GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True

print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)

GPUtil.showUtilization()
# Out:
# CPU Usage: 1.4%
# RAM Usage: 4.7%
# Available RAM: 959.7G
# Total RAM: 1007.0G
# 52.4G
# GPU found 0
# XGBoost version: 2.0.3
# cupy version: 13.1.0
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  5% |

# %% [markdown]
# ## Table of Contents
# - [Multidataset PLS](#PLS)
#     - [AHBA+HCP](#AHBA)
#     - [GTEx+HCP](#GTEx)
#     - [UTSW+HCP](#UTSW)
# - [AHBA+HCP](#AHBA)
#     - [Bilinear PLS](#PLS-Sims)
#       - [Random Splits](#PLS-Random-Splits)
#     - [XGBoost](#XGBoost-Sims)
#       - [Random Splits](#XGBoost-Random-Splits)

# %%
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean', 'functional']

# %%
for feature in feature_types:
    print('FEATURE', feature)
    single_sim_run(cv_type='random',
              model_type='xgboost',
              feature_type=[feature],
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              save_sim=True,
              search_method='bayes'
              )
# Out:
# FEATURE transcriptome
# Number of components explaining 95.0% of the variance: 34
# self X shape (114, 11053)
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22106) (7140,) (812, 22106) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.537 total time=   6.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.346 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.526 total time=   1.7s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.580 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.349 total time=   3.0s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.593 total time=   3.1s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.610 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.353 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.594 total time=   1.6s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.507 total time=   1.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.296 total time=   1.6s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.546 total time=   1.6s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.560 total time=   0.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.307 total time=   0.4s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.589 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.397 total time=   3.7s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.301 total time=   3.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.517 total time=   3.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.489 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.328 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.548 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.590 total time=   3.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.387 total time=   2.5s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.591 total time=   2.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.548 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.302 total time=   1.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.566 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.629 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.352 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.585 total time=   1.6s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.412 total time=   3.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.393 total time=   3.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.514 total time=   3.1s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.334 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.580 total time=   1.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.377 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.352 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.499 total time=   1.6s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.661 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.376 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.565 total time=   1.3s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.346 total time=   3.0s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.332 total time=   3.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.518 total time=   3.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.651 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.354 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.573 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.652 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.353 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.578 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.496 total time=   2.5s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.369 total time=   2.5s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.507 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.482 total time=   2.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.340 total time=   2.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.537 total time=   2.1s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.667 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.355 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.567 total time=   0.8s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.629 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.378 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.565 total time=   1.4s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.590 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.382 total time=   2.7s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.614 total time=   2.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.560 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.364 total time=   1.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.574 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.561 total time=   7.0s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.364 total time=   7.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   7.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.542 total time=   4.4s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.362 total time=   4.4s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.587 total time=   4.7s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.566 total time=   5.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.370 total time=   5.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.565 total time=   5.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.602 total time=   2.9s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.370 total time=   2.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.618 total time=   3.0s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.565 total time=   6.0s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.349 total time=   6.0s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.587 total time=   6.1s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.402 total time=   2.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.574 total time=   2.8s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.557 total time=   2.0s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.389 total time=   2.1s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.552 total time=   2.1s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 0.6), ('device', 'cuda'), ('learning_rate', 0.1), ('max_depth', 2), ('n_estimators', 250), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 0.1), ('reg_lambda', 0.1), ('subsample', 1), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.5340925481640907
#
# Train Metrics: {'mse': 0.012586948875405377, 'mae': 0.07590896170415226, 'r2': 0.42473201547830264, 'pearson_corr': 0.8069546698750408, 'connectome_corr': 0.6505061844902682, 'connectome_r2': 0.39993372168177926, 'geodesic_distance': 11.27846129143677}
# Test Metrics: {'mse': 0.019430902668462445, 'mae': 0.10231164958046836, 'r2': -0.667920870748159, 'pearson_corr': 0.595315070477201, 'connectome_corr': 0.44382189040522824, 'connectome_r2': -0.8779200860623712, 'geodesic_distance': 6.02549645736848}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 2, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 250, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 0.1, 'reg_lambda': 0.1, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 6.4%
# RAM Usage: 4.8%
# Available RAM: 958.8G
# Total RAM: 1007.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 13% |
#
#  Test fold num: 2
# (7140, 22106) (7140,) (812, 22106) (812,)
# 1
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.408 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.303 total time=   1.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.517 total time=   1.7s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.466 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.346 total time=   3.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.568 total time=   3.1s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.481 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.354 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.555 total time=   1.6s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.444 total time=   1.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.334 total time=   1.6s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.522 total time=   1.7s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.461 total time=   0.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.313 total time=   0.4s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.555 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.402 total time=   3.6s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.252 total time=   3.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.421 total time=   3.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.399 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.320 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.494 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.482 total time=   3.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.352 total time=   2.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.549 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.464 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.348 total time=   1.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.542 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.506 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.331 total time=   1.7s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.545 total time=   1.6s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.502 total time=   1.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.353 total time=   1.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.564 total time=   1.6s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.305 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.525 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.515 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.307 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.515 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.500 total time=   1.0s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.327 total time=   1.0s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=3, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.543 total time=   1.0s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.434 total time=   3.3s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.370 total time=   3.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.516 total time=   3.3s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.488 total time=   7.5s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.370 total time=   7.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.565 total time=   7.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.467 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.295 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.546 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.442 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.230 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.510 total time=   0.8s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.372 total time=   2.0s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.286 total time=   1.9s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.411 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.420 total time=   2.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.320 total time=   2.1s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.457 total time=   2.0s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.496 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   0.7s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.557 total time=   0.7s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.500 total time=   3.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.365 total time=   3.7s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.575 total time=   3.6s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.504 total time=   1.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.358 total time=   1.0s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.556 total time=   1.0s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.503 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.355 total time=   0.8s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.555 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.506 total time=   5.0s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.371 total time=   5.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.571 total time=   5.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.482 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   1.1s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.526 total time=   1.0s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.504 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.331 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.560 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.505 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.356 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.561 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.481 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.291 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.523 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.491 total time=   1.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.357 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.0001, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.551 total time=   1.2s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 0.6), ('device', 'cuda'), ('learning_rate', 0.01), ('max_depth', 6), ('n_estimators', 350), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 0), ('reg_lambda', 0.0001), ('subsample', 0.6), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.48276977890117695
#
# Train Metrics: {'mse': 0.005615461720464281, 'mae': 0.050334499293582746, 'r2': 0.7410052565602063, 'pearson_corr': 0.9231275830755878, 'connectome_corr': 0.9049422200434678, 'connectome_r2': 0.729858141045854, 'geodesic_distance': 8.341359484103233}
# Test Metrics: {'mse': 0.020790186078604195, 'mae': 0.10722094630414826, 'r2': -2.2290752032348387, 'pearson_corr': 0.6869524086863337, 'connectome_corr': 0.5564055895472987, 'connectome_r2': -2.671498619784779, 'geodesic_distance': 5.189258805686602}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.6, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 6, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 350, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.0001, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.6, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 2.8%
# RAM Usage: 5.6%
# Available RAM: 950.2G
# Total RAM: 1007.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 13% |
#
#  Test fold num: 3
# (7310, 22106) (7310,) (756, 22106) (756,)
# 1
# 2
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# ...
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.838 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.902 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.910 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.870 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.853 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.897 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.852 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.865 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.894 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.834 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.886 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.894 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.843 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.888 total time=   0.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.905 total time=   0.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.865 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.853 total time=   0.6s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.873 total time=   0.6s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.838 total time=   0.6s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.873 total time=   0.3s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.888 total time=   0.3s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=6, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.837 total time=   0.3s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.848 total time=   0.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.891 total time=   0.6s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.0001, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.841 total time=   0.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.883 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.910 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.867 total time=   0.3s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.898 total time=   1.0s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.912 total time=   1.0s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.906 total time=   1.0s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.895 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.905 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.868 total time=   0.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.911 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.910 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.917 total time=   0.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.869 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.903 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.850 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.915 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.918 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.902 total time=   0.2s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.830 total time=   0.2s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.881 total time=   0.2s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.0001, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.846 total time=   0.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.825 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.863 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=3, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.6, tree_method=gpu_hist, verbosity=0;, score=0.820 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.896 total time=   0.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.909 total time=   0.2s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=3, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.883 total time=   0.2s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.850 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.859 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.0001, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.822 total time=   0.1s
# [CV 1/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.866 total time=   0.1s
# [CV 2/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.870 total time=   0.1s
# [CV 3/3] END colsample_bytree=0.6, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.857 total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 0.8), ('device', 'cuda'), ('learning_rate', 0.1), ('max_depth', 3), ('n_estimators', 250), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 0.0001), ('reg_lambda', 0.01), ('subsample', 0.8), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.9126002562448351
#
# Train Metrics: {'mse': 0.0021373547867607097, 'mae': 0.030013464364313385, 'r2': 0.8309986228732442, 'pearson_corr': 0.969226337138139, 'connectome_corr': 0.9174662691356524, 'connectome_r2': 0.8210806356816144, 'geodesic_distance': 6.6974359092659395}
# Test Metrics: {'mse': 0.004641913463554684, 'mae': 0.045029607804437065, 'r2': 0.6237778633010154, 'pearson_corr': 0.9302775820006914, 'connectome_corr': 0.7959813215124238, 'connectome_r2': 0.5666403241039287, 'geodesic_distance': 3.965679714487578}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 3, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 250, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 0.0001, 'reg_lambda': 0.01, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 6.2%
# RAM Usage: 6.7%
# Available RAM: 939.7G
# Total RAM: 1007.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 16% |
# Simulation results have been saved.

# %%
# Loop over every pairwise combination of features
for feature_pair in itertools.combinations(feature_types, 2):
    print('FEATURE', feature_pair)
    single_sim_run(cv_type='random',
                   model_type='xgboost',
                   feature_type=list(feature_pair),  # Convert tuple to list
                   use_gpu=True,
                   use_shared_regions=False,
                   test_shared_regions=False,
                   save_sim=True,
                   search_method='bayes'
                   )
# Out:
# Number of components explaining 95.0% of the variance: 34
# self X shape (114, 11087)
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22174) (7140,) (812, 22174) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Loop over every pairwise combination of features
#       2 for feature_pair in itertools.combinations(feature_types, 2):
# ----> 3     single_sim_run(cv_type='random',
#       4                    model_type='xgboost',
#       5                    feature_type=list(feature_pair),  # Convert tuple to list
#       6                    use_gpu=True,
#       7                    use_shared_regions=False,
#       8                    test_shared_regions=False,
#       9                    save_sim=True,
#      10                    search_method='bayes'
#      11                    )
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/multi_sim_run.py:275, in single_sim_run(feature_type, cv_type, model_type, use_gpu, summary_measure, use_shared_regions, test_shared_regions, resolution, random_seed, save_sim, search_method)
#     260 # Structural
#     261 sim = Simulation(
#     262                 feature_type=feature_type,
#     263                 cv_type=cv_type,
#    (...)
#     272                 test_shared_regions=test_shared_regions
#     273             )
# --> 275 sim.run_sim(search_method)
#     276 single_model_results.append(sim.results)
#     278 # Save sim data
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim.py:280, in Simulation.run_sim(self, search_method)
#     276 train_network_dict = drop_test_network(self.cv_type, network_dict, test_indices, i+1)
#     278 # Step 5: Inner CV on training data
#     279 # search_method options: random, grid, bayes
# --> 280 best_model = self.run_innercv(train_indices, test_indices, train_network_dict, search_method=search_method, n_iter=100)
#     282 # convert to cupy if necessary
#     283 if self.gpu_acceleration:
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim.py:245, in Simulation.run_innercv(self, train_indices, test_indices, train_network_dict, search_method, n_iter)
#     241     grid_search, X_combined, Y_combined = bayes_search_init(self.gpu_acceleration, model, X_combined, Y_combined, param_dist, train_test_indices, n_iter=n_iter)
#     244 # Fit GridSearchCV on the combined data
# --> 245 grid_search.fit(X_combined, Y_combined)
#     247 # Display comprehensive results
#     248 print("\nGrid Search CV Results:")
#
# File /ext3/miniconda3/lib/python3.11/site-packages/skopt/searchcv.py:542, in BayesSearchCV.fit(self, X, y, groups, callback, **fit_params)
#     535 if callable(self.refit):
#     536     raise ValueError(
#     537         "BayesSearchCV doesn't support a callable refit, "
#     538         "as it doesn't define an implicit score to "
#     539         "optimize"
#     540     )
# --> 542 super().fit(X=X, y=y, groups=groups, **fit_params)
#     544 # BaseSearchCV never ranked train scores,
#     545 # but apparently we used to ship this (back-compat)
#     546 if self.return_train_score:
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File /ext3/miniconda3/lib/python3.11/site-packages/skopt/searchcv.py:599, in BayesSearchCV._run_search(self, evaluate_candidates)
#     595 while n_iter > 0:
#     596     # when n_iter < n_points points left for evaluation
#     597     n_points_adjusted = min(n_iter, n_points)
# --> 599     optim_result, score_name = self._step(
#     600         search_space,
#     601         optimizer,
#     602         score_name,
#     603         evaluate_candidates,
#     604         n_points=n_points_adjusted,
#     605     )
#     606     n_iter -= n_points
#     608     if eval_callbacks(callbacks, optim_result):
#
# File /ext3/miniconda3/lib/python3.11/site-packages/skopt/searchcv.py:453, in BayesSearchCV._step(self, search_space, optimizer, score_name, evaluate_candidates, n_points)
#     450 # make lists into dictionaries
#     451 params_dict = [point_asdict(search_space, p) for p in params]
# --> 453 all_results = evaluate_candidates(params_dict)
#     455 # if self.scoring is a callable, we have to wait until here
#     456 # to get the score name
#     457 if score_name is None:
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /ext3/miniconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:724, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     720     estimator = estimator.set_params(**cloned_parameters)
#     722 start_time = time.time()
# --> 724 X_train, y_train = _safe_split(estimator, X, y, train)
#     725 X_test, y_test = _safe_split(estimator, X, y, test, train)
#     727 result = {}
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/utils/metaestimators.py:155, in _safe_split(estimator, X, y, indices, train_indices)
#     153         X_subset = X[np.ix_(indices, train_indices)]
#     154 else:
# --> 155     X_subset = _safe_indexing(X, indices)
#     157 if y is not None:
#     158     y_subset = _safe_indexing(y, indices)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py:355, in _safe_indexing(X, indices, axis)
#     353     return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     354 elif hasattr(X, "shape"):
# --> 355     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     356 else:
#     357     return _list_indexing(X, indices, indices_dtype)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py:184, in _array_indexing(array, key, key_dtype, axis)
#     182 if isinstance(key, tuple):
#     183     key = list(key)
# --> 184 return array[key] if axis == 0 else array[:, key]
#
# File cupy/_core/core.pyx:1521, in cupy._core.core._ndarray_base.__getitem__()
#
# File cupy/_core/_routines_indexing.pyx:42, in cupy._core._routines_indexing._ndarray_getitem()
#
# File cupy/_core/core.pyx:829, in cupy._core.core._ndarray_base.take()
#
# File cupy/_core/_routines_indexing.pyx:131, in cupy._core._routines_indexing._ndarray_take()
#
# File cupy/_core/_routines_indexing.pyx:825, in cupy._core._routines_indexing._take()
#
# File cupy/_core/_kernel.pyx:920, in cupy._core._kernel.ElementwiseKernel.__call__()
#
# File cupy/_core/_kernel.pyx:945, in cupy._core._kernel.ElementwiseKernel._get_elementwise_kernel()
#
# File cupy/_util.pyx:64, in cupy._util.memoize.decorator.ret()
#
# File cupy/_core/_kernel.pyx:728, in cupy._core._kernel._get_elementwise_kernel()
#
# File cupy/_core/_kernel.pyx:82, in cupy._core._kernel._get_simple_elementwise_kernel_from_code()
#
# File cupy/_core/core.pyx:2250, in cupy._core.core.compile_with_cache()
#
# File cupy/_core/core.pyx:2152, in cupy._core.core._get_header_source()
#
# File cupy/_core/core.pyx:2153, in cupy._core.core._get_header_source()
#
# File <frozen codecs>:319, in decode(self, input, final)
#
# KeyboardInterrupt:

# %%
# Loop over every triple combination of features
for feature_triple in itertools.combinations(feature_types, 3):
    print('FEATURE', feature_triple)
    single_sim_run(cv_type='random',
                   model_type='xgboost',
                   feature_type=list(feature_triple),  # Convert tuple to list
                   use_gpu=True,
                   use_shared_regions=False,
                   test_shared_regions=False,
                   save_sim=True,
                   search_method='bayes'
                   )
# Out:
# Number of triple combinations: 10
