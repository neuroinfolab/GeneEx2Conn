# %% [markdown]
# ## Sim Demo

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from imports import *

# %%
# overall imports
import importlib
import data

# importlib.reload(data.data_utils)
# importlib.reload(data.data_load)
# importlib.reload(sim.sim_utils)
# importlib.reload(sim)
# importlib.reload(models)

import models
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
from sim.sim import Simulation
from sim.sim_run import single_sim_run, open_pickled_results

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))
# Out:
# CPU Usage: 4.0%
# RAM Usage: 10.9%
# Available RAM: 448.3G
# Total RAM: 503.0G
# 52.4G

# %%
print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)
# Out:
# XGBoost version: 2.0.3
# cupy version: 13.1.0

# %%
GPUtil.getAvailable()
# if a number is seen a GPU is available
# Out:
# [0]

# %%
GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None:
    print('GPU found', DEVICE_ID)
    use_gpu = True
# Out:
# GPU found 0

# %%
GPUtil.showUtilization()
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 11% |

# %%
torch.cuda.is_available()

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
print(torch.cuda.memory_allocated())
print(torch.cuda.max_memory_allocated())
# Out:
# 1714650112
# 1747584000

# %% [markdown]
# #### Simulation tests <a id="sims"></a>

# %%
# Run simulation
single_sim_run(
              cv_type='random',
              random_seed=42,
              model_type='shared_transformer',
              feature_type=[{'transcriptome': None}],
              connectome_target='FC',
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              omit_subcortical=False,
              parcellation='S400',
              gene_list='0.2',
              hemisphere='both',
              search_method=('wandb', 'mse', 3),
              save_sim=False,
              track_wandb=True, 
              skip_cv=True
              )

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Clear CPU memory
import gc
gc.collect()
# Out:
# Number of components for 95% variance PCA: 105
# X shape: (390, 7380)
# X_pca shape: (390, 105)
# Y_sc shape: (390, 390)
# Y_sc_spectralL shape: (390, 455)
# Y_sc_spectralA shape: (390, 456)
# Y_fc shape: (390, 390)
# Coordinates shape: (390, 3)
# Y shape (390, 390)
# feature_name:  transcriptome
# processing_type:  None
# X shape (390, 7380)
#
#  Test fold num: 1 X_train shape: (84972, 14760) Y_train shape: (84972,) X_test shape: (9506, 14760) Y_test shape: (9506,)
# 2
# 3
# 4
# BEST CONFIG {'input_dim': 14760, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 2, 'num_layers': 2, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 9e-05, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 50}
# Epoch 5/50, Train Loss: 0.0188, Val Loss: 0.0229
# Epoch 5/50, Train Pearson: 0.6629, Val Pearson: 0.4997
# Epoch 10/50, Train Loss: 0.0076, Val Loss: 0.0234
# Epoch 10/50, Train Pearson: 0.8806, Val Pearson: 0.4979
# Epoch 15/50, Train Loss: 0.0055, Val Loss: 0.0230
# Epoch 15/50, Train Pearson: 0.9176, Val Pearson: 0.5084
# Epoch 20/50, Train Loss: 0.0046, Val Loss: 0.0228
# Epoch 20/50, Train Pearson: 0.9322, Val Pearson: 0.5230
# Epoch 25/50, Train Loss: 0.0041, Val Loss: 0.0222
# Epoch 25/50, Train Pearson: 0.9398, Val Pearson: 0.5223
# Epoch 30/50, Train Loss: 0.0038, Val Loss: 0.0227
# Epoch 30/50, Train Pearson: 0.9455, Val Pearson: 0.5084
# Epoch 35/50, Train Loss: 0.0035, Val Loss: 0.0231
# Epoch 35/50, Train Pearson: 0.9503, Val Pearson: 0.5174
# Epoch 40/50, Train Loss: 0.0033, Val Loss: 0.0228
# Epoch 40/50, Train Pearson: 0.9529, Val Pearson: 0.5161
# Epoch 45/50, Train Loss: 0.0032, Val Loss: 0.0224
# Epoch 45/50, Train Pearson: 0.9553, Val Pearson: 0.5266
# Epoch 50/50, Train Loss: 0.0030, Val Loss: 0.0227
# Epoch 50/50, Train Pearson: 0.9577, Val Pearson: 0.5179
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.0015399634995714752, 'mae': 0.028977213605496176, 'r2': 0.9536349299107126, 'pearson_corr': 0.9767393321216021, 'geodesic_distance': 14.479928791870602}
# TEST METRICS: {'mse': 0.02266904273356681, 'mae': 0.10841070355410055, 'r2': 0.2528604313061106, 'pearson_corr': 0.5249904524644475, 'geodesic_distance': 13.913505444582842}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7380, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 2, 'num_layers': 2, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 9e-05, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 50}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_125442-6usg9zp9</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/6usg9zp9' target="_blank">shared_transformer_transcriptome_FC_random_fold0_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/6usg9zp9' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/6usg9zp9</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▄▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▂▂▁▁▂▂▂▂▂▁▁▂▂▂▁▂</td></tr><tr><td>test_pearson</td><td>▁▅▇▇▇▇▇▇▇▇▇▇▇▇▇▇█▇▇██████▇██▇█▇█▇▇███▇█▇</td></tr><tr><td>train_mse_loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▂▃▅▆▇▇▇▇▇██████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.02271</td></tr><tr><td>test_pearson</td><td>0.51793</td></tr><tr><td>train_mse_loss</td><td>0.00302</td></tr><tr><td>train_pearson</td><td>0.95774</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome_FC_random_fold0_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/6usg9zp9' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/6usg9zp9</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_125442-6usg9zp9/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 2.4%
# RAM Usage: 21.3%
# Available RAM: 395.9G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 27% |
#
#  Test fold num: 2 X_train shape: (84972, 14760) Y_train shape: (84972,) X_test shape: (9506, 14760) Y_test shape: (9506,)
# 1
# 3
# 4
# BEST CONFIG {'input_dim': 14760, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 2, 'num_layers': 2, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 9e-05, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 50}
# Epoch 5/50, Train Loss: 0.0178, Val Loss: 0.0244
# Epoch 5/50, Train Pearson: 0.6818, Val Pearson: 0.4837
# Epoch 10/50, Train Loss: 0.0078, Val Loss: 0.0254
# Epoch 10/50, Train Pearson: 0.8763, Val Pearson: 0.4948
# Epoch 15/50, Train Loss: 0.0057, Val Loss: 0.0236
# Epoch 15/50, Train Pearson: 0.9135, Val Pearson: 0.5164
# Epoch 20/50, Train Loss: 0.0047, Val Loss: 0.0234
# Epoch 20/50, Train Pearson: 0.9300, Val Pearson: 0.5199
# Epoch 25/50, Train Loss: 0.0042, Val Loss: 0.0237
# Epoch 25/50, Train Pearson: 0.9382, Val Pearson: 0.5129
# Epoch 30/50, Train Loss: 0.0037, Val Loss: 0.0240
# Epoch 30/50, Train Pearson: 0.9464, Val Pearson: 0.5030
# Epoch 35/50, Train Loss: 0.0035, Val Loss: 0.0235
# Epoch 35/50, Train Pearson: 0.9508, Val Pearson: 0.5168
# Epoch 40/50, Train Loss: 0.0033, Val Loss: 0.0240
# Epoch 40/50, Train Pearson: 0.9526, Val Pearson: 0.5002
# Epoch 45/50, Train Loss: 0.0031, Val Loss: 0.0241
# Epoch 45/50, Train Pearson: 0.9554, Val Pearson: 0.5007
# Epoch 50/50, Train Loss: 0.0030, Val Loss: 0.0248
# Epoch 50/50, Train Pearson: 0.9573, Val Pearson: 0.4824
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.0013435857513827408, 'mae': 0.026913200361909622, 'r2': 0.959211428387506, 'pearson_corr': 0.9794187548257332, 'geodesic_distance': 13.021700329024679}
# TEST METRICS: {'mse': 0.02484613837985113, 'mae': 0.11556407389915012, 'r2': 0.21734958289768924, 'pearson_corr': 0.4862946050166018, 'geodesic_distance': 14.771946244606507}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7380, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 2, 'num_layers': 2, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 9e-05, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 50}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_131736-9fvtj37s</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/9fvtj37s' target="_blank">shared_transformer_transcriptome_FC_random_fold1_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/9fvtj37s' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/9fvtj37s</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▆▃▃▂▃▃▂▃▁▂▂▁▁▂▁▁▁▃▁▂▁▂▂▁▁▁▁▁▂▂▂▁▂▂▂▂▂▂▂</td></tr><tr><td>test_pearson</td><td>▁▃▆▇▇▇▇▇▇█████▇████████▇███████▇▇█▇▇▇▇▇▇</td></tr><tr><td>train_mse_loss</td><td>█▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▂▃▅▆▇▇▇████████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.02478</td></tr><tr><td>test_pearson</td><td>0.48239</td></tr><tr><td>train_mse_loss</td><td>0.00301</td></tr><tr><td>train_pearson</td><td>0.95731</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome_FC_random_fold1_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/9fvtj37s' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/9fvtj37s</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_131736-9fvtj37s/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 3.6%
# RAM Usage: 22.1%
# Available RAM: 392.0G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 39% |
#
#  Test fold num: 3 X_train shape: (85556, 14760) Y_train shape: (85556,) X_test shape: (9312, 14760) Y_test shape: (9312,)
# 1
# 2
# 4
# BEST CONFIG {'input_dim': 14760, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0166, Val Loss: 0.0227
# Epoch 5/75, Train Pearson: 0.7043, Val Pearson: 0.5232
# Epoch 10/75, Train Loss: 0.0074, Val Loss: 0.0227
# Epoch 10/75, Train Pearson: 0.8829, Val Pearson: 0.5394
# Epoch 15/75, Train Loss: 0.0054, Val Loss: 0.0220
# Epoch 15/75, Train Pearson: 0.9177, Val Pearson: 0.5578
# Epoch 20/75, Train Loss: 0.0045, Val Loss: 0.0227
# Epoch 20/75, Train Pearson: 0.9334, Val Pearson: 0.5301
# Epoch 25/75, Train Loss: 0.0038, Val Loss: 0.0231
# Epoch 25/75, Train Pearson: 0.9447, Val Pearson: 0.5148
# Epoch 30/75, Train Loss: 0.0034, Val Loss: 0.0235
# Epoch 30/75, Train Pearson: 0.9512, Val Pearson: 0.5078
# Epoch 35/75, Train Loss: 0.0031, Val Loss: 0.0234
# Epoch 35/75, Train Pearson: 0.9557, Val Pearson: 0.5060
# Epoch 40/75, Train Loss: 0.0030, Val Loss: 0.0238
# Epoch 40/75, Train Pearson: 0.9585, Val Pearson: 0.4895
# Epoch 45/75, Train Loss: 0.0028, Val Loss: 0.0249
# Epoch 45/75, Train Pearson: 0.9612, Val Pearson: 0.4665
# Epoch 50/75, Train Loss: 0.0027, Val Loss: 0.0249
# Epoch 50/75, Train Pearson: 0.9623, Val Pearson: 0.4623
# Epoch 55/75, Train Loss: 0.0026, Val Loss: 0.0257
# Epoch 55/75, Train Pearson: 0.9641, Val Pearson: 0.4453
# Epoch 60/75, Train Loss: 0.0026, Val Loss: 0.0268
# Epoch 60/75, Train Pearson: 0.9643, Val Pearson: 0.4282
# Epoch 65/75, Train Loss: 0.0025, Val Loss: 0.0281
# Epoch 65/75, Train Pearson: 0.9658, Val Pearson: 0.4159
# Epoch 70/75, Train Loss: 0.0024, Val Loss: 0.0278
# Epoch 70/75, Train Pearson: 0.9665, Val Pearson: 0.4100
# Epoch 75/75, Train Loss: 0.0024, Val Loss: 0.0289
# Epoch 75/75, Train Pearson: 0.9673, Val Pearson: 0.4033
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:528: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
#   self.comm = Comm(**args)
# TRAIN METRICS: {'mse': 0.000923979381349449, 'mae': 0.02241618052366144, 'r2': 0.9718601111838171, 'pearson_corr': 0.9859714602890995, 'geodesic_distance': 11.209233935745548}
# TEST METRICS: {'mse': 0.028890261306847277, 'mae': 0.12524162257095423, 'r2': 0.06609348238509805, 'pearson_corr': 0.40633827778452275, 'geodesic_distance': 17.559558402747445}
# BEST VAL SCORE 0.0
# BEST MODEL PARAMS {'input_dim': 7380, 'token_encoder_dim': 20, 'd_model': 128, 'encoder_output_dim': 10, 'use_positional_encoding': False, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# WARNING: /ext3/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/ipython.py:77: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import HTML, display  # type: ignore
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/GeneEx2Conn/wandb/run-20250130_143312-8ns7rhzp</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/8ns7rhzp' target="_blank">shared_transformer_transcriptome_FC_random_fold2_final_eval</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/8ns7rhzp' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/8ns7rhzp</a>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>▁</td></tr><tr><td>test_mse_loss</td><td>█▅▂▂▃▁▁▁▂▁▁▂▁▂▂▃▃▃▂▃▃▃▃▄▃▄▄▄▄▄▅▅▅▅▆▆▆▅▆▆</td></tr><tr><td>test_pearson</td><td>▁▄▇▇█████▇▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅</td></tr><tr><td>train_mse_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_pearson</td><td>▁▄▅▆▆▇▇▇▇▇██████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_loss</td><td>0</td></tr><tr><td>test_mse_loss</td><td>0.02888</td></tr><tr><td>test_pearson</td><td>0.40332</td></tr><tr><td>train_mse_loss</td><td>0.00238</td></tr><tr><td>train_pearson</td><td>0.96734</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">shared_transformer_transcriptome_FC_random_fold2_final_eval</strong> at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/8ns7rhzp' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn/runs/8ns7rhzp</a><br/> View project at: <a href='https://wandb.ai/alexander-ratzan-new-york-university/gx2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/gx2conn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250130_143312-8ns7rhzp/logs</code>
# Final evaluation metrics logged successfully.
# CPU Usage: 2.5%
# RAM Usage: 22.0%
# Available RAM: 392.4G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 51% |
#
#  Test fold num: 4 X_train shape: (85556, 14760) Y_train shape: (85556,) X_test shape: (9312, 14760) Y_test shape: (9312,)
# 1
# 2
# 3
# BEST CONFIG {'input_dim': 14760, 'token_encoder_dim': 20, 'd_model': 128, 'use_positional_encoding': False, 'encoder_output_dim': 10, 'nhead': 4, 'num_layers': 4, 'deep_hidden_dims': [512, 256], 'transformer_dropout': 0.2, 'dropout_rate': 0.2, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'lambda_reg': 0, 'batch_size': 128, 'epochs': 75}
# Epoch 5/75, Train Loss: 0.0164, Val Loss: 0.0280
# Epoch 5/75, Train Pearson: 0.6975, Val Pearson: 0.4672
# Epoch 10/75, Train Loss: 0.0073, Val Loss: 0.0276
# Epoch 10/75, Train Pearson: 0.8812, Val Pearson: 0.4819
# Epoch 15/75, Train Loss: 0.0053, Val Loss: 0.0275
# Epoch 15/75, Train Pearson: 0.9158, Val Pearson: 0.4845
# Epoch 20/75, Train Loss: 0.0044, Val Loss: 0.0274
# Epoch 20/75, Train Pearson: 0.9316, Val Pearson: 0.4796
# Epoch 25/75, Train Loss: 0.0038, Val Loss: 0.0276
# Epoch 25/75, Train Pearson: 0.9421, Val Pearson: 0.4798
# Epoch 30/75, Train Loss: 0.0034, Val Loss: 0.0281
# Epoch 30/75, Train Pearson: 0.9490, Val Pearson: 0.4703

# %%
# Run simulation
single_sim_run(
              cv_type='random',
              random_seed=42,
              model_type='shared_transformer',
              feature_type=[{'transcriptome': None}],
              connectome_target='SC',
              use_gpu=True,
              use_shared_regions=False,
              test_shared_regions=False,
              omit_subcortical=False,
              parcellation='S400',
              gene_list='0.2',
              hemisphere='both',
              search_method=('wandb', 'mse', 3),
              save_sim=False,
              track_wandb=True, 
              skip_cv=True
              )

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Clear CPU memory
import gc
gc.collect()
