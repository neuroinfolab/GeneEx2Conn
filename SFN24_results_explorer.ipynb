# %% [markdown]
# ## SFN 24 Results Explorer

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from imports import *
# Out:
# 2024-09-26 21:35:02.214283: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-26 21:35:04.103922: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-26 21:35:06.310252: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from models import *
from data import * 
from env import *
from harmonize import *
from metrics import * 
from sim import *
from sim import multi_sim_run
from sim import plot

# %%
# overall imports
import importlib
import data

# data load
importlib.reload(data.data_load)
from data.data_load import load_transcriptome, load_connectome
importlib.reload(data.data_load)

# data utils
from data.data_utils import (
    reconstruct_connectome,
    reconstruct_upper_triangle,
    make_symmetric,
    expand_X_symmetric,
    expand_Y_symmetric,
    expand_X_symmetric_shared,
    expand_X_Y_symmetric_conn_only,
    expand_shared_matrices,
    expand_X_symmetric_w_conn, 
    process_cv_splits, 
    process_cv_splits_conn_only_model, 
    expanded_inner_folds_combined_plus_indices
)

import data.data_utils
importlib.reload(data.data_utils)

# cross-validation classes
import data.cv_split
from data.cv_split import RandomCVSplit, SchaeferCVSplit, CommunityCVSplit, SubnetworkCVSplit
importlib.reload(data.cv_split)

# prebuilt model classes
import models.prebuilt_models
from models.prebuilt_models import ModelBuild
importlib.reload(models.prebuilt_models)

# metric classes
import metrics.distance_FC
import metrics.eval
from metrics.eval import ModelEvaluator
from metrics.eval import pearson_numpy, mse_numpy, r2_numpy, pearson_cupy, mse_cupy, r2_cupy
importlib.reload(metrics.eval)

# sim class
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
import sim.multi_sim_run
from sim.sim import Simulation
from sim.multi_sim_run import multi_sim_run, single_sim_run, open_pickled_results, combine_results
importlib.reload(sim.sim)
importlib.reload(sim.sim_utils)
importlib.reload(sim.multi_sim_run)

import sim.plot
from sim.plot import (
    plot_predictions, 
    barplot_model_performance,
    boxplot_model_performance,
    plot_predictions_with_metrics, plot_single_model_predictions_with_metrics,
    plot_best_params_table, plot_best_parameters_table_colored, 
    violin_plot_model_performance, 
    plot_transcriptome_performance_bar, plot_connectome_performance_bar, 
    plot_combined_performance_bar
)

importlib.reload(sim.plot)
# Out:
# <module 'sim.plot' from '/scratch/asr655/neuroinformatics/GeneEx2Conn/sim/plot.py'>

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))

GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True

print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)

GPUtil.showUtilization()
# Out:
# CPU Usage: 29.3%
# RAM Usage: 9.3%
# Available RAM: 341.9G
# Total RAM: 376.8G
# 52.4G
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 8
#       4 print(bytes2human(total))
#       6 GPUtil.getGPUs()
# ----> 8 DEVICE_ID_LIST = GPUtil.getFirstAvailable()
#       9 DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
#      10 if DEVICE_ID != None:
#
# File /ext3/miniconda3/lib/python3.11/site-packages/GPUtil/GPUtil.py:203, in getFirstAvailable(order, maxLoad, maxMemory, attempts, interval, verbose, includeNan, excludeID, excludeUUID)
#     201 # Check if an GPU was found, or if the attempts simply ran out. Throw error, if no GPU was found
#     202 if (not(available)):
# --> 203     raise RuntimeError('Could not find an available GPU after ' + str(attempts) + ' attempts with ' + str(interval) + ' seconds interval.')
#     205 # Return found GPU
#     206 return available
#
# RuntimeError: Could not find an available GPU after 1 attempts with 900 seconds interval.

# %% [markdown]
# ## Table of Contents
# - [Multidataset PLS](#PLS)
#     - [AHBA+HCP](#AHBA)
#     - [GTEx+HCP](#GTEx)
#     - [UTSW+HCP](#UTSW)
# - [AHBA+HCP](#AHBA)
#     - [Bilinear PLS](#PLS-Sims)
#       - [Random Splits](#PLS-Random-Splits)
#     - [XGBoost](#XGBoost-Sims)
#       - [Random Splits](#XGBoost-Random-Splits)

# %%
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean', 'functional']

# %% [markdown]
# ## Results Analysis

# %% [markdown]
# ### Random

# %%
SFN_sim_path = os.getcwd() + '/sim/sim_results/SFN_runs'
os.listdir(SFN_sim_path)
# Out:
# ['transcriptomePCA structural_pls_community_gridsearch102_2.pickle',
#  'transcriptome_pls_community_gridsearch101_0.pickle',
#  'functional transcriptome_pls_community_gridsearch102_2.pickle',
#  'structural euclidean_pls_community_gridsearch102_4.pickle',
#  'functional_pls_community_gridsearch102_3.pickle',
#  'functional_pls_community_gridsearch102_42.pickle',
#  'transcriptome_pls_community_gridsearch101_2.pickle',
#  'transcriptomePCA transcriptome_pls_community_gridsearch102_5.pickle',
#  'functional_pls_random_gridsearch.pickle',
#  'euclidean transcriptome_pls_random_gridsearch.pickle',
#  'euclidean transcriptome_pls_community_gridsearch102_5.pickle',
#  'structural_xgboost_random_bayessearch.pickle',
#  'euclidean functional_pls_community_gridsearch102_4.pickle',
#  'transcriptomePCA transcriptome_pls_community_gridsearch102_2.pickle',
#  'euclidean transcriptome_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_42.pickle',
#  'functional_pls_community_gridsearch101_0.pickle',
#  'transcriptome_xgboost_community_bayessearch101_4.pickle',
#  'transcriptomePCA euclidean_xgboost_random_bayessearch.pickle',
#  'transcriptome transcriptomePCA_xgboost_random_bayessearch.pickle',
#  'structural_pls_community_gridsearch102_1.pickle',
#  'transcriptomePCA structural functional_ridge_random_gridsearch.pickle',
#  'structural_xgboost_community_bayessearch101_42.pickle',
#  'transcriptomePCA transcriptome_pls_community_gridsearch102_42.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_3.pickle',
#  'transcriptomePCA structural_xgboost_random_bayessearch.pickle',
#  'functional_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_4.pickle',
#  'functional transcriptome_pls_random_gridsearch.pickle',
#  'transcriptomePCA functional_pls_random_gridsearch.pickle',
#  'structural functional_xgboost_random_bayessearch.pickle',
#  'euclidean functional_pls_community_gridsearch102_3.pickle',
#  'structural euclidean functional_xgboost_random_bayessearch.pickle',
#  'transcriptomePCA euclidean functional_ridge_random_gridsearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA_xgboost_community_bayessearch102_3.pickle',
#  'transcriptome_xgboost_community_bayessearch101_2.pickle',
#  'functional_xgboost_community_bayessearch101_2.pickle',
#  'euclidean_pls_community_gridsearch101_2.pickle',
#  'functional transcriptome_pls_community_gridsearch102_3.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_1.pickle',
#  'euclidean_pls_random_gridsearch.pickle',
#  'transcriptomePCA euclidean transcriptome_ridge_random_gridsearch.pickle',
#  'euclidean_xgboost_community_bayessearch102_3.pickle',
#  'transcriptomePCA_xgboost_community_bayessearch102_2.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_4.pickle',
#  'transcriptome_pls_community_gridsearch102_0.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_1.pickle',
#  'structural functional_pls_community_gridsearch102_2.pickle',
#  'transcriptome_pls_community_gridsearch101_42.pickle',
#  'euclidean_xgboost_community_bayessearch102_2.pickle',
#  'functional transcriptome_pls_community_gridsearch102_5.pickle',
#  'euclidean_ridge_torch_random_bayessearch.pickle',
#  'transcriptomePCA structural_pls_community_gridsearch102_3.pickle',
#  'transcriptome_pls_community_gridsearch102_5.pickle',
#  'transcriptome functional_xgboost_random_bayessearch.pickle',
#  'transcriptome structural_xgboost_random_bayessearch.pickle',
#  'euclidean_pls_community_gridsearch102_5.pickle',
#  '.ipynb_checkpoints',
#  'structural functional_pls_community_gridsearch102_42.pickle',
#  'transcriptomePCA functional_pls_community_gridsearch102_5.pickle',
#  'transcriptomePCA functional_xgboost_random_bayessearch.pickle',
#  'euclidean transcriptome_pls_community_gridsearch102_3.pickle',
#  'structural euclidean_pls_community_gridsearch102_2.pickle',
#  'functional_pls_community_gridsearch101_42.pickle',
#  'transcriptome_pls_random_gridsearch.pickle',
#  'transcriptomePCA structural euclidean_xgboost_random_bayessearch.pickle',
#  'euclidean_pls_community_gridsearch102_3.pickle',
#  'euclidean functional_pls_community_gridsearch102_42.pickle',
#  'transcriptomePCA_pls_random_gridsearch.pickle',
#  'transcriptomePCA structural transcriptome_ridge_random_gridsearch.pickle',
#  'transcriptome_pls_community_gridsearch102_2.pickle',
#  'structural_xgboost_community_bayessearch101_3.pickle',
#  'transcriptome_xgboost_community_bayessearch101_42.pickle',
#  'transcriptomePCA euclidean_pls_community_gridsearch102_3.pickle',
#  'structural_ridge_random_bayessearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_3.pickle',
#  'functional_xgboost_community_bayessearch101_3.pickle',
#  'transcriptomePCA structural_pls_community_gridsearch102_42.pickle',
#  'transcriptomePCA euclidean_pls_community_gridsearch102_2.pickle',
#  'structural functional_pls_community_gridsearch102_4.pickle',
#  'structural_pls_community_gridsearch101_42.pickle',
#  'transcriptomePCA transcriptome_pls_community_gridsearch102_3.pickle',
#  'euclidean_pls_community_gridsearch101_5.pickle',
#  'transcriptomePCA_ridge_torch_random_bayessearch.pickle',
#  'structural transcriptome_pls_community_gridsearch102_2.pickle',
#  'structural_xgboost_community_bayessearch102_2.pickle',
#  'structural euclidean_xgboost_random_bayessearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_2.pickle',
#  'structural_ridge_torch_random_bayessearch.pickle',
#  'euclidean_xgboost_community_bayessearch101_42.pickle',
#  'transcriptomePCA structural_pls_random_gridsearch.pickle',
#  'transcriptome transcriptomePCA structural_xgboost_random_bayessearch.pickle',
#  'transcriptomePCA structural_pls_community_gridsearch102_4.pickle',
#  'structural_pls_community_gridsearch102_0.pickle',
#  'euclidean_xgboost_random_bayessearch.pickle',
#  'transcriptome_pls_community_gridsearch101_1.pickle',
#  'euclidean transcriptome_pls_community_gridsearch102_4.pickle',
#  'structural_pls_community_gridsearch101_2.pickle',
#  'structural functional_pls_random_gridsearch.pickle',
#  'transcriptome_xgboost_community_bayessearch101_0.pickle',
#  'transcriptomePCA euclidean_xgboost_random_gridsearch.pickle',
#  'structural transcriptome_pls_community_gridsearch102_5.pickle',
#  'euclidean functional_xgboost_random_bayessearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_42.pickle',
#  'structural functional_pls_community_gridsearch102_5.pickle',
#  'structural functional_pls_community_gridsearch102_3.pickle',
#  'transcriptomePCA functional_pls_community_gridsearch102_42.pickle',
#  'structural_pls_community_gridsearch101_3.pickle',
#  'structural euclidean_pls_community_gridsearch102_42.pickle',
#  'transcriptome_pls_community_gridsearch102_4.pickle',
#  'transcriptomePCA structural euclidean_ridge_random_gridsearch.pickle',
#  'euclidean_pls_community_gridsearch102_0.pickle',
#  'structural transcriptome_pls_community_gridsearch102_42.pickle',
#  'transcriptome_pls_community_gridsearch102_42.pickle',
#  'transcriptome_pls_community_gridsearch102_3.pickle',
#  'transcriptomePCA_xgboost_community_bayessearch101_42.pickle',
#  'structural_pls_community_gridsearch102_42.pickle',
#  'transcriptomePCA euclidean_pls_community_gridsearch102_5.pickle',
#  'euclidean_pls_community_gridsearch102_42.pickle',
#  'transcriptome_xgboost_community_bayessearch102_2.pickle',
#  'euclidean functional_pls_community_gridsearch102_2.pickle',
#  'euclidean_pls_community_gridsearch101_1.pickle',
#  'transcriptome euclidean functional_xgboost_random_bayessearch.pickle',
#  'euclidean_ridge_random_bayessearch.pickle',
#  'euclidean_pls_community_gridsearch101_4.pickle',
#  'transcriptomePCA_xgboost_community_bayessearch101_3.pickle',
#  'functional_pls_community_gridsearch101_4.pickle',
#  'structural transcriptome_pls_community_gridsearch102_3.pickle',
#  'euclidean_pls_community_gridsearch101_3.pickle',
#  'transcriptomePCA_ridge_random_bayessearch.pickle',
#  'structural_xgboost_community_bayessearch101_2.pickle',
#  'transcriptome_xgboost_random_bayessearch.pickle',
#  'functional_xgboost_community_bayessearch102_2.pickle',
#  'structural euclidean functional_ridge_random_gridsearch.pickle',
#  'structural_pls_community_gridsearch102_4.pickle',
#  'structural euclidean_pls_community_gridsearch102_3.pickle',
#  'transcriptome_pls_community_gridsearch101_3.pickle',
#  'euclidean transcriptome_pls_community_gridsearch102_42.pickle',
#  'euclidean_xgboost_community_bayessearch101_2.pickle',
#  'euclidean_xgboost_community_bayessearch101_3.pickle',
#  'functional_pls_community_gridsearch102_1.pickle',
#  'structural_pls_community_gridsearch101_1.pickle',
#  'structural functional transcriptome_ridge_random_gridsearch.pickle',
#  'transcriptome transcriptomePCA euclidean_xgboost_random_bayessearch.pickle',
#  'structural_pls_community_gridsearch102_5.pickle',
#  'euclidean_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA euclidean_pls_community_gridsearch102_42.pickle',
#  'structural_pls_community_gridsearch102_3.pickle',
#  'transcriptome euclidean_xgboost_random_bayessearch.pickle',
#  'transcriptomePCA structural_pls_community_gridsearch102_5.pickle',
#  'structural_pls_community_gridsearch101_5.pickle',
#  'transcriptome_pls_community_gridsearch101_5.pickle',
#  'transcriptome_pls_community_gridsearch101_4.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_0.pickle',
#  'transcriptome_pls_community_gridsearch102_1.pickle',
#  'structural euclidean_pls_community_gridsearch102_5.pickle',
#  'euclidean_pls_community_gridsearch102_1.pickle',
#  'transcriptomePCA structural functional_xgboost_random_bayessearch.pickle',
#  'transcriptome transcriptomePCA functional_xgboost_random_bayessearch.pickle',
#  'structural_pls_community_gridsearch101_0.pickle',
#  'structural_pls_random_gridsearch.pickle',
#  'transcriptomePCA functional transcriptome_ridge_random_gridsearch.pickle',
#  'structural_xgboost_community_bayessearch102_3.pickle',
#  'functional transcriptome_pls_community_gridsearch102_42.pickle',
#  'structural transcriptome_pls_community_gridsearch102_4.pickle',
#  'functional_pls_community_gridsearch101_1.pickle',
#  'transcriptomePCA functional_pls_community_gridsearch102_4.pickle',
#  'transcriptomePCA functional_pls_community_gridsearch102_3.pickle',
#  'transcriptome structural euclidean_xgboost_random_bayessearch.pickle',
#  'structural_pls_community_gridsearch101_4.pickle',
#  'transcriptomePCA euclidean functional_xgboost_random_bayessearch.pickle',
#  'structural euclidean transcriptome_ridge_random_gridsearch.pickle',
#  'transcriptomePCA_xgboost_community_bayessearch101_2.pickle',
#  'functional_pls_community_gridsearch101_3.pickle',
#  'functional_ridge_torch_random_bayessearch.pickle',
#  'transcriptome structural functional_xgboost_random_bayessearch.pickle',
#  'functional_xgboost_community_bayessearch102_3.pickle',
#  'transcriptome_xgboost_community_bayessearch102_42.pickle',
#  'transcriptomePCA transcriptome_pls_random_gridsearch.pickle',
#  'transcriptome_xgboost_community_bayessearch101_3.pickle',
#  'functional_xgboost_random_bayessearch.pickle',
#  'functional_pls_community_gridsearch102_5.pickle',
#  'transcriptomePCA euclidean_pls_community_gridsearch102_4.pickle',
#  'euclidean functional_pls_community_gridsearch102_5.pickle',
#  'functional_xgboost_community_bayessearch101_42.pickle',
#  'functional_pls_community_gridsearch101_5.pickle',
#  'functional_ridge_random_bayessearch.pickle',
#  'euclidean_pls_community_gridsearch102_4.pickle',
#  'functional transcriptome_pls_community_gridsearch102_4.pickle',
#  'transcriptome_xgboost_community_bayessearch102_3.pickle',
#  'euclidean_pls_community_gridsearch101_0.pickle',
#  'euclidean functional transcriptome_ridge_random_gridsearch.pickle',
#  'transcriptomePCA euclidean_pls_random_gridsearch.pickle',
#  'euclidean_pls_community_gridsearch101_42.pickle',
#  'transcriptomePCA transcriptome_pls_community_gridsearch102_4.pickle',
#  'euclidean functional_pls_random_gridsearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_0.pickle',
#  'functional_pls_community_gridsearch102_4.pickle',
#  'transcriptomePCA_pls_community_gridsearch101_5.pickle',
#  'structural euclidean_pls_random_gridsearch.pickle',
#  'structural transcriptome_pls_random_gridsearch.pickle',
#  'transcriptomePCA_pls_community_gridsearch102_5.pickle',
#  'functional_pls_community_gridsearch102_0.pickle',
#  'functional_pls_community_gridsearch101_2.pickle',
#  'transcriptome_xgboost_community_bayessearch102_4.pickle',
#  'structural_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA functional_pls_community_gridsearch102_2.pickle',
#  'transcriptomePCA_xgboost_random_bayessearch.pickle']

# %%
xgboost_random_bayessearch = open_pickled_results('transcriptome transcriptomePCA euclidean_xgboost_random_bayessearch.pickle', 'SFN_runs/')

# %%
plot_single_model_predictions_with_metrics(xgboost_random_bayessearch)

# %%
xgboost_random_bayessearch = open_pickled_results('transcriptome_xgboost_random_bayessearch.pickle', 'SFN_runs/')

# %%
plot_single_model_predictions_with_metrics(xgboost_random_bayessearch)

# %%
xgboost_random_bayessearch = open_pickled_results('euclidean_xgboost_random_bayessearch.pickle', 'SFN_runs/')

# %%
plot_single_model_predictions_with_metrics(xgboost_random_bayessearch)

# %%
xgboost_random_bayessearch = open_pickled_results('transcriptome euclidean_xgboost_random_bayessearch.pickle', 'SFN_runs/')

# %%
plot_single_model_predictions_with_metrics(xgboost_random_bayessearch)

# %%
def plot_performance(feature_types, model_type='xgboost', cv_split='random', resolution='', search_type='bayes', metric='pearson_corr', 
                     display_train_test=True, sim_path=SFN_sim_path):
    """
    Iterate over each feature type, extract performance results from the pickle files,
    and generate a boxplot for performance metrics.
    
    Args:
    - feature_types: List of feature types.
    - model_type: The type of model to use (e.g., 'xgboost').
    - cv_split: The type of cross-validation split (e.g., 'random').
    - metric: The performance metric to extract (e.g., 'pearson_corr').
    - display_train_test: If True, shows both train and test metrics in the plot.
    - sim_path: Path to the saved pickle files.
    """
    data = []
    
    # Iterate over each feature type and load the corresponding results
    for feature in feature_types:
        print(f'Processing feature: {feature}')
        
        # Construct pickle file name pattern based on feature type, model type, and CV split
        pickle_file_pattern = f"{feature}_{model_type}_{cv_split}_{search_type}search{resolution}.pickle"
        
        # Check if the file exists
        if pickle_file_pattern in os.listdir(sim_path):
            # Extract the performance metrics for the train and test sets
            results = open_pickled_results(pickle_file_pattern, 'SFN_runs/')
            
            if results:
                # Iterate over each fold in the results (assuming fold results are directly stored)
                for fold_idx, fold_results in enumerate(results[0]):
                    #print(fold_idx)
                    #print(fold_results)

                    # Optionally include train metrics
                    if display_train_test:
                        train_score = fold_results['train_metrics'][metric]
                        data.append({'Feature Type': feature, 'Metric': metric, 'Fold': fold_idx, 
                                     'Score': train_score, 'Set': 'Train'})
                    # Extract test metrics
                    test_score = fold_results['test_metrics'][metric]
                    data.append({'Feature Type': feature, 'Metric': metric, 'Fold': fold_idx, 
                                 'Score': test_score, 'Set': 'Test'})
                    
                    
        else:
            print(f"Pickle file not found for feature: {feature}")

    # Convert to DataFrame for easy plotting with seaborn
    import pandas as pd
    results_df = pd.DataFrame(data)
    
    # Plot the results using seaborn
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Feature Type', y='Score', hue='Set', data=results_df)
    sns.swarmplot(x='Feature Type', y='Score', hue='Set', data=results_df, dodge=True, color=".25", size=5)
    
    plt.title(f'Performance Comparison of {model_type} ({cv_split} CV) on {metric}')
    plt.ylabel(f'{metric.capitalize()} Score')
    #plt.ylim(0, 0.8)
    plt.xticks(rotation=45)
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()

# %%
# Example usage
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean']

# Run the function to generate the plot for 'pearson_corr'
plot_performance(feature_types, model_type='xgboost', cv_split='random', metric='pearson_corr', display_train_test=False)
# Out:
# Processing feature: transcriptome
# Processing feature: transcriptomePCA
# Processing feature: structural
# Processing feature: euclidean

# %%
# Example usage
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean']

# Run the function to generate the plot for 'pearson_corr'
plot_performance(feature_types, model_type='pls', cv_split='random', metric='pearson_corr', search_type='grid', display_train_test=False)
# Out:
# Processing feature: transcriptome
# Processing feature: transcriptomePCA
# Processing feature: structural
# Processing feature: euclidean

# %%
# Example usage
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean']

# Run the function to generate the plot for 'pearson_corr'
plot_performance(feature_types, model_type='ridge', cv_split='random', metric='pearson_corr', display_train_test=False)
# Out:
# Processing feature: transcriptome
# Pickle file not found for feature: transcriptome
# Processing feature: transcriptomePCA
# Processing feature: structural
# Processing feature: euclidean

# %%
# Example usage
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean']

# Run the function to generate the plot for 'pearson_corr'
plot_performance(feature_types, model_type='xgboost', cv_split='community', resolution='101_2', metric='pearson_corr', display_train_test=False)
# Out:
# Processing feature: transcriptome
# Processing feature: transcriptomePCA
# Processing feature: structural
# Processing feature: euclidean

# %%
# Example usage
feature_types = ['transcriptome', 'transcriptomePCA', 'structural', 'euclidean']

# Run the function to generate the plot for 'pearson_corr'
plot_performance(feature_types, model_type='pls', cv_split='community', resolution='101_2', metric='pearson_corr', search_type='grid', display_train_test=False)
# Out:
# Processing feature: transcriptome
# Processing feature: transcriptomePCA
# Processing feature: structural
# Processing feature: euclidean

# %%
pairs = list(itertools.combinations(feature_types, 2))
pairs

pair_feature_types = ['transcriptome transcriptomePCA',
                     'transcriptome structural',
                     'transcriptome euclidean',
                     'transcriptomePCA structural',
                     'transcriptomePCA euclidean',
                     'structural euclidean']

# %%
# Run the function to generate the plot for 'pearson_corr'
plot_performance(pair_feature_types, model_type='xgboost', cv_split='random', metric='pearson_corr', display_train_test=False)
# Out:
# Processing feature: transcriptome transcriptomePCA
# Processing feature: transcriptome structural
# Processing feature: transcriptome euclidean
# Processing feature: transcriptomePCA structural
# Processing feature: transcriptomePCA euclidean
# Processing feature: structural euclidean

# %%
triples = list(itertools.combinations(feature_types, 3))
triples

triple_feature_types = ['transcriptome transcriptomePCA structural',
 'transcriptome transcriptomePCA euclidean',
 'transcriptome structural euclidean',
 'transcriptomePCA structural euclidean']

# %%
plot_performance(triple_feature_types, model_type='xgboost', cv_split='random', metric='pearson_corr', display_train_test=False)
# Out:
# Processing feature: transcriptome transcriptomePCA structural
# Processing feature: transcriptome transcriptomePCA euclidean
# Processing feature: transcriptome structural euclidean
# Processing feature: transcriptomePCA structural euclidean

# %%
def create_latex_table_as_html(SFN_sim_path, feature_types, metrics=['mse', 'mae', 'r2'], model_type='xgboost', cv_type='random', display_train=False):
    """
    Create a LaTeX table embedded within an HTML structure for model performance metrics.
    
    Parameters:
        SFN_sim_path (str): Path where the pickled simulation files are stored.
        feature_types (list): List of feature types to include in the table.
        metrics (list): List of metrics to include as rows in the table (e.g., ['mse', 'mae', 'r2']).
        model_type (str): The model type to filter the pickle files (default: 'xgboost').
        cv_type (str): The cross-validation type to filter the pickle files (default: 'random').
        display_train (bool): Whether to display training performance in addition to test performance.
    
    Returns:
        None: Generates LaTeX code embedded within an HTML structure.
    """
    def open_pickled_results(file, added_dir=''):
        """
        Function to open a pickle file and return the results.
        """
        pickle_file_path = f"{SFN_sim_path}/{file}"
        with open(pickle_file_path, "rb") as file:
            pickle_results = pickle.load(file)
        return pickle_results

    results_dict = {metric: {feature: [] for feature in feature_types} for metric in metrics}
    
    # Iterate over the feature types and open the corresponding pickle files
    for feature in feature_types:
        pickle_file = f"{feature}_{model_type}_{cv_type}_bayessearch.pickle"
        
        try:
            results = open_pickled_results(pickle_file, 'SFN_runs/')
            for fold in results[0]:
                for metric in metrics:
                    if display_train:
                        results_dict[metric][feature].append(fold['train_metrics'][metric])
                    else:
                        results_dict[metric][feature].append(fold['test_metrics'][metric])
        except FileNotFoundError:
            print(f"File not found: {pickle_file}")
            continue
    
    # Create the LaTeX table within an HTML structure
    html_table = '<table>\n<tr>\n'
    
    # Create table headers (metrics)
    html_table += '<th>Metric</th>' + ''.join([f'<th>{feature}</th>' for feature in feature_types]) + '\n</tr>\n'
    
    # Fill in the data for each metric
    for metric in metrics:
        html_table += '<tr>\n<td>{}</td>'.format(metric)
        for feature in feature_types:
            values = np.array(results_dict[metric][feature])
            if len(values) > 0:
                mean_val = np.mean(values)
                std_val = np.std(values)
                html_table += '<td>{:.4f} $\\pm$ {:.4f}</td>'.format(mean_val, std_val)
            else:
                html_table += '<td>N/A</td>'
        html_table += '\n</tr>\n'
    
    html_table += '</table>\n'

    # Add LaTeX caption at the end
    html_table += '<p>\\caption{Model performance for each feature type using ' + model_type + ' with ' + cv_type + ' cross-validation.}</p>'
    
    # Display the HTML-embedded LaTeX table as raw text (to be copied into a Markdown cell)
    print(html_table)

# %%
create_latex_table_as_html(SFN_sim_path, feature_types, metrics, model_type='xgboost', cv_type='random', display_train=False)
# Out:
# <table>
# <tr>
# <th>Metric</th><th>transcriptome</th><th>transcriptomePCA</th><th>structural</th><th>euclidean</th><th>functional</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0204 $\pm$ 0.0029</td><td>0.0241 $\pm$ 0.0032</td><td>0.0277 $\pm$ 0.0035</td><td>0.0230 $\pm$ 0.0042</td><td>0.0052 $\pm$ 0.0004</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.6095 $\pm$ 0.0892</td><td>0.5303 $\pm$ 0.0788</td><td>0.3973 $\pm$ 0.0637</td><td>0.5557 $\pm$ 0.1224</td><td>0.9315 $\pm$ 0.0049</td>
# </tr>
# </table>
# <p>\caption{Model performance for each feature type using xgboost with random cross-validation.}</p>

# %%
create_latex_table_as_html(SFN_sim_path, pair_feature_types, metrics, model_type='xgboost', cv_type='random', display_train=False)
# Out:
# <table>
# <tr>
# <th>Metric</th><th>transcriptome transcriptomePCA</th><th>transcriptome structural</th><th>transcriptome euclidean</th><th>transcriptomePCA structural</th><th>transcriptomePCA euclidean</th><th>structural euclidean</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0204 $\pm$ 0.0028</td><td>0.0213 $\pm$ 0.0045</td><td>0.0214 $\pm$ 0.0042</td><td>0.0284 $\pm$ 0.0014</td><td>0.0221 $\pm$ 0.0025</td><td>0.0233 $\pm$ 0.0027</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.6113 $\pm$ 0.0903</td><td>0.5877 $\pm$ 0.1322</td><td>0.5891 $\pm$ 0.1202</td><td>0.3843 $\pm$ 0.0760</td><td>0.5698 $\pm$ 0.0859</td><td>0.5462 $\pm$ 0.0702</td>
# </tr>
# </table>
# <p>\caption{Model performance for each feature type using xgboost with random cross-validation.}</p>

# %%
create_latex_table_as_html(SFN_sim_path, triple_feature_types, metrics, model_type='xgboost', cv_type='random', display_train=False)
# Out:
# <table>
# <tr>
# <th>Metric</th><th>transcriptome transcriptomePCA structural</th><th>transcriptome transcriptomePCA euclidean</th><th>transcriptome structural euclidean</th><th>transcriptomePCA structural euclidean</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0210 $\pm$ 0.0021</td><td>0.0200 $\pm$ 0.0026</td><td>0.0205 $\pm$ 0.0028</td><td>0.0222 $\pm$ 0.0022</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.5979 $\pm$ 0.0761</td><td>0.6182 $\pm$ 0.0857</td><td>0.6085 $\pm$ 0.0875</td><td>0.5758 $\pm$ 0.0858</td>
# </tr>
# </table>
# <p>\caption{Model performance for each feature type using xgboost with random cross-validation.}</p>

# %% [markdown]
# #### Tables

# %% [markdown]
# <table>
# <tr>
# <th>Metric</th><th>transcriptome</th><th>transcriptomePCA</th><th>structural</th><th>euclidean</th><th>functional</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0204 $\pm$ 0.0029</td><td>0.0241 $\pm$ 0.0032</td><td>0.0277 $\pm$ 0.0035</td><td>0.0230 $\pm$ 0.0042</td><td>0.0052 $\pm$ 0.0004</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.6095 $\pm$ 0.0892</td><td>0.5303 $\pm$ 0.0788</td><td>0.3973 $\pm$ 0.0637</td><td>0.5557 $\pm$ 0.1224</td><td>0.9315 $\pm$ 0.0049</td>
# </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
# <th>Metric</th><th>transcriptome transcriptomePCA</th><th>transcriptome structural</th><th>transcriptome euclidean</th><th>transcriptomePCA structural</th><th>transcriptomePCA euclidean</th><th>structural euclidean</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0204 $\pm$ 0.0028</td><td>0.0213 $\pm$ 0.0045</td><td>0.0214 $\pm$ 0.0042</td><td>0.0284 $\pm$ 0.0014</td><td>0.0221 $\pm$ 0.0025</td><td>0.0233 $\pm$ 0.0027</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.6113 $\pm$ 0.0903</td><td>0.5877 $\pm$ 0.1322</td><td>0.5891 $\pm$ 0.1202</td><td>0.3843 $\pm$ 0.0760</td><td>0.5698 $\pm$ 0.0859</td><td>0.5462 $\pm$ 0.0702</td>
# </tr>
# </table>

# %% [markdown]
# <table>
# <tr>
# <th>Metric</th><th>transcriptome transcriptomePCA structural</th><th>transcriptome transcriptomePCA euclidean</th><th>transcriptome structural euclidean</th><th>transcriptomePCA structural euclidean</th>
# </tr>
# <tr>
# <td>mse</td><td>0.0210 $\pm$ 0.0021</td><td>0.0200 $\pm$ 0.0026</td><td>0.0205 $\pm$ 0.0028</td><td>0.0222 $\pm$ 0.0022</td>
# </tr>
# <tr>
# <td>pearson_corr</td><td>0.5979 $\pm$ 0.0761</td><td>0.6182 $\pm$ 0.0857</td><td>0.6085 $\pm$ 0.0875</td><td>0.5758 $\pm$ 0.0858</td>
# </tr>
# </table>
