# %% [markdown]
# ## SFN 24 Replication

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from imports import *
# Out:
# 2024-10-03 15:04:24.860307: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-03 15:04:26.691422: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-03 15:04:28.699039: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from models import *
from data import * 
from env import *
from harmonize import *
from metrics import * 
from sim import *
from sim import multi_sim_run
from sim import plot

# %%
# overall imports
import importlib
import data

# data load
importlib.reload(data.data_load)
from data.data_load import load_transcriptome, load_connectome
importlib.reload(data.data_load)

# data utils
from data.data_utils import (
    reconstruct_connectome,
    reconstruct_upper_triangle,
    make_symmetric,
    expand_X_symmetric,
    expand_Y_symmetric,
    expand_X_symmetric_shared,
    expand_X_Y_symmetric_conn_only,
    expand_shared_matrices,
    expand_X_symmetric_w_conn, 
    process_cv_splits, 
    process_cv_splits_conn_only_model, 
    expanded_inner_folds_combined_plus_indices
)

import data.data_utils
importlib.reload(data.data_utils)

# cross-validation classes
import data.cv_split
from data.cv_split import RandomCVSplit, SchaeferCVSplit, CommunityCVSplit, SubnetworkCVSplit
importlib.reload(data.cv_split)

# prebuilt model classes
import models.prebuilt_models
from models.prebuilt_models import ModelBuild
importlib.reload(models.prebuilt_models)

# metric classes
import metrics.distance_FC
import metrics.eval
from metrics.eval import ModelEvaluator
from metrics.eval import pearson_numpy, mse_numpy, r2_numpy, pearson_cupy, mse_cupy, r2_cupy
importlib.reload(metrics.eval)

# sim class
import sim.sim 
import sim.sim_utils
from sim.sim_utils import bytes2human, print_system_usage
import sim.multi_sim_run
from sim.sim import Simulation
from sim.multi_sim_run import multi_sim_run, single_sim_run, open_pickled_results, combine_results
importlib.reload(sim.sim)
importlib.reload(sim.sim_utils)
importlib.reload(sim.multi_sim_run)

import sim.plot
from sim.plot import (
    plot_predictions, 
    barplot_model_performance,
    boxplot_model_performance,
    plot_predictions_with_metrics,
    plot_best_params_table, plot_best_parameters_table_colored, 
    violin_plot_model_performance, 
    plot_transcriptome_performance_bar, plot_connectome_performance_bar, 
    plot_combined_performance_bar
)

importlib.reload(sim.plot)
# Out:
# <module 'sim.plot' from '/scratch/asr655/neuroinformatics/GeneEx2Conn/sim/plot.py'>

# %% [markdown]
# #### Check job specs

# %%
print_system_usage()

total = psutil.disk_usage('/').total
print(bytes2human(total))

GPUtil.getGPUs()

DEVICE_ID_LIST = GPUtil.getFirstAvailable()
DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
if DEVICE_ID != None: 
    print('GPU found', DEVICE_ID)
    use_gpu = True

print("XGBoost version:", xgboost.__version__)
print("cupy version:", cp.__version__)

GPUtil.showUtilization()
# Out:
# CPU Usage: 13.7%
# RAM Usage: 11.1%
# Available RAM: 335.1G
# Total RAM: 377.1G
# 52.4G
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 8
#       4 print(bytes2human(total))
#       6 GPUtil.getGPUs()
# ----> 8 DEVICE_ID_LIST = GPUtil.getFirstAvailable()
#       9 DEVICE_ID = DEVICE_ID_LIST[0] # grab first element from list
#      10 if DEVICE_ID != None:
#
# File /ext3/miniconda3/lib/python3.11/site-packages/GPUtil/GPUtil.py:203, in getFirstAvailable(order, maxLoad, maxMemory, attempts, interval, verbose, includeNan, excludeID, excludeUUID)
#     201 # Check if an GPU was found, or if the attempts simply ran out. Throw error, if no GPU was found
#     202 if (not(available)):
# --> 203     raise RuntimeError('Could not find an available GPU after ' + str(attempts) + ' attempts with ' + str(interval) + ' seconds interval.')
#     205 # Return found GPU
#     206 return available
#
# RuntimeError: Could not find an available GPU after 1 attempts with 900 seconds interval.

# %% [markdown]
# ## Table of Contents
# - [Multidataset PLS](#PLS)
#     - [AHBA+HCP](#AHBA)
#     - [GTEx+HCP](#GTEx)
#     - [UTSW+HCP](#UTSW)
# - [AHBA+HCP](#AHBA)
#     - [Bilinear PLS](#PLS-Sims)
#       - [Random Splits](#PLS-Random-Splits)
#     - [XGBoost](#XGBoost-Sims)
#       - [Random Splits](#XGBoost-Random-Splits)

# %% [markdown]
# ### Multidataset PLS

# %% [markdown]
# #### AHBA

# %%
X = load_transcriptome(dataset='AHBA')
Y = load_connectome(dataset='AHBA')

# %%
def fit_pls(X, Y, n_components):
    """Fit PLS model with specified number of components and return variance explained."""
    pls = PLSRegression(n_components=n_components)
    pls.fit(X, Y)

    # Predict on the training set
    Y_pred = pls.predict(X)

    # Calculate R² (variance explained) on the training set
    variance_explained = r2_score(Y, Y_pred)

    return pls, variance_explained

# %%
def run_pls_for_components(X, Y, max_components=20):
    """Fit PLS for multiple components and gather variance explained."""
    variances_explained = []

    # Fit PLS for each number of components
    for n_components in range(1, max_components + 1):
        _, variance_explained = fit_pls(X, Y, n_components)
        variances_explained.append(variance_explained)
        print(f"Components: {n_components}, Variance explained: {variance_explained}")

    return variances_explained

# %%
def plot_variance_explained(variances_explained, max_components=20):
    """Plot number of components vs variance explained."""
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, max_components + 1), variances_explained, label='Variance Explained (R²)', marker='o')
    plt.xlabel('Number of Components')
    plt.ylabel('Variance Explained (R²)')
    plt.title('Number of Components vs Variance Explained')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def load_ahba_gene_names(file_name='allgenes_stable_r0.2_schaefer_100.csv'):
    """
    Load gene names from a CSV file.
    
    Parameters:
    file_name (str): The CSV file name containing gene names.
    
    Returns:
    np.ndarray: Array of gene names.
    """
    relative_data_path = os.path.normpath(os.getcwd() + os.sep + os.pardir)    
    gene_file_path = os.path.join(relative_data_path, 'GeneEx2Conn/data', 'enigma', file_name)
    
    schaefer114_genes = pd.read_csv(gene_file_path)
    schaefer114_genes.set_index('label', inplace=True)
    gene_names = np.array(schaefer114_genes.columns.tolist())
    
    print(f'Loaded {len(gene_names)} gene names.')
    return gene_names

def load_gtex_gene_names(file_name='RxG_data_gtex_mean_gtex_ahba_space.csv'):
    relative_data_path = os.path.normpath(os.getcwd() + os.sep + os.pardir)    
    gene_file_path = os.path.join(relative_data_path, 'data/region_map_pickles', file_name)
    
    schaefer114_genes = pd.read_csv(gene_file_path)
    schaefer114_genes.set_index('region', inplace=True)
    gene_names = np.array(schaefer114_genes.columns.tolist())
    
    print(f'Loaded {len(gene_names)} gene names.')
    return gene_names

def load_utsw_gene_names(file_name='RxG_data_utsmc_mean_ahba_utsmc_space.csv'):
    relative_data_path = os.path.normpath(os.getcwd() + os.sep + os.pardir)    
    gene_file_path = os.path.join(relative_data_path, 'data/region_map_pickles', file_name)
    
    schaefer114_genes = pd.read_csv(gene_file_path)
    schaefer114_genes.set_index('region', inplace=True)
    gene_names = np.array(schaefer114_genes.columns.tolist())
    
    print(f'Loaded {len(gene_names)} gene names.')
    return gene_names
import pandas as pd
from sklearn.cross_decomposition import PLSRegression

def get_feature_importances(X, Y, n_components=3, gene_names=None):
    """
    Fit PLS and return a DataFrame of gene weights for the first n components.
    
    Parameters:
    X (ndarray): The transcriptome data (samples x genes).
    Y (ndarray): The connectome data (samples x regions).
    n_components (int): Number of components to extract from PLS.
    gene_names (list or ndarray): List or array of gene names corresponding to X's columns.
    
    Returns:
    pd.DataFrame: A DataFrame of gene weights (rows: genes, columns: components).
    """
    # Fit PLS model
    pls = PLSRegression(n_components=n_components)
    pls.fit(X, Y)

    # Get weights for the first n components
    weights = pls.x_weights_[:, :n_components]

    # If no gene names are provided, default to numeric indices
    if gene_names is None:
        gene_names = np.arange(0, X.shape[1], 1)

    # Create a DataFrame of feature importances (genes by component weights)
    feature_importances_df = pd.DataFrame(weights, index=gene_names, columns=[f'Component_{i+1}' for i in range(n_components)])
    
    return feature_importances_df

    
def normalize_components(df):
    """Normalize each component column to have values between 0 and 1."""
    normalized_df = df.copy()
    
    for column in normalized_df.columns:
        min_val = normalized_df[column].min()
        max_val = normalized_df[column].max()
        
        # Normalize to the range [0, 1]
        normalized_df[column] = (normalized_df[column] - min_val) / (max_val - min_val)
    
    return normalized_df

# %%
load_ahba_gene_names()
# Out:
# Loaded 11053 gene names.
# array(['A1BG', 'A1BG-AS1', 'AAAS', ..., 'ZYX', 'ZZEF1', 'ZZZ3'],
#       dtype='<U21')

# %%
load_gtex_gene_names()
# Out:
# Loaded 10704 gene names.
# array(['TUBG2', 'NUDCD3', 'PTPN12', ..., 'DUSP3', 'CCDC120', 'NT5C2'],
#       dtype='<U18')

# %%
load_utsw_gene_names()
# Out:
# Loaded 10005 gene names.
# array(['RABGGTA', 'CLDN5', 'MED8', ..., 'NKAIN2', 'EML6', 'CMTM8'],
#       dtype='<U16')

# %%
def compute_gene_name_intersection():
    """Compute the intersection of gene names from AHBA, GTEx, and UTSW datasets."""
    
    # Load gene names from each dataset
    ahba_gene_names = load_ahba_gene_names()
    gtex_gene_names = load_gtex_gene_names()
    utsw_gene_names = load_utsw_gene_names()
    
    # Convert to sets for easy intersection
    ahba_set = set(ahba_gene_names)
    gtex_set = set(gtex_gene_names)
    utsw_set = set(utsw_gene_names)
    
    # Compute the intersection of the three sets
    intersected_genes = ahba_set.intersection(gtex_set, utsw_set)
    
    print(f"Number of intersected genes: {len(intersected_genes)}")
    
    # Convert the result back to a sorted list or array
    intersected_gene_names = sorted(intersected_genes)
    
    return intersected_gene_names

# Example of using the function:
intersected_genes = compute_gene_name_intersection()
# Out:
# Loaded 11053 gene names.
# Loaded 10704 gene names.
# Loaded 10005 gene names.
# Number of intersected genes: 9888

# %%
# Step 1: Load the data
X = load_transcriptome(dataset='AHBA')
Y = load_connectome(dataset='AHBA')

# Step 2: Run PLS for multiple components and get variance explained
max_components = 10
variances_explained = run_pls_for_components(X, Y, max_components)

# Step 3: Plot the number of components vs variance explained
plot_variance_explained(variances_explained, max_components)

ahba_feature_importances_df = get_feature_importances(X, Y, n_components=3, gene_names=load_ahba_gene_names())
ahba_normalized_importances_df = normalize_components(ahba_feature_importances_df)
# Out:
# Components: 1, Variance explained: 0.17269528617251495
# Components: 2, Variance explained: 0.2382253906932577
# Components: 3, Variance explained: 0.2893838391109028
# Components: 4, Variance explained: 0.36001005091476046
# Components: 5, Variance explained: 0.3894282517782608
# Components: 6, Variance explained: 0.4194429962282351
# Components: 7, Variance explained: 0.4512820187322228
# Components: 8, Variance explained: 0.47556418904104125
# Components: 9, Variance explained: 0.5195969847997496
# Components: 10, Variance explained: 0.5577210134082744
# Loaded 11053 gene names.

# %%
ahba_feature_importances_df
# Out:
#           Component_1  Component_2  Component_3
# A1BG        -0.010853     0.010779     0.008289
# A1BG-AS1     0.011132     0.008183     0.011174
# AAAS         0.008836    -0.009938     0.000574
# AACS         0.013549     0.006949     0.002022
# AADAT        0.008383    -0.001006     0.011122
# ...               ...          ...          ...
# ZXDC        -0.011107    -0.005067    -0.004756
# ZYG11B       0.013243     0.005303     0.005364
# ZYX          0.015577    -0.004292    -0.002192
# ZZEF1        0.006778    -0.022955     0.003380
# ZZZ3        -0.010867     0.005505     0.000642
#
# [11053 rows x 3 columns]

# %% [markdown]
# #### GTEx

# %%
X = load_transcriptome(dataset='GTEx')
Y = load_connectome(dataset='GTEx')

# Step 2: Run PLS for multiple components and get variance explained
max_components = 10
variances_explained = run_pls_for_components(X, Y, max_components)

# Step 3: Plot the number of components vs variance explained
plot_variance_explained(variances_explained, max_components)

gtex_feature_importances_df = get_feature_importances(X, Y, n_components=3, gene_names=load_gtex_gene_names())
gtex_normalized_importances_df = normalize_components(gtex_feature_importances_df)
# Out:
# Components: 1, Variance explained: 0.13696402626343804
# Components: 2, Variance explained: 0.3299616450870909
# Components: 3, Variance explained: 0.4321768911529551
# Components: 4, Variance explained: 0.565359354539021
# Components: 5, Variance explained: 0.7036924398359168
# Components: 6, Variance explained: 0.8691477479821343
# Components: 7, Variance explained: 1.0
# Components: 8, Variance explained: 1.0
# Components: 9, Variance explained: 1.0
# Components: 10, Variance explained: 1.0
# Loaded 10704 gene names.

# %%
gtex_feature_importances_df
# Out:
#            Component_1  Component_2  Component_3
# TUBG2         0.011459     0.001647     0.008237
# NUDCD3        0.011851    -0.002469    -0.002825
# PTPN12        0.011284    -0.012088    -0.000845
# TMEM87A      -0.004238    -0.017873    -0.011441
# DPP10-AS1     0.011630     0.004457     0.004691
# ...                ...          ...          ...
# B4GALT5       0.013567    -0.000041    -0.002555
# CRIP2         0.010576     0.011370     0.002650
# DUSP3         0.012433     0.001158     0.006054
# CCDC120       0.008681     0.013625     0.003696
# NT5C2         0.010384     0.004854    -0.014697
#
# [10704 rows x 3 columns]

# %% [markdown]
# #### UTSW

# %%
X = load_transcriptome(dataset='UTSW')
Y = load_connectome(dataset='UTSW')

# Step 2: Run PLS for multiple components and get variance explained
max_components = 10
variances_explained = run_pls_for_components(X, Y, max_components)

# Step 3: Plot the number of components vs variance explained
plot_variance_explained(variances_explained, max_components)

utsw_feature_importances_df = get_feature_importances(X, Y, n_components=3, gene_names=load_utsw_gene_names())
utsw_normalized_importances_df = normalize_components(utsw_feature_importances_df)
# Out:
# Components: 1, Variance explained: 0.14416221888628505
# Components: 2, Variance explained: 0.2609250598681544
# Components: 3, Variance explained: 0.37723598294978933
# Components: 4, Variance explained: 0.5176886615079771
# Components: 5, Variance explained: 0.6500272446030027
# Components: 6, Variance explained: 0.7525941375253418
# Components: 7, Variance explained: 0.87189800296156
# Components: 8, Variance explained: 0.961949087518129
# Components: 9, Variance explained: 0.9999999517062186
# Components: 10, Variance explained: 1.0
# Loaded 10005 gene names.

# %%
utsw_feature_importances_df
# Out:
#          Component_1  Component_2  Component_3
# RABGGTA     0.014430    -0.008812     0.002349
# CLDN5      -0.009901     0.009492    -0.010605
# MED8        0.002003     0.003133    -0.003404
# CALHM6      0.010912     0.007263     0.017946
# AFF2       -0.001145    -0.000315    -0.016722
# ...              ...          ...          ...
# ZBTB18      0.009447     0.000673     0.020541
# NAGLU      -0.015241     0.004246     0.002151
# NKAIN2      0.001257     0.001369     0.017613
# EML6        0.006124    -0.006054     0.010777
# CMTM8      -0.013668    -0.009782     0.006555
#
# [10005 rows x 3 columns]

# %% [markdown]
# #### Evaluate PLS similarity across datasets

# %%
# PLS ANALYSIS HELPER FUNCS
def filter_and_sort_by_genes(df, intersected_genes):
    """
    Filter the DataFrame to include only intersecting genes and sort alphabetically.
    
    Parameters:
    df (pd.DataFrame): The feature importance DataFrame.
    intersected_genes (list or ndarray): List or array of intersecting gene names.
    
    Returns:
    pd.DataFrame: Filtered and sorted DataFrame.
    """
    # Filter the DataFrame to include only the intersecting genes
    filtered_df = df.loc[intersected_genes]

    # Sort the DataFrame alphabetically by gene names
    filtered_df = filtered_df.sort_index()

    return filtered_df

from scipy.stats import spearmanr, pearsonr, kendalltau

def compute_correlation(df1, df2, correlation_type='spearman', use_abs=False):
    """
    Compute the correlation matrix between the components of two DataFrames.
    
    Parameters:
    df1 (pd.DataFrame): The first DataFrame (e.g., AHBA feature importance).
    df2 (pd.DataFrame): The second DataFrame (e.g., GTEx or UTSW feature importance).
    correlation_type (str): The type of correlation to use ('spearman', 'pearson', 'kendall').
    use_abs (bool): Whether to use the absolute values of the weights for correlation.
    
    Returns:
    pd.DataFrame: A correlation matrix (components from df1 vs df2).
    """
    # Optionally take the absolute values of the weights
    if use_abs:
        df1 = df1.abs()
        df2 = df2.abs()

    # Initialize an empty correlation matrix
    n_components_df1 = df1.shape[1]
    n_components_df2 = df2.shape[1]
    correlation_matrix = np.zeros((n_components_df1, n_components_df2))

    # Choose the correlation function
    def get_correlation_func(correlation_type):
        if correlation_type == 'spearman':
            return spearmanr
        elif correlation_type == 'pearson':
            return pearsonr
        elif correlation_type == 'kendall':
            return kendalltau
        else:
            raise ValueError("Invalid correlation type. Choose 'spearman', 'pearson', or 'kendall'.")

    correlation_func = get_correlation_func(correlation_type)

    # Compute correlation between each pair of components
    for i in range(n_components_df1):
        for j in range(n_components_df2):
            # Correlation between df1 component i and df2 component j
            corr, _ = correlation_func(df1.iloc[:, i], df2.iloc[:, j])
            correlation_matrix[i, j] = corr

    # Convert to DataFrame for easier handling and labeling
    correlation_df = pd.DataFrame(correlation_matrix, 
                                  index=[f'{df1.columns[i]}' for i in range(n_components_df1)], 
                                  columns=[f'{df2.columns[j]}' for j in range(n_components_df2)])

    return correlation_df
    
def compute_correlation_with_labels(df1, df2, dataset1_name='AHBA', dataset2_name='GTEx', correlation_type='spearman', use_abs=False):
    """
    Compute the correlation matrix between the components of two DataFrames and label axes with dataset names.

    Parameters:
    df1 (pd.DataFrame): The first DataFrame (e.g., AHBA feature importance).
    df2 (pd.DataFrame): The second DataFrame (e.g., GTEx feature importance).
    dataset1_name (str): The name of the first dataset (for axis labeling).
    dataset2_name (str): The name of the second dataset (for axis labeling).
    correlation_type (str): The type of correlation to use ('spearman', 'pearson', 'kendall').
    use_abs (bool): Whether to use the absolute values of the weights for correlation.

    Returns:
    pd.DataFrame: A correlation matrix (components from df1 vs df2) with labeled axes.
    """
    # Optionally take the absolute values of the weights
    if use_abs:
        df1 = df1.abs()
        df2 = df2.abs()

    # Initialize an empty correlation matrix
    n_components_df1 = df1.shape[1]
    n_components_df2 = df2.shape[1]
    correlation_matrix = np.zeros((n_components_df1, n_components_df2))

    # Choose the correlation function
    def get_correlation_func(correlation_type):
        if correlation_type == 'spearman':
            return spearmanr
        elif correlation_type == 'pearson':
            return pearsonr
        elif correlation_type == 'kendall':
            return kendalltau
        else:
            raise ValueError("Invalid correlation type. Choose 'spearman', 'pearson', or 'kendall'.")

    correlation_func = get_correlation_func(correlation_type)

    # Compute correlation between each pair of components
    for i in range(n_components_df1):
        for j in range(n_components_df2):
            # Correlation between df1 component i and df2 component j
            corr, _ = correlation_func(df1.iloc[:, i], df2.iloc[:, j])
            correlation_matrix[i, j] = corr

    # Add dataset-specific labels to the rows and columns
    df1_labels = [f'{dataset1_name}_Component_{i+1}' for i in range(n_components_df1)]
    df2_labels = [f'{dataset2_name}_Component_{i+1}' for i in range(n_components_df2)]

    # Convert to DataFrame for easier handling and labeling
    correlation_df = pd.DataFrame(correlation_matrix, index=df1_labels, columns=df2_labels)

    return correlation_df

def compute_correlation_with_pvalues(df1, df2, dataset1_name='AHBA', dataset2_name='GTEx', correlation_type='spearman', use_abs=False):
    """
    Compute the correlation matrix and p-values between the components of two DataFrames and label axes with dataset names.

    Parameters:
    df1 (pd.DataFrame): The first DataFrame (e.g., AHBA feature importance).
    df2 (pd.DataFrame): The second DataFrame (e.g., GTEx feature importance).
    dataset1_name (str): The name of the first dataset (for axis labeling).
    dataset2_name (str): The name of the second dataset (for axis labeling).
    correlation_type (str): The type of correlation to use ('spearman', 'pearson', 'kendall').
    use_abs (bool): Whether to use the absolute values of the weights for correlation.

    Returns:
    pd.DataFrame: A p-value matrix (components from df1 vs df2) with labeled axes.
    """
    # Optionally take the absolute values of the weights
    if use_abs:
        df1 = df1.abs()
        df2 = df2.abs()

    # Initialize an empty p-value matrix
    n_components_df1 = df1.shape[1]
    n_components_df2 = df2.shape[1]
    pvalue_matrix = np.zeros((n_components_df1, n_components_df2))

    # Choose the correlation function
    def get_correlation_func(correlation_type):
        if correlation_type == 'spearman':
            return spearmanr
        elif correlation_type == 'pearson':
            return pearsonr
        elif correlation_type == 'kendall':
            return kendalltau
        else:
            raise ValueError("Invalid correlation type. Choose 'spearman', 'pearson', or 'kendall'.")

    correlation_func = get_correlation_func(correlation_type)

    # Compute correlation and p-values between each pair of components
    for i in range(n_components_df1):
        for j in range(n_components_df2):
            _, p_value = correlation_func(df1.iloc[:, i], df2.iloc[:, j])
            pvalue_matrix[i, j] = p_value

    # Add dataset-specific labels to the rows and columns
    df1_labels = [f'{dataset1_name}_Component_{i+1}' for i in range(n_components_df1)]
    df2_labels = [f'{dataset2_name}_Component_{i+1}' for i in range(n_components_df2)]

    # Convert to DataFrame for easier handling and labeling
    pvalue_df = pd.DataFrame(pvalue_matrix, index=df1_labels, columns=df2_labels)

    return pvalue_df


def compute_correlation_across_datasets(ahba_df, gtex_df, utsw_df, correlation_type='spearman', use_abs=False):
    """
    Compute the correlation matrix for components across AHBA, GTEx, and UTSW datasets.
    
    Parameters:
    ahba_df (pd.DataFrame): AHBA feature importance DataFrame.
    gtex_df (pd.DataFrame): GTEx feature importance DataFrame.
    utsw_df (pd.DataFrame): UTSW feature importance DataFrame.
    correlation_type (str): The type of correlation to use ('spearman', 'pearson', 'kendall').
    use_abs (bool): Whether to use absolute values of the weights for correlation.
    
    Returns:
    pd.DataFrame: A 9x9 correlation matrix (components from AHBA, GTEx, and UTSW).
    """
    # Optionally take the absolute values of the weights
    if use_abs:
        ahba_df = ahba_df.abs()
        gtex_df = gtex_df.abs()
        utsw_df = utsw_df.abs()

    # Combine all components from the three datasets into one DataFrame
    combined_df = pd.concat([ahba_df, gtex_df, utsw_df], axis=1)

    # Create labels for combined components
    component_labels = ([f'AHBA_Component_{i+1}' for i in range(ahba_df.shape[1])] +
                        [f'GTEx_Component_{i+1}' for i in range(gtex_df.shape[1])] +
                        [f'UTSW_Component_{i+1}' for i in range(utsw_df.shape[1])])

    # Initialize an empty 9x9 correlation matrix
    correlation_matrix = np.zeros((9, 9))

    # Choose the correlation function
    def get_correlation_func(correlation_type):
        if correlation_type == 'spearman':
            return spearmanr
        elif correlation_type == 'pearson':
            return pearsonr
        elif correlation_type == 'kendall':
            return kendalltau
        else:
            raise ValueError("Invalid correlation type. Choose 'spearman', 'pearson', or 'kendall'.")

    correlation_func = get_correlation_func(correlation_type)

    # Compute correlation between each pair of components across datasets
    for i in range(9):
        for j in range(9):
            # Correlation between component i and component j
            corr, _ = correlation_func(combined_df.iloc[:, i], combined_df.iloc[:, j])
            correlation_matrix[i, j] = corr

    # Convert to DataFrame with proper labels
    correlation_df = pd.DataFrame(correlation_matrix, 
                                  index=component_labels, 
                                  columns=component_labels)
    
    return correlation_df

def compute_correlation_pvalues_across_datasets(ahba_df, gtex_df, utsw_df, correlation_type='spearman', use_abs=False):
    """
    Compute the p-value matrix for correlations between components across AHBA, GTEx, and UTSW datasets.
    
    Parameters:
    ahba_df (pd.DataFrame): AHBA feature importance DataFrame.
    gtex_df (pd.DataFrame): GTEx feature importance DataFrame.
    utsw_df (pd.DataFrame): UTSW feature importance DataFrame.
    correlation_type (str): The type of correlation to use ('spearman', 'pearson', 'kendall').
    use_abs (bool): Whether to use the absolute values of the weights for correlation.
    
    Returns:
    pd.DataFrame: A 9x9 p-value matrix (components from AHBA, GTEx, and UTSW).
    """
    # Optionally take the absolute values of the weights
    if use_abs:
        ahba_df = ahba_df.abs()
        gtex_df = gtex_df.abs()
        utsw_df = utsw_df.abs()

    # Combine all components from the three datasets into one DataFrame
    combined_df = pd.concat([ahba_df, gtex_df, utsw_df], axis=1)

    # Create labels for combined components
    component_labels = ([f'AHBA_Component_{i+1}' for i in range(ahba_df.shape[1])] +
                        [f'GTEx_Component_{i+1}' for i in range(gtex_df.shape[1])] +
                        [f'UTSW_Component_{i+1}' for i in range(utsw_df.shape[1])])

    # Initialize an empty 9x9 p-value matrix
    pvalue_matrix = np.zeros((9, 9))

    # Choose the correlation function
    def get_correlation_func(correlation_type):
        if correlation_type == 'spearman':
            return spearmanr
        elif correlation_type == 'pearson':
            return pearsonr
        elif correlation_type == 'kendall':
            return kendalltau
        else:
            raise ValueError("Invalid correlation type. Choose 'spearman', 'pearson', or 'kendall'.")

    correlation_func = get_correlation_func(correlation_type)

    # Compute p-values between each pair of components across datasets
    for i in range(9):
        for j in range(9):
            # Correlation and p-value between component i and component j
            _, p_value = correlation_func(combined_df.iloc[:, i], combined_df.iloc[:, j])
            pvalue_matrix[i, j] = p_value

    # Convert to DataFrame with proper labels
    pvalue_df = pd.DataFrame(pvalue_matrix, 
                             index=component_labels, 
                             columns=component_labels)
    
    return pvalue_df

from statsmodels.stats.multitest import multipletests

def apply_benjamini_hochberg_correction(p_values_df):
    """
    Apply Benjamini-Hochberg correction (FDR) to a DataFrame of p-values.
    
    Parameters:
    p_values_df (pd.DataFrame): DataFrame containing p-values.
    
    Returns:
    pd.DataFrame: DataFrame with FDR-adjusted p-values.
    """
    # Flatten the p-values into a 1D array
    p_values = p_values_df.values.flatten()

    # Apply the Benjamini-Hochberg correction
    _, corrected_p_values, _, _ = multipletests(p_values, method='fdr_bh')

    # Reshape corrected p-values back into the original DataFrame format
    corrected_p_values_df = pd.DataFrame(corrected_p_values.reshape(p_values_df.shape),
                                         index=p_values_df.index,
                                         columns=p_values_df.columns)
    
    return corrected_p_values_df

from statsmodels.stats.multitest import multipletests

def apply_bonferroni_correction(p_values_df):
    """
    Apply Bonferroni correction to a DataFrame of p-values.
    
    Parameters:
    p_values_df (pd.DataFrame): DataFrame containing p-values.
    
    Returns:
    pd.DataFrame: DataFrame with Bonferroni-adjusted p-values.
    """
    # Flatten the p-values into a 1D array
    p_values = p_values_df.values.flatten()

    # Apply the Bonferroni correction
    _, corrected_p_values, _, _ = multipletests(p_values, method='bonferroni')

    # Reshape corrected p-values back into the original DataFrame format
    corrected_p_values_df = pd.DataFrame(corrected_p_values.reshape(p_values_df.shape),
                                         index=p_values_df.index,
                                         columns=p_values_df.columns)
    
    return corrected_p_values_df

def plot_correlation_heatmap(correlation_df, title='Correlation Heatmap'):
    """
    Plot a heatmap for the correlation matrix.
    
    Parameters:
    correlation_df (pd.DataFrame): The correlation matrix.
    title (str): The title for the heatmap.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_df, annot=True, cmap='coolwarm', vmin=-1, vmax=1, annot_kws={"fontsize": 12})
    plt.title(title)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

def plot_pvalue_heatmap(pvalue_df, title='P-value Heatmap'):
    """
    Plot a heatmap for the p-value matrix.
    
    Parameters:
    pvalue_df (pd.DataFrame): The p-value matrix.
    title (str): The title for the heatmap.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(pvalue_df, annot=True, cmap='viridis', vmin=0, vmax=0.05, 
                cbar_kws={'label': 'P-value'}, annot_kws={"fontsize": 8})
    plt.title(title)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

def get_top_n_values_per_column(df, n=5):
    """
    Get the top N absolute values for each column in the DataFrame and return the 
    corresponding gene names and values for each component.

    Parameters:
    df (pd.DataFrame): The DataFrame containing component weights (e.g., utsw_feature_importances_df).
    n (int): The number of top values to return for each column.

    Returns:
    dict: A dictionary where each component is a key, and the value is a DataFrame of 
          gene names and corresponding top N values.
    """
    top_n_dict = {}

    for col in df.columns:
        # Sort by absolute values and get the top N values for each column separately
        top_n = df[col].abs().nlargest(n)

        # Store the gene names (index) and their corresponding values in a DataFrame
        top_n_df = pd.DataFrame({
            'Gene': df.loc[top_n.index].index,
            'Value': df.loc[top_n.index, col]
        })

        # Store in the dictionary
        top_n_dict[col] = top_n_df

    return top_n_dict

# %% [markdown]
# ##### Recompute PLS for AHBA subset into GTEx and UTSW space

# %%
X = load_transcriptome(dataset='AHBA in GTEx')
Y = load_connectome(dataset='GTEx')

# %%
# Increase figure size for better resolution
plt.figure(figsize=(10, 10))  # Increase width and height

# Plot the data
plt.imshow(X, aspect=400)

# Save with high DPI
plt.savefig('ahbagtex_image_large.png', dpi=600)

# Show the plot
plt.show()

# %%
# Increase figure size for better resolution
plt.figure(figsize=(10, 10))  # Increase width and height

# Plot the data
plt.imshow(load_transcriptome(dataset='GTEx'), aspect=400)

# Save with high DPI
plt.savefig('gtex_image_large.png', dpi=600)

# Show the plot
plt.show()

# %%
# Step 2: Run PLS for multiple components and get variance explained
max_components = 10
variances_explained = run_pls_for_components(X, Y, max_components)

# Step 3: Plot the number of components vs variance explained
plot_variance_explained(variances_explained, max_components)

ahba_in_gtex_feature_importances_df = get_feature_importances(X, Y, n_components=3, gene_names=load_gtex_gene_names())
ahba_in_gtex_normalized_importances_df = normalize_components(ahba_in_gtex_feature_importances_df)
# Out:
# Components: 1, Variance explained: 0.15269521195990893
# Components: 2, Variance explained: 0.30090282331476964
# Components: 3, Variance explained: 0.4753113504740173
# Components: 4, Variance explained: 0.6873425068544686
# Components: 5, Variance explained: 0.7564531058252135
# Components: 6, Variance explained: 0.9190106735718288
# Components: 7, Variance explained: 1.0
# Components: 8, Variance explained: 1.0
# Components: 9, Variance explained: 1.0
# Components: 10, Variance explained: 1.0
# Loaded 10704 gene names.

# %%
X = load_transcriptome(dataset='AHBA in UTSW')
Y = load_connectome(dataset='UTSW')

# %%
# Increase figure size for better resolution
plt.figure(figsize=(10, 10))  # Increase width and height

# Plot the data
plt.imshow(X, aspect = 400)

# Save with high DPI
plt.savefig('ahbaut_image_large.png', dpi=600)

# Show the plot
plt.show()

# %%
# Increase figure size for better resolution
plt.figure(figsize=(10, 10))  # Increase width and height

plt.imshow(load_transcriptome(dataset='UTSW'), aspect=400)

# Save with high DPI
plt.savefig('ut_image_large.png', dpi=600)

# Show the plot
plt.show()

# %%
X = load_transcriptome(dataset='AHBA in UTSW')
Y = load_connectome(dataset='UTSW')

# Step 2: Run PLS for multiple components and get variance explained
max_components = 10
variances_explained = run_pls_for_components(X, Y, max_components)

# Step 3: Plot the number of components vs variance explained
plot_variance_explained(variances_explained, max_components)

ahba_in_utsw_feature_importances_df = get_feature_importances(X, Y, n_components=3, gene_names=load_utsw_gene_names())
ahba_in_utsw_normalized_importances_df = normalize_components(ahba_in_utsw_feature_importances_df)
# Out:
# /scratch/asr655/neuroinformatics
# Components: 1, Variance explained: 0.09470952853569295
# Components: 2, Variance explained: 0.2101488569849384
# Components: 3, Variance explained: 0.33621413935892447
# Components: 4, Variance explained: 0.42974945159073563
# Components: 5, Variance explained: 0.5338600536190977
# Components: 6, Variance explained: 0.6689878876270858
# Components: 7, Variance explained: 0.7886321413690143
# Components: 8, Variance explained: 0.9026192275142881
# Components: 9, Variance explained: 1.0
# Components: 10, Variance explained: 1.0
# Loaded 10005 gene names.

# %% [markdown]
# #### Analysis of subsampled components

# %%
# Step 1: Compute the intersected gene names
intersected_genes = compute_gene_name_intersection()

# Step 2: Filter and sort the feature importance DataFrames
ahba_in_gtex_filtered_sorted_df = filter_and_sort_by_genes(ahba_in_gtex_feature_importances_df, intersected_genes)
gtex_filtered_sorted_df = filter_and_sort_by_genes(gtex_feature_importances_df, intersected_genes)
ahba_in_utsw_filtered_sorted_df = filter_and_sort_by_genes(ahba_in_utsw_feature_importances_df, intersected_genes)
utsw_filtered_sorted_df = filter_and_sort_by_genes(utsw_feature_importances_df, intersected_genes)

# Step 3: Display the results (or save them)
print(ahba_in_gtex_filtered_sorted_df.head())
print(gtex_filtered_sorted_df.head())
print(ahba_in_utsw_filtered_sorted_df.head())
print(utsw_filtered_sorted_df.head())
# Out:
# Loaded 11053 gene names.
# Loaded 10704 gene names.
# Loaded 10005 gene names.
# Number of intersected genes: 9888
#        Component_1  Component_2  Component_3
# A1BG      0.001649    -0.003914    -0.023171
# AAAS     -0.012817    -0.012734     0.002441
# AACS     -0.012198     0.005039     0.003103
# AADAT    -0.007992     0.003483    -0.021726
# AAED1     0.006933    -0.014268     0.010417
#        Component_1  Component_2  Component_3
# A1BG     -0.014281     0.008120     0.000765
# AAAS      0.009136    -0.014050    -0.011496
# AACS      0.011677    -0.000379     0.008708
# AADAT     0.013668     0.005304    -0.015317
# AAED1    -0.003705    -0.003495    -0.014424
#        Component_1  Component_2  Component_3
# A1BG      0.000973     0.008635     0.008390
# AAAS     -0.005139    -0.004401     0.015123
# AACS      0.000156    -0.004748    -0.007253
# AADAT     0.012156    -0.008723    -0.000719
# AAED1    -0.013978     0.003125    -0.001411
#        Component_1  Component_2  Component_3
# A1BG     -0.010167    -0.008973    -0.007658
# AAAS     -0.006713     0.004892     0.006996
# AACS      0.006239    -0.014569     0.006949
# AADAT     0.005016     0.008296    -0.013648
# AAED1    -0.011901    -0.012899     0.006549

# %%
# Step 1: Compute the correlation matrix
correlation_matrix_df = compute_correlation_with_labels(ahba_in_gtex_filtered_sorted_df, gtex_filtered_sorted_df,
                                                        dataset1_name='AHBA', dataset2_name='GTEx', 
                                                        correlation_type='spearman', use_abs=False)

# Step 2: Plot the heatmap
plot_correlation_heatmap(correlation_matrix_df, title='Spearman Correlation Heatmap between AHBA and GTEx')

# %%
# Step 1: Compute p-values for the correlations across all datasets using Spearman correlation
pvalue_df = compute_correlation_with_pvalues(ahba_in_gtex_filtered_sorted_df, 
                                             gtex_filtered_sorted_df, 
                                             dataset1_name='AHBA', dataset2_name='GTEx', 
                                             correlation_type='spearman', use_abs=False)

# Step 2: Apply Bonferroni correction to the computed p-values
corrected_pvalue_df = apply_bonferroni_correction(pvalue_df)

# Step 3: Plot the Bonferroni-corrected p-value heatmap
plot_pvalue_heatmap(corrected_pvalue_df, title='Bonferroni-Corrected Spearman P-values Heatmap')

# %%
# Step 1: Compute the correlation matrix
correlation_matrix_df = compute_correlation_with_labels(ahba_in_utsw_filtered_sorted_df, utsw_filtered_sorted_df,
                                                        dataset1_name='AHBA', dataset2_name='UTSW', 
                                                        correlation_type='spearman', use_abs=False)

# Step 2: Plot the heatmap
plot_correlation_heatmap(correlation_matrix_df, title='Spearman Correlation Heatmap between AHBA and UTSW')

# %%
# Step 1: Compute p-values for the correlations across all datasets using Spearman correlation
pvalue_df = compute_correlation_with_pvalues(ahba_in_gtex_filtered_sorted_df, 
                                             gtex_filtered_sorted_df, 
                                             dataset1_name='AHBA', dataset2_name='UTSW', 
                                             correlation_type='spearman', use_abs=False)

# Step 2: Apply Bonferroni correction to the computed p-values
corrected_pvalue_df = apply_bonferroni_correction(pvalue_df)

# Step 3: Plot the Bonferroni-corrected p-value heatmap
plot_pvalue_heatmap(corrected_pvalue_df, title='Bonferroni-Corrected Spearman P-values Heatmap')

# %%
# Assuming utsw_feature_importances_df is already defined and loaded
top_5_ahba_per_component = get_top_n_values_per_column(ahba_in_gtex_filtered_sorted_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_ahba_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)

# Assuming utsw_feature_importances_df is already defined and loaded
top_5_gtex_per_component = get_top_n_values_per_column(gtex_filtered_sorted_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_gtex_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)
# Out:
# Top 5 genes for Component_1:
#             Gene     Value
# FAM136A  FAM136A  0.015452
# COL5A3    COL5A3 -0.015364
# SPA17      SPA17  0.015238
# SPATA6L  SPATA6L  0.015194
# KIFC2      KIFC2 -0.015191
#
# Top 5 genes for Component_2:
#           Gene     Value
# MYDGF    MYDGF  0.023903
# CCDC57  CCDC57 -0.023475
# NUS1      NUS1  0.023191
# CIT        CIT -0.023162
# TCEAL9  TCEAL9  0.023122
#
# Top 5 genes for Component_3:
#           Gene     Value
# KDM7A    KDM7A  0.027293
# CRYZL1  CRYZL1 -0.026945
# TOMM40  TOMM40  0.026843
# SUSD1    SUSD1 -0.026631
# DPYSL3  DPYSL3 -0.026495
#
# Top 5 genes for Component_1:
#               Gene     Value
# NLN            NLN  0.015844
# METTL21A  METTL21A  0.015747
# MYO1B        MYO1B  0.015713
# LLPH          LLPH  0.015668
# KBTBD2      KBTBD2  0.015665
#
# Top 5 genes for Component_2:
#         Gene     Value
# DTNA    DTNA  0.031255
# GNA12  GNA12  0.031155
# NPAS3  NPAS3  0.030124
# NUPR2  NUPR2  0.029857
# CDH4    CDH4  0.029760
#
# Top 5 genes for Component_3:
#             Gene     Value
# MEIS3P1  MEIS3P1 -0.029338
# RAB29      RAB29 -0.029302
# TGDS        TGDS -0.029286
# AK3          AK3 -0.029134
# MSRB3      MSRB3 -0.028576

# %%
# Assuming utsw_feature_importances_df is already defined and loaded
top_5_ahba_per_component = get_top_n_values_per_column(ahba_in_utsw_filtered_sorted_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_ahba_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)

# Assuming utsw_feature_importances_df is already defined and loaded
top_5_utsw_per_component = get_top_n_values_per_column(utsw_filtered_sorted_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_utsw_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)
# Out:
# Top 5 genes for Component_1:
#             Gene     Value
# MNAT1      MNAT1  0.016726
# EPCAM      EPCAM -0.016675
# GPCPD1    GPCPD1  0.016640
# ARHGDIB  ARHGDIB  0.016630
# CORO6      CORO6 -0.016583
#
# Top 5 genes for Component_2:
#               Gene     Value
# HCP5          HCP5  0.025589
# LONRF2      LONRF2 -0.025394
# SEC11A      SEC11A  0.024843
# ARHGAP19  ARHGAP19  0.024827
# OLFML2B    OLFML2B  0.024737
#
# Top 5 genes for Component_3:
#           Gene     Value
# DHX9      DHX9  0.033987
# ARFIP2  ARFIP2 -0.032357
# GSK3A    GSK3A -0.031899
# NFIA      NFIA -0.031816
# HRH2      HRH2  0.031476
#
# Top 5 genes for Component_1:
#               Gene     Value
# NMT2          NMT2  0.017746
# ZBTB38      ZBTB38  0.017623
# SLC39A12  SLC39A12 -0.017619
# PSPH          PSPH  0.017564
# BHLHE22    BHLHE22  0.017549
#
# Top 5 genes for Component_2:
#               Gene     Value
# TRIM26      TRIM26  0.022186
# INTU          INTU -0.021855
# ADNP-AS1  ADNP-AS1  0.021805
# KCNG3        KCNG3 -0.021707
# TASP1        TASP1 -0.021701
#
# Top 5 genes for Component_3:
#           Gene     Value
# DAPK1    DAPK1  0.028529
# PLAGL1  PLAGL1 -0.027713
# VANGL1  VANGL1  0.027242
# PHLDA3  PHLDA3  0.027121
# BCL2L1  BCL2L1 -0.026954

# %% [markdown]
# #### Analysis of full dataset components (not subsampled)

# %%
# Step 1: Compute the intersected gene names
intersected_genes = compute_gene_name_intersection()

# Step 2: Filter and sort the feature importance DataFrames
ahba_filtered_sorted_df = filter_and_sort_by_genes(ahba_feature_importances_df, intersected_genes)
gtex_filtered_sorted_df = filter_and_sort_by_genes(gtex_feature_importances_df, intersected_genes)
utsw_filtered_sorted_df = filter_and_sort_by_genes(utsw_feature_importances_df, intersected_genes)

# Step 3: Display the results (or save them)
print(ahba_filtered_sorted_df.head())  # Check the first few rows
print(gtex_filtered_sorted_df.head())
print(utsw_filtered_sorted_df.head())
# Out:
# Loaded 11053 gene names.
# Loaded 10704 gene names.
# Loaded 10005 gene names.
# Number of intersected genes: 9888
#        Component_1  Component_2  Component_3
# A1BG     -0.010853     0.010779     0.008289
# AAAS      0.008836    -0.009938     0.000574
# AACS      0.013549     0.006949     0.002022
# AADAT     0.008383    -0.001006     0.011122
# AAED1    -0.010731     0.003559    -0.002743
#        Component_1  Component_2  Component_3
# A1BG     -0.014281     0.008120     0.000765
# AAAS      0.009136    -0.014050    -0.011496
# AACS      0.011677    -0.000379     0.008708
# AADAT     0.013668     0.005304    -0.015317
# AAED1    -0.003705    -0.003495    -0.014424
#        Component_1  Component_2  Component_3
# A1BG     -0.010167    -0.008973    -0.007658
# AAAS     -0.006713     0.004892     0.006996
# AACS      0.006239    -0.014569     0.006949
# AADAT     0.005016     0.008296    -0.013648
# AAED1    -0.011901    -0.012899     0.006549

# %%
# Step 1: Compute correlations for the original values across all datasets using Spearman correlation
spearman_correlation_df = compute_correlation_across_datasets(
    ahba_filtered_sorted_df, 
    gtex_filtered_sorted_df, 
    utsw_filtered_sorted_df,
    correlation_type='spearman', 
    use_abs=False
)

# Step 2: Plot the Spearman correlation heatmap
plot_correlation_heatmap(spearman_correlation_df, title='Spearman Correlation - Original Values')

# %%
# Step 1: Compute p-values for the correlations across all datasets using Spearman correlation
spearman_pvalue_df = compute_correlation_pvalues_across_datasets(
    ahba_filtered_sorted_df, 
    gtex_filtered_sorted_df, 
    utsw_filtered_sorted_df, 
    correlation_type='spearman', 
    use_abs=False
)

# Step 2: Plot the Spearman correlation p-value heatmap
plot_pvalue_heatmap(spearman_pvalue_df, title='Spearman Correlation P-values - Original Values')

#https://stats.stackexchange.com/questions/55288/understanding-the-p-value-in-spearmans-rank-correlation

# Step 1: Compute p-values for the correlations across all datasets using Spearman correlation
spearman_pvalue_df = compute_correlation_pvalues_across_datasets(
    ahba_filtered_sorted_df, 
    gtex_filtered_sorted_df, 
    utsw_filtered_sorted_df, 
    correlation_type='spearman', 
    use_abs=False
)

# Step 2: Apply Bonferroni correction to the computed p-values
corrected_spearman_pvalue_df = apply_bonferroni_correction(spearman_pvalue_df)

# Step 3: Plot the Bonferroni-adjusted p-value heatmap
plot_pvalue_heatmap(corrected_spearman_pvalue_df, title='Bonferroni-Corrected Spearman Correlation P-values')

# %%
# Assuming utsw_feature_importances_df is already defined and loaded
top_5_ahba_per_component = get_top_n_values_per_column(ahba_feature_importances_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_ahba_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)
# Out:
# Top 5 genes for Component_1:
#           Gene     Value
# COX7A1  COX7A1  0.016773
# HEBP1    HEBP1 -0.016674
# ECM1      ECM1  0.016516
# CABP1    CABP1  0.016378
# NKAIN4  NKAIN4 -0.016350
#
# Top 5 genes for Component_2:
#           Gene     Value
# CAPN12  CAPN12  0.028804
# NEB        NEB -0.027031
# CDH8      CDH8  0.026358
# NT5DC2  NT5DC2  0.025896
# BAIAP3  BAIAP3  0.025871
#
# Top 5 genes for Component_3:
#           Gene     Value
# KYNU      KYNU  0.045405
# OPN4      OPN4  0.041695
# SNHG18  SNHG18  0.038434
# LIPC      LIPC  0.036351
# UST        UST -0.036268

# %%
# Assuming utsw_feature_importances_df is already defined and loaded
top_5_gtex_per_component = get_top_n_values_per_column(gtex_feature_importances_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_gtex_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)
# Out:
# Top 5 genes for Component_1:
#               Gene     Value
# NCOA4        NCOA4  0.015880
# NLN            NLN  0.015844
# METTL21A  METTL21A  0.015747
# MYO1B        MYO1B  0.015713
# LLPH          LLPH  0.015668
#
# Top 5 genes for Component_2:
#         Gene     Value
# DTNA    DTNA  0.031255
# GNA12  GNA12  0.031155
# HES5    HES5  0.030700
# NPAS3  NPAS3  0.030124
# NUPR2  NUPR2  0.029857
#
# Top 5 genes for Component_3:
#                 Gene     Value
# C14orf177  C14orf177  0.029626
# MEIS3P1      MEIS3P1 -0.029338
# RAB29          RAB29 -0.029302
# TGDS            TGDS -0.029286
# AK3              AK3 -0.029134

# %%
# Assuming utsw_feature_importances_df is already defined and loaded
top_5_utsw_per_component = get_top_n_values_per_column(utsw_feature_importances_df, n=5)

# Display the top 5 values for each component
for component, df in top_5_utsw_per_component.items():
    print(f"\nTop 5 genes for {component}:")
    print(df)
# Out:
# Top 5 genes for Component_1:
#               Gene     Value
# NMT2          NMT2  0.017746
# ZBTB38      ZBTB38  0.017623
# SLC39A12  SLC39A12 -0.017619
# PSPH          PSPH  0.017564
# BHLHE22    BHLHE22  0.017549
#
# Top 5 genes for Component_2:
#               Gene     Value
# TRIM26      TRIM26  0.022186
# INTU          INTU -0.021855
# ADNP-AS1  ADNP-AS1  0.021805
# KCNG3        KCNG3 -0.021707
# TASP1        TASP1 -0.021701
#
# Top 5 genes for Component_3:
#           Gene     Value
# DAPK1    DAPK1  0.028529
# PLAGL1  PLAGL1 -0.027713
# VANGL1  VANGL1  0.027242
# PHLDA3  PHLDA3  0.027121
# BCL2L1  BCL2L1 -0.026954

# %% [markdown]
# ### PREDICTION ANALYSIS

# %% [markdown]
# ### AHBA PLS <a id="PLS-Sims"></a>

# %% [markdown]
# #### 4-Fold Random split

# %%
full_pls_random_shared_sim_results = multi_sim_run('random',
                                                'pls',
                                                use_gpu=False, 
                                                use_shared_regions=False, 
                                                test_shared_regions=False, 
                                                save_sim=True,
                                                search_method='grid'
                                                )
# Out:
# Number of components explaining 95% of the variance: 34
#
#  Test fold num: 1
# (7140, 170) (7140,) (812, 170) (812,)
# 2
# 3
# 4
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.0s[CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
#
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.2s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.018882593074404437
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.02511629685616319
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.017969201862774925
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([11, 12,  1,  6,  3, 10,  9,  5,  7,  2,  8,  4], dtype=int32), array([11, 12,  9,  1, 10,  5,  8,  3,  7,  2,  6,  4], dtype=int32), array([ 1, 12,  2,  9,  4, 11,  3, 10,  5,  8,  6,  7], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.020216747789077318, 'mae': 0.10267893842932749, 'r2': -1.3338113573284627, 'pearson_corr': 0.6499782859174912, 'connectome_corr': 0.4744372054964307, 'connectome_r2': -1.4612861724877007, 'geodesic_distance': 13.86821880542978}
# Test Metrics: {'mse': 0.01780927279193806, 'mae': 0.09807910382187943, 'r2': -0.3357045157808045, 'pearson_corr': 0.6389783480874769, 'connectome_corr': 0.507360316239714, 'connectome_r2': -0.5245426380709558, 'geodesic_distance': 6.6828155788592065}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# CPU Usage: 11.3%
# RAM Usage: 7.3%
# Available RAM: 349.7G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 2
# (7140, 170) (7140,) (812, 170) (812,)
# 1
# 3
# 4
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.2s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.01850795083072665
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.024684125259308354
# Best Parameters:  {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.018022509891849312
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([11, 12, 10,  1,  9,  2,  7,  5,  6,  4,  8,  3], dtype=int32), array([11, 12, 10,  4,  9,  5,  8,  3,  7,  1,  6,  2], dtype=int32), array([ 1, 11,  2, 12,  3, 10,  4,  9,  8,  6,  7,  5], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.02011613336040364, 'mae': 0.10151970480873951, 'r2': -0.5299894905036154, 'pearson_corr': 0.5982220786277404, 'connectome_corr': 0.4302201219649102, 'connectome_r2': -0.6056960615333451, 'geodesic_distance': 13.691435434262901}
# Test Metrics: {'mse': 0.017962587998328207, 'mae': 0.09653478536809713, 'r2': -2.5577828126725137, 'pearson_corr': 0.7289436064095977, 'connectome_corr': 0.5991578177365673, 'connectome_r2': -3.1821300000093165, 'geodesic_distance': 6.79853335249348}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.3%
# RAM Usage: 7.3%
# Available RAM: 349.7G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 3
# (7310, 172) (7310,) (756, 172) (756,)
# 1
# 2
# 4
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.2s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.018612577648829242
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.01849009044083723
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.017617503285416013
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([11, 12,  9,  1, 10,  5,  8,  2,  6,  3,  7,  4], dtype=int32), array([11, 12,  1, 10,  3,  7,  2,  5,  4,  9,  6,  8], dtype=int32), array([ 1,  4,  2, 12,  3, 11,  5, 10,  6,  9,  7,  8], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.017958054367820865, 'mae': 0.0979403806886642, 'r2': -1.4555764163866514, 'pearson_corr': 0.6755669229921337, 'connectome_corr': 0.5059516141959058, 'connectome_r2': -1.5761351930418863, 'geodesic_distance': 14.23872676169895}
# Test Metrics: {'mse': 0.02380608424216931, 'mae': 0.10884221323227893, 'r2': 0.0858244605434236, 'pearson_corr': 0.49623676356847335, 'connectome_corr': 0.3065635580018694, 'connectome_r2': -0.08868292285884116, 'geodesic_distance': 6.306125300656506}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# CPU Usage: 11.5%
# RAM Usage: 7.3%
# Available RAM: 349.7G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 4
# (7310, 172) (7310,) (756, 172) (756,)
# 1
# 2
# 3
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.2s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.2s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.018329866283647637
# Best Parameters:  {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.019073882008423654
# Best Parameters:  {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=   0.1s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=   0.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.02471652294259815
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([11, 12, 10,  3,  9,  1,  8,  6,  7,  4,  2,  5], dtype=int32), array([11, 12, 10,  8,  1,  9,  2,  7,  3,  5,  6,  4], dtype=int32), array([11, 12,  9,  6, 10,  4,  8,  3,  7,  2,  5,  1], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.020645007869358124, 'mae': 0.102326030802704, 'r2': -1.0541314537654691, 'pearson_corr': 0.6257682528483526, 'connectome_corr': 0.48969275514616234, 'connectome_r2': -1.1822183051228528, 'geodesic_distance': 12.596769370473984}
# Test Metrics: {'mse': 0.0174668240568681, 'mae': 0.09679803386505005, 'r2': -1.0689931031774167, 'pearson_corr': 0.661445133132605, 'connectome_corr': 0.365592663905288, 'connectome_r2': -1.3276668011837198, 'geodesic_distance': 6.6624727178642145}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 7.3%
# Available RAM: 349.7G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
# Number of components explaining 95% of the variance: 34
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22106) (7140,) (812, 22106) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.8s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  15.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.2s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.3s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.7s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.7s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.2s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.9s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.9s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  28.6s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  32.6s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.4s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.4s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  40.9s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  37.0s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.3s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.4s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  45.3s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.7s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.8s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  49.0s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.1s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  49.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  50.7s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  53.4s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.6s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.0s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  52.3s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# Best Cross-Validation Score:  -0.02608093178741781
#
# Train Metrics: {'mse': 0.025928901446782202, 'mae': 0.12083463420150334, 'r2': -1.82481424746891, 'pearson_corr': 0.5092088938305254, 'connectome_corr': 0.36915504876637145, 'connectome_r2': -1.986123655975782, 'geodesic_distance': 11.294267450980197}
# Test Metrics: {'mse': 0.020768435632073572, 'mae': 0.10893779858060117, 'r2': -0.5804369776165392, 'pearson_corr': 0.5727350047024624, 'connectome_corr': 0.42844032320105613, 'connectome_r2': -0.7821518905823164, 'geodesic_distance': 7.317689589007227}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.9%
# RAM Usage: 8.7%
# Available RAM: 344.3G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 2
# (7140, 22106) (7140,) (812, 22106) (812,)
# 1
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.7s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  15.8s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.2s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.2s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.6s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.7s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.8s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.9s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  28.5s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  32.6s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.4s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.4s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.5s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  41.0s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  37.0s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.3s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.1s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.4s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  45.4s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.7s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  49.0s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.0s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  49.6s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  50.7s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  53.5s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  53.9s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  52.3s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# Best Cross-Validation Score:  -0.02443232525208824
#
# Train Metrics: {'mse': 0.02390258048979733, 'mae': 0.11441801062858073, 'r2': -0.9090497039310448, 'pearson_corr': 0.4868283727200488, 'connectome_corr': 0.3396082060061211, 'connectome_r2': -1.001792048979198, 'geodesic_distance': 12.726265934922257}
# Test Metrics: {'mse': 0.0261582739501278, 'mae': 0.1256471753332848, 'r2': -4.058089516431732, 'pearson_corr': 0.570571860097045, 'connectome_corr': 0.48227909141452585, 'connectome_r2': -4.835878400319596, 'geodesic_distance': 6.004070857660408}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 8.7%
# Available RAM: 344.3G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 3
# (7310, 22106) (7310,) (756, 22106) (756,)
# 1
# 2
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.1s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.1s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.4s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.3s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.4s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.7s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.7s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.8s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  21.3s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  25.0s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  25.0s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.5s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.6s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  30.3s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.3s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.4s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  43.6s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  39.3s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.9s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.8s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  48.0s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.4s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.5s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  51.3s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  52.9s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.8s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.4s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.5s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  52.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.6s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# Best Cross-Validation Score:  -0.02430965525159273
#
# Train Metrics: {'mse': 0.02066472178444614, 'mae': 0.10604900017338237, 'r2': -1.583157098811478, 'pearson_corr': 0.6119288986332627, 'connectome_corr': 0.45796753543188184, 'connectome_r2': -1.7102221547235015, 'geodesic_distance': 12.960166951531269}
# Test Metrics: {'mse': 0.026507047776585795, 'mae': 0.12233676765636585, 'r2': -0.06879339762258467, 'pearson_corr': 0.39889371389937356, 'connectome_corr': 0.21152685577810154, 'connectome_r2': -0.3119094330066045, 'geodesic_distance': 6.357431832404359}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}
# CPU Usage: 11.8%
# RAM Usage: 8.7%
# Available RAM: 344.3G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 4
# (7310, 22106) (7310,) (756, 22106) (756,)
# 1
# 2
# 3
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.1s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.2s
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.4s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.3s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.4s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.7s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.8s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.8s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  21.3s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  24.9s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  25.0s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.4s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  29.5s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  30.4s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  34.7s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.4s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  42.4s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  43.7s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  39.4s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  47.0s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  46.8s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  48.0s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.5s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  50.4s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  51.3s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  52.9s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  51.9s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.5s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.5s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  52.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  54.7s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# Best Cross-Validation Score:  -0.024810478668936972
#
# Train Metrics: {'mse': 0.025042063781729136, 'mae': 0.11859346480951802, 'r2': -1.4144808432399625, 'pearson_corr': 0.5118627277012502, 'connectome_corr': 0.3949212422992557, 'connectome_r2': -1.5656421631122917, 'geodesic_distance': 11.343972694349128}
# Test Metrics: {'mse': 0.023431849486459922, 'mae': 0.10750630920321659, 'r2': -1.5073657226625126, 'pearson_corr': 0.5368282203870042, 'connectome_corr': 0.26445562730624306, 'connectome_r2': -1.8444086672118567, 'geodesic_distance': 5.49191284977861}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 8.7%
# Available RAM: 344.4G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
# Number of components explaining 95% of the variance: 34
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22276) (7140,) (812, 22276) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.6s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  15.6s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.0s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.0s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.0s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  27.3s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  29.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  31.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  32.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  37.2s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  37.5s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.021673228699136286
# Best Parameters:  {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.0s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.8s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.4s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.7s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.02643818375303584
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.0s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.5s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.3s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.1s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.6s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.2s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.7s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.023614581093351687
# Best Parameters:  {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([12, 11, 10,  8,  9,  4,  6,  1,  5,  2,  7,  3], dtype=int32), array([ 8,  6,  9,  5, 12, 10, 11,  3,  7,  2,  4,  1], dtype=int32), array([ 2,  1, 12, 11,  9,  6,  8,  4, 10,  5,  7,  3], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.020224198974556105, 'mae': 0.1026161547015809, 'r2': -1.3405968703715658, 'pearson_corr': 0.6498145239049422, 'connectome_corr': 0.4732993553380988, 'connectome_r2': -1.468570593498267, 'geodesic_distance': 13.964089512933183}
# Test Metrics: {'mse': 0.01826248984229275, 'mae': 0.09811866405123776, 'r2': -0.3578319980939012, 'pearson_corr': 0.6227218940584265, 'connectome_corr': 0.48587292761087386, 'connectome_r2': -0.5372950670741347, 'geodesic_distance': 7.189913349673835}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.5%
# RAM Usage: 10.1%
# Available RAM: 339.0G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 2
# (7140, 22276) (7140,) (812, 22276) (812,)
# 1
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.6s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  15.6s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.0s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.1s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.0s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  27.3s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  29.6s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  31.3s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  32.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  37.2s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  37.6s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.019795677227891637
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.0s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.8s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.4s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.8s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.026078444773027145
# Best Parameters:  {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.0s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.8s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.023046281738004513
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([10,  9,  8,  6, 12,  7, 11,  4,  5,  2,  3,  1], dtype=int32), array([ 9,  8, 12, 10, 11,  7,  6,  3,  4,  1,  5,  2], dtype=int32), array([ 7,  5, 12, 11, 10,  4,  9,  2,  8,  3,  6,  1], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.020138751580687744, 'mae': 0.10158233491504806, 'r2': -0.5323081598901034, 'pearson_corr': 0.5976183192405615, 'connectome_corr': 0.4295815606234734, 'connectome_r2': -0.608111157925865, 'geodesic_distance': 13.77374182142592}
# Test Metrics: {'mse': 0.019938746773821684, 'mae': 0.1032977513413666, 'r2': -2.6968002180719517, 'pearson_corr': 0.700742956741488, 'connectome_corr': 0.5683136512576351, 'connectome_r2': -3.3227508303621907, 'geodesic_distance': 6.093560713910081}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 10.1%
# Available RAM: 338.9G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 3
# (7310, 22278) (7310,) (756, 22278) (756,)
# 1
# 2
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.8s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.4s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.8s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.019959187009170657
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.8s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.8s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.021486764945854338
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.3s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.5s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.2s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  23.4s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  26.6s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  29.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  31.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  33.3s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  35.9s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  39.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  40.1s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.020671591084040795
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([ 7,  6, 10,  8, 12, 11,  9,  3,  5,  2,  4,  1], dtype=int32), array([11, 12, 10,  9,  8,  7,  6,  4,  5,  2,  3,  1], dtype=int32), array([11, 10,  9,  7, 12,  8,  6,  4,  5,  2,  3,  1], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.017972242910504088, 'mae': 0.09789487217891774, 'r2': -1.4606451082521146, 'pearson_corr': 0.675248965360963, 'connectome_corr': 0.5048744000134913, 'connectome_r2': -1.5814986683933323, 'geodesic_distance': 13.80730068871058}
# Test Metrics: {'mse': 0.024771031725295038, 'mae': 0.11203875460197435, 'r2': -0.014593620258473763, 'pearson_corr': 0.46825438288799065, 'connectome_corr': 0.2687020921574688, 'connectome_r2': -0.2285338827844448, 'geodesic_distance': 6.593181709873811}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 10.1%
# Available RAM: 338.9G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
#
#  Test fold num: 4
# (7310, 22278) (7310,) (756, 22278) (756,)
# 1
# 2
# 3
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  11.9s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.8s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.5s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.4s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.8s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.019932780983214646
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.0s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.1s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  19.6s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  22.7s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  25.7s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  28.2s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  30.4s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  32.2s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  33.7s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  34.7s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  38.3s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  38.7s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.02207043063378938
# Best Parameters:  {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}
# Fitting 1 folds for each of 12 candidates, totalling 12 fits
# [CV] END max_iter=1000, n_components=1, scale=False, tol=1e-07; total time=  12.2s
# [CV] END max_iter=1000, n_components=1, scale=True, tol=1e-07; total time=  16.5s
# [CV] END max_iter=1000, n_components=3, scale=False, tol=1e-07; total time=  20.1s
# [CV] END max_iter=1000, n_components=3, scale=True, tol=1e-07; total time=  23.4s
# [CV] END max_iter=1000, n_components=5, scale=False, tol=1e-07; total time=  26.5s
# [CV] END max_iter=1000, n_components=5, scale=True, tol=1e-07; total time=  29.1s
# [CV] END max_iter=1000, n_components=7, scale=False, tol=1e-07; total time=  31.4s
# [CV] END max_iter=1000, n_components=7, scale=True, tol=1e-07; total time=  33.3s
# [CV] END max_iter=1000, n_components=9, scale=False, tol=1e-07; total time=  34.8s
# [CV] END max_iter=1000, n_components=9, scale=True, tol=1e-07; total time=  35.9s
# [CV] END max_iter=1000, n_components=15, scale=False, tol=1e-07; total time=  39.6s
# [CV] END max_iter=1000, n_components=15, scale=True, tol=1e-07; total time=  40.0s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  -0.025527290247810527
# Best Parameters:  {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}
# PARAMETER COMBOS [{'max_iter': 1000, 'n_components': 1, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 1, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 3, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 5, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 7, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': True, 'tol': 1e-07}, {'max_iter': 1000, 'n_components': 15, 'scale': False, 'tol': 1e-07}]
# GRIDSEARCH RANK [array([ 5,  4, 11, 10, 12,  7,  9,  3,  8,  2,  6,  1], dtype=int32), array([12, 11, 10,  9,  8,  4,  5,  2,  6,  1,  7,  3], dtype=int32), array([12, 11, 10,  8,  9,  6,  7,  4,  5,  2,  3,  1], dtype=int32)]
# BEST INNNER PARAMS {'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}
#
# Train Metrics: {'mse': 0.02080054203304603, 'mae': 0.10267590530869189, 'r2': -1.0710494078224981, 'pearson_corr': 0.6220950662379806, 'connectome_corr': 0.4841948040895119, 'connectome_r2': -1.2006171365448315, 'geodesic_distance': 12.177135339259168}
# Test Metrics: {'mse': 0.02098560589995543, 'mae': 0.10116356378849835, 'r2': -2.108176817670815, 'pearson_corr': 0.606493011533405, 'connectome_corr': 0.31867294731257584, 'connectome_r2': -2.505870357509085, 'geodesic_distance': 5.208873767777758}
# BEST MODEL PARAMS {'copy': True, 'max_iter': 1000, 'n_components': 9, 'scale': False, 'tol': 1e-07}
# CPU Usage: 11.4%
# RAM Usage: 10.1%
# Available RAM: 338.9G
# Total RAM: 377.1G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  0% |
# Multi simulation results have been saved.

# %%
multi_sim_random_pls = open_pickled_results('multi_sim_random_pls.pickle')

# %%
boxplot_model_performance(multi_sim_random_pls)

# %%
plot_predictions_with_metrics(multi_sim_random_pls)

# %% [markdown]
# ### AHBA XGBoost <a id="XGBoost-Sims"></a>

# %% [markdown]
# #### 4-Fold Random split

# %% [markdown]
# Random split, trained on non-shared regions, test on non-shared

# %%
full_xgb_random_nonshared_sim_results = multi_sim_run('random',
                                              'xgboost',
                                              use_gpu=True,
                                              use_shared_regions=False,
                                              test_shared_regions=False, 
                                              save_sim=True,
                                              search_method='random'
                                              )
# Out:
# Number of components explaining 95% of the variance: 34
#
#  Test fold num: 1
# (7140, 170) (7140,) (812, 170) (812,)
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# CUDARuntimeError                          Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 full_xgb_random_nonshared_sim_results = multi_sim_run('random',
#       2                                               'xgboost',
#       3                                               use_gpu=True,
#       4                                               use_shared_regions=False,
#       5                                               test_shared_regions=False,
#       6                                               save_sim=True,
#       7                                               search_method='random'
#       8                                               )
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/multi_sim_run.py:165, in multi_sim_run(cv_type, model_type, use_gpu, use_shared_regions, test_shared_regions, resolution, random_seed, save_sim, search_method)
#     157 conn_sim = Simulation(
#     158         cv_type=cv_type, model_type=model_type, gpu_acceleration=use_gpu,
#     159                 predict_connectome_from_connectome=True, resolution=resolution,
#     160                 random_seed=random_seed, use_shared_regions=use_shared_regions,
#     161                 include_conn_feats=False, test_shared_regions=test_shared_regions
#     162     )
#     164 # Execute sim
# --> 165 conn_sim.run_sim(search_method)
#     166 multi_model_results.append(conn_sim.results)
#     168 # Transcriptome only
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim.py:230, in Simulation.run_sim(self, search_method)
#     226 train_network_dict = drop_test_network(self.cv_type, network_dict, test_indices, i+1)
#     228 # Step 5: Inner CV on training data
#     229 # search_method options: random, grid, bayes
# --> 230 best_model = self.run_innercv(train_indices, test_indices, train_network_dict, search_method=search_method, n_iter=100)
#     232 # convert to cupy if necessary
#     233 if self.gpu_acceleration:
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim.py:153, in Simulation.run_innercv(self, train_indices, test_indices, train_network_dict, search_method, n_iter)
#     151     grid_search, X_combined, Y_combined = grid_search_init(self.gpu_acceleration, model, X_combined, Y_combined, param_grid, train_test_indices)
#     152 elif search_method == 'random':
# --> 153     grid_search, X_combined, Y_combined = random_search_init(self.gpu_acceleration, model, X_combined, Y_combined, param_dist, train_test_indices, n_iter)
#     154 elif search_method == 'bayes':
#     155     grid_search, X_combined, Y_combined = bayes_search_init(self.gpu_acceleration, model, X_combined, Y_combined, param_dist, train_test_indices, n_iter)
#
# File /scratch/asr655/neuroinformatics/GeneEx2Conn/sim/sim_utils.py:143, in random_search_init(gpu_acceleration, model, X_combined, Y_combined, param_distributions, train_test_indices, n_iter)
#     139 """
#     140 Helper function to initialize RandomizedSearchCV object based on if GPU acceleration is being used.
#     141 """
#     142 if gpu_acceleration:
# --> 143     X_combined = cp.array(X_combined)
#     144     Y_combined = cp.array(Y_combined)
#     145     cupy_scorer = make_scorer(pearson_cupy, greater_is_better=True)
#
# File /ext3/miniconda3/lib/python3.11/site-packages/cupy/_creation/from_data.py:53, in array(obj, dtype, copy, order, subok, ndmin, blocking)
#       7 def array(obj, dtype=None, copy=True, order='K', subok=False, ndmin=0, *,
#       8           blocking=False):
#       9     """Creates an array on the current device.
#      10
#      11     This function currently does not support the ``subok`` option.
#    (...)
#      51
#      52     """
# ---> 53     return _core.array(obj, dtype, copy, order, subok, ndmin, blocking)
#
# File cupy/_core/core.pyx:2379, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2406, in cupy._core.core.array()
#
# File cupy/_core/core.pyx:2548, in cupy._core.core._array_default()
#
# File cupy/_core/core.pyx:132, in cupy._core.core.ndarray.__new__()
#
# File cupy/_core/core.pyx:220, in cupy._core.core._ndarray_base._init()
#
# File cupy/cuda/memory.pyx:738, in cupy.cuda.memory.alloc()
#
# File cupy/cuda/memory.pyx:1424, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/memory.pyx:1444, in cupy.cuda.memory.MemoryPool.malloc()
#
# File cupy/cuda/device.pyx:40, in cupy.cuda.device.get_device_id()
#
# File cupy_backends/cuda/api/runtime.pyx:202, in cupy_backends.cuda.api.runtime.getDevice()
#
# File cupy_backends/cuda/api/runtime.pyx:146, in cupy_backends.cuda.api.runtime.check_status()
#
# CUDARuntimeError: cudaErrorNoDevice: no CUDA-capable device is detected

# %%
trans_xgb_random_nonshared_sim_results = single_sim_run(cv_type='random',
                                              model_type='xgboost',
                                              feature_type='trans only',
                                              use_gpu=True,
                                              use_shared_regions=False,
                                              test_shared_regions=False, 
                                              save_sim=True,
                                              search_method='bayes'
                                              )
# Out:
# Number of components explaining 95% of the variance: 34
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22106) (7140,) (812, 22106) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# {'base_estimator': 'GP', 'acq_func': 'PI'}
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.481 total time=   2.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.351 total time=   2.2s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.548 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.493 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.289 total time=   2.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.558 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.520 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.317 total time=   1.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.591 total time=   1.7s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.451 total time=   1.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.267 total time=   1.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.529 total time=   1.4s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.490 total time=   0.5s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.274 total time=   0.4s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.547 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.434 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.335 total time=   3.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.485 total time=   3.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.505 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.356 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.529 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.523 total time=   3.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   2.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.572 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.486 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.274 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.554 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.647 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.336 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.575 total time=   1.4s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.652 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.573 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.639 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.314 total time=   0.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   0.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.582 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.268 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.572 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.536 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.206 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.535 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.640 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.361 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.572 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.269 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.586 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.584 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.270 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.569 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.584 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.270 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.568 total time=   0.3s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.665 total time=   0.7s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.357 total time=   0.7s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.587 total time=   0.7s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.671 total time=   0.7s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.366 total time=   0.7s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.577 total time=   0.7s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 1), ('device', 'cuda'), ('learning_rate', 0.1), ('max_depth', 2), ('n_estimators', 150), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 1), ('reg_lambda', 0), ('subsample', 1), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.5379865163618844
#
# Train Metrics: {'mse': 0.013712502126188492, 'mae': 0.07901612188932007, 'r2': 0.3589588713532893, 'pearson_corr': 0.7876265005863328, 'connectome_corr': 0.6091147031031402, 'connectome_r2': 0.3311453224276798, 'geodesic_distance': 10.318122188738498}
# Test Metrics: {'mse': 0.01880886928461123, 'mae': 0.09820663904311897, 'r2': -0.24253783301738593, 'pearson_corr': 0.6101353108367511, 'connectome_corr': 0.45996793627381094, 'connectome_r2': -0.3935693469294637, 'geodesic_distance': 7.30187864073253}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 1, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 2, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 150, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 15.6%
# RAM Usage: 8.5%
# Available RAM: 460.4G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 28% |
#
#  Test fold num: 2
# (7140, 22106) (7140,) (812, 22106) (812,)
# 1
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# {'base_estimator': 'GP', 'acq_func': 'PI'}
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.373 total time=   2.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.309 total time=   2.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.471 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.439 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.330 total time=   2.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.519 total time=   2.7s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.429 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.334 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.484 total time=   1.7s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.411 total time=   1.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.328 total time=   1.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.444 total time=   1.5s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.422 total time=   0.5s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.330 total time=   0.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.527 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.353 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.321 total time=   3.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.493 total time=   3.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.365 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.316 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.475 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.448 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.340 total time=   2.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.477 total time=   2.8s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.444 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.337 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   1.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.510 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.293 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.511 total time=   1.4s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.497 total time=   0.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.302 total time=   0.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.507 total time=   0.8s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.441 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.273 total time=   2.0s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.490 total time=   1.8s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.302 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.487 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.324 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.557 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.481 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.318 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.530 total time=   1.9s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.384 total time=   0.3s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.225 total time=   0.3s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.335 total time=   0.3s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.396 total time=   0.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.292 total time=   0.6s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.476 total time=   0.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.504 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.296 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.483 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.477 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.361 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.471 total time=   1.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.465 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.295 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.512 total time=   1.9s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 0.8), ('device', 'cuda'), ('learning_rate', 0.1), ('max_depth', 2), ('n_estimators', 350), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 1), ('reg_lambda', 0.1), ('subsample', 0.8), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.4560446132637315
#
# Train Metrics: {'mse': 0.01241856338411541, 'mae': 0.07631736897026009, 'r2': 0.4425339405093294, 'pearson_corr': 0.7858507767150322, 'connectome_corr': 0.6678012164093764, 'connectome_r2': 0.41913076872011074, 'geodesic_distance': 10.037584519378923}
# Test Metrics: {'mse': 0.019625740807346952, 'mae': 0.1034070072032715, 'r2': -1.650613919319136, 'pearson_corr': 0.7059117619285226, 'connectome_corr': 0.5841238230412312, 'connectome_r2': -2.0641695195633254, 'geodesic_distance': 5.111059263087639}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 2, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 350, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0.1, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 15.7%
# RAM Usage: 7.0%
# Available RAM: 467.9G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 28% |
#
#  Test fold num: 3
# (7310, 22106) (7310,) (756, 22106) (756,)
# 1
# 2
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING
# {'base_estimator': 'GP', 'acq_func': 'PI'}
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.407 total time=   2.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.604 total time=   2.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.581 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.449 total time=   2.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.615 total time=   2.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.655 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.467 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.634 total time=   1.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.619 total time=   1.8s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.384 total time=   1.5s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.606 total time=   1.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.634 total time=   1.5s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.445 total time=   0.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.625 total time=   0.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.634 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.451 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.635 total time=   3.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.469 total time=   3.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.487 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.575 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.579 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.451 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.606 total time=   2.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.645 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.446 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.614 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.650 total time=   1.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.525 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.620 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   1.4s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.466 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.597 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.544 total time=   1.4s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.431 total time=   0.3s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.562 total time=   0.3s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.557 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.457 total time=   3.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.621 total time=   3.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.648 total time=   3.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.521 total time=   1.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.669 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.604 total time=   1.9s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.446 total time=   1.2s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.605 total time=   1.2s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.581 total time=   1.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.460 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.559 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.581 total time=   1.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.494 total time=   2.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.641 total time=   2.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.631 total time=   2.9s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.338 total time=   0.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.569 total time=   0.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.609 total time=   0.4s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.380 total time=   1.0s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.613 total time=   1.0s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.628 total time=   1.0s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.374 total time=   2.9s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.469 total time=   3.0s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.579 total time=   2.8s
#
# Grid Search CV Results:
# =======================
# ...
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.302 total time=   2.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.517 total time=   2.6s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.524 total time=   2.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.325 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.541 total time=   1.7s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.561 total time=   1.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.320 total time=   1.8s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.515 total time=   1.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.454 total time=   1.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.300 total time=   1.5s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.493 total time=   0.4s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.568 total time=   0.5s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.310 total time=   0.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.394 total time=   3.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.436 total time=   3.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.334 total time=   3.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.441 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.562 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.319 total time=   0.5s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.540 total time=   2.6s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.473 total time=   2.8s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.320 total time=   2.6s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.529 total time=   1.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.540 total time=   1.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.332 total time=   1.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.522 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.628 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.351 total time=   1.4s
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.539 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.605 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.338 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.541 total time=   0.3s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.603 total time=   0.3s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.338 total time=   0.3s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.526 total time=   4.8s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.603 total time=   4.7s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.334 total time=   4.5s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.525 total time=   1.1s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.624 total time=   1.1s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   1.1s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.523 total time=   1.4s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.627 total time=   1.4s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.350 total time=   1.4s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.506 total time=   2.2s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.632 total time=   2.2s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.335 total time=   2.2s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.519 total time=   1.9s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.631 total time=   1.9s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.349 total time=   1.9s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.539 total time=   3.8s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.571 total time=   3.8s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.312 total time=   3.9s
# [CV 1/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.494 total time=   0.5s
# [CV 2/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.621 total time=   0.5s
# [CV 3/3] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.300 total time=   0.5s
# [CV 1/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.527 total time=   0.6s
# [CV 2/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.590 total time=   0.6s
# [CV 3/3] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.329 total time=   0.6s
#
# Grid Search CV Results:
# =======================
# Best Parameters:  OrderedDict([('colsample_bytree', 0.8), ('device', 'cuda'), ('learning_rate', 0.01), ('max_depth', 2), ('n_estimators', 250), ('n_gpus', -1), ('random_state', 42), ('reg_alpha', 0.01), ('reg_lambda', 0.1), ('subsample', 0.8), ('tree_method', 'gpu_hist'), ('verbosity', 0)])
# Best Cross-Validation Score:  0.500366796578478
#
# Train Metrics: {'mse': 0.019972215696514577, 'mae': 0.10047098601558183, 'r2': -0.44531601908995655, 'pearson_corr': 0.6623980527877026, 'connectome_corr': 0.513040068055393, 'connectome_r2': -0.5277129491524498, 'geodesic_distance': 10.465647498781816}
# Test Metrics: {'mse': 0.019493792469546075, 'mae': 0.09747571381522444, 'r2': -1.2178676659222807, 'pearson_corr': 0.6115650568207158, 'connectome_corr': 0.27434401346406917, 'connectome_r2': -1.4534872994888215, 'geodesic_distance': 5.666518933019175}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.01, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 2, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 250, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 0.01, 'reg_lambda': 0.1, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 15.6%
# RAM Usage: 7.1%
# Available RAM: 467.5G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 31% |
# Multi simulation results have been saved.

# %%
transplusconn_xgb_random_nonshared_sim_results = single_sim_run(cv_type='random',
                                              model_type='xgboost',
                                              feature_type='trans plus conn',
                                              use_gpu=True,
                                              use_shared_regions=False,
                                              test_shared_regions=False, 
                                              save_sim=True,
                                              search_method='random'
                                              )
# Out:
# Number of components explaining 95% of the variance: 34
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (7140, 22276) (7140,) (812, 22276) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.780 total time=   2.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.817 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.831 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.819 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.799 total time=   3.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.805 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.748 total time=   7.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.720 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.825 total time=   1.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.807 total time=   2.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.818 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.782 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.748 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.776 total time=   2.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.811 total time=   1.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.827 total time=   0.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.836 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.859 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.771 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.800 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.833 total time=   2.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.837 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.740 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.831 total time=   5.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.850 total time=   1.2s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.733 total time=   1.6s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.760 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.838 total time=   4.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.753 total time=   3.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.784 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.779 total time=   3.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.817 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.844 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.841 total time=   2.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.816 total time=   1.2s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.784 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.809 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.694 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.816 total time=   1.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.794 total time=   4.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.837 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.784 total time=   3.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.832 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.838 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.707 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.839 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.728 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.672 total time=   3.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.798 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.825 total time=   1.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.836 total time=   3.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.765 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.831 total time=   3.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.847 total time=   2.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.707 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.814 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.804 total time=   6.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.740 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.830 total time=   2.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.837 total time=   2.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.849 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.793 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.784 total time=   8.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.743 total time=   7.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.788 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.828 total time=   7.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.794 total time=   2.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.737 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.783 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.812 total time=   3.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.722 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.826 total time=   3.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.811 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.722 total time=   0.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.821 total time=   3.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.748 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.804 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.831 total time=   6.2s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.808 total time=   2.0s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.820 total time=   0.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.783 total time=   0.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.792 total time=   1.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.829 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.728 total time=   0.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.861 total time=   2.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.782 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.766 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.809 total time=   0.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.829 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.830 total time=   3.0s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.726 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.739 total time=   2.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.825 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.809 total time=   2.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.791 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.793 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.815 total time=   1.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.837 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.835 total time=   1.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.814 total time=   1.3s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  0.8605070247477844
# Best Parameters:  {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.657 total time=   2.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.657 total time=   1.6s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.784 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.697 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.647 total time=   3.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.618 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.617 total time=   6.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.592 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.665 total time=   1.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.743 total time=   2.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.741 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.568 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.550 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.663 total time=   2.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.712 total time=   1.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.758 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.745 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.786 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.676 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.730 total time=   1.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.775 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.751 total time=   0.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.664 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.758 total time=   5.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.765 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.574 total time=   1.6s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.674 total time=   2.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.764 total time=   4.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.696 total time=   3.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.581 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.653 total time=   3.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.721 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.767 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.766 total time=   2.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.708 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.669 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.649 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.635 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.722 total time=   1.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.657 total time=   4.7s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.742 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.676 total time=   3.2s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.792 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.744 total time=   0.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.769 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.598 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.660 total time=   3.6s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.745 total time=   0.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.726 total time=   1.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.712 total time=   4.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.611 total time=   2.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.753 total time=   4.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.794 total time=   2.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.577 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.739 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.725 total time=   5.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.533 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.777 total time=   2.8s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.735 total time=   3.0s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.804 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.709 total time=   1.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.713 total time=   7.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.623 total time=   7.0s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.648 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.744 total time=   7.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.695 total time=   2.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.633 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.576 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.709 total time=   4.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.595 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.718 total time=   3.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.725 total time=   1.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.595 total time=   0.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.750 total time=   3.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.569 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.697 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.771 total time=   6.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.718 total time=   2.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.613 total time=   0.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.521 total time=   0.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.587 total time=   1.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.735 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.597 total time=   0.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.774 total time=   2.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.568 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.655 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.623 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.778 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.747 total time=   3.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.586 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.577 total time=   2.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.766 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.690 total time=   2.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.611 total time=   1.5s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.577 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.708 total time=   1.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.764 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.713 total time=   1.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.638 total time=   1.3s
#
# Grid Search CV Results:
# =======================
# ...
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=7, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.765 total time=   2.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.665 total time=   0.5s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.571 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.746 total time=   3.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.330 total time=   0.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.765 total time=   4.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.764 total time=   1.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.330 total time=   0.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.779 total time=   3.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.449 total time=   0.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.635 total time=   1.6s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=7, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.801 total time=   6.3s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.754 total time=   2.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.649 total time=   0.7s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.539 total time=   0.9s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.557 total time=   1.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.775 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=50, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.342 total time=   0.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.818 total time=   3.0s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.564 total time=   1.1s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.677 total time=   1.2s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.675 total time=   0.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.731 total time=   3.0s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=4, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.778 total time=   3.2s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.408 total time=   1.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.001, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.441 total time=   1.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.756 total time=   1.3s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=4, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.770 total time=   2.4s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.606 total time=   1.6s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.01, max_depth=2, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.584 total time=   1.4s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=0, reg_lambda=0.01, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.629 total time=   1.9s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.1, max_depth=5, n_estimators=250, n_gpus=-1, random_state=42, reg_alpha=0.1, reg_lambda=0.1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.799 total time=   3.1s
# [CV 1/1] END colsample_bytree=0.8, device=cuda, learning_rate=0.3, max_depth=5, n_estimators=150, n_gpus=-1, random_state=42, reg_alpha=0.01, reg_lambda=1, subsample=0.8, tree_method=gpu_hist, verbosity=0;, score=0.702 total time=   1.8s
# [CV 1/1] END colsample_bytree=1, device=cuda, learning_rate=0.1, max_depth=2, n_estimators=350, n_gpus=-1, random_state=42, reg_alpha=1, reg_lambda=0.1, subsample=1, tree_method=gpu_hist, verbosity=0;, score=0.622 total time=   1.4s
#
# Grid Search CV Results:
# =======================
# Best Cross-Validation Score:  0.8181167153594022
# Best Parameters:  {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}
# PARAMETER COMBOS [{'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 250, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 150, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 2, 'n_estimators': 250, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.1, 'reg_lambda': 0, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 7, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.01, 'reg_lambda': 0, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.01, 'reg_lambda': 0.1, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.001, 'max_depth': 7, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.001, 'max_depth': 2, 'n_estimators': 150, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.01, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 250, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 50, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0.01, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 250, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0.1, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 50, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.1, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.001, 'max_depth': 4, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0, 'subsample': 0.8, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 5, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 1, 'reg_lambda': 0, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': 'cuda', 'learning_rate': 0.3, 'max_depth': 4, 'n_estimators': 50, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 50, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}, {'colsample_bytree': 1, 'device': ' ...
# GRIDSEARCH RANK [array([ 74,  61,  18,  95,  47,  72,  57,  86,  54,  30,  32,  80,  97,
#         50,  44,  68,  23,   7,  26,  39,  22,  13,  66,  40,   4,  87,
#         27,  12,  35,  89,  60,   5,  34,  19,  33,  51,  77,  76,  49,
#         75,  20,  41,  28,  16, 100,   3,  90,  79,  52,  29,  64,  62,
#          8,   6,  99,  42,  25,  96,  10,  37,  15,  55,  43,  58,  71,
#         17,  38,  59,  85,  31,  93,   2,  53,  92,  24,  83,  63,  21,
#         46,  67,  94,  73,  11,  88,   1,  80,  56,  70,  48,   9,  91,
#         82,  45,  36,  84,  78,  98,  14,  65,  69], dtype=int32), array([ 57,  27,  15,  72,  71,  59,  79, 100,  32,  63,  22,  77,  81,
#         47,  36,  70,  18,   4,  88,  42,  35,  23,  90,  21,   1,  83,
#         89,  14,  75,  73,  39,  25,  26,  30,  33,  40,  65,  99,  37,
#         82,  17,  48,   5,  16,  93,  13,  97,  96,  34,  64,  61,  68,
#          9,   3,  92,  24,  44,  91,   6,  55,   2,  52,  53,  80,  58,
#         11,  50,  69,  74,  29,  95,  20,  38,  94,  28,  84,  51,  19,
#         10,  45,  85,  54,  31,  98,   7,  77,  60,  46,  49,   8,  86,
#         87,  41,  43,  67,  76,  66,  12,  62,  56], dtype=int32), array([ 57,  70,   2,  71,  48,  78,  59, 100,  60,  44,  15,  83,  90,
#         61,  49,  38,  11,   4,  51,  32,  13,  12,  68,  10,   6,  91,
#         52,   8,  39,  81,  63,  40,  17,  20,  46,  62,  85,  73,  56,
#         53,  23,  50,  18,  28,  96,  14,  94,  67,  37,  43,  54,  74,
#         19,   3,  97,  34,  36,  93,  16,  27,   5,  45,  42,  58,  72,
#         26,  29,  66,  82,  41,  98,  30,  31,  99,  21,  88,  75,   7,
#         35,  69,  87,  86,  24,  95,   1,  83,  64,  65,  47,  22,  92,
#         89,  33,  25,  79,  80,  76,   9,  55,  77], dtype=int32)]
# BEST INNNER PARAMS {'colsample_bytree': 0.8, 'device': 'cuda', 'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 350, 'n_gpus': -1, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'subsample': 1, 'tree_method': 'gpu_hist', 'verbosity': 0}
#
# Train Metrics: {'mse': 0.0005452644400814372, 'mae': 0.015366215071211163, 'r2': 0.9560446856714571, 'pearson_corr': 0.9924498797603418, 'connectome_corr': 0.9775038943235141, 'connectome_r2': 0.9534344924360305, 'geodesic_distance': 4.833739480731715}
# Test Metrics: {'mse': 0.005521588099013679, 'mae': 0.05378920670557023, 'r2': 0.4229499333689372, 'pearson_corr': 0.907829416231284, 'connectome_corr': 0.7520325412762812, 'connectome_r2': 0.328071682374405, 'geodesic_distance': 4.647024311698581}
# BEST MODEL PARAMS {'objective': 'reg:squarederror', 'base_score': None, 'booster': None, 'callbacks': None, 'colsample_bylevel': None, 'colsample_bynode': None, 'colsample_bytree': 0.8, 'device': 'cuda', 'early_stopping_rounds': None, 'enable_categorical': False, 'eval_metric': None, 'feature_types': None, 'gamma': None, 'grow_policy': None, 'importance_type': None, 'interaction_constraints': None, 'learning_rate': 0.1, 'max_bin': None, 'max_cat_threshold': None, 'max_cat_to_onehot': None, 'max_delta_step': None, 'max_depth': 4, 'max_leaves': None, 'min_child_weight': None, 'missing': nan, 'monotone_constraints': None, 'multi_strategy': None, 'n_estimators': 350, 'n_jobs': None, 'num_parallel_tree': None, 'random_state': 42, 'reg_alpha': 0, 'reg_lambda': 0.01, 'sampling_method': None, 'scale_pos_weight': None, 'subsample': 1, 'tree_method': 'gpu_hist', 'validate_parameters': None, 'verbosity': 0, 'n_gpus': -1}
# CPU Usage: 10.3%
# RAM Usage: 8.5%
# Available RAM: 460.4G
# Total RAM: 503.0G
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 26% |
# Multi simulation results have been saved.

# %% [markdown]
# Functions to combine single sim results

# %%
# File names
conn_file = 'single_sim_conn_random_xgboost.pickle'
# trans_file = 'single_sim_trans_rsearch_random_xgboost.pickle'
trans_file = 'single_sim_trans_bsearch_random_xgboost.pickle'
transconn_file = 'single_sim_transplusconn_random_xgboost.pickle'
output_file = 'multi_sim_random_xgboost_combined.pickle'

# Combine the results
combine_results(conn_file, trans_file, transconn_file, output_file)
# Out:
# Combined results saved to ./sim/sim_results/multi_sim_random_xgboost_combined.pickle

# %%
multi_sim_random_xgb = open_pickled_results('multi_sim_random_xgboost_combined.pickle')

# %%
boxplot_model_performance(multi_sim_random_xgb)

# %%
plot_predictions_with_metrics(multi_sim_random_xgb)

# %% [markdown]
# High accuracy transcriptome replication

# %%
# This is the high accuracy replication
trans_xgb_random_nonshared_sim_results = single_sim_run(cv_type='random',
                                              model_type='xgboost',
                                              feature_type='trans only',
                                              use_gpu=True,
                                              use_shared_regions=True,
                                              test_shared_regions=False, 
                                              save_sim=True,
                                              search_method='bayes'
                                              )
# Out:
# Number of components explaining 95% of the variance: 34
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# Processing fold 3...
#
#  Test fold num: 1
# (12070, 22106) (12070,) (812, 22106) (812,)
# 2
# 3
# 4
# Processing fold 0...
# Processing fold 1...
# Processing fold 2...
# ACCELERATING

# %%
trans_sim_random_shared_xgb = multi_sim_run.open_pickled_results('single_sim_trans_bsearch_random_xgboost_useshared_trainshared.pickle')

# %%
plot.plot_single_model_predictions_with_metrics(trans_sim_random_shared_xgb)
